# %% [markdown]
# # NBAComParser: Documentation

# %%
import logging
logger = logging.getLogger()
logger.setLevel(logging.ERROR)

# %%
from nba.scrapers.nbacom import NBAComScraper
from nba.parsers.nbacom import NBAComParser

# %% [markdown]
# ## Initialization

# %%
scraper = NBAComScraper()
parser = NBAComParser()

# %% [markdown]
# ## Boxscore
#
# http://stats.nba.com/stats/boxscoretraditionalv2?EndPeriod=10&EndRange=100000&GameID=0021500001&RangeType=2&Season=2015-16&SeasonType=Regular+Season&StartPeriod=1&StartRange=0

# %%
game_id = '0021500001'
season = '2015-16'
box = parser.boxscore(scraper.boxscore(game_id, season))

# %%
box
# Out:
# ([{u'AST': 4,
#    u'BLK': 0,
#    u'COMMENT': u'',
#    u'DREB': 5,
#    u'FG3A': 4,
#    u'FG3M': 1,
#    u'FG3_PCT': 0.25,
#    u'FGA': 19,
#    u'FGM': 6,
#    u'FG_PCT': 0.316,
#    u'FTA': 6,
#    u'FTM': 5,
#    u'FT_PCT': 0.833,
#    u'GAME_ID': u'0021500001',
#    u'MIN': u'37:05',
#    'MIN_PLAYED': u'37',
#    u'OREB': 5,
#    u'PF': 1,
#    u'PLAYER_ID': 202694,
#    u'PLAYER_NAME': u'Marcus Morris',
#    u'PLUS_MINUS': 17.0,
#    u'PTS': 18,
#    u'REB': 10,
#    'SEC_PLAYED': u'05',
#    u'START_POSITION': u'F',
#    u'STL': 0,
#    u'TEAM_ABBREVIATION': u'DET',
#    u'TEAM_CITY': u'Detroit',
#    u'TEAM_ID': 1610612765,
#    u'TO': 0},
#   {u'AST': 3,
#    u'BLK': 1,
#    u'COMMENT': u'',
#    u'DREB': 4,
#    u'FG3A': 6,
#    u'FG3M': 3,
#    u'FG3_PCT': 0.5,
#    u'FGA': 12,
#    u'FGM': 6,
#    u'FG_PCT': 0.5,
#    u'FTA': 2,
#    u'FTM': 1,
#    u'FT_PCT': 0.5,
#    u'GAME_ID': u'0021500001',
#    u'MIN': u'34:26',
#    'MIN_PLAYED': u'34',
#    u'OREB': 3,
#    u'PF': 4,
#    u'PLAYER_ID': 101141,
#    u'PLAYER_NAME': u'Ersan Ilyasova',
#    u'PLUS_MINUS': 20.0,
#    u'PTS': 16,
#    u'REB': 7,
#    'SEC_PLAYED': u'26',
#    u'START_POSITION': u'F',
#    u'STL': 0,
#    u'TEAM_ABBREVIATION': u'DET',
#    u'TEAM_CITY': u'Detroit',
#    u'TEAM_ID': 1610612765,
#    u'TO': 3},
#   {u'AST': 3,
#    u'BLK': 2,
#    u'COMMENT': u'',
#    u'DREB': 11,
#    u'FG3A': 0,
#    u'FG3M': 0,
#    u'FG3_PCT': 0.0,
#    u'FGA': 16,
#    u'FGM': 6,
#    u'FG_PCT': 0.375,
#    u'FTA': 10,
#    u'FTM': 6,
#    u'FT_PCT': 0.6,
#    u'GAME_ID': u'0021500001',
#    u'MIN': u'37:09',
#    'MIN_PLAYED': u'37',
#    u'OREB': 8,
#    u'PF': 4,
#    u'PLAYER_ID': 203083,
#    u'PLAYER_NAME': u'Andre Drummond',
#    u'PLUS_MINUS': 23.0,
#    u'PTS': 18,
#    u'REB': 19,
#    'SEC_PLAYED': u'09',
#    u'START_POSITION': u'C',
#    u'STL': 1,
#    u'TEAM_ABBREVIATION': u'DET',
#    u'TEAM_CITY': u'Detroit',
#    u'TEAM_ID': 1610612765,
#    u'TO': 2},
#   {u'AST': 1,
#    u'BLK': 0,
#    u'COMMENT': u'',
#    u'DREB': 3,
#    u'FG3A': 7,
#    u'FG3M': 4,
#    u'FG3_PCT': 0.571,
#    u'FGA': 14,
#    u'FGM': 7,
#    u'FG_PCT': 0.5,
#    u'FTA': 3,
#    u'FTM': 3,
#    u'FT_PCT': 1.0,
#    u'GAME_ID': u'0021500001',
#    u'MIN': u'37:03',
#    'MIN_PLAYED': u'37',
#    u'OREB': 1,
#    u'PF': 1,
#    u'PLAYER_ID': 203484,
#    u'PLAYER_NAME': u'Kentavious Caldwell-Pope',
#    u'PLUS_MINUS': 17.0,
#    u'PTS': 21,
#    u'REB': 4,
#    'SEC_PLAYED': u'03',
#    u'START_POSITION': u'G',
#    u'STL': 1,
#    u'TEAM_ABBREVIATION': u'DET',
#    u'TEAM_CITY': u'Detroit',
#    u'TEAM_ID': 1610612765,
#    u'TO': 2},
#   {u'AST': 5,
#    u'BLK': 0,
#    u'COMMENT': u'',
#    u'DREB': 7,
#    u'FG3A': 4,
#    u'FG3M': 2,
#    u'FG3_PCT': 0.5,
#    u'FGA': 10,
#    u'FGM': 4,
#    u'FG_PCT': 0.4,
#    u'FTA': 5,
#    u'FTM': 5,
#    u'FT_PCT': 1.0,
#    u'GAME_ID': u'0021500001',
#    u'MIN': u'32:07',
#    'MIN_PLAYED': u'32',
#    u'OREB': 1,
#    u'PF': 0,
#    u'PLAYER_ID': 202704,
#    u'PLAYER_NAME': u'Reggie Jackson',
#    u'PLUS_MINUS': 26.0,
#    u'PTS': 15,
#    u'REB': 8,
#    'SEC_PLAYED': u'07',
#    u'START_POSITION': u'G',
#    u'STL': 2,
#    u'TEAM_ABBREVIATION': u'DET',
#    u'TEAM_CITY': u'Detroit',
#    u'TEAM_ID': 1610612765,
#    u'TO': 2},
#   {u'AST': 3,
#    u'BLK': 0,
#    u'COMMENT': u'',
#    u'DREB': 1,
#    u'FG3A': 3,
#    u'FG3M': 1,
#    u'FG3_PCT': 0.333,
#    u'FGA': 10,
#    u'FGM': 3,
#    u'FG_PCT': 0.3,
#    u'FTA': 0,
#    u'FTM': 0,
#    u'FT_PCT': 0.0,
#    u'GAME_ID': u'0021500001',
#    u'MIN': u'24:29',
#    'MIN_PLAYED': u'24',
#    u'OREB': 3,
#    u'PF': 1,
#    u'PLAYER_ID': 1626169,
#    u'PLAYER_NAME': u'Stanley Johnson',
#    u'PLUS_MINUS': -13.0,
#    u'PTS': 7,
#    u'REB': 4,
#    'SEC_PLAYED': u'29',
#    u'START_POSITION': u'',
#    u'STL': 0,
#    u'TEAM_ABBREVIATION': u'DET',
#    u'TEAM_CITY': u'Detroit',
#    u'TEAM_ID': 1610612765,
#    u'TO': 1},
#   {u'AST': 0,
#    u'BLK': 0,
#    u'COMMENT': u'',
#    u'DREB': 4,
#    u'FG3A': 0,
#    u'FG3M': 0,
#    u'FG3_PCT': 0.0,
#    u'FGA': 5,
#    u'FGM': 3,
#    u'FG_PCT': 0.6,
#    u'FTA': 0,
#    u'FTM': 0,
#    u'FT_PCT': 0.0,
#    u'GAME_ID': u'0021500001',
#    u'MIN': u'10:51',
#    'MIN_PLAYED': u'10',
#    u'OREB': 1,
#    u'PF': 2,
#    u'PLAYER_ID': 203382,
#    u'PLAYER_NAME': u'Aron Baynes',
#    u'PLUS_MINUS': -11.0,
#    u'PTS': 6,
#    u'REB': 5,
#    'SEC_PLAYED': u'51',
#    u'START_POSITION': u'',
#    u'STL': 0,
#    u'TEAM_ABBREVIATION': u'DET',
#    u'TEAM_CITY': u'Detroit',
#    u'TEAM_ID': 1610612765,
#    u'TO': 1},
#   {u'AST': 4,
#    u'BLK': 0,
#    u'COMMENT': u'',
#    u'DREB': 0,
#    u'FG3A': 5,
#    u'FG3M': 1,
#    u'FG3_PCT': 0.2,
#    u'FGA': 6,
#    u'FGM': 1,
#    u'FG_PCT': 0.167,
#    u'FTA': 0,
#    u'FTM': 0,
#    u'FT_PCT': 0.0,
#    u'GAME_ID': u'0021500001',
#    u'MIN': u'15:53',
#    'MIN_PLAYED': u'15',
#    u'OREB': 0,
#    u'PF': 1,
#    u'PLAYER_ID': 2581,
#    u'PLAYER_NAME': u'Steve Blake',
#    u'PLUS_MINUS': -14.0,
#    u'PTS': 3,
#    u'REB': 0,
#    'SEC_PLAYED': u'53',
#    u'START_POSITION': u'',
#    u'STL': 1,
#    u'TEAM_ABBREVIATION': u'DET',
#    u'TEAM_CITY': u'Detroit',
#    u'TEAM_ID': 1610612765,
#    u'TO': 3},
#   {u'AST': 0,
#    u'BLK': 0,
#    u'COMMENT': u'',
#    u'DREB': 1,
#    u'FG3A': 0,
#    u'FG3M': 0,
#    u'FG3_PCT': 0.0,
#    u'FGA': 4,
#    u'FGM': 1,
#    u'FG_PCT': 0.25,
#    u'FTA': 0,
#    u'FTM': 0,
#    u'FT_PCT': 0.0,
#    u'GAME_ID': u'0021500001',
#    u'MIN': u'10:57',
#    'MIN_PLAYED': u'10',
#    u'OREB': 1,
#    u'PF': 1,
#    u'PLAYER_ID': 201975,
#    u'PLAYER_NAME': u'Jodie Meeks',
#    u'PLUS_MINUS': -5.0,
#    u'PTS': 2,
#    u'REB': 2,
#    'SEC_PLAYED': u'57',
#    u'START_POSITION': u'',
#    u'STL': 0,
#    u'TEAM_ABBREVIATION': u'DET',
#    u'TEAM_CITY': u'Detroit',
#    u'TEAM_ID': 1610612765,
#    u'TO': 1},
#   {u'AST': 1,
#    u'BLK': 0,
#    u'COMMENT': u'',
#    u'DREB': 7,
#    u'FG3A': 1,
#    u'FG3M': 0,
#    u'FG3_PCT': 0.0,
#    u'FGA': 3,
#    u'FGM': 0,
#    u'FG_PCT': 0.0,
#    u'FTA': 0,
#    u'FTM': 0,
#    u'FT_PCT': 0.0,
#    u'GAME_ID': u'0021500001',
#    u'MIN': u'20:50',
#    'MIN_PLAYED': u'20',
#    u'OREB': 0,
#    u'PF': 3,
#    u'PLAYER_ID': 203145,
#    u'PLAYER_NAME': u'Kent Bazemore',
#    u'PLUS_MINUS': -17.0,
#    u'PTS': 0,
#    u'REB': 7,
#    'SEC_PLAYED': u'50',
#    u'START_POSITION': u'F',
#    u'STL': 0,
#    u'TEAM_ABBREVIATION': u'ATL',
#    u'TEAM_CITY': u'Atlanta',
#    u'TEAM_ID': 1610612737,
#    u'TO': 4},
#   {u'AST': 3,
#    u'BLK': 0,
#    u'COMMENT': u'',
#    u'DREB': 7,
#    u'FG3A': 6,
#    u'FG3M': 2,
#    u'FG3_PCT': 0.333,
#    u'FGA': 15,
#    u'FGM': 7,
#    u'FG_PCT': 0.467,
#    u'FTA': 4,
#    u'FTM': 3,
#    u'FT_PCT': 0.75,
#    u'GAME_ID': u'0021500001',
#    u'MIN': u'36:00',
#    'MIN_PLAYED': u'36',
#    u'OREB': 1,
#    u'PF': 4,
#    u'PLAYER_ID': 200794,
#    u'PLAYER_NAME': u'Paul Millsap',
#    u'PLUS_MINUS': -22.0,
#    u'PTS': 19,
#    u'REB': 8,
#    'SEC_PLAYED': u'00',
#    u'START_POSITION': u'F',
#    u'STL': 0,
#    u'TEAM_ABBREVIATION': u'ATL',
#    u'TEAM_CITY': u'Atlanta',
#    u'TEAM_ID': 1610612737,
#    u'TO': 2},
#   {u'AST': 4,
#    u'BLK': 3,
#    u'COMMENT': u'',
#    u'DREB': 3,
#    u'FG3A': 3,
#    u'FG3M': 1,
#    u'FG3_PCT': 0.333,
#    u'FGA': 11,
#    u'FGM': 6,
#    u'FG_PCT': 0.545,
#    u'FTA': 3,
#    u'FTM': 2,
#    u'FT_PCT': 0.667,
#    u'GAME_ID': u'0021500001',
#    u'MIN': u'30:14',
#    'MIN_PLAYED': u'30',
#    u'OREB': 1,
#    u'PF': 1,
#    u'PLAYER_ID': 201143,
#    u'PLAYER_NAME': u'Al Horford',
#    u'PLUS_MINUS': -5.0,
#    u'PTS': 15,
#    u'REB': 4,
#    'SEC_PLAYED': u'14',
#    u'START_POSITION': u'C',
#    u'STL': 2,
#    u'TEAM_ABBREVIATION': u'ATL',
#    u'TEAM_CITY': u'Atlanta',
#    u'TEAM_ID': 1610612737,
#    u'TO': 1},
#   {u'AST': 1,
#    u'BLK': 0,
#    u'COMMENT': u'',
#    u'DREB': 2,
#    u'FG3A': 5,
#    u'FG3M': 1,
#    u'FG3_PCT': 0.2,
#    u'FGA': 9,
#    u'FGM': 3,
#    u'FG_PCT': 0.333,
#    u'FTA': 0,
#    u'FTM': 0,
#    u'FT_PCT': 0.0,
#    u'GAME_ID': u'0021500001',
#    u'MIN': u'28:42',
#    'MIN_PLAYED': u'28',
#    u'OREB': 0,
#    u'PF': 4,
#    u'PLAYER_ID': 2594,
#    u'PLAYER_NAME': u'Kyle Korver',
#    u'PLUS_MINUS': -9.0,
#    u'PTS': 7,
#    u'REB': 2,
#    'SEC_PLAYED': u'42',
#    u'START_POSITION': u'G',
#    u'STL': 1,
#    u'TEAM_ABBREVIATION': u'ATL',
#    u'TEAM_CITY': u'Atlanta',
#    u'TEAM_ID': 1610612737,
#    u'TO': 1},
#   {u'AST': 4,
#    u'BLK': 0,
#    u'COMMENT': u'',
#    u'DREB': 2,
#    u'FG3A': 3,
#    u'FG3M': 1,
#    u'FG3_PCT': 0.333,
#    u'FGA': 16,
#    u'FGM': 7,
#    u'FG_PCT': 0.438,
#    u'FTA': 4,
#    u'FTM': 3,
#    u'FT_PCT': 0.75,
#    u'GAME_ID': u'0021500001',
#    u'MIN': u'31:52',
#    'MIN_PLAYED': u'31',
#    u'OREB': 0,
#    u'PF': 1,
#    u'PLAYER_ID': 201952,
#    u'PLAYER_NAME': u'Jeff Teague',
#    u'PLUS_MINUS': -23.0,
#    u'PTS': 18,
#    u'REB': 2,
#    'SEC_PLAYED': u'52',
#    u'START_POSITION': u'G',
#    u'STL': 0,
#    u'TEAM_ABBREVIATION': u'ATL',
#    u'TEAM_CITY': u'Atlanta',
#    u'TEAM_ID': 1610612737,
#    u'TO': 5},
#   {u'AST': 3,
#    u'BLK': 0,
#    u'COMMENT': u'',
#    u'DREB': 6,
#    u'FG3A': 1,
#    u'FG3M': 0,
#    u'FG3_PCT': 0.0,
#    u'FGA': 3,
#    u'FGM': 1,
#    u'FG_PCT': 0.333,
#    u'FTA': 0,
#    u'FTM': 0,
#    u'FT_PCT': 0.0,
#    u'GAME_ID': u'0021500001',
#    u'MIN': u'18:56',
#    'MIN_PLAYED': u'18',
#    u'OREB': 1,
#    u'PF': 1,
#    u'PLAYER_ID': 200757,
#    u'PLAYER_NAME': u'Thabo Sefolosha',
#    u'PLUS_MINUS': -1.0,
#    u'PTS': 2,
#    u'REB': 7,
#    'SEC_PLAYED': u'56',
#    u'START_POSITION': u'',
#    u'STL': 4,
#    u'TEAM_ABBREVIATION': u'ATL',
#    u'TEAM_CITY': u'Atlanta',
#    u'TEAM_ID': 1610612737,
#    u'TO': 0},
#   {u'AST': 0,
#    u'BLK': 1,
#    u'COMMENT': u'',
#    u'DREB': 1,
#    u'FG3A': 0,
#    u'FG3M': 0,
#    u'FG3_PCT': 0.0,
#    u'FGA': 5,
#    u'FGM': 2,
#    u'FG_PCT': 0.4,
#    u'FTA': 0,
#    u'FTM': 0,
#    u'FT_PCT': 0.0,
#    u'GAME_ID': u'0021500001',
#    u'MIN': u'16:18',
#    'MIN_PLAYED': u'16',
#    u'OREB': 3,
#    u'PF': 4,
#    u'PLAYER_ID': 201168,
#    u'PLAYER_NAME': u'Tiago Splitter',
#    u'PLUS_MINUS': -3.0,
#    u'PTS': 4,
#    u'REB': 4,
#    'SEC_PLAYED': u'18',
#    u'START_POSITION': u'',
#    u'STL': 0,
#    u'TEAM_ABBREVIATION': u'ATL',
#    u'TEAM_CITY': u'Atlanta',
#    u'TEAM_ID': 1610612737,
#    u'TO': 0},
#   {u'AST': 2,
#    u'BLK': 0,
#    u'COMMENT': u'',
#    u'DREB': 1,
#    u'FG3A': 1,
#    u'FG3M': 1,
#    u'FG3_PCT': 1.0,
#    u'FGA': 1,
#    u'FGM': 1,
#    u'FG_PCT': 1.0,
#    u'FTA': 2,
#    u'FTM': 2,
#    u'FT_PCT': 1.0,
#    u'GAME_ID': u'0021500001',
#    u'MIN': u'18:18',
#    'MIN_PLAYED': u'18',
#    u'OREB': 0,
#    u'PF': 4,
#    u'PLAYER_ID': 203934,
#    u'PLAYER_NAME': u'Lamar Patterson',
#    u'PLUS_MINUS': 10.0,
#    u'PTS': 5,
#    u'REB': 1,
#    'SEC_PLAYED': u'18',
#    u'START_POSITION': u'',
#    u'STL': 0,
#    u'TEAM_ABBREVIATION': u'ATL',
#    u'TEAM_CITY': u'Atlanta',
#    u'TEAM_ID': 1610612737,
#    u'TO': 0},
#   {u'AST': 4,
#    u'BLK': 0,
#    u'COMMENT': u'',
#    u'DREB': 2,
#    u'FG3A': 5,
#    u'FG3M': 2,
#    u'FG3_PCT': 0.4,
#    u'FGA': 14,
#    u'FGM': 8,
#    u'FG_PCT': 0.571,
#    u'FTA': 2,
#    u'FTM': 2,
#    u'FT_PCT': 1.0,
#    u'GAME_ID': u'0021500001',
#    u'MIN': u'25:22',
#    'MIN_PLAYED': u'25',
#    u'OREB': 1,
#    u'PF': 1,
#    u'PLAYER_ID': 203471,
#    u'PLAYER_NAME': u'Dennis Schroder',
#    u'PLUS_MINUS': 4.0,
#    u'PTS': 20,
#    u'REB': 3,
#    'SEC_PLAYED': u'22',
#    u'START_POSITION': u'',
#    u'STL': 2,
#    u'TEAM_ABBREVIATION': u'ATL',
#    u'TEAM_CITY': u'Atlanta',
#    u'TEAM_ID': 1610612737,
#    u'TO': 1},
#   {u'AST': 0,
#    u'BLK': 0,
#    u'COMMENT': u'',
#    u'DREB': 1,
#    u'FG3A': 0,
#    u'FG3M': 0,
#    u'FG3_PCT': 0.0,
#    u'FGA': 1,
#    u'FGM': 0,
#    u'FG_PCT': 0.0,
#    u'FTA': 0,
#    u'FTM': 0,
#    u'FT_PCT': 0.0,
#    u'GAME_ID': u'0021500001',
#    u'MIN': u'7:59',
#    'MIN_PLAYED': u'7',
#    u'OREB': 0,
#    u'PF': 2,
#    u'PLAYER_ID': 203488,
#    u'PLAYER_NAME': u'Mike Muscala',
#    u'PLUS_MINUS': 5.0,
#    u'PTS': 0,
#    u'REB': 1,
#    'SEC_PLAYED': u'59',
#    u'START_POSITION': u'',
#    u'STL': 0,
#    u'TEAM_ABBREVIATION': u'ATL',
#    u'TEAM_CITY': u'Atlanta',
#    u'TEAM_ID': 1610612737,
#    u'TO': 1},
#   {u'AST': 0,
#    u'BLK': 0,
#    u'COMMENT': u'',
#    u'DREB': 1,
#    u'FG3A': 2,
#    u'FG3M': 0,
#    u'FG3_PCT': 0.0,
#    u'FGA': 4,
#    u'FGM': 2,
#    u'FG_PCT': 0.5,
#    u'FTA': 0,
#    u'FTM': 0,
#    u'FT_PCT': 0.0,
#    u'GAME_ID': u'0021500001',
#    u'MIN': u'5:29',
#    'MIN_PLAYED': u'5',
#    u'OREB': 0,
#    u'PF': 0,
#    u'PLAYER_ID': 203118,
#    u'PLAYER_NAME': u'Mike Scott',
#    u'PLUS_MINUS': 1.0,
#    u'PTS': 4,
#    u'REB': 1,
#    'SEC_PLAYED': u'29',
#    u'START_POSITION': u'',
#    u'STL': 0,
#    u'TEAM_ABBREVIATION': u'ATL',
#    u'TEAM_CITY': u'Atlanta',
#    u'TEAM_ID': 1610612737,
#    u'TO': 0}],
#  [{u'AST': 23,
#    u'BLK': 3,
#    u'DREB': 36,
#    u'FG3A': 29,
#    u'FG3M': 12,
#    u'FG3_PCT': 0.414,
#    u'FGA': 96,
#    u'FGM': 37,
#    u'FG_PCT': 0.385,
#    u'FTA': 26,
#    u'FTM': 20,
#    u'FT_PCT': 0.769,
#    u'GAME_ID': u'0021500001',
#    u'MIN': u'240:00',
#    u'OREB': 23,
#    u'PF': 15,
#    u'PLUS_MINUS': 12.0,
#    u'PTS': 106,
#    u'REB': 59,
#    u'STL': 5,
#    u'TEAM_ABBREVIATION': u'DET',
#    u'TEAM_CITY': u'Detroit',
#    u'TEAM_ID': 1610612765,
#    u'TEAM_NAME': u'Pistons',
#    u'TO': 15},
#   {u'AST': 22,
#    u'BLK': 4,
#    u'DREB': 33,
#    u'FG3A': 27,
#    u'FG3M': 8,
#    u'FG3_PCT': 0.296,
#    u'FGA': 82,
#    u'FGM': 37,
#    u'FG_PCT': 0.451,
#    u'FTA': 15,
#    u'FTM': 12,
#    u'FT_PCT': 0.8,
#    u'GAME_ID': u'0021500001',
#    u'MIN': u'240:00',
#    u'OREB': 7,
#    u'PF': 25,
#    u'PLUS_MINUS': -12.0,
#    u'PTS': 94,
#    u'REB': 40,
#    u'STL': 9,
#    u'TEAM_ABBREVIATION': u'ATL',
#    u'TEAM_CITY': u'Atlanta',
#    u'TEAM_ID': 1610612737,
#    u'TEAM_NAME': u'Hawks',
#    u'TO': 15}],
#  [{u'AST': 48,
#    u'BLK': 4,
#    u'DREB': 18,
#    u'FG3A': 10,
#    u'FG3M': 0.408,
#    u'FG3_PCT': 21,
#    u'FGA': 29,
#    u'FGM': u'177:50',
#    u'FG_PCT': 71,
#    u'FTA': 20,
#    u'FTM': 0.476,
#    u'FT_PCT': 26,
#    u'GAME_ID': u'0021500001',
#    u'MIN': u'Starters',
#    u'OREB': 0.769,
#    u'PF': 9,
#    u'PLUS_MINUS': 88,
#    u'PTS': 10,
#    u'REB': 30,
#    u'STL': 16,
#    u'TEAM_ABBREVIATION': u'DET',
#    u'TEAM_CITY': u'Detroit',
#    u'TEAM_ID': 1610612765,
#    u'TEAM_NAME': u'Pistons',
#    u'TO': 3},
#   {u'AST': 48,
#    u'BLK': 4,
#    u'DREB': 18,
#    u'FG3A': 10,
#    u'FG3M': 0.408,
#    u'FG3_PCT': 21,
#    u'FGA': 29,
#    u'FGM': u'177:50',
#    u'FG_PCT': 71,
#    u'FTA': 20,
#    u'FTM': 0.476,
#    u'FT_PCT': 26,
#    u'GAME_ID': u'0021500001',
#    u'MIN': u'Bench',
#    u'OREB': 0.769,
#    u'PF': 9,
#    u'PLUS_MINUS': 88,
#    u'PTS': 10,
#    u'REB': 30,
#    u'STL': 16,
#    u'TEAM_ABBREVIATION': u'DET',
#    u'TEAM_CITY': u'Detroit',
#    u'TEAM_ID': 1610612765,
#    u'TEAM_NAME': u'Pistons',
#    u'TO': 3},
#   {u'AST': 23,
#    u'BLK': 3,
#    u'DREB': 2,
#    u'FG3A': 5,
#    u'FG3M': 0.426,
#    u'FG3_PCT': 18,
#    u'FGA': 23,
#    u'FGM': u'147:38',
#    u'FG_PCT': 54,
#    u'FTA': 8,
#    u'FTM': 0.278,
#    u'FT_PCT': 11,
#    u'GAME_ID': u'0021500001',
#    u'MIN': u'Starters',
#    u'OREB': 0.727,
#    u'PF': 13,
#    u'PLUS_MINUS': 59,
#    u'PTS': 13,
#    u'REB': 21,
#    u'STL': 13,
#    u'TEAM_ABBREVIATION': u'ATL',
#    u'TEAM_CITY': u'Atlanta',
#    u'TEAM_ID': 1610612737,
#    u'TEAM_NAME': u'Hawks',
#    u'TO': 3},
#   {u'AST': 23,
#    u'BLK': 3,
#    u'DREB': 2,
#    u'FG3A': 5,
#    u'FG3M': 0.426,
#    u'FG3_PCT': 18,
#    u'FGA': 23,
#    u'FGM': u'147:38',
#    u'FG_PCT': 54,
#    u'FTA': 8,
#    u'FTM': 0.278,
#    u'FT_PCT': 11,
#    u'GAME_ID': u'0021500001',
#    u'MIN': u'Bench',
#    u'OREB': 0.727,
#    u'PF': 13,
#    u'PLUS_MINUS': 59,
#    u'PTS': 13,
#    u'REB': 21,
#    u'STL': 13,
#    u'TEAM_ABBREVIATION': u'ATL',
#    u'TEAM_CITY': u'Atlanta',
#    u'TEAM_ID': 1610612737,
#    u'TEAM_NAME': u'Hawks',
#    u'TO': 3}])

# %% [markdown]
# ## One_player_gamelogs
#
# http://stats.nba.com/stats/playergamelog?LeagueID=00&PlayerID=202694&Season=2015-16&SeasonType=Regular+Season

# %%
gamelogs = parser.one_player_gamelogs(scraper.one_player_gamelogs(player_id='202694', season='2015-16'))

# %%
gamelogs
# Out:
# {u'parameters': {u'LeagueID': u'00',
#   u'PlayerID': 202694,
#   u'Season': u'2015-16',
#   u'SeasonType': u'Regular Season'},
#  u'resource': u'playergamelog',
#  u'resultSets': [{u'headers': [u'SEASON_ID',
#     u'Player_ID',
#     u'Game_ID',
#     u'GAME_DATE',
#     u'MATCHUP',
#     u'WL',
#     u'MIN',
#     u'FGM',
#     u'FGA',
#     u'FG_PCT',
#     u'FG3M',
#     u'FG3A',
#     u'FG3_PCT',
#     u'FTM',
#     u'FTA',
#     u'FT_PCT',
#     u'OREB',
#     u'DREB',
#     u'REB',
#     u'AST',
#     u'STL',
#     u'BLK',
#     u'TOV',
#     u'PF',
#     u'PTS',
#     u'PLUS_MINUS',
#     u'VIDEO_AVAILABLE'],
#    u'name': u'PlayerGameLog',
#    u'rowSet': [[u'22015',
#      202694,
#      u'0021500708',
#      u'JAN 30, 2016',
#      u'DET @ TOR',
#      u'L',
#      34,
#      6,
#      13,
#      0.462,
#      1,
#      3,
#      0.333,
#      0,
#      0,
#      0.0,
#      1,
#      2,
#      3,
#      2,
#      2,
#      1,
#      2,
#      0,
#      13,
#      -5,
#      1],
#     [u'22015',
#      202694,
#      u'0021500699',
#      u'JAN 29, 2016',
#      u'DET vs. CLE',
#      u'L',
#      30,
#      4,
#      10,
#      0.4,
#      1,
#      4,
#      0.25,
#      5,
#      5,
#      1.0,
#      0,
#      2,
#      2,
#      2,
#      1,
#      0,
#      1,
#      4,
#      14,
#      -11,
#      1],
#     [u'22015',
#      202694,
#      u'0021500686',
#      u'JAN 27, 2016',
#      u'DET vs. PHI',
#      u'W',
#      36,
#      4,
#      11,
#      0.364,
#      0,
#      3,
#      0.0,
#      2,
#      4,
#      0.5,
#      2,
#      5,
#      7,
#      3,
#      0,
#      0,
#      1,
#      2,
#      10,
#      12,
#      1],
#     [u'22015',
#      202694,
#      u'0021500673',
#      u'JAN 25, 2016',
#      u'DET @ UTA',
#      u'W',
#      35,
#      1,
#      9,
#      0.111,
#      0,
#      3,
#      0.0,
#      0,
#      0,
#      0.0,
#      1,
#      3,
#      4,
#      4,
#      1,
#      0,
#      0,
#      2,
#      2,
#      -2,
#      1],
#     [u'22015',
#      202694,
#      u'0021500661',
#      u'JAN 23, 2016',
#      u'DET @ DEN',
#      u'L',
#      33,
#      7,
#      10,
#      0.7,
#      3,
#      4,
#      0.75,
#      3,
#      4,
#      0.75,
#      0,
#      2,
#      2,
#      2,
#      1,
#      0,
#      2,
#      5,
#      20,
#      1,
#      1],
#     [u'22015',
#      202694,
#      u'0021500641',
#      u'JAN 21, 2016',
#      u'DET @ NOP',
#      u'L',
#      35,
#      2,
#      11,
#      0.182,
#      0,
#      2,
#      0.0,
#      0,
#      0,
#      0.0,
#      3,
#      3,
#      6,
#      2,
#      0,
#      1,
#      2,
#      0,
#      4,
#      -22,
#      1],
#     [u'22015',
#      202694,
#      u'0021500635',
#      u'JAN 20, 2016',
#      u'DET @ HOU',
#      u'W',
#      37,
#      6,
#      10,
#      0.6,
#      4,
#      6,
#      0.667,
#      6,
#      6,
#      1.0,
#      0,
#      5,
#      5,
#      1,
#      0,
#      1,
#      2,
#      3,
#      22,
#      -4,
#      1],
#     [u'22015',
#      202694,
#      u'0021500619',
#      u'JAN 18, 2016',
#      u'DET vs. CHI',
#      u'L',
#      38,
#      8,
#      16,
#      0.5,
#      0,
#      6,
#      0.0,
#      2,
#      2,
#      1.0,
#      3,
#      3,
#      6,
#      0,
#      1,
#      0,
#      2,
#      2,
#      18,
#      2,
#      1],
#     [u'22015',
#      202694,
#      u'0021500605',
#      u'JAN 16, 2016',
#      u'DET vs. GSW',
#      u'W',
#      40,
#      6,
#      14,
#      0.429,
#      1,
#      4,
#      0.25,
#      3,
#      4,
#      0.75,
#      1,
#      7,
#      8,
#      6,
#      0,
#      2,
#      1,
#      1,
#      16,
#      30,
#      1],
#     [u'22015',
#      202694,
#      u'0021500589',
#      u'JAN 14, 2016',
#      u'DET @ MEM',
#      u'L',
#      40,
#      5,
#      10,
#      0.5,
#      1,
#      4,
#      0.25,
#      1,
#      2,
#      0.5,
#      0,
#      4,
#      4,
#      5,
#      0,
#      0,
#      6,
#      1,
#      12,
#      3,
#      1],
#     [u'22015',
#      202694,
#      u'0021500570',
#      u'JAN 12, 2016',
#      u'DET vs. SAS',
#      u'L',
#      28,
#      1,
#      6,
#      0.167,
#      0,
#      3,
#      0.0,
#      2,
#      2,
#      1.0,
#      0,
#      5,
#      5,
#      3,
#      1,
#      0,
#      0,
#      3,
#      4,
#      -12,
#      1],
#     [u'22015',
#      202694,
#      u'0021500528',
#      u'JAN 06, 2016',
#      u'DET @ BOS',
#      u'W',
#      37,
#      2,
#      8,
#      0.25,
#      0,
#      0,
#      0.0,
#      4,
#      5,
#      0.8,
#      2,
#      4,
#      6,
#      0,
#      0,
#      0,
#      2,
#      5,
#      8,
#      3,
#      1],
#     [u'22015',
#      202694,
#      u'0021500514',
#      u'JAN 04, 2016',
#      u'DET vs. ORL',
#      u'W',
#      30,
#      4,
#      7,
#      0.571,
#      0,
#      1,
#      0.0,
#      5,
#      5,
#      1.0,
#      1,
#      2,
#      3,
#      1,
#      0,
#      0,
#      0,
#      2,
#      13,
#      9,
#      1],
#     [u'22015',
#      202694,
#      u'0021500498',
#      u'JAN 02, 2016',
#      u'DET @ IND',
#      u'L',
#      36,
#      5,
#      13,
#      0.385,
#      0,
#      1,
#      0.0,
#      1,
#      2,
#      0.5,
#      1,
#      1,
#      2,
#      4,
#      0,
#      0,
#      1,
#      3,
#      11,
#      -18,
#      1],
#     [u'22015',
#      202694,
#      u'0021500486',
#      u'DEC 31, 2015',
#      u'DET vs. MIN',
#      u'W',
#      34,
#      1,
#      5,
#      0.2,
#      0,
#      3,
#      0.0,
#      6,
#      6,
#      1.0,
#      0,
#      2,
#      2,
#      3,
#      1,
#      0,
#      4,
#      1,
#      8,
#      17,
#      1],
#     [u'22015',
#      202694,
#      u'0021500469',
#      u'DEC 29, 2015',
#      u'DET @ NYK',
#      u'L',
#      36,
#      7,
#      16,
#      0.438,
#      1,
#      5,
#      0.2,
#      2,
#      2,
#      1.0,
#      2,
#      2,
#      4,
#      2,
#      1,
#      1,
#      2,
#      1,
#      17,
#      -7,
#      1],
#     [u'22015',
#      202694,
#      u'0021500446',
#      u'DEC 26, 2015',
#      u'DET vs. BOS',
#      u'L',
#      37,
#      7,
#      14,
#      0.5,
#      0,
#      2,
#      0.0,
#      2,
#      4,
#      0.5,
#      2,
#      3,
#      5,
#      1,
#      1,
#      0,
#      3,
#      4,
#      16,
#      -1,
#      1],
#     [u'22015',
#      202694,
#      u'0021500429',
#      u'DEC 23, 2015',
#      u'DET @ ATL',
#      u'L',
#      38,
#      9,
#      16,
#      0.563,
#      2,
#      2,
#      1.0,
#      2,
#      3,
#      0.667,
#      2,
#      5,
#      7,
#      1,
#      1,
#      0,
#      1,
#      0,
#      22,
#      0,
#      1],
#     [u'22015',
#      202694,
#      u'0021500420',
#      u'DEC 22, 2015',
#      u'DET @ MIA',
#      u'W',
#      33,
#      3,
#      7,
#      0.429,
#      0,
#      1,
#      0.0,
#      2,
#      4,
#      0.5,
#      0,
#      5,
#      5,
#      3,
#      0,
#      0,
#      5,
#      1,
#      8,
#      -8,
#      1],
#     [u'22015',
#      202694,
#      u'0021500391',
#      u'DEC 18, 2015',
#      u'DET @ CHI',
#      u'W',
#      57,
#      7,
#      17,
#      0.412,
#      3,
#      6,
#      0.5,
#      3,
#      6,
#      0.5,
#      2,
#      5,
#      7,
#      2,
#      0,
#      1,
#      2,
#      6,
#      20,
#      7,
#      1],
#     [u'22015',
#      202694,
#      u'0021500374',
#      u'DEC 16, 2015',
#      u'DET vs. BOS',
#      u'W',
#      33,
#      4,
#      9,
#      0.444,
#      1,
#      2,
#      0.5,
#      2,
#      2,
#      1.0,
#      0,
#      1,
#      1,
#      2,
#      1,
#      0,
#      1,
#      3,
#      11,
#      -1,
#      1],
#     [u'22015',
#      202694,
#      u'0021500359',
#      u'DEC 14, 2015',
#      u'DET vs. LAC',
#      u'L',
#      42,
#      3,
#      10,
#      0.3,
#      0,
#      1,
#      0.0,
#      0,
#      0,
#      0.0,
#      0,
#      4,
#      4,
#      2,
#      2,
#      0,
#      1,
#      3,
#      6,
#      -10,
#      1],
#     [u'22015',
#      202694,
#      u'0021500346',
#      u'DEC 12, 2015',
#      u'DET vs. IND',
#      u'W',
#      30,
#      7,
#      13,
#      0.538,
#      2,
#      4,
#      0.5,
#      0,
#      0,
#      0.0,
#      1,
#      2,
#      3,
#      0,
#      0,
#      0,
#      1,
#      1,
#      16,
#      22,
#      1],
#     [u'22015',
#      202694,
#      u'0021500335',
#      u'DEC 11, 2015',
#      u'DET @ PHI',
#      u'W',
#      34,
#      7,
#      9,
#      0.778,
#      3,
#      3,
#      1.0,
#      4,
#      4,
#      1.0,
#      1,
#      7,
#      8,
#      4,
#      1,
#      1,
#      4,
#      2,
#      21,
#      31,
#      1],
#     [u'22015',
#      202694,
#      u'0021500322',
#      u'DEC 09, 2015',
#      u'DET vs. MEM',
#      u'L',
#      37,
#      6,
#      13,
#      0.462,
#      2,
#      4,
#      0.5,
#      2,
#      2,
#      1.0,
#      1,
#      1,
#      2,
#      0,
#      0,
#      0,
#      0,
#      0,
#      16,
#      -7,
#      1],
#     [u'22015',
#      202694,
#      u'0021500304',
#      u'DEC 07, 2015',
#      u'DET @ CHA',
#      u'L',
#      30,
#      4,
#      11,
#      0.364,
#      1,
#      2,
#      0.5,
#      2,
#      3,
#      0.667,
#      1,
#      2,
#      3,
#      1,
#      0,
#      1,
#      2,
#      2,
#      11,
#      -16,
#      1],
#     [u'22015',
#      202694,
#      u'0021500301',
#      u'DEC 06, 2015',
#      u'DET vs. LAL',
#      u'W',
#      31,
#      4,
#      13,
#      0.308,
#      0,
#      2,
#      0.0,
#      1,
#      3,
#      0.333,
#      0,
#      3,
#      3,
#      3,
#      0,
#      0,
#      1,
#      2,
#      9,
#      16,
#      1],
#     [u'22015',
#      202694,
#      u'0021500285',
#      u'DEC 04, 2015',
#      u'DET vs. MIL',
#      u'W',
#      39,
#      7,
#      14,
#      0.5,
#      1,
#      2,
#      0.5,
#      8,
#      9,
#      0.889,
#      2,
#      2,
#      4,
#      3,
#      1,
#      0,
#      2,
#      1,
#      23,
#      13,
#      1],
#     [u'22015',
#      202694,
#      u'0021500270',
#      u'DEC 02, 2015',
#      u'DET vs. PHX',
#      u'W',
#      42,
#      7,
#      10,
#      0.7,
#      3,
#      4,
#      0.75,
#      7,
#      10,
#      0.7,
#      3,
#      11,
#      14,
#      3,
#      2,
#      0,
#      2,
#      2,
#      24,
#      17,
#      1],
#     [u'22015',
#      202694,
#      u'0021500254',
#      u'NOV 30, 2015',
#      u'DET vs. HOU',
#      u'W',
#      34,
#      5,
#      11,
#      0.455,
#      0,
#      5,
#      0.0,
#      2,
#      3,
#      0.667,
#      1,
#      3,
#      4,
#      6,
#      0,
#      0,
#      3,
#      1,
#      12,
#      4,
#      1],
#     [u'22015',
#      202694,
#      u'0021500248',
#      u'NOV 29, 2015',
#      u'DET @ BKN',
#      u'L',
#      35,
#      3,
#      10,
#      0.3,
#      1,
#      3,
#      0.333,
#      0,
#      0,
#      0.0,
#      1,
#      2,
#      3,
#      2,
#      3,
#      0,
#      2,
#      3,
#      7,
#      -7,
#      1],
#     [u'22015',
#      202694,
#      u'0021500234',
#      u'NOV 27, 2015',
#      u'DET @ OKC',
#      u'L',
#      40,
#      5,
#      13,
#      0.385,
#      2,
#      4,
#      0.5,
#      5,
#      6,
#      0.833,
#      0,
#      4,
#      4,
#      0,
#      1,
#      0,
#      0,
#      1,
#      17,
#      -19,
#      1],
#     [u'22015',
#      202694,
#      u'0021500218',
#      u'NOV 25, 2015',
#      u'DET vs. MIA',
#      u'W',
#      36,
#      6,
#      13,
#      0.462,
#      2,
#      3,
#      0.667,
#      0,
#      0,
#      0.0,
#      2,
#      4,
#      6,
#      0,
#      1,
#      0,
#      0,
#      1,
#      14,
#      29,
#      1],
#     [u'22015',
#      202694,
#      u'0021500205',
#      u'NOV 23, 2015',
#      u'DET @ MIL',
#      u'L',
#      26,
#      2,
#      7,
#      0.286,
#      0,
#      3,
#      0.0,
#      0,
#      0,
#      0.0,
#      0,
#      5,
#      5,
#      1,
#      0,
#      0,
#      3,
#      1,
#      4,
#      -17,
#      1],
#     [u'22015',
#      202694,
#      u'0021500192',
#      u'NOV 21, 2015',
#      u'DET vs. WAS',
#      u'L',
#      37,
#      6,
#      14,
#      0.429,
#      2,
#      6,
#      0.333,
#      4,
#      4,
#      1.0,
#      2,
#      7,
#      9,
#      4,
#      0,
#      0,
#      1,
#      0,
#      18,
#      15,
#      1],
#     [u'22015',
#      202694,
#      u'0021500181',
#      u'NOV 20, 2015',
#      u'DET @ MIN',
#      u'W',
#      36,
#      6,
#      14,
#      0.429,
#      0,
#      5,
#      0.0,
#      4,
#      4,
#      1.0,
#      0,
#      11,
#      11,
#      0,
#      1,
#      1,
#      0,
#      4,
#      16,
#      14,
#      1],
#     [u'22015',
#      202694,
#      u'0021500160',
#      u'NOV 17, 2015',
#      u'DET vs. CLE',
#      u'W',
#      36,
#      4,
#      12,
#      0.333,
#      1,
#      4,
#      0.25,
#      5,
#      6,
#      0.833,
#      0,
#      4,
#      4,
#      1,
#      2,
#      0,
#      2,
#      5,
#      14,
#      13,
#      1],
#     [u'22015',
#      202694,
#      u'0021500151',
#      u'NOV 15, 2015',
#      u'DET @ LAL',
#      u'L',
#      32,
#      3,
#      12,
#      0.25,
#      0,
#      3,
#      0.0,
#      1,
#      3,
#      0.333,
#      3,
#      4,
#      7,
#      2,
#      1,
#      2,
#      0,
#      3,
#      7,
#      4,
#      1],
#     [u'22015',
#      202694,
#      u'0021500138',
#      u'NOV 14, 2015',
#      u'DET @ LAC',
#      u'L',
#      38,
#      2,
#      10,
#      0.2,
#      0,
#      5,
#      0.0,
#      2,
#      2,
#      1.0,
#      2,
#      0,
#      2,
#      2,
#      1,
#      0,
#      2,
#      2,
#      6,
#      7,
#      1],
#     [u'22015',
#      202694,
#      u'0021500122',
#      u'NOV 11, 2015',
#      u'DET @ SAC',
#      u'L',
#      36,
#      5,
#      15,
#      0.333,
#      1,
#      4,
#      0.25,
#      5,
#      6,
#      0.833,
#      2,
#      7,
#      9,
#      3,
#      5,
#      0,
#      3,
#      1,
#      16,
#      6,
#      1],
#     [u'22015',
#      202694,
#      u'0021500104',
#      u'NOV 09, 2015',
#      u'DET @ GSW',
#      u'L',
#      43,
#      6,
#      12,
#      0.5,
#      1,
#      1,
#      1.0,
#      2,
#      4,
#      0.5,
#      1,
#      4,
#      5,
#      3,
#      2,
#      0,
#      1,
#      2,
#      15,
#      -8,
#      1],
#     [u'22015',
#      202694,
#      u'0021500098',
#      u'NOV 08, 2015',
#      u'DET @ POR',
#      u'W',
#      37,
#      5,
#      18,
#      0.278,
#      1,
#      7,
#      0.143,
#      2,
#      2,
#      1.0,
#      3,
#      0,
#      3,
#      3,
#      3,
#      0,
#      3,
#      3,
#      13,
#      19,
#      1],
#     [u'22015',
#      202694,
#      u'0021500082',
#      u'NOV 06, 2015',
#      u'DET @ PHX',
#      u'W',
#      39,
#      7,
#      14,
#      0.5,
#      2,
#      4,
#      0.5,
#      4,
#      6,
#      0.667,
#      1,
#      5,
#      6,
#      2,
#      2,
#      0,
#      1,
#      1,
#      20,
#      6,
#      1],
#     [u'22015',
#      202694,
#      u'0021500054',
#      u'NOV 03, 2015',
#      u'DET vs. IND',
#      u'L',
#      39,
#      3,
#      11,
#      0.273,
#      1,
#      6,
#      0.167,
#      4,
#      4,
#      1.0,
#      3,
#      4,
#      7,
#      0,
#      2,
#      2,
#      4,
#      2,
#      11,
#      -5,
#      1],
#     [u'22015',
#      202694,
#      u'0021500025',
#      u'OCT 30, 2015',
#      u'DET vs. CHI',
#      u'W',
#      42,
#      10,
#      15,
#      0.667,
#      2,
#      2,
#      1.0,
#      4,
#      9,
#      0.444,
#      1,
#      6,
#      7,
#      2,
#      0,
#      0,
#      2,
#      4,
#      26,
#      6,
#      1],
#     [u'22015',
#      202694,
#      u'0021500007',
#      u'OCT 28, 2015',
#      u'DET vs. UTA',
#      u'W',
#      35,
#      5,
#      10,
#      0.5,
#      1,
#      1,
#      1.0,
#      3,
#      3,
#      1.0,
#      1,
#      5,
#      6,
#      1,
#      0,
#      0,
#      2,
#      3,
#      14,
#      13,
#      1],
#     [u'22015',
#      202694,
#      u'0021500001',
#      u'OCT 27, 2015',
#      u'DET @ ATL',
#      u'W',
#      37,
#      6,
#      19,
#      0.316,
#      1,
#      4,
#      0.25,
#      5,
#      6,
#      0.833,
#      5,
#      5,
#      10,
#      4,
#      0,
#      0,
#      0,
#      1,
#      18,
#      17,
#      1]]}]}

# %% [markdown]
# ## One_team_gamelogs
#
# http://stats.nba.com/stats/teamgamelog?teamId=1610612765&season=2015-16&LeagueID=00&SeasonType=Regular+Season

# %%
gamelogs = parser.one_team_gamelogs(scraper.one_team_gamelogs(team_id='1610612765', season='2015-16'))

# %%
gamelogs
# Out:
# [{u'AST': 9,
#   u'BLK': 6,
#   u'DREB': 29,
#   u'FG3A': 28,
#   u'FG3M': 9,
#   u'FG3_PCT': 0.321,
#   u'FGA': 87,
#   u'FGM': 39,
#   u'FG_PCT': 0.448,
#   u'FTA': 34,
#   u'FTM': 20,
#   u'FT_PCT': 0.588,
#   u'GAME_DATE': u'JAN 30, 2016',
#   u'Game_ID': u'0021500708',
#   u'MATCHUP': u'DET @ TOR',
#   u'MIN': 240,
#   u'OREB': 10,
#   u'PF': 29,
#   u'PTS': 107,
#   u'REB': 39,
#   u'STL': 10,
#   u'TOV': 11,
#   u'Team_ID': 1610612765,
#   u'WL': u'L'},
#  {u'AST': 20,
#   u'BLK': 4,
#   u'DREB': 30,
#   u'FG3A': 23,
#   u'FG3M': 7,
#   u'FG3_PCT': 0.304,
#   u'FGA': 84,
#   u'FGM': 40,
#   u'FG_PCT': 0.476,
#   u'FTA': 26,
#   u'FTM': 19,
#   u'FT_PCT': 0.731,
#   u'GAME_DATE': u'JAN 29, 2016',
#   u'Game_ID': u'0021500699',
#   u'MATCHUP': u'DET vs. CLE',
#   u'MIN': 240,
#   u'OREB': 9,
#   u'PF': 24,
#   u'PTS': 106,
#   u'REB': 39,
#   u'STL': 5,
#   u'TOV': 9,
#   u'Team_ID': 1610612765,
#   u'WL': u'L'},
#  {u'AST': 15,
#   u'BLK': 2,
#   u'DREB': 30,
#   u'FG3A': 21,
#   u'FG3M': 5,
#   u'FG3_PCT': 0.238,
#   u'FGA': 91,
#   u'FGM': 39,
#   u'FG_PCT': 0.429,
#   u'FTA': 38,
#   u'FTM': 27,
#   u'FT_PCT': 0.711,
#   u'GAME_DATE': u'JAN 27, 2016',
#   u'Game_ID': u'0021500686',
#   u'MATCHUP': u'DET vs. PHI',
#   u'MIN': 240,
#   u'OREB': 21,
#   u'PF': 19,
#   u'PTS': 110,
#   u'REB': 51,
#   u'STL': 9,
#   u'TOV': 10,
#   u'Team_ID': 1610612765,
#   u'WL': u'W'},
#  {u'AST': 19,
#   u'BLK': 1,
#   u'DREB': 35,
#   u'FG3A': 22,
#   u'FG3M': 11,
#   u'FG3_PCT': 0.5,
#   u'FGA': 75,
#   u'FGM': 34,
#   u'FG_PCT': 0.453,
#   u'FTA': 33,
#   u'FTM': 16,
#   u'FT_PCT': 0.485,
#   u'GAME_DATE': u'JAN 25, 2016',
#   u'Game_ID': u'0021500673',
#   u'MATCHUP': u'DET @ UTA',
#   u'MIN': 240,
#   u'OREB': 7,
#   u'PF': 18,
#   u'PTS': 95,
#   u'REB': 42,
#   u'STL': 7,
#   u'TOV': 10,
#   u'Team_ID': 1610612765,
#   u'WL': u'W'},
#  {u'AST': 23,
#   u'BLK': 5,
#   u'DREB': 40,
#   u'FG3A': 29,
#   u'FG3M': 11,
#   u'FG3_PCT': 0.379,
#   u'FGA': 84,
#   u'FGM': 40,
#   u'FG_PCT': 0.476,
#   u'FTA': 19,
#   u'FTM': 10,
#   u'FT_PCT': 0.526,
#   u'GAME_DATE': u'JAN 23, 2016',
#   u'Game_ID': u'0021500661',
#   u'MATCHUP': u'DET @ DEN',
#   u'MIN': 240,
#   u'OREB': 11,
#   u'PF': 22,
#   u'PTS': 101,
#   u'REB': 51,
#   u'STL': 4,
#   u'TOV': 16,
#   u'Team_ID': 1610612765,
#   u'WL': u'L'},
#  {u'AST': 17,
#   u'BLK': 2,
#   u'DREB': 26,
#   u'FG3A': 30,
#   u'FG3M': 7,
#   u'FG3_PCT': 0.233,
#   u'FGA': 91,
#   u'FGM': 38,
#   u'FG_PCT': 0.418,
#   u'FTA': 20,
#   u'FTM': 16,
#   u'FT_PCT': 0.8,
#   u'GAME_DATE': u'JAN 21, 2016',
#   u'Game_ID': u'0021500641',
#   u'MATCHUP': u'DET @ NOP',
#   u'MIN': 240,
#   u'OREB': 18,
#   u'PF': 14,
#   u'PTS': 99,
#   u'REB': 44,
#   u'STL': 5,
#   u'TOV': 15,
#   u'Team_ID': 1610612765,
#   u'WL': u'L'},
#  {u'AST': 23,
#   u'BLK': 7,
#   u'DREB': 38,
#   u'FG3A': 30,
#   u'FG3M': 12,
#   u'FG3_PCT': 0.4,
#   u'FGA': 80,
#   u'FGM': 38,
#   u'FG_PCT': 0.475,
#   u'FTA': 59,
#   u'FTM': 35,
#   u'FT_PCT': 0.593,
#   u'GAME_DATE': u'JAN 20, 2016',
#   u'Game_ID': u'0021500635',
#   u'MATCHUP': u'DET @ HOU',
#   u'MIN': 240,
#   u'OREB': 14,
#   u'PF': 17,
#   u'PTS': 123,
#   u'REB': 52,
#   u'STL': 8,
#   u'TOV': 10,
#   u'Team_ID': 1610612765,
#   u'WL': u'W'},
#  {u'AST': 18,
#   u'BLK': 2,
#   u'DREB': 30,
#   u'FG3A': 26,
#   u'FG3M': 5,
#   u'FG3_PCT': 0.192,
#   u'FGA': 95,
#   u'FGM': 42,
#   u'FG_PCT': 0.442,
#   u'FTA': 20,
#   u'FTM': 12,
#   u'FT_PCT': 0.6,
#   u'GAME_DATE': u'JAN 18, 2016',
#   u'Game_ID': u'0021500619',
#   u'MATCHUP': u'DET vs. CHI',
#   u'MIN': 240,
#   u'OREB': 20,
#   u'PF': 16,
#   u'PTS': 101,
#   u'REB': 50,
#   u'STL': 8,
#   u'TOV': 11,
#   u'Team_ID': 1610612765,
#   u'WL': u'L'},
#  {u'AST': 22,
#   u'BLK': 11,
#   u'DREB': 40,
#   u'FG3A': 23,
#   u'FG3M': 8,
#   u'FG3_PCT': 0.348,
#   u'FGA': 101,
#   u'FGM': 47,
#   u'FG_PCT': 0.465,
#   u'FTA': 20,
#   u'FTM': 11,
#   u'FT_PCT': 0.55,
#   u'GAME_DATE': u'JAN 16, 2016',
#   u'Game_ID': u'0021500605',
#   u'MATCHUP': u'DET vs. GSW',
#   u'MIN': 240,
#   u'OREB': 17,
#   u'PF': 22,
#   u'PTS': 113,
#   u'REB': 57,
#   u'STL': 8,
#   u'TOV': 9,
#   u'Team_ID': 1610612765,
#   u'WL': u'W'},
#  {u'AST': 18,
#   u'BLK': 2,
#   u'DREB': 27,
#   u'FG3A': 32,
#   u'FG3M': 15,
#   u'FG3_PCT': 0.469,
#   u'FGA': 72,
#   u'FGM': 37,
#   u'FG_PCT': 0.514,
#   u'FTA': 17,
#   u'FTM': 12,
#   u'FT_PCT': 0.706,
#   u'GAME_DATE': u'JAN 14, 2016',
#   u'Game_ID': u'0021500589',
#   u'MATCHUP': u'DET @ MEM',
#   u'MIN': 240,
#   u'OREB': 8,
#   u'PF': 21,
#   u'PTS': 101,
#   u'REB': 35,
#   u'STL': 3,
#   u'TOV': 20,
#   u'Team_ID': 1610612765,
#   u'WL': u'L'},
#  {u'AST': 22,
#   u'BLK': 2,
#   u'DREB': 30,
#   u'FG3A': 23,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.261,
#   u'FGA': 91,
#   u'FGM': 38,
#   u'FG_PCT': 0.418,
#   u'FTA': 26,
#   u'FTM': 17,
#   u'FT_PCT': 0.654,
#   u'GAME_DATE': u'JAN 12, 2016',
#   u'Game_ID': u'0021500570',
#   u'MATCHUP': u'DET vs. SAS',
#   u'MIN': 240,
#   u'OREB': 11,
#   u'PF': 24,
#   u'PTS': 99,
#   u'REB': 41,
#   u'STL': 8,
#   u'TOV': 12,
#   u'Team_ID': 1610612765,
#   u'WL': u'L'},
#  {u'AST': 23,
#   u'BLK': 5,
#   u'DREB': 36,
#   u'FG3A': 27,
#   u'FG3M': 8,
#   u'FG3_PCT': 0.296,
#   u'FGA': 92,
#   u'FGM': 43,
#   u'FG_PCT': 0.467,
#   u'FTA': 14,
#   u'FTM': 9,
#   u'FT_PCT': 0.643,
#   u'GAME_DATE': u'JAN 09, 2016',
#   u'Game_ID': u'0021500553',
#   u'MATCHUP': u'DET vs. BKN',
#   u'MIN': 240,
#   u'OREB': 11,
#   u'PF': 12,
#   u'PTS': 103,
#   u'REB': 47,
#   u'STL': 10,
#   u'TOV': 9,
#   u'Team_ID': 1610612765,
#   u'WL': u'W'},
#  {u'AST': 18,
#   u'BLK': 5,
#   u'DREB': 36,
#   u'FG3A': 27,
#   u'FG3M': 10,
#   u'FG3_PCT': 0.37,
#   u'FGA': 74,
#   u'FGM': 33,
#   u'FG_PCT': 0.446,
#   u'FTA': 36,
#   u'FTM': 23,
#   u'FT_PCT': 0.639,
#   u'GAME_DATE': u'JAN 06, 2016',
#   u'Game_ID': u'0021500528',
#   u'MATCHUP': u'DET @ BOS',
#   u'MIN': 240,
#   u'OREB': 11,
#   u'PF': 27,
#   u'PTS': 99,
#   u'REB': 47,
#   u'STL': 4,
#   u'TOV': 18,
#   u'Team_ID': 1610612765,
#   u'WL': u'W'},
#  {u'AST': 25,
#   u'BLK': 6,
#   u'DREB': 36,
#   u'FG3A': 30,
#   u'FG3M': 14,
#   u'FG3_PCT': 0.467,
#   u'FGA': 88,
#   u'FGM': 43,
#   u'FG_PCT': 0.489,
#   u'FTA': 21,
#   u'FTM': 15,
#   u'FT_PCT': 0.714,
#   u'GAME_DATE': u'JAN 04, 2016',
#   u'Game_ID': u'0021500514',
#   u'MATCHUP': u'DET vs. ORL',
#   u'MIN': 240,
#   u'OREB': 18,
#   u'PF': 18,
#   u'PTS': 115,
#   u'REB': 54,
#   u'STL': 6,
#   u'TOV': 10,
#   u'Team_ID': 1610612765,
#   u'WL': u'W'},
#  {u'AST': 17,
#   u'BLK': 2,
#   u'DREB': 36,
#   u'FG3A': 20,
#   u'FG3M': 3,
#   u'FG3_PCT': 0.15,
#   u'FGA': 93,
#   u'FGM': 33,
#   u'FG_PCT': 0.355,
#   u'FTA': 23,
#   u'FTM': 13,
#   u'FT_PCT': 0.565,
#   u'GAME_DATE': u'JAN 02, 2016',
#   u'Game_ID': u'0021500498',
#   u'MATCHUP': u'DET @ IND',
#   u'MIN': 240,
#   u'OREB': 12,
#   u'PF': 18,
#   u'PTS': 82,
#   u'REB': 48,
#   u'STL': 5,
#   u'TOV': 10,
#   u'Team_ID': 1610612765,
#   u'WL': u'L'},
#  {u'AST': 24,
#   u'BLK': 3,
#   u'DREB': 40,
#   u'FG3A': 35,
#   u'FG3M': 14,
#   u'FG3_PCT': 0.4,
#   u'FGA': 86,
#   u'FGM': 41,
#   u'FG_PCT': 0.477,
#   u'FTA': 28,
#   u'FTM': 19,
#   u'FT_PCT': 0.679,
#   u'GAME_DATE': u'DEC 31, 2015',
#   u'Game_ID': u'0021500486',
#   u'MATCHUP': u'DET vs. MIN',
#   u'MIN': 240,
#   u'OREB': 12,
#   u'PF': 16,
#   u'PTS': 115,
#   u'REB': 52,
#   u'STL': 7,
#   u'TOV': 16,
#   u'Team_ID': 1610612765,
#   u'WL': u'W'},
#  {u'AST': 21,
#   u'BLK': 4,
#   u'DREB': 24,
#   u'FG3A': 27,
#   u'FG3M': 10,
#   u'FG3_PCT': 0.37,
#   u'FGA': 89,
#   u'FGM': 37,
#   u'FG_PCT': 0.416,
#   u'FTA': 17,
#   u'FTM': 12,
#   u'FT_PCT': 0.706,
#   u'GAME_DATE': u'DEC 29, 2015',
#   u'Game_ID': u'0021500469',
#   u'MATCHUP': u'DET @ NYK',
#   u'MIN': 240,
#   u'OREB': 15,
#   u'PF': 14,
#   u'PTS': 96,
#   u'REB': 39,
#   u'STL': 6,
#   u'TOV': 10,
#   u'Team_ID': 1610612765,
#   u'WL': u'L'},
#  {u'AST': 16,
#   u'BLK': 2,
#   u'DREB': 33,
#   u'FG3A': 25,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.24,
#   u'FGA': 91,
#   u'FGM': 35,
#   u'FG_PCT': 0.385,
#   u'FTA': 25,
#   u'FTM': 17,
#   u'FT_PCT': 0.68,
#   u'GAME_DATE': u'DEC 26, 2015',
#   u'Game_ID': u'0021500446',
#   u'MATCHUP': u'DET vs. BOS',
#   u'MIN': 240,
#   u'OREB': 18,
#   u'PF': 24,
#   u'PTS': 93,
#   u'REB': 51,
#   u'STL': 11,
#   u'TOV': 15,
#   u'Team_ID': 1610612765,
#   u'WL': u'L'},
#  {u'AST': 18,
#   u'BLK': 9,
#   u'DREB': 33,
#   u'FG3A': 21,
#   u'FG3M': 7,
#   u'FG3_PCT': 0.333,
#   u'FGA': 89,
#   u'FGM': 38,
#   u'FG_PCT': 0.427,
#   u'FTA': 33,
#   u'FTM': 17,
#   u'FT_PCT': 0.515,
#   u'GAME_DATE': u'DEC 23, 2015',
#   u'Game_ID': u'0021500429',
#   u'MATCHUP': u'DET @ ATL',
#   u'MIN': 240,
#   u'OREB': 13,
#   u'PF': 20,
#   u'PTS': 100,
#   u'REB': 46,
#   u'STL': 7,
#   u'TOV': 14,
#   u'Team_ID': 1610612765,
#   u'WL': u'L'},
#  {u'AST': 16,
#   u'BLK': 3,
#   u'DREB': 31,
#   u'FG3A': 30,
#   u'FG3M': 15,
#   u'FG3_PCT': 0.5,
#   u'FGA': 78,
#   u'FGM': 35,
#   u'FG_PCT': 0.449,
#   u'FTA': 14,
#   u'FTM': 8,
#   u'FT_PCT': 0.571,
#   u'GAME_DATE': u'DEC 22, 2015',
#   u'Game_ID': u'0021500420',
#   u'MATCHUP': u'DET @ MIA',
#   u'MIN': 240,
#   u'OREB': 12,
#   u'PF': 11,
#   u'PTS': 93,
#   u'REB': 43,
#   u'STL': 3,
#   u'TOV': 16,
#   u'Team_ID': 1610612765,
#   u'WL': u'W'},
#  {u'AST': 28,
#   u'BLK': 4,
#   u'DREB': 45,
#   u'FG3A': 29,
#   u'FG3M': 8,
#   u'FG3_PCT': 0.276,
#   u'FGA': 124,
#   u'FGM': 56,
#   u'FG_PCT': 0.452,
#   u'FTA': 46,
#   u'FTM': 27,
#   u'FT_PCT': 0.587,
#   u'GAME_DATE': u'DEC 18, 2015',
#   u'Game_ID': u'0021500391',
#   u'MATCHUP': u'DET @ CHI',
#   u'MIN': 340,
#   u'OREB': 19,
#   u'PF': 35,
#   u'PTS': 147,
#   u'REB': 64,
#   u'STL': 7,
#   u'TOV': 11,
#   u'Team_ID': 1610612765,
#   u'WL': u'W'},
#  {u'AST': 13,
#   u'BLK': 4,
#   u'DREB': 29,
#   u'FG3A': 21,
#   u'FG3M': 11,
#   u'FG3_PCT': 0.524,
#   u'FGA': 78,
#   u'FGM': 38,
#   u'FG_PCT': 0.487,
#   u'FTA': 43,
#   u'FTM': 32,
#   u'FT_PCT': 0.744,
#   u'GAME_DATE': u'DEC 16, 2015',
#   u'Game_ID': u'0021500374',
#   u'MATCHUP': u'DET vs. BOS',
#   u'MIN': 240,
#   u'OREB': 7,
#   u'PF': 22,
#   u'PTS': 119,
#   u'REB': 36,
#   u'STL': 5,
#   u'TOV': 11,
#   u'Team_ID': 1610612765,
#   u'WL': u'W'},
#  {u'AST': 17,
#   u'BLK': 0,
#   u'DREB': 39,
#   u'FG3A': 19,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.316,
#   u'FGA': 89,
#   u'FGM': 37,
#   u'FG_PCT': 0.416,
#   u'FTA': 31,
#   u'FTM': 23,
#   u'FT_PCT': 0.742,
#   u'GAME_DATE': u'DEC 14, 2015',
#   u'Game_ID': u'0021500359',
#   u'MATCHUP': u'DET vs. LAC',
#   u'MIN': 265,
#   u'OREB': 15,
#   u'PF': 21,
#   u'PTS': 103,
#   u'REB': 54,
#   u'STL': 8,
#   u'TOV': 18,
#   u'Team_ID': 1610612765,
#   u'WL': u'L'},
#  {u'AST': 26,
#   u'BLK': 6,
#   u'DREB': 36,
#   u'FG3A': 29,
#   u'FG3M': 13,
#   u'FG3_PCT': 0.448,
#   u'FGA': 90,
#   u'FGM': 45,
#   u'FG_PCT': 0.5,
#   u'FTA': 19,
#   u'FTM': 15,
#   u'FT_PCT': 0.789,
#   u'GAME_DATE': u'DEC 12, 2015',
#   u'Game_ID': u'0021500346',
#   u'MATCHUP': u'DET vs. IND',
#   u'MIN': 240,
#   u'OREB': 10,
#   u'PF': 18,
#   u'PTS': 118,
#   u'REB': 46,
#   u'STL': 11,
#   u'TOV': 14,
#   u'Team_ID': 1610612765,
#   u'WL': u'W'},
#  {u'AST': 18,
#   u'BLK': 9,
#   u'DREB': 31,
#   u'FG3A': 27,
#   u'FG3M': 10,
#   u'FG3_PCT': 0.37,
#   u'FGA': 93,
#   u'FGM': 43,
#   u'FG_PCT': 0.462,
#   u'FTA': 16,
#   u'FTM': 11,
#   u'FT_PCT': 0.688,
#   u'GAME_DATE': u'DEC 11, 2015',
#   u'Game_ID': u'0021500335',
#   u'MATCHUP': u'DET @ PHI',
#   u'MIN': 240,
#   u'OREB': 17,
#   u'PF': 21,
#   u'PTS': 107,
#   u'REB': 48,
#   u'STL': 9,
#   u'TOV': 14,
#   u'Team_ID': 1610612765,
#   u'WL': u'W'},
#  {u'AST': 17,
#   u'BLK': 6,
#   u'DREB': 30,
#   u'FG3A': 29,
#   u'FG3M': 8,
#   u'FG3_PCT': 0.276,
#   u'FGA': 87,
#   u'FGM': 37,
#   u'FG_PCT': 0.425,
#   u'FTA': 15,
#   u'FTM': 10,
#   u'FT_PCT': 0.667,
#   u'GAME_DATE': u'DEC 09, 2015',
#   u'Game_ID': u'0021500322',
#   u'MATCHUP': u'DET vs. MEM',
#   u'MIN': 240,
#   u'OREB': 13,
#   u'PF': 16,
#   u'PTS': 92,
#   u'REB': 43,
#   u'STL': 9,
#   u'TOV': 12,
#   u'Team_ID': 1610612765,
#   u'WL': u'L'},
#  {u'AST': 17,
#   u'BLK': 2,
#   u'DREB': 34,
#   u'FG3A': 34,
#   u'FG3M': 10,
#   u'FG3_PCT': 0.294,
#   u'FGA': 87,
#   u'FGM': 32,
#   u'FG_PCT': 0.368,
#   u'FTA': 22,
#   u'FTM': 10,
#   u'FT_PCT': 0.455,
#   u'GAME_DATE': u'DEC 07, 2015',
#   u'Game_ID': u'0021500304',
#   u'MATCHUP': u'DET @ CHA',
#   u'MIN': 240,
#   u'OREB': 7,
#   u'PF': 20,
#   u'PTS': 84,
#   u'REB': 41,
#   u'STL': 11,
#   u'TOV': 12,
#   u'Team_ID': 1610612765,
#   u'WL': u'L'},
#  {u'AST': 20,
#   u'BLK': 1,
#   u'DREB': 44,
#   u'FG3A': 24,
#   u'FG3M': 9,
#   u'FG3_PCT': 0.375,
#   u'FGA': 93,
#   u'FGM': 41,
#   u'FG_PCT': 0.441,
#   u'FTA': 26,
#   u'FTM': 20,
#   u'FT_PCT': 0.769,
#   u'GAME_DATE': u'DEC 06, 2015',
#   u'Game_ID': u'0021500301',
#   u'MATCHUP': u'DET vs. LAL',
#   u'MIN': 240,
#   u'OREB': 17,
#   u'PF': 21,
#   u'PTS': 111,
#   u'REB': 61,
#   u'STL': 11,
#   u'TOV': 16,
#   u'Team_ID': 1610612765,
#   u'WL': u'W'},
#  {u'AST': 18,
#   u'BLK': 4,
#   u'DREB': 38,
#   u'FG3A': 23,
#   u'FG3M': 7,
#   u'FG3_PCT': 0.304,
#   u'FGA': 82,
#   u'FGM': 34,
#   u'FG_PCT': 0.415,
#   u'FTA': 39,
#   u'FTM': 27,
#   u'FT_PCT': 0.692,
#   u'GAME_DATE': u'DEC 04, 2015',
#   u'Game_ID': u'0021500285',
#   u'MATCHUP': u'DET vs. MIL',
#   u'MIN': 240,
#   u'OREB': 8,
#   u'PF': 11,
#   u'PTS': 102,
#   u'REB': 46,
#   u'STL': 8,
#   u'TOV': 9,
#   u'Team_ID': 1610612765,
#   u'WL': u'W'},
#  {u'AST': 24,
#   u'BLK': 1,
#   u'DREB': 37,
#   u'FG3A': 27,
#   u'FG3M': 12,
#   u'FG3_PCT': 0.444,
#   u'FGA': 87,
#   u'FGM': 44,
#   u'FG_PCT': 0.506,
#   u'FTA': 44,
#   u'FTM': 27,
#   u'FT_PCT': 0.614,
#   u'GAME_DATE': u'DEC 02, 2015',
#   u'Game_ID': u'0021500270',
#   u'MATCHUP': u'DET vs. PHX',
#   u'MIN': 265,
#   u'OREB': 13,
#   u'PF': 20,
#   u'PTS': 127,
#   u'REB': 50,
#   u'STL': 10,
#   u'TOV': 18,
#   u'Team_ID': 1610612765,
#   u'WL': u'W'},
#  {u'AST': 22,
#   u'BLK': 8,
#   u'DREB': 32,
#   u'FG3A': 23,
#   u'FG3M': 8,
#   u'FG3_PCT': 0.348,
#   u'FGA': 85,
#   u'FGM': 45,
#   u'FG_PCT': 0.529,
#   u'FTA': 37,
#   u'FTM': 18,
#   u'FT_PCT': 0.486,
#   u'GAME_DATE': u'NOV 30, 2015',
#   u'Game_ID': u'0021500254',
#   u'MATCHUP': u'DET vs. HOU',
#   u'MIN': 240,
#   u'OREB': 14,
#   u'PF': 19,
#   u'PTS': 116,
#   u'REB': 46,
#   u'STL': 8,
#   u'TOV': 11,
#   u'Team_ID': 1610612765,
#   u'WL': u'W'},
#  {u'AST': 19,
#   u'BLK': 1,
#   u'DREB': 32,
#   u'FG3A': 24,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.25,
#   u'FGA': 101,
#   u'FGM': 34,
#   u'FG_PCT': 0.337,
#   u'FTA': 21,
#   u'FTM': 9,
#   u'FT_PCT': 0.429,
#   u'GAME_DATE': u'NOV 29, 2015',
#   u'Game_ID': u'0021500248',
#   u'MATCHUP': u'DET @ BKN',
#   u'MIN': 240,
#   u'OREB': 19,
#   u'PF': 15,
#   u'PTS': 83,
#   u'REB': 51,
#   u'STL': 11,
#   u'TOV': 14,
#   u'Team_ID': 1610612765,
#   u'WL': u'L'},
#  {u'AST': 17,
#   u'BLK': 1,
#   u'DREB': 25,
#   u'FG3A': 29,
#   u'FG3M': 9,
#   u'FG3_PCT': 0.31,
#   u'FGA': 90,
#   u'FGM': 31,
#   u'FG_PCT': 0.344,
#   u'FTA': 20,
#   u'FTM': 16,
#   u'FT_PCT': 0.8,
#   u'GAME_DATE': u'NOV 27, 2015',
#   u'Game_ID': u'0021500234',
#   u'MATCHUP': u'DET @ OKC',
#   u'MIN': 240,
#   u'OREB': 13,
#   u'PF': 21,
#   u'PTS': 87,
#   u'REB': 38,
#   u'STL': 9,
#   u'TOV': 8,
#   u'Team_ID': 1610612765,
#   u'WL': u'L'},
#  {u'AST': 24,
#   u'BLK': 7,
#   u'DREB': 36,
#   u'FG3A': 31,
#   u'FG3M': 16,
#   u'FG3_PCT': 0.516,
#   u'FGA': 98,
#   u'FGM': 41,
#   u'FG_PCT': 0.418,
#   u'FTA': 7,
#   u'FTM': 6,
#   u'FT_PCT': 0.857,
#   u'GAME_DATE': u'NOV 25, 2015',
#   u'Game_ID': u'0021500218',
#   u'MATCHUP': u'DET vs. MIA',
#   u'MIN': 240,
#   u'OREB': 18,
#   u'PF': 16,
#   u'PTS': 104,
#   u'REB': 54,
#   u'STL': 6,
#   u'TOV': 7,
#   u'Team_ID': 1610612765,
#   u'WL': u'W'},
#  {u'AST': 19,
#   u'BLK': 3,
#   u'DREB': 26,
#   u'FG3A': 28,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.214,
#   u'FGA': 91,
#   u'FGM': 31,
#   u'FG_PCT': 0.341,
#   u'FTA': 24,
#   u'FTM': 20,
#   u'FT_PCT': 0.833,
#   u'GAME_DATE': u'NOV 23, 2015',
#   u'Game_ID': u'0021500205',
#   u'MATCHUP': u'DET @ MIL',
#   u'MIN': 240,
#   u'OREB': 22,
#   u'PF': 18,
#   u'PTS': 88,
#   u'REB': 48,
#   u'STL': 7,
#   u'TOV': 17,
#   u'Team_ID': 1610612765,
#   u'WL': u'L'},
#  {u'AST': 20,
#   u'BLK': 2,
#   u'DREB': 30,
#   u'FG3A': 26,
#   u'FG3M': 8,
#   u'FG3_PCT': 0.308,
#   u'FGA': 79,
#   u'FGM': 36,
#   u'FG_PCT': 0.456,
#   u'FTA': 21,
#   u'FTM': 15,
#   u'FT_PCT': 0.714,
#   u'GAME_DATE': u'NOV 21, 2015',
#   u'Game_ID': u'0021500192',
#   u'MATCHUP': u'DET vs. WAS',
#   u'MIN': 240,
#   u'OREB': 8,
#   u'PF': 17,
#   u'PTS': 95,
#   u'REB': 38,
#   u'STL': 3,
#   u'TOV': 13,
#   u'Team_ID': 1610612765,
#   u'WL': u'L'},
#  {u'AST': 13,
#   u'BLK': 5,
#   u'DREB': 37,
#   u'FG3A': 28,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.214,
#   u'FGA': 87,
#   u'FGM': 40,
#   u'FG_PCT': 0.46,
#   u'FTA': 13,
#   u'FTM': 10,
#   u'FT_PCT': 0.769,
#   u'GAME_DATE': u'NOV 20, 2015',
#   u'Game_ID': u'0021500181',
#   u'MATCHUP': u'DET @ MIN',
#   u'MIN': 240,
#   u'OREB': 8,
#   u'PF': 23,
#   u'PTS': 96,
#   u'REB': 45,
#   u'STL': 11,
#   u'TOV': 14,
#   u'Team_ID': 1610612765,
#   u'WL': u'W'},
#  {u'AST': 20,
#   u'BLK': 1,
#   u'DREB': 37,
#   u'FG3A': 21,
#   u'FG3M': 7,
#   u'FG3_PCT': 0.333,
#   u'FGA': 84,
#   u'FGM': 36,
#   u'FG_PCT': 0.429,
#   u'FTA': 31,
#   u'FTM': 25,
#   u'FT_PCT': 0.806,
#   u'GAME_DATE': u'NOV 17, 2015',
#   u'Game_ID': u'0021500160',
#   u'MATCHUP': u'DET vs. CLE',
#   u'MIN': 240,
#   u'OREB': 11,
#   u'PF': 15,
#   u'PTS': 104,
#   u'REB': 48,
#   u'STL': 11,
#   u'TOV': 13,
#   u'Team_ID': 1610612765,
#   u'WL': u'W'},
#  {u'AST': 16,
#   u'BLK': 2,
#   u'DREB': 34,
#   u'FG3A': 27,
#   u'FG3M': 7,
#   u'FG3_PCT': 0.259,
#   u'FGA': 96,
#   u'FGM': 35,
#   u'FG_PCT': 0.365,
#   u'FTA': 15,
#   u'FTM': 8,
#   u'FT_PCT': 0.533,
#   u'GAME_DATE': u'NOV 15, 2015',
#   u'Game_ID': u'0021500151',
#   u'MATCHUP': u'DET @ LAL',
#   u'MIN': 240,
#   u'OREB': 12,
#   u'PF': 25,
#   u'PTS': 85,
#   u'REB': 46,
#   u'STL': 7,
#   u'TOV': 10,
#   u'Team_ID': 1610612765,
#   u'WL': u'L'},
#  {u'AST': 15,
#   u'BLK': 2,
#   u'DREB': 31,
#   u'FG3A': 27,
#   u'FG3M': 7,
#   u'FG3_PCT': 0.259,
#   u'FGA': 74,
#   u'FGM': 33,
#   u'FG_PCT': 0.446,
#   u'FTA': 35,
#   u'FTM': 23,
#   u'FT_PCT': 0.657,
#   u'GAME_DATE': u'NOV 14, 2015',
#   u'Game_ID': u'0021500138',
#   u'MATCHUP': u'DET @ LAC',
#   u'MIN': 240,
#   u'OREB': 11,
#   u'PF': 23,
#   u'PTS': 96,
#   u'REB': 42,
#   u'STL': 8,
#   u'TOV': 15,
#   u'Team_ID': 1610612765,
#   u'WL': u'L'},
#  {u'AST': 16,
#   u'BLK': 3,
#   u'DREB': 31,
#   u'FG3A': 32,
#   u'FG3M': 9,
#   u'FG3_PCT': 0.281,
#   u'FGA': 89,
#   u'FGM': 34,
#   u'FG_PCT': 0.382,
#   u'FTA': 20,
#   u'FTM': 15,
#   u'FT_PCT': 0.75,
#   u'GAME_DATE': u'NOV 11, 2015',
#   u'Game_ID': u'0021500122',
#   u'MATCHUP': u'DET @ SAC',
#   u'MIN': 240,
#   u'OREB': 14,
#   u'PF': 20,
#   u'PTS': 92,
#   u'REB': 45,
#   u'STL': 10,
#   u'TOV': 16,
#   u'Team_ID': 1610612765,
#   u'WL': u'L'},
#  {u'AST': 15,
#   u'BLK': 3,
#   u'DREB': 29,
#   u'FG3A': 19,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.316,
#   u'FGA': 85,
#   u'FGM': 40,
#   u'FG_PCT': 0.471,
#   u'FTA': 15,
#   u'FTM': 9,
#   u'FT_PCT': 0.6,
#   u'GAME_DATE': u'NOV 09, 2015',
#   u'Game_ID': u'0021500104',
#   u'MATCHUP': u'DET @ GSW',
#   u'MIN': 240,
#   u'OREB': 12,
#   u'PF': 14,
#   u'PTS': 95,
#   u'REB': 41,
#   u'STL': 9,
#   u'TOV': 20,
#   u'Team_ID': 1610612765,
#   u'WL': u'L'},
#  {u'AST': 16,
#   u'BLK': 5,
#   u'DREB': 28,
#   u'FG3A': 30,
#   u'FG3M': 11,
#   u'FG3_PCT': 0.367,
#   u'FGA': 96,
#   u'FGM': 47,
#   u'FG_PCT': 0.49,
#   u'FTA': 22,
#   u'FTM': 15,
#   u'FT_PCT': 0.682,
#   u'GAME_DATE': u'NOV 08, 2015',
#   u'Game_ID': u'0021500098',
#   u'MATCHUP': u'DET @ POR',
#   u'MIN': 240,
#   u'OREB': 18,
#   u'PF': 16,
#   u'PTS': 120,
#   u'REB': 46,
#   u'STL': 13,
#   u'TOV': 9,
#   u'Team_ID': 1610612765,
#   u'WL': u'W'},
#  {u'AST': 15,
#   u'BLK': 3,
#   u'DREB': 41,
#   u'FG3A': 22,
#   u'FG3M': 8,
#   u'FG3_PCT': 0.364,
#   u'FGA': 74,
#   u'FGM': 37,
#   u'FG_PCT': 0.5,
#   u'FTA': 36,
#   u'FTM': 18,
#   u'FT_PCT': 0.5,
#   u'GAME_DATE': u'NOV 06, 2015',
#   u'Game_ID': u'0021500082',
#   u'MATCHUP': u'DET @ PHX',
#   u'MIN': 240,
#   u'OREB': 6,
#   u'PF': 21,
#   u'PTS': 100,
#   u'REB': 47,
#   u'STL': 8,
#   u'TOV': 15,
#   u'Team_ID': 1610612765,
#   u'WL': u'W'},
#  {u'AST': 14,
#   u'BLK': 5,
#   u'DREB': 31,
#   u'FG3A': 22,
#   u'FG3M': 5,
#   u'FG3_PCT': 0.227,
#   u'FGA': 86,
#   u'FGM': 33,
#   u'FG_PCT': 0.384,
#   u'FTA': 17,
#   u'FTM': 11,
#   u'FT_PCT': 0.647,
#   u'GAME_DATE': u'NOV 03, 2015',
#   u'Game_ID': u'0021500054',
#   u'MATCHUP': u'DET vs. IND',
#   u'MIN': 240,
#   u'OREB': 19,
#   u'PF': 21,
#   u'PTS': 82,
#   u'REB': 50,
#   u'STL': 8,
#   u'TOV': 23,
#   u'Team_ID': 1610612765,
#   u'WL': u'L'},
#  {u'AST': 18,
#   u'BLK': 2,
#   u'DREB': 41,
#   u'FG3A': 28,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.214,
#   u'FGA': 104,
#   u'FGM': 39,
#   u'FG_PCT': 0.375,
#   u'FTA': 28,
#   u'FTM': 14,
#   u'FT_PCT': 0.5,
#   u'GAME_DATE': u'OCT 30, 2015',
#   u'Game_ID': u'0021500025',
#   u'MATCHUP': u'DET vs. CHI',
#   u'MIN': 265,
#   u'OREB': 20,
#   u'PF': 19,
#   u'PTS': 98,
#   u'REB': 61,
#   u'STL': 9,
#   u'TOV': 14,
#   u'Team_ID': 1610612765,
#   u'WL': u'W'},
#  {u'AST': 16,
#   u'BLK': 4,
#   u'DREB': 35,
#   u'FG3A': 19,
#   u'FG3M': 7,
#   u'FG3_PCT': 0.368,
#   u'FGA': 74,
#   u'FGM': 30,
#   u'FG_PCT': 0.405,
#   u'FTA': 34,
#   u'FTM': 25,
#   u'FT_PCT': 0.735,
#   u'GAME_DATE': u'OCT 28, 2015',
#   u'Game_ID': u'0021500007',
#   u'MATCHUP': u'DET vs. UTA',
#   u'MIN': 240,
#   u'OREB': 8,
#   u'PF': 20,
#   u'PTS': 92,
#   u'REB': 43,
#   u'STL': 2,
#   u'TOV': 10,
#   u'Team_ID': 1610612765,
#   u'WL': u'W'},
#  {u'AST': 23,
#   u'BLK': 3,
#   u'DREB': 36,
#   u'FG3A': 29,
#   u'FG3M': 12,
#   u'FG3_PCT': 0.414,
#   u'FGA': 96,
#   u'FGM': 37,
#   u'FG_PCT': 0.385,
#   u'FTA': 26,
#   u'FTM': 20,
#   u'FT_PCT': 0.769,
#   u'GAME_DATE': u'OCT 27, 2015',
#   u'Game_ID': u'0021500001',
#   u'MATCHUP': u'DET @ ATL',
#   u'MIN': 240,
#   u'OREB': 23,
#   u'PF': 15,
#   u'PTS': 106,
#   u'REB': 59,
#   u'STL': 5,
#   u'TOV': 15,
#   u'Team_ID': 1610612765,
#   u'WL': u'W'}]

# %% [markdown]
# ## Player_info
#
# http://stats.nba.com/stats/commonplayerinfo?LeagueID=00&PlayerID=202694&Season=2015-16&SeasonType=Regular+Season

# %%
player = parser.player_info(scraper.player_info(player_id='202694', season='2015-16'))

# %%
player
# Out:
# {u'BIRTHDATE': u'1989-09-02T00:00:00',
#  u'COUNTRY': u'USA',
#  u'DISPLAY_FIRST_LAST': u'Marcus Morris',
#  u'DISPLAY_FI_LAST': u'M. Morris',
#  u'DISPLAY_LAST_COMMA_FIRST': u'Morris, Marcus',
#  u'DLEAGUE_FLAG': u'Y',
#  u'FIRST_NAME': u'Marcus',
#  u'FROM_YEAR': 2011,
#  u'GAMES_PLAYED_FLAG': u'Y',
#  u'HEIGHT': u'6-9',
#  u'JERSEY': u'13',
#  u'LAST_AFFILIATION': u'Kansas/USA',
#  u'LAST_NAME': u'Morris',
#  u'PERSON_ID': 202694,
#  u'PLAYERCODE': u'marcus_morris',
#  u'POSITION': u'Forward',
#  u'ROSTERSTATUS': u'Active',
#  u'SCHOOL': u'Kansas',
#  u'SEASON_EXP': 4,
#  u'TEAM_ABBREVIATION': u'DET',
#  u'TEAM_CITY': u'Detroit',
#  u'TEAM_CODE': u'pistons',
#  u'TEAM_ID': 1610612765,
#  u'TEAM_NAME': u'Pistons',
#  u'TO_YEAR': 2015,
#  u'WEIGHT': u'235'}

# %% [markdown]
# ## Players
#
# http://stats.nba.com/stats/commonallplayers?IsOnlyCurrentSeason=1&LeagueID=00&Season=2015-16

# %%
players = parser.players(scraper.players(season='2016-17', cs_only='1'))

# %%
players
# Out:
# [{u'DISPLAY_LAST_COMMA_FIRST': u'Acy, Quincy',
#   u'FROM_YEAR': u'2012',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203112,
#   u'PLAYERCODE': u'quincy_acy',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'SAC',
#   u'TEAM_CITY': u'Sacramento',
#   u'TEAM_CODE': u'kings',
#   u'TEAM_ID': 1610612758,
#   u'TEAM_NAME': u'Kings',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Adams, Jordan',
#   u'FROM_YEAR': u'2014',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203919,
#   u'PLAYERCODE': u'jordan_adams',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'MEM',
#   u'TEAM_CITY': u'Memphis',
#   u'TEAM_CODE': u'grizzlies',
#   u'TEAM_ID': 1610612763,
#   u'TEAM_NAME': u'Grizzlies',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Adams, Steven',
#   u'FROM_YEAR': u'2013',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203500,
#   u'PLAYERCODE': u'steven_adams',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'OKC',
#   u'TEAM_CITY': u'Oklahoma City',
#   u'TEAM_CODE': u'thunder',
#   u'TEAM_ID': 1610612760,
#   u'TEAM_NAME': u'Thunder',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Afflalo, Arron',
#   u'FROM_YEAR': u'2007',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201167,
#   u'PLAYERCODE': u'arron_afflalo',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'NYK',
#   u'TEAM_CITY': u'New York',
#   u'TEAM_CODE': u'knicks',
#   u'TEAM_ID': 1610612752,
#   u'TEAM_NAME': u'Knicks',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Ajinca, Alexis',
#   u'FROM_YEAR': u'2008',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201582,
#   u'PLAYERCODE': u'alexis_ajinca',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'NOP',
#   u'TEAM_CITY': u'New Orleans',
#   u'TEAM_CODE': u'pelicans',
#   u'TEAM_ID': 1610612740,
#   u'TEAM_NAME': u'Pelicans',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Aldrich, Cole',
#   u'FROM_YEAR': u'2010',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 202332,
#   u'PLAYERCODE': u'cole_aldrich',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'LAC',
#   u'TEAM_CITY': u'Los Angeles',
#   u'TEAM_CODE': u'clippers',
#   u'TEAM_ID': 1610612746,
#   u'TEAM_NAME': u'Clippers',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Aldridge, LaMarcus',
#   u'FROM_YEAR': u'2006',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 200746,
#   u'PLAYERCODE': u'lamarcus_aldridge',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'SAS',
#   u'TEAM_CITY': u'San Antonio',
#   u'TEAM_CODE': u'spurs',
#   u'TEAM_ID': 1610612759,
#   u'TEAM_NAME': u'Spurs',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Alexander, Cliff',
#   u'FROM_YEAR': u'2015',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 1626146,
#   u'PLAYERCODE': u'cliff_alexander',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'POR',
#   u'TEAM_CITY': u'Portland',
#   u'TEAM_CODE': u'blazers',
#   u'TEAM_ID': 1610612757,
#   u'TEAM_NAME': u'Trail Blazers',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Allen, Lavoy',
#   u'FROM_YEAR': u'2011',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 202730,
#   u'PLAYERCODE': u'lavoy_allen',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'IND',
#   u'TEAM_CITY': u'Indiana',
#   u'TEAM_CODE': u'pacers',
#   u'TEAM_ID': 1610612754,
#   u'TEAM_NAME': u'Pacers',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Allen, Tony',
#   u'FROM_YEAR': u'2004',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 2754,
#   u'PLAYERCODE': u'tony_allen',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'MEM',
#   u'TEAM_CITY': u'Memphis',
#   u'TEAM_CODE': u'grizzlies',
#   u'TEAM_ID': 1610612763,
#   u'TEAM_NAME': u'Grizzlies',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Aminu, Al-Farouq',
#   u'FROM_YEAR': u'2010',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 202329,
#   u'PLAYERCODE': u'al-farouq_aminu',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'POR',
#   u'TEAM_CITY': u'Portland',
#   u'TEAM_CODE': u'blazers',
#   u'TEAM_ID': 1610612757,
#   u'TEAM_NAME': u'Trail Blazers',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Amundson, Lou',
#   u'FROM_YEAR': u'2006',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 200811,
#   u'PLAYERCODE': u'lou_amundson',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'NYK',
#   u'TEAM_CITY': u'New York',
#   u'TEAM_CODE': u'knicks',
#   u'TEAM_ID': 1610612752,
#   u'TEAM_NAME': u'Knicks',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Andersen, Chris',
#   u'FROM_YEAR': u'2001',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 2365,
#   u'PLAYERCODE': u'chris_andersen',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'MIA',
#   u'TEAM_CITY': u'Miami',
#   u'TEAM_CODE': u'heat',
#   u'TEAM_ID': 1610612748,
#   u'TEAM_NAME': u'Heat',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Anderson, Alan',
#   u'FROM_YEAR': u'2005',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 101187,
#   u'PLAYERCODE': u'alan_anderson',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'WAS',
#   u'TEAM_CITY': u'Washington',
#   u'TEAM_CODE': u'wizards',
#   u'TEAM_ID': 1610612764,
#   u'TEAM_NAME': u'Wizards',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Anderson, James',
#   u'FROM_YEAR': u'2010',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 202341,
#   u'PLAYERCODE': u'james_anderson',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'SAC',
#   u'TEAM_CITY': u'Sacramento',
#   u'TEAM_CODE': u'kings',
#   u'TEAM_ID': 1610612758,
#   u'TEAM_NAME': u'Kings',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Anderson, Justin',
#   u'FROM_YEAR': u'2015',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 1626147,
#   u'PLAYERCODE': u'justin_anderson',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'DAL',
#   u'TEAM_CITY': u'Dallas',
#   u'TEAM_CODE': u'mavericks',
#   u'TEAM_ID': 1610612742,
#   u'TEAM_NAME': u'Mavericks',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Anderson, Kyle',
#   u'FROM_YEAR': u'2014',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203937,
#   u'PLAYERCODE': u'kyle_anderson',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'SAS',
#   u'TEAM_CITY': u'San Antonio',
#   u'TEAM_CODE': u'spurs',
#   u'TEAM_ID': 1610612759,
#   u'TEAM_NAME': u'Spurs',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Anderson, Ryan',
#   u'FROM_YEAR': u'2008',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201583,
#   u'PLAYERCODE': u'ryan_j_anderson',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'NOP',
#   u'TEAM_CITY': u'New Orleans',
#   u'TEAM_CODE': u'pelicans',
#   u'TEAM_ID': 1610612740,
#   u'TEAM_NAME': u'Pelicans',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Antetokounmpo, Giannis',
#   u'FROM_YEAR': u'2013',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203507,
#   u'PLAYERCODE': u'giannis_antetokounmpo',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'MIL',
#   u'TEAM_CITY': u'Milwaukee',
#   u'TEAM_CODE': u'bucks',
#   u'TEAM_ID': 1610612749,
#   u'TEAM_NAME': u'Bucks',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Antetokounmpo, Thanasis',
#   u'FROM_YEAR': u'2015',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203648,
#   u'PLAYERCODE': u'thanasis_antetokounmpo',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'NYK',
#   u'TEAM_CITY': u'New York',
#   u'TEAM_CODE': u'knicks',
#   u'TEAM_ID': 1610612752,
#   u'TEAM_NAME': u'Knicks',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Anthony, Carmelo',
#   u'FROM_YEAR': u'2003',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 2546,
#   u'PLAYERCODE': u'carmelo_anthony',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'NYK',
#   u'TEAM_CITY': u'New York',
#   u'TEAM_CODE': u'knicks',
#   u'TEAM_ID': 1610612752,
#   u'TEAM_NAME': u'Knicks',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Anthony, Joel',
#   u'FROM_YEAR': u'2007',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201202,
#   u'PLAYERCODE': u'joel_anthony',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'DET',
#   u'TEAM_CITY': u'Detroit',
#   u'TEAM_CODE': u'pistons',
#   u'TEAM_ID': 1610612765,
#   u'TEAM_NAME': u'Pistons',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Appling, Keith',
#   u'FROM_YEAR': u'2015',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203951,
#   u'PLAYERCODE': u'keith_appling',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'ORL',
#   u'TEAM_CITY': u'Orlando',
#   u'TEAM_CODE': u'magic',
#   u'TEAM_ID': 1610612753,
#   u'TEAM_NAME': u'Magic',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Ariza, Trevor',
#   u'FROM_YEAR': u'2004',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 2772,
#   u'PLAYERCODE': u'trevor_ariza',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'HOU',
#   u'TEAM_CITY': u'Houston',
#   u'TEAM_CODE': u'rockets',
#   u'TEAM_ID': 1610612745,
#   u'TEAM_NAME': u'Rockets',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Arthur, Darrell',
#   u'FROM_YEAR': u'2008',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201589,
#   u'PLAYERCODE': u'darrell_arthur',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'DEN',
#   u'TEAM_CITY': u'Denver',
#   u'TEAM_CODE': u'nuggets',
#   u'TEAM_ID': 1610612743,
#   u'TEAM_NAME': u'Nuggets',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Asik, Omer',
#   u'FROM_YEAR': u'2010',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201600,
#   u'PLAYERCODE': u'omer_asik',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'NOP',
#   u'TEAM_CITY': u'New Orleans',
#   u'TEAM_CODE': u'pelicans',
#   u'TEAM_ID': 1610612740,
#   u'TEAM_NAME': u'Pelicans',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Augustin, D.J.',
#   u'FROM_YEAR': u'2008',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201571,
#   u'PLAYERCODE': u'dj_augustin',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'OKC',
#   u'TEAM_CITY': u'Oklahoma City',
#   u'TEAM_CODE': u'thunder',
#   u'TEAM_ID': 1610612760,
#   u'TEAM_NAME': u'Thunder',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Ayres, Jeff',
#   u'FROM_YEAR': u'2009',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201965,
#   u'PLAYERCODE': u'jeff_ayres',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'LAC',
#   u'TEAM_CITY': u'Los Angeles',
#   u'TEAM_CODE': u'clippers',
#   u'TEAM_ID': 1610612746,
#   u'TEAM_NAME': u'Clippers',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Babbitt, Luke',
#   u'FROM_YEAR': u'2010',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 202337,
#   u'PLAYERCODE': u'luke_babbitt',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'NOP',
#   u'TEAM_CITY': u'New Orleans',
#   u'TEAM_CODE': u'pelicans',
#   u'TEAM_ID': 1610612740,
#   u'TEAM_NAME': u'Pelicans',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Bairstow, Cameron',
#   u'FROM_YEAR': u'2014',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203946,
#   u'PLAYERCODE': u'cameron_bairstow',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'CHI',
#   u'TEAM_CITY': u'Chicago',
#   u'TEAM_CODE': u'bulls',
#   u'TEAM_ID': 1610612741,
#   u'TEAM_NAME': u'Bulls',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Barbosa, Leandro',
#   u'FROM_YEAR': u'2003',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 2571,
#   u'PLAYERCODE': u'leandro_barbosa',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_CITY': u'Golden State',
#   u'TEAM_CODE': u'warriors',
#   u'TEAM_ID': 1610612744,
#   u'TEAM_NAME': u'Warriors',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Barea, Jose Juan',
#   u'FROM_YEAR': u'2006',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 200826,
#   u'PLAYERCODE': u'jose_barea',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'DAL',
#   u'TEAM_CITY': u'Dallas',
#   u'TEAM_CODE': u'mavericks',
#   u'TEAM_ID': 1610612742,
#   u'TEAM_NAME': u'Mavericks',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Bargnani, Andrea',
#   u'FROM_YEAR': u'2006',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 200745,
#   u'PLAYERCODE': u'andrea_bargnani',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'BKN',
#   u'TEAM_CITY': u'Brooklyn',
#   u'TEAM_CODE': u'nets',
#   u'TEAM_ID': 1610612751,
#   u'TEAM_NAME': u'Nets',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Barnes, Harrison',
#   u'FROM_YEAR': u'2012',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203084,
#   u'PLAYERCODE': u'harrison_barnes',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_CITY': u'Golden State',
#   u'TEAM_CODE': u'warriors',
#   u'TEAM_ID': 1610612744,
#   u'TEAM_NAME': u'Warriors',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Barnes, Matt',
#   u'FROM_YEAR': u'2002',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 2440,
#   u'PLAYERCODE': u'matt_barnes',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'MEM',
#   u'TEAM_CITY': u'Memphis',
#   u'TEAM_CODE': u'grizzlies',
#   u'TEAM_ID': 1610612763,
#   u'TEAM_NAME': u'Grizzlies',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Barton, Will',
#   u'FROM_YEAR': u'2012',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203115,
#   u'PLAYERCODE': u'will_barton',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'DEN',
#   u'TEAM_CITY': u'Denver',
#   u'TEAM_CODE': u'nuggets',
#   u'TEAM_ID': 1610612743,
#   u'TEAM_NAME': u'Nuggets',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Bass, Brandon',
#   u'FROM_YEAR': u'2005',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 101138,
#   u'PLAYERCODE': u'brandon_bass',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'LAL',
#   u'TEAM_CITY': u'Los Angeles',
#   u'TEAM_CODE': u'lakers',
#   u'TEAM_ID': 1610612747,
#   u'TEAM_NAME': u'Lakers',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Batum, Nicolas',
#   u'FROM_YEAR': u'2008',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201587,
#   u'PLAYERCODE': u'nicolas_batum',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'CHA',
#   u'TEAM_CITY': u'Charlotte',
#   u'TEAM_CODE': u'hornets',
#   u'TEAM_ID': 1610612766,
#   u'TEAM_NAME': u'Hornets',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Bayless, Jerryd',
#   u'FROM_YEAR': u'2008',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201573,
#   u'PLAYERCODE': u'jerryd_bayless',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'MIL',
#   u'TEAM_CITY': u'Milwaukee',
#   u'TEAM_CODE': u'bucks',
#   u'TEAM_ID': 1610612749,
#   u'TEAM_NAME': u'Bucks',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Baynes, Aron',
#   u'FROM_YEAR': u'2012',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203382,
#   u'PLAYERCODE': u'aron_baynes',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'DET',
#   u'TEAM_CITY': u'Detroit',
#   u'TEAM_CODE': u'pistons',
#   u'TEAM_ID': 1610612765,
#   u'TEAM_NAME': u'Pistons',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Bazemore, Kent',
#   u'FROM_YEAR': u'2012',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203145,
#   u'PLAYERCODE': u'kent_bazemore',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'ATL',
#   u'TEAM_CITY': u'Atlanta',
#   u'TEAM_CODE': u'hawks',
#   u'TEAM_ID': 1610612737,
#   u'TEAM_NAME': u'Hawks',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Beal, Bradley',
#   u'FROM_YEAR': u'2012',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203078,
#   u'PLAYERCODE': u'bradley_beal',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'WAS',
#   u'TEAM_CITY': u'Washington',
#   u'TEAM_CODE': u'wizards',
#   u'TEAM_ID': 1610612764,
#   u'TEAM_NAME': u'Wizards',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Belinelli, Marco',
#   u'FROM_YEAR': u'2007',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201158,
#   u'PLAYERCODE': u'marco_belinelli',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'SAC',
#   u'TEAM_CITY': u'Sacramento',
#   u'TEAM_CODE': u'kings',
#   u'TEAM_ID': 1610612758,
#   u'TEAM_NAME': u'Kings',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Bennett, Anthony',
#   u'FROM_YEAR': u'2013',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203461,
#   u'PLAYERCODE': u'anthony_bennett',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'TOR',
#   u'TEAM_CITY': u'Toronto',
#   u'TEAM_CODE': u'raptors',
#   u'TEAM_ID': 1610612761,
#   u'TEAM_NAME': u'Raptors',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Beverley, Patrick',
#   u'FROM_YEAR': u'2012',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201976,
#   u'PLAYERCODE': u'patrick_beverley',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'HOU',
#   u'TEAM_CITY': u'Houston',
#   u'TEAM_CODE': u'rockets',
#   u'TEAM_ID': 1610612745,
#   u'TEAM_NAME': u'Rockets',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Biyombo, Bismack',
#   u'FROM_YEAR': u'2011',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 202687,
#   u'PLAYERCODE': u'bismack_biyombo',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'TOR',
#   u'TEAM_CITY': u'Toronto',
#   u'TEAM_CODE': u'raptors',
#   u'TEAM_ID': 1610612761,
#   u'TEAM_NAME': u'Raptors',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Bjelica, Nemanja',
#   u'FROM_YEAR': u'2015',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 202357,
#   u'PLAYERCODE': u'nemanja_bjelica',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'MIN',
#   u'TEAM_CITY': u'Minnesota',
#   u'TEAM_CODE': u'timberwolves',
#   u'TEAM_ID': 1610612750,
#   u'TEAM_NAME': u'Timberwolves',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Black, Tarik',
#   u'FROM_YEAR': u'2014',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 204028,
#   u'PLAYERCODE': u'tarik_black',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'LAL',
#   u'TEAM_CITY': u'Los Angeles',
#   u'TEAM_CODE': u'lakers',
#   u'TEAM_ID': 1610612747,
#   u'TEAM_NAME': u'Lakers',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Blair, DeJuan',
#   u'FROM_YEAR': u'2009',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201971,
#   u'PLAYERCODE': u'dejuan_blair',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'WAS',
#   u'TEAM_CITY': u'Washington',
#   u'TEAM_CODE': u'wizards',
#   u'TEAM_ID': 1610612764,
#   u'TEAM_NAME': u'Wizards',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Blake, Steve',
#   u'FROM_YEAR': u'2003',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 2581,
#   u'PLAYERCODE': u'steve_blake',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'DET',
#   u'TEAM_CITY': u'Detroit',
#   u'TEAM_CODE': u'pistons',
#   u'TEAM_ID': 1610612765,
#   u'TEAM_NAME': u'Pistons',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Bledsoe, Eric',
#   u'FROM_YEAR': u'2010',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 202339,
#   u'PLAYERCODE': u'eric_bledsoe',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'PHX',
#   u'TEAM_CITY': u'Phoenix',
#   u'TEAM_CODE': u'suns',
#   u'TEAM_ID': 1610612756,
#   u'TEAM_NAME': u'Suns',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Bogdanovic, Bojan',
#   u'FROM_YEAR': u'2014',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 202711,
#   u'PLAYERCODE': u'bojan_bogdanovic',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'BKN',
#   u'TEAM_CITY': u'Brooklyn',
#   u'TEAM_CODE': u'nets',
#   u'TEAM_ID': 1610612751,
#   u'TEAM_NAME': u'Nets',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Bogut, Andrew',
#   u'FROM_YEAR': u'2005',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 101106,
#   u'PLAYERCODE': u'andrew_bogut',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_CITY': u'Golden State',
#   u'TEAM_CODE': u'warriors',
#   u'TEAM_ID': 1610612744,
#   u'TEAM_NAME': u'Warriors',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Bonner, Matt',
#   u'FROM_YEAR': u'2004',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 2588,
#   u'PLAYERCODE': u'matt_bonner',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'SAS',
#   u'TEAM_CITY': u'San Antonio',
#   u'TEAM_CODE': u'spurs',
#   u'TEAM_ID': 1610612759,
#   u'TEAM_NAME': u'Spurs',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Booker, Devin',
#   u'FROM_YEAR': u'2015',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 1626164,
#   u'PLAYERCODE': u'devin_booker',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'PHX',
#   u'TEAM_CITY': u'Phoenix',
#   u'TEAM_CODE': u'suns',
#   u'TEAM_ID': 1610612756,
#   u'TEAM_NAME': u'Suns',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Booker, Trevor',
#   u'FROM_YEAR': u'2010',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 202344,
#   u'PLAYERCODE': u'trevor_booker',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'UTA',
#   u'TEAM_CITY': u'Utah',
#   u'TEAM_CODE': u'jazz',
#   u'TEAM_ID': 1610612762,
#   u'TEAM_NAME': u'Jazz',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Bosh, Chris',
#   u'FROM_YEAR': u'2003',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 2547,
#   u'PLAYERCODE': u'chris_bosh',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'MIA',
#   u'TEAM_CITY': u'Miami',
#   u'TEAM_CODE': u'heat',
#   u'TEAM_ID': 1610612748,
#   u'TEAM_NAME': u'Heat',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Bradley, Avery',
#   u'FROM_YEAR': u'2010',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 202340,
#   u'PLAYERCODE': u'avery_bradley',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'BOS',
#   u'TEAM_CITY': u'Boston',
#   u'TEAM_CODE': u'celtics',
#   u'TEAM_ID': 1610612738,
#   u'TEAM_NAME': u'Celtics',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Brand, Elton',
#   u'FROM_YEAR': u'1999',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 1882,
#   u'PLAYERCODE': u'elton_brand',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'PHI',
#   u'TEAM_CITY': u'Philadelphia',
#   u'TEAM_CODE': u'sixers',
#   u'TEAM_ID': 1610612755,
#   u'TEAM_NAME': u'76ers',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Brewer, Corey',
#   u'FROM_YEAR': u'2007',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201147,
#   u'PLAYERCODE': u'corey_brewer',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'HOU',
#   u'TEAM_CITY': u'Houston',
#   u'TEAM_CODE': u'rockets',
#   u'TEAM_ID': 1610612745,
#   u'TEAM_NAME': u'Rockets',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Brooks, Aaron',
#   u'FROM_YEAR': u'2007',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201166,
#   u'PLAYERCODE': u'aaron_brooks',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'CHI',
#   u'TEAM_CITY': u'Chicago',
#   u'TEAM_CODE': u'bulls',
#   u'TEAM_ID': 1610612741,
#   u'TEAM_NAME': u'Bulls',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Brown, Anthony',
#   u'FROM_YEAR': u'2015',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 1626148,
#   u'PLAYERCODE': u'anthony_brown',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'LAL',
#   u'TEAM_CITY': u'Los Angeles',
#   u'TEAM_CODE': u'lakers',
#   u'TEAM_ID': 1610612747,
#   u'TEAM_NAME': u'Lakers',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Brown, Lorenzo',
#   u'FROM_YEAR': u'2013',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203485,
#   u'PLAYERCODE': u'lorenzo_brown',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'PHX',
#   u'TEAM_CITY': u'Phoenix',
#   u'TEAM_CODE': u'suns',
#   u'TEAM_ID': 1610612756,
#   u'TEAM_NAME': u'Suns',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Brown, Markel',
#   u'FROM_YEAR': u'2014',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203900,
#   u'PLAYERCODE': u'markel_brown',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'BKN',
#   u'TEAM_CITY': u'Brooklyn',
#   u'TEAM_CODE': u'nets',
#   u'TEAM_ID': 1610612751,
#   u'TEAM_NAME': u'Nets',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Bryant, Kobe',
#   u'FROM_YEAR': u'1996',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 977,
#   u'PLAYERCODE': u'kobe_bryant',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'LAL',
#   u'TEAM_CITY': u'Los Angeles',
#   u'TEAM_CODE': u'lakers',
#   u'TEAM_ID': 1610612747,
#   u'TEAM_NAME': u'Lakers',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Budinger, Chase',
#   u'FROM_YEAR': u'2009',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201978,
#   u'PLAYERCODE': u'chase_budinger',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'IND',
#   u'TEAM_CITY': u'Indiana',
#   u'TEAM_CODE': u'pacers',
#   u'TEAM_ID': 1610612754,
#   u'TEAM_NAME': u'Pacers',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Bullock, Reggie',
#   u'FROM_YEAR': u'2013',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203493,
#   u'PLAYERCODE': u'reggie_bullock',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'DET',
#   u'TEAM_CITY': u'Detroit',
#   u'TEAM_CODE': u'pistons',
#   u'TEAM_ID': 1610612765,
#   u'TEAM_NAME': u'Pistons',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Burke, Trey',
#   u'FROM_YEAR': u'2013',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203504,
#   u'PLAYERCODE': u'trey_burke',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'UTA',
#   u'TEAM_CITY': u'Utah',
#   u'TEAM_CODE': u'jazz',
#   u'TEAM_ID': 1610612762,
#   u'TEAM_NAME': u'Jazz',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Burks, Alec',
#   u'FROM_YEAR': u'2011',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 202692,
#   u'PLAYERCODE': u'alec_burks',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'UTA',
#   u'TEAM_CITY': u'Utah',
#   u'TEAM_CODE': u'jazz',
#   u'TEAM_ID': 1610612762,
#   u'TEAM_NAME': u'Jazz',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Butler, Caron',
#   u'FROM_YEAR': u'2002',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 2406,
#   u'PLAYERCODE': u'caron_butler',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'SAC',
#   u'TEAM_CITY': u'Sacramento',
#   u'TEAM_CODE': u'kings',
#   u'TEAM_ID': 1610612758,
#   u'TEAM_NAME': u'Kings',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Butler, Jimmy',
#   u'FROM_YEAR': u'2011',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 202710,
#   u'PLAYERCODE': u'jimmy_butler',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'CHI',
#   u'TEAM_CITY': u'Chicago',
#   u'TEAM_CODE': u'bulls',
#   u'TEAM_ID': 1610612741,
#   u'TEAM_NAME': u'Bulls',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Butler, Rasual',
#   u'FROM_YEAR': u'2002',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 2446,
#   u'PLAYERCODE': u'rasual_butler',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'SAS',
#   u'TEAM_CITY': u'San Antonio',
#   u'TEAM_CODE': u'spurs',
#   u'TEAM_ID': 1610612759,
#   u'TEAM_NAME': u'Spurs',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Caboclo, Bruno',
#   u'FROM_YEAR': u'2014',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203998,
#   u'PLAYERCODE': u'bruno_caboclo',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'TOR',
#   u'TEAM_CITY': u'Toronto',
#   u'TEAM_CODE': u'raptors',
#   u'TEAM_ID': 1610612761,
#   u'TEAM_NAME': u'Raptors',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Calderon, Jose',
#   u'FROM_YEAR': u'2005',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 101181,
#   u'PLAYERCODE': u'jose_calderon',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'NYK',
#   u'TEAM_CITY': u'New York',
#   u'TEAM_CODE': u'knicks',
#   u'TEAM_ID': 1610612752,
#   u'TEAM_NAME': u'Knicks',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Caldwell-Pope, Kentavious',
#   u'FROM_YEAR': u'2013',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203484,
#   u'PLAYERCODE': u'kentavious_caldwell-pope',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'DET',
#   u'TEAM_CITY': u'Detroit',
#   u'TEAM_CODE': u'pistons',
#   u'TEAM_ID': 1610612765,
#   u'TEAM_NAME': u'Pistons',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Canaan, Isaiah',
#   u'FROM_YEAR': u'2013',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203477,
#   u'PLAYERCODE': u'isaiah_canaan',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'PHI',
#   u'TEAM_CITY': u'Philadelphia',
#   u'TEAM_CODE': u'sixers',
#   u'TEAM_ID': 1610612755,
#   u'TEAM_NAME': u'76ers',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Capela, Clint',
#   u'FROM_YEAR': u'2014',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203991,
#   u'PLAYERCODE': u'clint_capela',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'HOU',
#   u'TEAM_CITY': u'Houston',
#   u'TEAM_CODE': u'rockets',
#   u'TEAM_ID': 1610612745,
#   u'TEAM_NAME': u'Rockets',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Carroll, DeMarre',
#   u'FROM_YEAR': u'2009',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201960,
#   u'PLAYERCODE': u'demarre_carroll',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'TOR',
#   u'TEAM_CITY': u'Toronto',
#   u'TEAM_CODE': u'raptors',
#   u'TEAM_ID': 1610612761,
#   u'TEAM_NAME': u'Raptors',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Carter, Vince',
#   u'FROM_YEAR': u'1998',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 1713,
#   u'PLAYERCODE': u'vince_carter',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'MEM',
#   u'TEAM_CITY': u'Memphis',
#   u'TEAM_CODE': u'grizzlies',
#   u'TEAM_ID': 1610612763,
#   u'TEAM_NAME': u'Grizzlies',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Carter-Williams, Michael',
#   u'FROM_YEAR': u'2013',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203487,
#   u'PLAYERCODE': u'michael_carter-williams',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'MIL',
#   u'TEAM_CITY': u'Milwaukee',
#   u'TEAM_CODE': u'bucks',
#   u'TEAM_ID': 1610612749,
#   u'TEAM_NAME': u'Bucks',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Casspi, Omri',
#   u'FROM_YEAR': u'2009',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201956,
#   u'PLAYERCODE': u'omri_casspi',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'SAC',
#   u'TEAM_CITY': u'Sacramento',
#   u'TEAM_CODE': u'kings',
#   u'TEAM_ID': 1610612758,
#   u'TEAM_NAME': u'Kings',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Cauley-Stein, Willie',
#   u'FROM_YEAR': u'2015',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 1626161,
#   u'PLAYERCODE': u'willie_cauley-stein',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'SAC',
#   u'TEAM_CITY': u'Sacramento',
#   u'TEAM_CODE': u'kings',
#   u'TEAM_ID': 1610612758,
#   u'TEAM_NAME': u'Kings',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Chalmers, Mario',
#   u'FROM_YEAR': u'2008',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201596,
#   u'PLAYERCODE': u'mario_chalmers',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'MEM',
#   u'TEAM_CITY': u'Memphis',
#   u'TEAM_CODE': u'grizzlies',
#   u'TEAM_ID': 1610612763,
#   u'TEAM_NAME': u'Grizzlies',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Chandler, Tyson',
#   u'FROM_YEAR': u'2001',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 2199,
#   u'PLAYERCODE': u'tyson_chandler',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'PHX',
#   u'TEAM_CITY': u'Phoenix',
#   u'TEAM_CODE': u'suns',
#   u'TEAM_ID': 1610612756,
#   u'TEAM_NAME': u'Suns',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Chandler, Wilson',
#   u'FROM_YEAR': u'2007',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201163,
#   u'PLAYERCODE': u'wilson_chandler',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'DEN',
#   u'TEAM_CITY': u'Denver',
#   u'TEAM_CODE': u'nuggets',
#   u'TEAM_ID': 1610612743,
#   u'TEAM_NAME': u'Nuggets',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Christmas, Rakeem',
#   u'FROM_YEAR': u'2015',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 1626176,
#   u'PLAYERCODE': u'rakeem_christmas',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'IND',
#   u'TEAM_CITY': u'Indiana',
#   u'TEAM_CODE': u'pacers',
#   u'TEAM_ID': 1610612754,
#   u'TEAM_NAME': u'Pacers',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Clark, Ian',
#   u'FROM_YEAR': u'2013',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203546,
#   u'PLAYERCODE': u'ian_clark',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_CITY': u'Golden State',
#   u'TEAM_CODE': u'warriors',
#   u'TEAM_ID': 1610612744,
#   u'TEAM_NAME': u'Warriors',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Clarkson, Jordan',
#   u'FROM_YEAR': u'2014',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203903,
#   u'PLAYERCODE': u'jordan_clarkson',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'LAL',
#   u'TEAM_CITY': u'Los Angeles',
#   u'TEAM_CODE': u'lakers',
#   u'TEAM_ID': 1610612747,
#   u'TEAM_NAME': u'Lakers',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Cole, Norris',
#   u'FROM_YEAR': u'2011',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 202708,
#   u'PLAYERCODE': u'norris_cole',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'NOP',
#   u'TEAM_CITY': u'New Orleans',
#   u'TEAM_CODE': u'pelicans',
#   u'TEAM_ID': 1610612740,
#   u'TEAM_NAME': u'Pelicans',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Collison, Darren',
#   u'FROM_YEAR': u'2009',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201954,
#   u'PLAYERCODE': u'darren_collison',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'SAC',
#   u'TEAM_CITY': u'Sacramento',
#   u'TEAM_CODE': u'kings',
#   u'TEAM_ID': 1610612758,
#   u'TEAM_NAME': u'Kings',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Collison, Nick',
#   u'FROM_YEAR': u'2003',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 2555,
#   u'PLAYERCODE': u'nick_collison',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'OKC',
#   u'TEAM_CITY': u'Oklahoma City',
#   u'TEAM_CODE': u'thunder',
#   u'TEAM_ID': 1610612760,
#   u'TEAM_NAME': u'Thunder',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Conley, Mike',
#   u'FROM_YEAR': u'2007',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201144,
#   u'PLAYERCODE': u'mike_conley',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'MEM',
#   u'TEAM_CITY': u'Memphis',
#   u'TEAM_CODE': u'grizzlies',
#   u'TEAM_ID': 1610612763,
#   u'TEAM_NAME': u'Grizzlies',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Connaughton, Pat',
#   u'FROM_YEAR': u'2015',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 1626192,
#   u'PLAYERCODE': u'pat_connaughton',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'POR',
#   u'TEAM_CITY': u'Portland',
#   u'TEAM_CODE': u'blazers',
#   u'TEAM_ID': 1610612757,
#   u'TEAM_NAME': u'Trail Blazers',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Copeland, Chris',
#   u'FROM_YEAR': u'2012',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203142,
#   u'PLAYERCODE': u'chris_copeland',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'MIL',
#   u'TEAM_CITY': u'Milwaukee',
#   u'TEAM_CODE': u'bucks',
#   u'TEAM_ID': 1610612749,
#   u'TEAM_NAME': u'Bucks',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Cotton, Bryce',
#   u'FROM_YEAR': u'2014',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203955,
#   u'PLAYERCODE': u'bryce_cotton',
#   u'ROSTERSTATUS': 0,
#   u'TEAM_ABBREVIATION': u'',
#   u'TEAM_CITY': u'',
#   u'TEAM_CODE': u'',
#   u'TEAM_ID': 0,
#   u'TEAM_NAME': u'',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Cousins, DeMarcus',
#   u'FROM_YEAR': u'2010',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 202326,
#   u'PLAYERCODE': u'demarcus_cousins',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'SAC',
#   u'TEAM_CITY': u'Sacramento',
#   u'TEAM_CODE': u'kings',
#   u'TEAM_ID': 1610612758,
#   u'TEAM_NAME': u'Kings',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Covington, Robert',
#   u'FROM_YEAR': u'2013',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203496,
#   u'PLAYERCODE': u'robert_covington',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'PHI',
#   u'TEAM_CITY': u'Philadelphia',
#   u'TEAM_CODE': u'sixers',
#   u'TEAM_ID': 1610612755,
#   u'TEAM_NAME': u'76ers',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Crabbe, Allen',
#   u'FROM_YEAR': u'2013',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203459,
#   u'PLAYERCODE': u'allen_crabbe',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'POR',
#   u'TEAM_CITY': u'Portland',
#   u'TEAM_CODE': u'blazers',
#   u'TEAM_ID': 1610612757,
#   u'TEAM_NAME': u'Trail Blazers',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Crawford, Jamal',
#   u'FROM_YEAR': u'2000',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 2037,
#   u'PLAYERCODE': u'jamal_crawford',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'LAC',
#   u'TEAM_CITY': u'Los Angeles',
#   u'TEAM_CODE': u'clippers',
#   u'TEAM_ID': 1610612746,
#   u'TEAM_NAME': u'Clippers',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Crowder, Jae',
#   u'FROM_YEAR': u'2012',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203109,
#   u'PLAYERCODE': u'jae_crowder',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'BOS',
#   u'TEAM_CITY': u'Boston',
#   u'TEAM_CODE': u'celtics',
#   u'TEAM_ID': 1610612738,
#   u'TEAM_NAME': u'Celtics',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Cunningham, Dante',
#   u'FROM_YEAR': u'2009',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201967,
#   u'PLAYERCODE': u'dante_cunningham',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'NOP',
#   u'TEAM_CITY': u'New Orleans',
#   u'TEAM_CODE': u'pelicans',
#   u'TEAM_ID': 1610612740,
#   u'TEAM_NAME': u'Pelicans',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Cunningham, Jared',
#   u'FROM_YEAR': u'2012',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203099,
#   u'PLAYERCODE': u'jared_cunningham',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'CLE',
#   u'TEAM_CITY': u'Cleveland',
#   u'TEAM_CODE': u'cavaliers',
#   u'TEAM_ID': 1610612739,
#   u'TEAM_NAME': u'Cavaliers',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Curry, Seth',
#   u'FROM_YEAR': u'2013',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203552,
#   u'PLAYERCODE': u'seth_curry',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'SAC',
#   u'TEAM_CITY': u'Sacramento',
#   u'TEAM_CODE': u'kings',
#   u'TEAM_ID': 1610612758,
#   u'TEAM_NAME': u'Kings',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Curry, Stephen',
#   u'FROM_YEAR': u'2009',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201939,
#   u'PLAYERCODE': u'stephen_curry',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_CITY': u'Golden State',
#   u'TEAM_CODE': u'warriors',
#   u'TEAM_ID': 1610612744,
#   u'TEAM_NAME': u'Warriors',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Daniels, Troy',
#   u'FROM_YEAR': u'2013',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203584,
#   u'PLAYERCODE': u'troy_daniels',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'CHA',
#   u'TEAM_CITY': u'Charlotte',
#   u'TEAM_CODE': u'hornets',
#   u'TEAM_ID': 1610612766,
#   u'TEAM_NAME': u'Hornets',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Davis, Anthony',
#   u'FROM_YEAR': u'2012',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203076,
#   u'PLAYERCODE': u'anthony_davis',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'NOP',
#   u'TEAM_CITY': u'New Orleans',
#   u'TEAM_CODE': u'pelicans',
#   u'TEAM_ID': 1610612740,
#   u'TEAM_NAME': u'Pelicans',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Davis, Ed',
#   u'FROM_YEAR': u'2010',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 202334,
#   u'PLAYERCODE': u'ed_davis',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'POR',
#   u'TEAM_CITY': u'Portland',
#   u'TEAM_CODE': u'blazers',
#   u'TEAM_ID': 1610612757,
#   u'TEAM_NAME': u'Trail Blazers',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Dawson, Branden',
#   u'FROM_YEAR': u'2015',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 1626183,
#   u'PLAYERCODE': u'branden_dawson',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'LAC',
#   u'TEAM_CITY': u'Los Angeles',
#   u'TEAM_CODE': u'clippers',
#   u'TEAM_ID': 1610612746,
#   u'TEAM_NAME': u'Clippers',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'DeRozan, DeMar',
#   u'FROM_YEAR': u'2009',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201942,
#   u'PLAYERCODE': u'demar_derozan',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'TOR',
#   u'TEAM_CITY': u'Toronto',
#   u'TEAM_CODE': u'raptors',
#   u'TEAM_ID': 1610612761,
#   u'TEAM_NAME': u'Raptors',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Dedmon, Dewayne',
#   u'FROM_YEAR': u'2013',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203473,
#   u'PLAYERCODE': u'dewayne_dedmon',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'ORL',
#   u'TEAM_CITY': u'Orlando',
#   u'TEAM_CODE': u'magic',
#   u'TEAM_ID': 1610612753,
#   u'TEAM_NAME': u'Magic',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Dejean-Jones, Bryce',
#   u'FROM_YEAR': u'2015',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 1626214,
#   u'PLAYERCODE': u'bryce_dejean-jones',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'NOP',
#   u'TEAM_CITY': u'New Orleans',
#   u'TEAM_CODE': u'pelicans',
#   u'TEAM_ID': 1610612740,
#   u'TEAM_NAME': u'Pelicans',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Dekker, Sam',
#   u'FROM_YEAR': u'2015',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 1626155,
#   u'PLAYERCODE': u'sam_dekker',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'HOU',
#   u'TEAM_CITY': u'Houston',
#   u'TEAM_CODE': u'rockets',
#   u'TEAM_ID': 1610612745,
#   u'TEAM_NAME': u'Rockets',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Dellavedova, Matthew',
#   u'FROM_YEAR': u'2013',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203521,
#   u'PLAYERCODE': u'matthew_dellavedova',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'CLE',
#   u'TEAM_CITY': u'Cleveland',
#   u'TEAM_CODE': u'cavaliers',
#   u'TEAM_ID': 1610612739,
#   u'TEAM_NAME': u'Cavaliers',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Deng, Luol',
#   u'FROM_YEAR': u'2004',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 2736,
#   u'PLAYERCODE': u'luol_deng',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'MIA',
#   u'TEAM_CITY': u'Miami',
#   u'TEAM_CODE': u'heat',
#   u'TEAM_ID': 1610612748,
#   u'TEAM_NAME': u'Heat',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Diaw, Boris',
#   u'FROM_YEAR': u'2003',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 2564,
#   u'PLAYERCODE': u'boris_diaw',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'SAS',
#   u'TEAM_CITY': u'San Antonio',
#   u'TEAM_CODE': u'spurs',
#   u'TEAM_ID': 1610612759,
#   u'TEAM_NAME': u'Spurs',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Dieng, Gorgui',
#   u'FROM_YEAR': u'2013',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203476,
#   u'PLAYERCODE': u'gorgui_dieng',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'MIN',
#   u'TEAM_CITY': u'Minnesota',
#   u'TEAM_CODE': u'timberwolves',
#   u'TEAM_ID': 1610612750,
#   u'TEAM_NAME': u'Timberwolves',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Dinwiddie, Spencer',
#   u'FROM_YEAR': u'2014',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203915,
#   u'PLAYERCODE': u'spencer_dinwiddie',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'DET',
#   u'TEAM_CITY': u'Detroit',
#   u'TEAM_CODE': u'pistons',
#   u'TEAM_ID': 1610612765,
#   u'TEAM_NAME': u'Pistons',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Douglas, Toney',
#   u'FROM_YEAR': u'2009',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201962,
#   u'PLAYERCODE': u'toney_douglas',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'NOP',
#   u'TEAM_CITY': u'New Orleans',
#   u'TEAM_CODE': u'pelicans',
#   u'TEAM_ID': 1610612740,
#   u'TEAM_NAME': u'Pelicans',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Dragic, Goran',
#   u'FROM_YEAR': u'2008',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201609,
#   u'PLAYERCODE': u'goran_dragic',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'MIA',
#   u'TEAM_CITY': u'Miami',
#   u'TEAM_CODE': u'heat',
#   u'TEAM_ID': 1610612748,
#   u'TEAM_NAME': u'Heat',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Drummond, Andre',
#   u'FROM_YEAR': u'2012',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203083,
#   u'PLAYERCODE': u'andre_drummond',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'DET',
#   u'TEAM_CITY': u'Detroit',
#   u'TEAM_CODE': u'pistons',
#   u'TEAM_ID': 1610612765,
#   u'TEAM_NAME': u'Pistons',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Dudley, Jared',
#   u'FROM_YEAR': u'2007',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201162,
#   u'PLAYERCODE': u'jared_dudley',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'WAS',
#   u'TEAM_CITY': u'Washington',
#   u'TEAM_CODE': u'wizards',
#   u'TEAM_ID': 1610612764,
#   u'TEAM_NAME': u'Wizards',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Dukan, Duje',
#   u'FROM_YEAR': u'2015',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 1626251,
#   u'PLAYERCODE': u'duje_dukan',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'SAC',
#   u'TEAM_CITY': u'Sacramento',
#   u'TEAM_CODE': u'kings',
#   u'TEAM_ID': 1610612758,
#   u'TEAM_NAME': u'Kings',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Duncan, Tim',
#   u'FROM_YEAR': u'1997',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 1495,
#   u'PLAYERCODE': u'tim_duncan',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'SAS',
#   u'TEAM_CITY': u'San Antonio',
#   u'TEAM_CODE': u'spurs',
#   u'TEAM_ID': 1610612759,
#   u'TEAM_NAME': u'Spurs',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Dunleavy, Mike',
#   u'FROM_YEAR': u'2002',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 2399,
#   u'PLAYERCODE': u'mike_dunleavy',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'CHI',
#   u'TEAM_CITY': u'Chicago',
#   u'TEAM_CODE': u'bulls',
#   u'TEAM_ID': 1610612741,
#   u'TEAM_NAME': u'Bulls',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Durant, Kevin',
#   u'FROM_YEAR': u'2007',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201142,
#   u'PLAYERCODE': u'kevin_durant',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'OKC',
#   u'TEAM_CITY': u'Oklahoma City',
#   u'TEAM_CODE': u'thunder',
#   u'TEAM_ID': 1610612760,
#   u'TEAM_NAME': u'Thunder',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Early, Cleanthony',
#   u'FROM_YEAR': u'2014',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203921,
#   u'PLAYERCODE': u'cleanthony_early',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'NYK',
#   u'TEAM_CITY': u'New York',
#   u'TEAM_CODE': u'knicks',
#   u'TEAM_ID': 1610612752,
#   u'TEAM_NAME': u'Knicks',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Eddie, Jarell',
#   u'FROM_YEAR': u'2015',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 204067,
#   u'PLAYERCODE': u'jarell_eddie',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'WAS',
#   u'TEAM_CITY': u'Washington',
#   u'TEAM_CODE': u'wizards',
#   u'TEAM_ID': 1610612764,
#   u'TEAM_NAME': u'Wizards',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Ellington, Wayne',
#   u'FROM_YEAR': u'2009',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201961,
#   u'PLAYERCODE': u'wayne_ellington',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'BKN',
#   u'TEAM_CITY': u'Brooklyn',
#   u'TEAM_CODE': u'nets',
#   u'TEAM_ID': 1610612751,
#   u'TEAM_NAME': u'Nets',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Ellis, Monta',
#   u'FROM_YEAR': u'2005',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 101145,
#   u'PLAYERCODE': u'monta_ellis',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'IND',
#   u'TEAM_CITY': u'Indiana',
#   u'TEAM_CODE': u'pacers',
#   u'TEAM_ID': 1610612754,
#   u'TEAM_NAME': u'Pacers',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Embiid, Joel',
#   u'FROM_YEAR': u'2014',
#   u'GAMES_PLAYED_FLAG': u'N',
#   u'PERSON_ID': 203954,
#   u'PLAYERCODE': u'joel_embiid',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'PHI',
#   u'TEAM_CITY': u'Philadelphia',
#   u'TEAM_CODE': u'sixers',
#   u'TEAM_ID': 1610612755,
#   u'TEAM_NAME': u'76ers',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Ennis, James',
#   u'FROM_YEAR': u'2014',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203516,
#   u'PLAYERCODE': u'james_ennis',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'MEM',
#   u'TEAM_CITY': u'Memphis',
#   u'TEAM_CODE': u'grizzlies',
#   u'TEAM_ID': 1610612763,
#   u'TEAM_NAME': u'Grizzlies',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Ennis, Tyler',
#   u'FROM_YEAR': u'2014',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203898,
#   u'PLAYERCODE': u'tyler_ennis',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'MIL',
#   u'TEAM_CITY': u'Milwaukee',
#   u'TEAM_CODE': u'bucks',
#   u'TEAM_ID': 1610612749,
#   u'TEAM_NAME': u'Bucks',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Evans, Jeremy',
#   u'FROM_YEAR': u'2010',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 202379,
#   u'PLAYERCODE': u'jeremy_evans',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'DAL',
#   u'TEAM_CITY': u'Dallas',
#   u'TEAM_CODE': u'mavericks',
#   u'TEAM_ID': 1610612742,
#   u'TEAM_NAME': u'Mavericks',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Evans, Tyreke',
#   u'FROM_YEAR': u'2009',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201936,
#   u'PLAYERCODE': u'tyreke_evans',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'NOP',
#   u'TEAM_CITY': u'New Orleans',
#   u'TEAM_CODE': u'pelicans',
#   u'TEAM_ID': 1610612740,
#   u'TEAM_NAME': u'Pelicans',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Exum, Dante',
#   u'FROM_YEAR': u'2014',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203957,
#   u'PLAYERCODE': u'dante_exum',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'UTA',
#   u'TEAM_CITY': u'Utah',
#   u'TEAM_CODE': u'jazz',
#   u'TEAM_ID': 1610612762,
#   u'TEAM_NAME': u'Jazz',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Ezeli, Festus',
#   u'FROM_YEAR': u'2012',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203105,
#   u'PLAYERCODE': u'festus_ezeli',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_CITY': u'Golden State',
#   u'TEAM_CODE': u'warriors',
#   u'TEAM_ID': 1610612744,
#   u'TEAM_NAME': u'Warriors',
#   u'TO_YEAR': u'2015'},
# ...
#   u'PLAYERCODE': u'anthony_tolliver',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'DET',
#   u'TEAM_CITY': u'Detroit',
#   u'TEAM_CODE': u'pistons',
#   u'TEAM_ID': 1610612765,
#   u'TEAM_NAME': u'Pistons',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Towns, Karl-Anthony',
#   u'FROM_YEAR': u'2015',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 1626157,
#   u'PLAYERCODE': u'karl-anthony_towns',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'MIN',
#   u'TEAM_CITY': u'Minnesota',
#   u'TEAM_CODE': u'timberwolves',
#   u'TEAM_ID': 1610612750,
#   u'TEAM_NAME': u'Timberwolves',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Tucker, PJ',
#   u'FROM_YEAR': u'2006',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 200782,
#   u'PLAYERCODE': u'pj_tucker',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'PHX',
#   u'TEAM_CITY': u'Phoenix',
#   u'TEAM_CODE': u'suns',
#   u'TEAM_ID': 1610612756,
#   u'TEAM_NAME': u'Suns',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Turner, Evan',
#   u'FROM_YEAR': u'2010',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 202323,
#   u'PLAYERCODE': u'evan_turner',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'BOS',
#   u'TEAM_CITY': u'Boston',
#   u'TEAM_CODE': u'celtics',
#   u'TEAM_ID': 1610612738,
#   u'TEAM_NAME': u'Celtics',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Turner, Myles',
#   u'FROM_YEAR': u'2015',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 1626167,
#   u'PLAYERCODE': u'myles_turner',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'IND',
#   u'TEAM_CITY': u'Indiana',
#   u'TEAM_CODE': u'pacers',
#   u'TEAM_ID': 1610612754,
#   u'TEAM_NAME': u'Pacers',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Udrih, Beno',
#   u'FROM_YEAR': u'2004',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 2757,
#   u'PLAYERCODE': u'beno_udrih',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'MIA',
#   u'TEAM_CITY': u'Miami',
#   u'TEAM_CODE': u'heat',
#   u'TEAM_ID': 1610612748,
#   u'TEAM_NAME': u'Heat',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Valanciunas, Jonas',
#   u'FROM_YEAR': u'2012',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 202685,
#   u'PLAYERCODE': u'jonas_valanciunas',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'TOR',
#   u'TEAM_CITY': u'Toronto',
#   u'TEAM_CODE': u'raptors',
#   u'TEAM_ID': 1610612761,
#   u'TEAM_NAME': u'Raptors',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Varejao, Anderson',
#   u'FROM_YEAR': u'2004',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 2760,
#   u'PLAYERCODE': u'anderson_varejao',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'CLE',
#   u'TEAM_CITY': u'Cleveland',
#   u'TEAM_CODE': u'cavaliers',
#   u'TEAM_ID': 1610612739,
#   u'TEAM_NAME': u'Cavaliers',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Vasquez, Greivis',
#   u'FROM_YEAR': u'2010',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 202349,
#   u'PLAYERCODE': u'greivis_vasquez',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'MIL',
#   u'TEAM_CITY': u'Milwaukee',
#   u'TEAM_CODE': u'bucks',
#   u'TEAM_ID': 1610612749,
#   u'TEAM_NAME': u'Bucks',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Vaughn, Rashad',
#   u'FROM_YEAR': u'2015',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 1626173,
#   u'PLAYERCODE': u'rashad_vaughn',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'MIL',
#   u'TEAM_CITY': u'Milwaukee',
#   u'TEAM_CODE': u'bucks',
#   u'TEAM_ID': 1610612749,
#   u'TEAM_NAME': u'Bucks',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Villanueva, Charlie',
#   u'FROM_YEAR': u'2005',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 101111,
#   u'PLAYERCODE': u'charlie_villanueva',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'DAL',
#   u'TEAM_CITY': u'Dallas',
#   u'TEAM_CODE': u'mavericks',
#   u'TEAM_ID': 1610612742,
#   u'TEAM_NAME': u'Mavericks',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Vonleh, Noah',
#   u'FROM_YEAR': u'2014',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203943,
#   u'PLAYERCODE': u'noah_vonleh',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'POR',
#   u'TEAM_CITY': u'Portland',
#   u'TEAM_CODE': u'blazers',
#   u'TEAM_ID': 1610612757,
#   u'TEAM_NAME': u'Trail Blazers',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Vucevic, Nikola',
#   u'FROM_YEAR': u'2011',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 202696,
#   u'PLAYERCODE': u'nikola_vucevic',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'ORL',
#   u'TEAM_CITY': u'Orlando',
#   u'TEAM_CODE': u'magic',
#   u'TEAM_ID': 1610612753,
#   u'TEAM_NAME': u'Magic',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Vujacic, Sasha',
#   u'FROM_YEAR': u'2004',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 2756,
#   u'PLAYERCODE': u'sasha_vujacic',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'NYK',
#   u'TEAM_CITY': u'New York',
#   u'TEAM_CODE': u'knicks',
#   u'TEAM_ID': 1610612752,
#   u'TEAM_NAME': u'Knicks',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Wade, Dwyane',
#   u'FROM_YEAR': u'2003',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 2548,
#   u'PLAYERCODE': u'dwyane_wade',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'MIA',
#   u'TEAM_CITY': u'Miami',
#   u'TEAM_CODE': u'heat',
#   u'TEAM_ID': 1610612748,
#   u'TEAM_NAME': u'Heat',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Waiters, Dion',
#   u'FROM_YEAR': u'2012',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203079,
#   u'PLAYERCODE': u'dion_waiters',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'OKC',
#   u'TEAM_CITY': u'Oklahoma City',
#   u'TEAM_CODE': u'thunder',
#   u'TEAM_ID': 1610612760,
#   u'TEAM_NAME': u'Thunder',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Walker, Kemba',
#   u'FROM_YEAR': u'2011',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 202689,
#   u'PLAYERCODE': u'kemba_walker',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'CHA',
#   u'TEAM_CITY': u'Charlotte',
#   u'TEAM_CODE': u'hornets',
#   u'TEAM_ID': 1610612766,
#   u'TEAM_NAME': u'Hornets',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Wall, John',
#   u'FROM_YEAR': u'2010',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 202322,
#   u'PLAYERCODE': u'john_wall',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'WAS',
#   u'TEAM_CITY': u'Washington',
#   u'TEAM_CODE': u'wizards',
#   u'TEAM_ID': 1610612764,
#   u'TEAM_NAME': u'Wizards',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Warren, TJ',
#   u'FROM_YEAR': u'2014',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203933,
#   u'PLAYERCODE': u'tj_warren',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'PHX',
#   u'TEAM_CITY': u'Phoenix',
#   u'TEAM_CODE': u'suns',
#   u'TEAM_ID': 1610612756,
#   u'TEAM_NAME': u'Suns',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Watson, CJ',
#   u'FROM_YEAR': u'2007',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201228,
#   u'PLAYERCODE': u'cj_watson',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'ORL',
#   u'TEAM_CITY': u'Orlando',
#   u'TEAM_CODE': u'magic',
#   u'TEAM_ID': 1610612753,
#   u'TEAM_NAME': u'Magic',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Weems, Sonny',
#   u'FROM_YEAR': u'2008',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201603,
#   u'PLAYERCODE': u'sonny_weems',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'PHX',
#   u'TEAM_CITY': u'Phoenix',
#   u'TEAM_CODE': u'suns',
#   u'TEAM_ID': 1610612756,
#   u'TEAM_NAME': u'Suns',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'West, David',
#   u'FROM_YEAR': u'2003',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 2561,
#   u'PLAYERCODE': u'david_west',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'SAS',
#   u'TEAM_CITY': u'San Antonio',
#   u'TEAM_CODE': u'spurs',
#   u'TEAM_ID': 1610612759,
#   u'TEAM_NAME': u'Spurs',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Westbrook, Russell',
#   u'FROM_YEAR': u'2008',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201566,
#   u'PLAYERCODE': u'russell_westbrook',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'OKC',
#   u'TEAM_CITY': u'Oklahoma City',
#   u'TEAM_CODE': u'thunder',
#   u'TEAM_ID': 1610612760,
#   u'TEAM_NAME': u'Thunder',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Whiteside, Hassan',
#   u'FROM_YEAR': u'2010',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 202355,
#   u'PLAYERCODE': u'hassan_whiteside',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'MIA',
#   u'TEAM_CITY': u'Miami',
#   u'TEAM_CODE': u'heat',
#   u'TEAM_ID': 1610612748,
#   u'TEAM_NAME': u'Heat',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Whittington, Shayne',
#   u'FROM_YEAR': u'2014',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203963,
#   u'PLAYERCODE': u'shayne_whittington',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'IND',
#   u'TEAM_CITY': u'Indiana',
#   u'TEAM_CODE': u'pacers',
#   u'TEAM_ID': 1610612754,
#   u'TEAM_NAME': u'Pacers',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Wiggins, Andrew',
#   u'FROM_YEAR': u'2014',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203952,
#   u'PLAYERCODE': u'andrew_wiggins',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'MIN',
#   u'TEAM_CITY': u'Minnesota',
#   u'TEAM_CODE': u'timberwolves',
#   u'TEAM_ID': 1610612750,
#   u'TEAM_NAME': u'Timberwolves',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Wilcox, CJ',
#   u'FROM_YEAR': u'2014',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203912,
#   u'PLAYERCODE': u'cj_wilcox',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'LAC',
#   u'TEAM_CITY': u'Los Angeles',
#   u'TEAM_CODE': u'clippers',
#   u'TEAM_ID': 1610612746,
#   u'TEAM_NAME': u'Clippers',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Williams, Deron',
#   u'FROM_YEAR': u'2005',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 101114,
#   u'PLAYERCODE': u'deron_williams',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'DAL',
#   u'TEAM_CITY': u'Dallas',
#   u'TEAM_CODE': u'mavericks',
#   u'TEAM_ID': 1610612742,
#   u'TEAM_NAME': u'Mavericks',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Williams, Derrick',
#   u'FROM_YEAR': u'2011',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 202682,
#   u'PLAYERCODE': u'derrick_williams',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'NYK',
#   u'TEAM_CITY': u'New York',
#   u'TEAM_CODE': u'knicks',
#   u'TEAM_ID': 1610612752,
#   u'TEAM_NAME': u'Knicks',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Williams, Elliot',
#   u'FROM_YEAR': u'2010',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 202343,
#   u'PLAYERCODE': u'elliot_williams',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'MEM',
#   u'TEAM_CITY': u'Memphis',
#   u'TEAM_CODE': u'grizzlies',
#   u'TEAM_ID': 1610612763,
#   u'TEAM_NAME': u'Grizzlies',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Williams, Lou',
#   u'FROM_YEAR': u'2005',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 101150,
#   u'PLAYERCODE': u'louis_williams',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'LAL',
#   u'TEAM_CITY': u'Los Angeles',
#   u'TEAM_CODE': u'lakers',
#   u'TEAM_ID': 1610612747,
#   u'TEAM_NAME': u'Lakers',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Williams, Marvin',
#   u'FROM_YEAR': u'2005',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 101107,
#   u'PLAYERCODE': u'marvin_williams',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'CHA',
#   u'TEAM_CITY': u'Charlotte',
#   u'TEAM_CODE': u'hornets',
#   u'TEAM_ID': 1610612766,
#   u'TEAM_NAME': u'Hornets',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Williams, Mo',
#   u'FROM_YEAR': u'2003',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 2590,
#   u'PLAYERCODE': u'maurice_williams',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'CLE',
#   u'TEAM_CITY': u'Cleveland',
#   u'TEAM_CODE': u'cavaliers',
#   u'TEAM_ID': 1610612739,
#   u'TEAM_NAME': u'Cavaliers',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Winslow, Justise',
#   u'FROM_YEAR': u'2015',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 1626159,
#   u'PLAYERCODE': u'justise_winslow',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'MIA',
#   u'TEAM_CITY': u'Miami',
#   u'TEAM_CODE': u'heat',
#   u'TEAM_ID': 1610612748,
#   u'TEAM_NAME': u'Heat',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Withey, Jeff',
#   u'FROM_YEAR': u'2013',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203481,
#   u'PLAYERCODE': u'jeff_withey',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'UTA',
#   u'TEAM_CITY': u'Utah',
#   u'TEAM_CODE': u'jazz',
#   u'TEAM_ID': 1610612762,
#   u'TEAM_NAME': u'Jazz',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Wood, Christian',
#   u'FROM_YEAR': u'2015',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 1626174,
#   u'PLAYERCODE': u'christian_wood',
#   u'ROSTERSTATUS': 0,
#   u'TEAM_ABBREVIATION': u'',
#   u'TEAM_CITY': u'',
#   u'TEAM_CODE': u'',
#   u'TEAM_ID': 0,
#   u'TEAM_NAME': u'',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'World Peace, Metta',
#   u'FROM_YEAR': u'1999',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 1897,
#   u'PLAYERCODE': u'metta_world_peace',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'LAL',
#   u'TEAM_CITY': u'Los Angeles',
#   u'TEAM_CODE': u'lakers',
#   u'TEAM_ID': 1610612747,
#   u'TEAM_NAME': u'Lakers',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Wright, Brandan',
#   u'FROM_YEAR': u'2007',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201148,
#   u'PLAYERCODE': u'brandan_wright',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'MEM',
#   u'TEAM_CITY': u'Memphis',
#   u'TEAM_CODE': u'grizzlies',
#   u'TEAM_ID': 1610612763,
#   u'TEAM_NAME': u'Grizzlies',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Wright, Delon',
#   u'FROM_YEAR': u'2015',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 1626153,
#   u'PLAYERCODE': u'delon_wright',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'TOR',
#   u'TEAM_CITY': u'Toronto',
#   u'TEAM_CODE': u'raptors',
#   u'TEAM_ID': 1610612761,
#   u'TEAM_NAME': u'Raptors',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Wroten, Tony',
#   u'FROM_YEAR': u'2012',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203100,
#   u'PLAYERCODE': u'tony_wroten',
#   u'ROSTERSTATUS': 0,
#   u'TEAM_ABBREVIATION': u'',
#   u'TEAM_CITY': u'',
#   u'TEAM_CODE': u'',
#   u'TEAM_ID': 0,
#   u'TEAM_NAME': u'',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Young, James',
#   u'FROM_YEAR': u'2014',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203923,
#   u'PLAYERCODE': u'james_young',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'BOS',
#   u'TEAM_CITY': u'Boston',
#   u'TEAM_CODE': u'celtics',
#   u'TEAM_ID': 1610612738,
#   u'TEAM_NAME': u'Celtics',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Young, Joe',
#   u'FROM_YEAR': u'2015',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 1626202,
#   u'PLAYERCODE': u'joe_young',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'IND',
#   u'TEAM_CITY': u'Indiana',
#   u'TEAM_CODE': u'pacers',
#   u'TEAM_ID': 1610612754,
#   u'TEAM_NAME': u'Pacers',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Young, Nick',
#   u'FROM_YEAR': u'2007',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201156,
#   u'PLAYERCODE': u'nick_young',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'LAL',
#   u'TEAM_CITY': u'Los Angeles',
#   u'TEAM_CODE': u'lakers',
#   u'TEAM_ID': 1610612747,
#   u'TEAM_NAME': u'Lakers',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Young, Thaddeus',
#   u'FROM_YEAR': u'2007',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 201152,
#   u'PLAYERCODE': u'thaddeus_young',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'BKN',
#   u'TEAM_CITY': u'Brooklyn',
#   u'TEAM_CODE': u'nets',
#   u'TEAM_ID': 1610612751,
#   u'TEAM_NAME': u'Nets',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Zeller, Cody',
#   u'FROM_YEAR': u'2013',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203469,
#   u'PLAYERCODE': u'cody_zeller',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'CHA',
#   u'TEAM_CITY': u'Charlotte',
#   u'TEAM_CODE': u'hornets',
#   u'TEAM_ID': 1610612766,
#   u'TEAM_NAME': u'Hornets',
#   u'TO_YEAR': u'2015'},
#  {u'DISPLAY_LAST_COMMA_FIRST': u'Zeller, Tyler',
#   u'FROM_YEAR': u'2012',
#   u'GAMES_PLAYED_FLAG': u'Y',
#   u'PERSON_ID': 203092,
#   u'PLAYERCODE': u'tyler_zeller',
#   u'ROSTERSTATUS': 1,
#   u'TEAM_ABBREVIATION': u'BOS',
#   u'TEAM_CITY': u'Boston',
#   u'TEAM_CODE': u'celtics',
#   u'TEAM_ID': 1610612738,
#   u'TEAM_NAME': u'Celtics',
#   u'TO_YEAR': u'2015'}]

# %% [markdown]
# ## Playerstats
#
# http://stats.nba.com/stats/leaguedashplayerstats?DateFrom=&DateTo=&GameScope=&GameSegment=&LastNGames=0&LeagueID=00&Location=&MeasureType=Base&Month=0&OpponentTeamID=0&Outcome=&PaceAdjust=N&PerMode=Totals&Period=0&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season=2015-16&SeasonSegment=&SeasonType=Regular+Season&StarterBench=&VsConference=&VsDivision=

# %%
stats = parser.playerstats(scraper.playerstats(season='2015-16'))

# %%
stats
# Out:
# [{u'AGE': 31.0,
#   u'AST': 84,
#   u'BLK': 6,
#   u'BLKA': 17,
#   u'CFID': 5,
#   u'CFPARAMS': u'201166,1610612741',
#   u'DD2': 0,
#   u'DREB': 52,
#   u'FG3A': 105,
#   u'FG3M': 40,
#   u'FG3_PCT': 0.381,
#   u'FGA': 247,
#   u'FGM': 102,
#   u'FG_PCT': 0.413,
#   u'FTA': 34,
#   u'FTM': 28,
#   u'FT_PCT': 0.824,
#   u'GP': 35,
#   u'L': 14,
#   u'MIN': 573.1916666666667,
#   'MIN_PLAYED': 573.0,
#   u'OREB': 14,
#   u'PF': 73,
#   u'PFD': 41,
#   u'PLAYER_ID': 201166,
#   u'PLAYER_NAME': u'Aaron Brooks',
#   u'PLUS_MINUS': 61,
#   u'PTS': 272,
#   u'REB': 66,
#   'SEC_PLAYED': 0.19166666666671972,
#   u'STL': 11,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'CHI',
#   u'TEAM_ID': 1610612741,
#   u'TOV': 35,
#   u'W': 21,
#   u'W_PCT': 0.6},
#  {u'AGE': 20.0,
#   u'AST': 56,
#   u'BLK': 28,
#   u'BLKA': 13,
#   u'CFID': 5,
#   u'CFPARAMS': u'203932,1610612753',
#   u'DD2': 1,
#   u'DREB': 158,
#   u'FG3A': 65,
#   u'FG3M': 22,
#   u'FG3_PCT': 0.338,
#   u'FGA': 252,
#   u'FGM': 121,
#   u'FG_PCT': 0.48,
#   u'FTA': 92,
#   u'FTM': 65,
#   u'FT_PCT': 0.707,
#   u'GP': 44,
#   u'L': 25,
#   u'MIN': 893.02,
#   'MIN_PLAYED': 893.0,
#   u'OREB': 76,
#   u'PF': 80,
#   u'PFD': 75,
#   u'PLAYER_ID': 203932,
#   u'PLAYER_NAME': u'Aaron Gordon',
#   u'PLUS_MINUS': -71,
#   u'PTS': 329,
#   u'REB': 234,
#   'SEC_PLAYED': 0.01999999999998181,
#   u'STL': 25,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'ORL',
#   u'TEAM_ID': 1610612753,
#   u'TOV': 38,
#   u'W': 19,
#   u'W_PCT': 0.432},
#  {u'AGE': 21.0,
#   u'AST': 0,
#   u'BLK': 0,
#   u'BLKA': 0,
#   u'CFID': 5,
#   u'CFPARAMS': u'1626151,1610612766',
#   u'DD2': 0,
#   u'DREB': 5,
#   u'FG3A': 3,
#   u'FG3M': 1,
#   u'FG3_PCT': 0.333,
#   u'FGA': 8,
#   u'FGM': 2,
#   u'FG_PCT': 0.25,
#   u'FTA': 6,
#   u'FTM': 2,
#   u'FT_PCT': 0.333,
#   u'GP': 12,
#   u'L': 5,
#   u'MIN': 52.05,
#   'MIN_PLAYED': 52.0,
#   u'OREB': 3,
#   u'PF': 2,
#   u'PFD': 5,
#   u'PLAYER_ID': 1626151,
#   u'PLAYER_NAME': u'Aaron Harrison',
#   u'PLUS_MINUS': 5,
#   u'PTS': 7,
#   u'REB': 8,
#   'SEC_PLAYED': 0.04999999999999716,
#   u'STL': 3,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'CHA',
#   u'TEAM_ID': 1610612766,
#   u'TOV': 2,
#   u'W': 7,
#   u'W_PCT': 0.583},
#  {u'AGE': 24.0,
#   u'AST': 14,
#   u'BLK': 8,
#   u'BLKA': 6,
#   u'CFID': 5,
#   u'CFPARAMS': u'203940,1610612750',
#   u'DD2': 0,
#   u'DREB': 51,
#   u'FG3A': 21,
#   u'FG3M': 8,
#   u'FG3_PCT': 0.381,
#   u'FGA': 81,
#   u'FGM': 33,
#   u'FG_PCT': 0.407,
#   u'FTA': 12,
#   u'FTM': 8,
#   u'FT_PCT': 0.667,
#   u'GP': 30,
#   u'L': 19,
#   u'MIN': 285.46666666666664,
#   'MIN_PLAYED': 285.0,
#   u'OREB': 10,
#   u'PF': 46,
#   u'PFD': 18,
#   u'PLAYER_ID': 203940,
#   u'PLAYER_NAME': u'Adreian Payne',
#   u'PLUS_MINUS': -41,
#   u'PTS': 82,
#   u'REB': 61,
#   'SEC_PLAYED': 0.46666666666664014,
#   u'STL': 9,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'MIN',
#   u'TEAM_ID': 1610612750,
#   u'TOV': 19,
#   u'W': 11,
#   u'W_PCT': 0.367},
#  {u'AGE': 29.0,
#   u'AST': 145,
#   u'BLK': 70,
#   u'BLKA': 25,
#   u'CFID': 5,
#   u'CFPARAMS': u'201143,1610612737',
#   u'DD2': 10,
#   u'DREB': 238,
#   u'FG3A': 142,
#   u'FG3M': 45,
#   u'FG3_PCT': 0.317,
#   u'FGA': 623,
#   u'FGM': 312,
#   u'FG_PCT': 0.501,
#   u'FTA': 80,
#   u'FTM': 61,
#   u'FT_PCT': 0.763,
#   u'GP': 48,
#   u'L': 21,
#   u'MIN': 1513.995,
#   'MIN_PLAYED': 1513.0,
#   u'OREB': 102,
#   u'PF': 92,
#   u'PFD': 66,
#   u'PLAYER_ID': 201143,
#   u'PLAYER_NAME': u'Al Horford',
#   u'PLUS_MINUS': 61,
#   u'PTS': 730,
#   u'REB': 340,
#   'SEC_PLAYED': 0.9949999999998909,
#   u'STL': 41,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'ATL',
#   u'TEAM_ID': 1610612737,
#   u'TOV': 63,
#   u'W': 27,
#   u'W_PCT': 0.563},
#  {u'AGE': 31.0,
#   u'AST': 30,
#   u'BLK': 20,
#   u'BLKA': 15,
#   u'CFID': 5,
#   u'CFPARAMS': u'2744,1610612766',
#   u'DD2': 4,
#   u'DREB': 93,
#   u'FG3A': 0,
#   u'FG3M': 0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 222,
#   u'FGM': 107,
#   u'FG_PCT': 0.482,
#   u'FTA': 42,
#   u'FTM': 24,
#   u'FT_PCT': 0.571,
#   u'GP': 19,
#   u'L': 7,
#   u'MIN': 478.365,
#   'MIN_PLAYED': 478.0,
#   u'OREB': 23,
#   u'PF': 46,
#   u'PFD': 32,
#   u'PLAYER_ID': 2744,
#   u'PLAYER_NAME': u'Al Jefferson',
#   u'PLUS_MINUS': -11,
#   u'PTS': 238,
#   u'REB': 116,
#   'SEC_PLAYED': 0.3650000000000091,
#   u'STL': 14,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'CHA',
#   u'TEAM_ID': 1610612766,
#   u'TOV': 14,
#   u'W': 12,
#   u'W_PCT': 0.632},
#  {u'AGE': 25.0,
#   u'AST': 73,
#   u'BLK': 32,
#   u'BLKA': 25,
#   u'CFID': 5,
#   u'CFPARAMS': u'202329,1610612757',
#   u'DD2': 7,
#   u'DREB': 256,
#   u'FG3A': 201,
#   u'FG3M': 70,
#   u'FG3_PCT': 0.348,
#   u'FGA': 444,
#   u'FGM': 183,
#   u'FG_PCT': 0.412,
#   u'FTA': 95,
#   u'FTM': 70,
#   u'FT_PCT': 0.737,
#   u'GP': 48,
#   u'L': 26,
#   u'MIN': 1392.29,
#   'MIN_PLAYED': 1392.0,
#   u'OREB': 58,
#   u'PF': 109,
#   u'PFD': 87,
#   u'PLAYER_ID': 202329,
#   u'PLAYER_NAME': u'Al-Farouq Aminu',
#   u'PLUS_MINUS': 26,
#   u'PTS': 506,
#   u'REB': 314,
#   'SEC_PLAYED': 0.2899999999999636,
#   u'STL': 42,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'POR',
#   u'TEAM_ID': 1610612757,
#   u'TOV': 78,
#   u'W': 22,
#   u'W_PCT': 0.458},
#  {u'AGE': 24.0,
#   u'AST': 59,
#   u'BLK': 4,
#   u'BLKA': 26,
#   u'CFID': 5,
#   u'CFPARAMS': u'202692,1610612762',
#   u'DD2': 0,
#   u'DREB': 84,
#   u'FG3A': 75,
#   u'FG3M': 29,
#   u'FG3_PCT': 0.387,
#   u'FGA': 325,
#   u'FGM': 133,
#   u'FG_PCT': 0.409,
#   u'FTA': 141,
#   u'FTM': 106,
#   u'FT_PCT': 0.752,
#   u'GP': 28,
#   u'L': 16,
#   u'MIN': 759.6266666666667,
#   'MIN_PLAYED': 759.0,
#   u'OREB': 16,
#   u'PF': 69,
#   u'PFD': 108,
#   u'PLAYER_ID': 202692,
#   u'PLAYER_NAME': u'Alec Burks',
#   u'PLUS_MINUS': -25,
#   u'PTS': 401,
#   u'REB': 100,
#   'SEC_PLAYED': 0.6266666666666652,
#   u'STL': 16,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'UTA',
#   u'TEAM_ID': 1610612762,
#   u'TOV': 49,
#   u'W': 12,
#   u'W_PCT': 0.429},
#  {u'AGE': 22.0,
#   u'AST': 41,
#   u'BLK': 40,
#   u'BLKA': 19,
#   u'CFID': 5,
#   u'CFPARAMS': u'203458,1610612756',
#   u'DD2': 5,
#   u'DREB': 188,
#   u'FG3A': 4,
#   u'FG3M': 1,
#   u'FG3_PCT': 0.25,
#   u'FGA': 259,
#   u'FGM': 118,
#   u'FG_PCT': 0.456,
#   u'FTA': 100,
#   u'FTM': 72,
#   u'FT_PCT': 0.72,
#   u'GP': 45,
#   u'L': 31,
#   u'MIN': 883.0533333333333,
#   'MIN_PLAYED': 883.0,
#   u'OREB': 81,
#   u'PF': 115,
#   u'PFD': 65,
#   u'PLAYER_ID': 203458,
#   u'PLAYER_NAME': u'Alex Len',
#   u'PLUS_MINUS': -109,
#   u'PTS': 309,
#   u'REB': 269,
#   'SEC_PLAYED': 0.05333333333328483,
#   u'STL': 22,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'PHX',
#   u'TEAM_ID': 1610612756,
#   u'TOV': 65,
#   u'W': 14,
#   u'W_PCT': 0.311},
#  {u'AGE': 27.0,
#   u'AST': 16,
#   u'BLK': 18,
#   u'BLKA': 3,
#   u'CFID': 5,
#   u'CFPARAMS': u'201582,1610612740',
#   u'DD2': 2,
#   u'DREB': 101,
#   u'FG3A': 1,
#   u'FG3M': 0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 143,
#   u'FGM': 74,
#   u'FG_PCT': 0.517,
#   u'FTA': 19,
#   u'FTM': 18,
#   u'FT_PCT': 0.947,
#   u'GP': 35,
#   u'L': 25,
#   u'MIN': 426.995,
#   'MIN_PLAYED': 426.0,
#   u'OREB': 40,
#   u'PF': 77,
#   u'PFD': 25,
#   u'PLAYER_ID': 201582,
#   u'PLAYER_NAME': u'Alexis Ajinca',
#   u'PLUS_MINUS': -16,
#   u'PTS': 166,
#   u'REB': 141,
#   'SEC_PLAYED': 0.9950000000000045,
#   u'STL': 10,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'NOP',
#   u'TEAM_ID': 1610612740,
#   u'TOV': 20,
#   u'W': 10,
#   u'W_PCT': 0.286},
#  {u'AGE': 23.0,
#   u'AST': 59,
#   u'BLK': 6,
#   u'BLKA': 6,
#   u'CFID': 5,
#   u'CFPARAMS': u'203459,1610612757',
#   u'DD2': 0,
#   u'DREB': 114,
#   u'FG3A': 183,
#   u'FG3M': 70,
#   u'FG3_PCT': 0.383,
#   u'FGA': 447,
#   u'FGM': 209,
#   u'FG_PCT': 0.468,
#   u'FTA': 61,
#   u'FTM': 52,
#   u'FT_PCT': 0.852,
#   u'GP': 48,
#   u'L': 26,
#   u'MIN': 1256.805,
#   'MIN_PLAYED': 1256.0,
#   u'OREB': 13,
#   u'PF': 123,
#   u'PFD': 44,
#   u'PLAYER_ID': 203459,
#   u'PLAYER_NAME': u'Allen Crabbe',
#   u'PLUS_MINUS': -19,
#   u'PTS': 540,
#   u'REB': 127,
#   'SEC_PLAYED': 0.8050000000000637,
#   u'STL': 40,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'POR',
#   u'TEAM_ID': 1610612757,
#   u'TOV': 43,
#   u'W': 22,
#   u'W_PCT': 0.458},
#  {u'AGE': 28.0,
#   u'AST': 46,
#   u'BLK': 8,
#   u'BLKA': 16,
#   u'CFID': 5,
#   u'CFPARAMS': u'202087,1610612740',
#   u'DD2': 0,
#   u'DREB': 121,
#   u'FG3A': 42,
#   u'FG3M': 12,
#   u'FG3_PCT': 0.286,
#   u'FGA': 155,
#   u'FGM': 77,
#   u'FG_PCT': 0.497,
#   u'FTA': 31,
#   u'FTM': 25,
#   u'FT_PCT': 0.806,
#   u'GP': 46,
#   u'L': 28,
#   u'MIN': 999.73,
#   'MIN_PLAYED': 999.0,
#   u'OREB': 36,
#   u'PF': 105,
#   u'PFD': 32,
#   u'PLAYER_ID': 202087,
#   u'PLAYER_NAME': u'Alonzo Gee',
#   u'PLUS_MINUS': -95,
#   u'PTS': 191,
#   u'REB': 157,
#   'SEC_PLAYED': 0.7300000000000182,
#   u'STL': 42,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'NOP',
#   u'TEAM_ID': 1610612740,
#   u'TOV': 30,
#   u'W': 18,
#   u'W_PCT': 0.391},
#  {u'AGE': 33.0,
#   u'AST': 12,
#   u'BLK': 10,
#   u'BLKA': 9,
#   u'CFID': 5,
#   u'CFPARAMS': u'2405,1610612748',
#   u'DD2': 0,
#   u'DREB': 45,
#   u'FG3A': 0,
#   u'FG3M': 0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 70,
#   u'FGM': 37,
#   u'FG_PCT': 0.529,
#   u'FTA': 23,
#   u'FTM': 17,
#   u'FT_PCT': 0.739,
#   u'GP': 19,
#   u'L': 10,
#   u'MIN': 248.495,
#   'MIN_PLAYED': 248.0,
#   u'OREB': 20,
#   u'PF': 22,
#   u'PFD': 28,
#   u'PLAYER_ID': 2405,
#   u'PLAYER_NAME': u"Amar'e Stoudemire",
#   u'PLUS_MINUS': -37,
#   u'PTS': 91,
#   u'REB': 65,
#   'SEC_PLAYED': 0.49500000000000455,
#   u'STL': 6,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'MIA',
#   u'TEAM_ID': 1610612748,
#   u'TOV': 16,
#   u'W': 9,
#   u'W_PCT': 0.474},
#  {u'AGE': 28.0,
#   u'AST': 81,
#   u'BLK': 52,
#   u'BLKA': 14,
#   u'CFID': 5,
#   u'CFPARAMS': u'101161,1610612738',
#   u'DD2': 4,
#   u'DREB': 188,
#   u'FG3A': 34,
#   u'FG3M': 9,
#   u'FG3_PCT': 0.265,
#   u'FGA': 263,
#   u'FGM': 153,
#   u'FG_PCT': 0.582,
#   u'FTA': 72,
#   u'FTM': 40,
#   u'FT_PCT': 0.556,
#   u'GP': 45,
#   u'L': 21,
#   u'MIN': 1074.0116666666668,
#   'MIN_PLAYED': 1074.0,
#   u'OREB': 102,
#   u'PF': 127,
#   u'PFD': 78,
#   u'PLAYER_ID': 101161,
#   u'PLAYER_NAME': u'Amir Johnson',
#   u'PLUS_MINUS': 107,
#   u'PTS': 355,
#   u'REB': 290,
#   'SEC_PLAYED': 0.011666666666769743,
#   u'STL': 32,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'BOS',
#   u'TEAM_ID': 1610612738,
#   u'TOV': 52,
#   u'W': 24,
#   u'W_PCT': 0.533},
#  {u'AGE': 33.0,
#   u'AST': 17,
#   u'BLK': 3,
#   u'BLKA': 2,
#   u'CFID': 5,
#   u'CFPARAMS': u'2760,1610612739',
#   u'DD2': 0,
#   u'DREB': 54,
#   u'FG3A': 1,
#   u'FG3M': 0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 61,
#   u'FGM': 26,
#   u'FG_PCT': 0.426,
#   u'FTA': 17,
#   u'FTM': 13,
#   u'FT_PCT': 0.765,
#   u'GP': 27,
#   u'L': 8,
#   u'MIN': 248.06666666666666,
#   'MIN_PLAYED': 248.0,
#   u'OREB': 19,
#   u'PF': 26,
#   u'PFD': 29,
#   u'PLAYER_ID': 2760,
#   u'PLAYER_NAME': u'Anderson Varejao',
#   u'PLUS_MINUS': 48,
#   u'PTS': 65,
#   u'REB': 73,
#   'SEC_PLAYED': 0.06666666666666288,
#   u'STL': 8,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'CLE',
#   u'TEAM_ID': 1610612739,
#   u'TOV': 13,
#   u'W': 19,
#   u'W_PCT': 0.704},
#  {u'AGE': 22.0,
#   u'AST': 39,
#   u'BLK': 71,
#   u'BLKA': 47,
#   u'CFID': 5,
#   u'CFPARAMS': u'203083,1610612765',
#   u'DD2': 39,
#   u'DREB': 470,
#   u'FG3A': 3,
#   u'FG3M': 1,
#   u'FG3_PCT': 0.333,
#   u'FGA': 666,
#   u'FGM': 347,
#   u'FG_PCT': 0.521,
#   u'FTA': 378,
#   u'FTM': 131,
#   u'FT_PCT': 0.347,
#   u'GP': 48,
#   u'L': 23,
#   u'MIN': 1613.4583333333333,
#   'MIN_PLAYED': 1613.0,
#   u'OREB': 250,
#   u'PF': 151,
#   u'PFD': 258,
#   u'PLAYER_ID': 203083,
#   u'PLAYER_NAME': u'Andre Drummond',
#   u'PLUS_MINUS': 114,
#   u'PTS': 826,
#   u'REB': 720,
#   'SEC_PLAYED': 0.45833333333325754,
#   u'STL': 81,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'DET',
#   u'TEAM_ID': 1610612765,
#   u'TOV': 99,
#   u'W': 25,
#   u'W_PCT': 0.521},
#  {u'AGE': 32.0,
#   u'AST': 161,
#   u'BLK': 16,
#   u'BLKA': 5,
#   u'CFID': 5,
#   u'CFPARAMS': u'2738,1610612744',
#   u'DD2': 1,
#   u'DREB': 155,
#   u'FG3A': 113,
#   u'FG3M': 43,
#   u'FG3_PCT': 0.381,
#   u'FGA': 268,
#   u'FGM': 132,
#   u'FG_PCT': 0.493,
#   u'FTA': 57,
#   u'FTM': 38,
#   u'FT_PCT': 0.667,
#   u'GP': 46,
#   u'L': 4,
#   u'MIN': 1259.36,
#   'MIN_PLAYED': 1259.0,
#   u'OREB': 43,
#   u'PF': 74,
#   u'PFD': 63,
#   u'PLAYER_ID': 2738,
#   u'PLAYER_NAME': u'Andre Iguodala',
#   u'PLUS_MINUS': 377,
#   u'PTS': 345,
#   u'REB': 198,
#   'SEC_PLAYED': 0.35999999999989996,
#   u'STL': 57,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_ID': 1610612744,
#   u'TOV': 56,
#   u'W': 42,
#   u'W_PCT': 0.913},
#  {u'AGE': 39.0,
#   u'AST': 47,
#   u'BLK': 0,
#   u'BLKA': 5,
#   u'CFID': 5,
#   u'CFPARAMS': u'1889,1610612750',
#   u'DD2': 0,
#   u'DREB': 12,
#   u'FG3A': 2,
#   u'FG3M': 1,
#   u'FG3_PCT': 0.5,
#   u'FGA': 46,
#   u'FGM': 28,
#   u'FG_PCT': 0.609,
#   u'FTA': 18,
#   u'FTM': 14,
#   u'FT_PCT': 0.778,
#   u'GP': 20,
#   u'L': 14,
#   u'MIN': 215.65333333333334,
#   'MIN_PLAYED': 215.0,
#   u'OREB': 5,
#   u'PF': 27,
#   u'PFD': 13,
#   u'PLAYER_ID': 1889,
#   u'PLAYER_NAME': u'Andre Miller',
#   u'PLUS_MINUS': 9,
#   u'PTS': 71,
#   u'REB': 17,
#   'SEC_PLAYED': 0.653333333333336,
#   u'STL': 9,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'MIN',
#   u'TEAM_ID': 1610612750,
#   u'TOV': 17,
#   u'W': 6,
#   u'W_PCT': 0.3},
#  {u'AGE': 24.0,
#   u'AST': 36,
#   u'BLK': 30,
#   u'BLKA': 14,
#   u'CFID': 5,
#   u'CFPARAMS': u'203460,1610612760',
#   u'DD2': 0,
#   u'DREB': 99,
#   u'FG3A': 62,
#   u'FG3M': 17,
#   u'FG3_PCT': 0.274,
#   u'FGA': 184,
#   u'FGM': 91,
#   u'FG_PCT': 0.495,
#   u'FTA': 36,
#   u'FTM': 22,
#   u'FT_PCT': 0.611,
#   u'GP': 45,
#   u'L': 12,
#   u'MIN': 978.19,
#   'MIN_PLAYED': 978.0,
#   u'OREB': 50,
#   u'PF': 81,
#   u'PFD': 32,
#   u'PLAYER_ID': 203460,
#   u'PLAYER_NAME': u'Andre Roberson',
#   u'PLUS_MINUS': 209,
#   u'PTS': 221,
#   u'REB': 149,
#   'SEC_PLAYED': 0.19000000000005457,
#   u'STL': 40,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'OKC',
#   u'TEAM_ID': 1610612760,
#   u'TOV': 28,
#   u'W': 33,
#   u'W_PCT': 0.733},
#  {u'AGE': 30.0,
#   u'AST': 14,
#   u'BLK': 8,
#   u'BLKA': 12,
#   u'CFID': 5,
#   u'CFPARAMS': u'200745,1610612751',
#   u'DD2': 0,
#   u'DREB': 62,
#   u'FG3A': 16,
#   u'FG3M': 3,
#   u'FG3_PCT': 0.188,
#   u'FGA': 255,
#   u'FGM': 116,
#   u'FG_PCT': 0.455,
#   u'FTA': 53,
#   u'FTM': 43,
#   u'FT_PCT': 0.811,
#   u'GP': 42,
#   u'L': 32,
#   u'MIN': 577.9333333333333,
#   'MIN_PLAYED': 577.0,
#   u'OREB': 26,
#   u'PF': 58,
#   u'PFD': 49,
#   u'PLAYER_ID': 200745,
#   u'PLAYER_NAME': u'Andrea Bargnani',
#   u'PLUS_MINUS': -189,
#   u'PTS': 278,
#   u'REB': 88,
#   'SEC_PLAYED': 0.9333333333332803,
#   u'STL': 4,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'BKN',
#   u'TEAM_ID': 1610612751,
#   u'TOV': 26,
#   u'W': 10,
#   u'W_PCT': 0.238},
#  {u'AGE': 31.0,
#   u'AST': 80,
#   u'BLK': 66,
#   u'BLKA': 4,
#   u'CFID': 5,
#   u'CFPARAMS': u'101106,1610612744',
#   u'DD2': 3,
#   u'DREB': 222,
#   u'FG3A': 0,
#   u'FG3M': 0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 169,
#   u'FGM': 106,
#   u'FG_PCT': 0.627,
#   u'FTA': 29,
#   u'FTM': 12,
#   u'FT_PCT': 0.414,
#   u'GP': 40,
#   u'L': 4,
#   u'MIN': 836.015,
#   'MIN_PLAYED': 836.0,
#   u'OREB': 72,
#   u'PF': 122,
#   u'PFD': 40,
#   u'PLAYER_ID': 101106,
#   u'PLAYER_NAME': u'Andrew Bogut',
#   u'PLUS_MINUS': 255,
#   u'PTS': 224,
#   u'REB': 294,
#   'SEC_PLAYED': 0.014999999999986358,
#   u'STL': 13,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_ID': 1610612744,
#   u'TOV': 45,
#   u'W': 36,
#   u'W_PCT': 0.9},
#  {u'AGE': 26.0,
#   u'AST': 11,
#   u'BLK': 11,
#   u'BLKA': 7,
#   u'CFID': 5,
#   u'CFPARAMS': u'203094,1610612753',
#   u'DD2': 0,
#   u'DREB': 103,
#   u'FG3A': 69,
#   u'FG3M': 24,
#   u'FG3_PCT': 0.348,
#   u'FGA': 189,
#   u'FGM': 84,
#   u'FG_PCT': 0.444,
#   u'FTA': 32,
#   u'FTM': 25,
#   u'FT_PCT': 0.781,
#   u'GP': 33,
#   u'L': 17,
#   u'MIN': 527.8166666666667,
#   'MIN_PLAYED': 527.0,
#   u'OREB': 23,
#   u'PF': 44,
#   u'PFD': 33,
#   u'PLAYER_ID': 203094,
#   u'PLAYER_NAME': u'Andrew Nicholson',
#   u'PLUS_MINUS': 14,
#   u'PTS': 217,
#   u'REB': 126,
#   'SEC_PLAYED': 0.8166666666667197,
#   u'STL': 6,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'ORL',
#   u'TEAM_ID': 1610612753,
#   u'TOV': 27,
#   u'W': 16,
#   u'W_PCT': 0.485},
#  {u'AGE': 20.0,
#   u'AST': 86,
#   u'BLK': 25,
#   u'BLKA': 58,
#   u'CFID': 5,
#   u'CFPARAMS': u'203952,1610612750',
#   u'DD2': 1,
#   u'DREB': 103,
#   u'FG3A': 111,
#   u'FG3M': 27,
#   u'FG3_PCT': 0.243,
#   u'FGA': 769,
#   u'FGM': 343,
#   u'FG_PCT': 0.446,
#   u'FTA': 337,
#   u'FTM': 249,
#   u'FT_PCT': 0.739,
#   u'GP': 47,
#   u'L': 33,
#   u'MIN': 1648.2766666666666,
#   'MIN_PLAYED': 1648.0,
#   u'OREB': 70,
#   u'PF': 100,
#   u'PFD': 246,
#   u'PLAYER_ID': 203952,
#   u'PLAYER_NAME': u'Andrew Wiggins',
#   u'PLUS_MINUS': -113,
#   u'PTS': 962,
#   u'REB': 173,
#   'SEC_PLAYED': 0.2766666666666424,
#   u'STL': 40,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'MIN',
#   u'TEAM_ID': 1610612750,
#   u'TOV': 102,
#   u'W': 14,
#   u'W_PCT': 0.298},
#  {u'AGE': 22.0,
#   u'AST': 0,
#   u'BLK': 0,
#   u'BLKA': 1,
#   u'CFID': 5,
#   u'CFPARAMS': u'203461,1610612761',
#   u'DD2': 0,
#   u'DREB': 13,
#   u'FG3A': 12,
#   u'FG3M': 2,
#   u'FG3_PCT': 0.167,
#   u'FGA': 20,
#   u'FGM': 5,
#   u'FG_PCT': 0.25,
#   u'FTA': 8,
#   u'FTM': 7,
#   u'FT_PCT': 0.875,
#   u'GP': 13,
#   u'L': 4,
#   u'MIN': 64.21333333333334,
#   'MIN_PLAYED': 64.0,
#   u'OREB': 5,
#   u'PF': 8,
#   u'PFD': 4,
#   u'PLAYER_ID': 203461,
#   u'PLAYER_NAME': u'Anthony Bennett',
#   u'PLUS_MINUS': -29,
#   u'PTS': 19,
#   u'REB': 18,
#   'SEC_PLAYED': 0.21333333333333826,
#   u'STL': 3,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'TOR',
#   u'TEAM_ID': 1610612761,
#   u'TOV': 4,
#   u'W': 9,
#   u'W_PCT': 0.692},
#  {u'AGE': 23.0,
#   u'AST': 12,
#   u'BLK': 5,
#   u'BLKA': 9,
#   u'CFID': 5,
#   u'CFPARAMS': u'1626148,1610612747',
#   u'DD2': 0,
#   u'DREB': 47,
#   u'FG3A': 55,
#   u'FG3M': 16,
#   u'FG3_PCT': 0.291,
#   u'FGA': 99,
#   u'FGM': 31,
#   u'FG_PCT': 0.313,
#   u'FTA': 17,
#   u'FTM': 14,
#   u'FT_PCT': 0.824,
#   u'GP': 24,
#   u'L': 21,
#   u'MIN': 469.6333333333333,
#   'MIN_PLAYED': 469.0,
#   u'OREB': 7,
#   u'PF': 26,
#   u'PFD': 14,
#   u'PLAYER_ID': 1626148,
#   u'PLAYER_NAME': u'Anthony Brown',
#   u'PLUS_MINUS': -1,
#   u'PTS': 92,
#   u'REB': 54,
#   'SEC_PLAYED': 0.6333333333333258,
#   u'STL': 10,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'LAL',
#   u'TEAM_ID': 1610612747,
#   u'TOV': 14,
#   u'W': 3,
#   u'W_PCT': 0.125},
#  {u'AGE': 22.0,
#   u'AST': 72,
#   u'BLK': 96,
#   u'BLKA': 29,
#   u'CFID': 5,
#   u'CFPARAMS': u'203076,1610612740',
#   u'DD2': 24,
#   u'DREB': 327,
#   u'FG3A': 68,
#   u'FG3M': 20,
#   u'FG3_PCT': 0.294,
#   u'FGA': 709,
#   u'FGM': 347,
#   u'FG_PCT': 0.489,
#   u'FTA': 263,
#   u'FTM': 201,
#   u'FT_PCT': 0.764,
#   u'GP': 40,
#   u'L': 23,
#   u'MIN': 1416.54,
#   'MIN_PLAYED': 1416.0,
#   u'OREB': 85,
#   u'PF': 96,
#   u'PFD': 218,
#   u'PLAYER_ID': 203076,
#   u'PLAYER_NAME': u'Anthony Davis',
#   u'PLUS_MINUS': -32,
#   u'PTS': 915,
#   u'REB': 412,
#   'SEC_PLAYED': 0.5399999999999636,
#   u'STL': 50,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'NOP',
#   u'TEAM_ID': 1610612740,
#   u'TOV': 85,
#   u'W': 17,
#   u'W_PCT': 0.425},
#  {u'AGE': 30.0,
#   u'AST': 14,
#   u'BLK': 3,
#   u'BLKA': 6,
#   u'CFID': 5,
#   u'CFPARAMS': u'201627,1610612760',
#   u'DD2': 0,
#   u'DREB': 42,
#   u'FG3A': 130,
#   u'FG3M': 54,
#   u'FG3_PCT': 0.415,
#   u'FGA': 210,
#   u'FGM': 89,
#   u'FG_PCT': 0.424,
#   u'FTA': 21,
#   u'FTM': 17,
#   u'FT_PCT': 0.81,
#   u'GP': 43,
#   u'L': 12,
#   u'MIN': 640.3883333333333,
#   'MIN_PLAYED': 640.0,
#   u'OREB': 8,
#   u'PF': 45,
#   u'PFD': 17,
#   u'PLAYER_ID': 201627,
#   u'PLAYER_NAME': u'Anthony Morrow',
#   u'PLUS_MINUS': 79,
#   u'PTS': 249,
#   u'REB': 50,
#   'SEC_PLAYED': 0.3883333333333212,
#   u'STL': 18,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'OKC',
#   u'TEAM_ID': 1610612760,
#   u'TOV': 10,
#   u'W': 31,
#   u'W_PCT': 0.721},
#  {u'AGE': 30.0,
#   u'AST': 40,
#   u'BLK': 12,
#   u'BLKA': 8,
#   u'CFID': 5,
#   u'CFPARAMS': u'201229,1610612765',
#   u'DD2': 0,
#   u'DREB': 131,
#   u'FG3A': 175,
#   u'FG3M': 64,
#   u'FG3_PCT': 0.366,
#   u'FGA': 218,
#   u'FGM': 83,
#   u'FG_PCT': 0.381,
#   u'FTA': 35,
#   u'FTM': 23,
#   u'FT_PCT': 0.657,
#   u'GP': 47,
#   u'L': 23,
#   u'MIN': 925.845,
#   'MIN_PLAYED': 925.0,
#   u'OREB': 26,
#   u'PF': 58,
#   u'PFD': 35,
#   u'PLAYER_ID': 201229,
#   u'PLAYER_NAME': u'Anthony Tolliver',
#   u'PLUS_MINUS': 65,
#   u'PTS': 253,
#   u'REB': 157,
#   'SEC_PLAYED': 0.8450000000000273,
#   u'STL': 18,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'DET',
#   u'TEAM_ID': 1610612765,
#   u'TOV': 15,
#   u'W': 24,
#   u'W_PCT': 0.511},
#  {u'AGE': 21.0,
#   u'AST': 45,
#   u'BLK': 7,
#   u'BLKA': 26,
#   u'CFID': 5,
#   u'CFPARAMS': u'203462,1610612756',
#   u'DD2': 0,
#   u'DREB': 54,
#   u'FG3A': 35,
#   u'FG3M': 9,
#   u'FG3_PCT': 0.257,
#   u'FGA': 168,
#   u'FGM': 71,
#   u'FG_PCT': 0.423,
#   u'FTA': 98,
#   u'FTM': 64,
#   u'FT_PCT': 0.653,
#   u'GP': 28,
#   u'L': 21,
#   u'MIN': 454.26,
#   'MIN_PLAYED': 454.0,
#   u'OREB': 10,
#   u'PF': 28,
#   u'PFD': 75,
#   u'PLAYER_ID': 203462,
#   u'PLAYER_NAME': u'Archie Goodwin',
#   u'PLUS_MINUS': -53,
#   u'PTS': 215,
#   u'REB': 64,
#   'SEC_PLAYED': 0.2599999999999909,
#   u'STL': 15,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'PHX',
#   u'TEAM_ID': 1610612756,
#   u'TOV': 39,
#   u'W': 7,
#   u'W_PCT': 0.25},
#  {u'AGE': 29.0,
#   u'AST': 37,
#   u'BLK': 25,
#   u'BLKA': 14,
#   u'CFID': 5,
#   u'CFPARAMS': u'203382,1610612765',
#   u'DD2': 1,
#   u'DREB': 136,
#   u'FG3A': 1,
#   u'FG3M': 0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 209,
#   u'FGM': 105,
#   u'FG_PCT': 0.502,
#   u'FTA': 77,
#   u'FTM': 58,
#   u'FT_PCT': 0.753,
#   u'GP': 47,
#   u'L': 23,
#   u'MIN': 669.975,
#   'MIN_PLAYED': 669.0,
#   u'OREB': 76,
#   u'PF': 89,
#   u'PFD': 76,
#   u'PLAYER_ID': 203382,
#   u'PLAYER_NAME': u'Aron Baynes',
#   u'PLUS_MINUS': -47,
#   u'PTS': 268,
#   u'REB': 212,
#   'SEC_PLAYED': 0.9750000000000227,
#   u'STL': 13,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'DET',
#   u'TEAM_ID': 1610612765,
#   u'TOV': 41,
#   u'W': 24,
#   u'W_PCT': 0.511},
#  {u'AGE': 30.0,
#   u'AST': 78,
#   u'BLK': 8,
#   u'BLKA': 33,
#   u'CFID': 5,
#   u'CFPARAMS': u'201167,1610612752',
#   u'DD2': 0,
#   u'DREB': 134,
#   u'FG3A': 146,
#   u'FG3M': 55,
#   u'FG3_PCT': 0.377,
#   u'FGA': 503,
#   u'FGM': 228,
#   u'FG_PCT': 0.453,
#   u'FTA': 79,
#   u'FTM': 70,
#   u'FT_PCT': 0.886,
#   u'GP': 41,
#   u'L': 22,
#   u'MIN': 1361.36,
#   'MIN_PLAYED': 1361.0,
#   u'OREB': 13,
#   u'PF': 96,
#   u'PFD': 71,
#   u'PLAYER_ID': 201167,
#   u'PLAYER_NAME': u'Arron Afflalo',
#   u'PLUS_MINUS': 6,
#   u'PTS': 581,
#   u'REB': 147,
#   'SEC_PLAYED': 0.35999999999989996,
#   u'STL': 13,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'NYK',
#   u'TEAM_ID': 1610612752,
#   u'TOV': 40,
#   u'W': 19,
#   u'W_PCT': 0.463},
#  {u'AGE': 23.0,
#   u'AST': 59,
#   u'BLK': 9,
#   u'BLKA': 18,
#   u'CFID': 5,
#   u'CFPARAMS': u'203085,1610612746',
#   u'DD2': 0,
#   u'DREB': 68,
#   u'FG3A': 109,
#   u'FG3M': 28,
#   u'FG3_PCT': 0.257,
#   u'FGA': 327,
#   u'FGM': 141,
#   u'FG_PCT': 0.431,
#   u'FTA': 60,
#   u'FTM': 41,
#   u'FT_PCT': 0.683,
#   u'GP': 44,
#   u'L': 15,
#   u'MIN': 966.8366666666667,
#   'MIN_PLAYED': 966.0,
#   u'OREB': 15,
#   u'PF': 96,
#   u'PFD': 55,
#   u'PLAYER_ID': 203085,
#   u'PLAYER_NAME': u'Austin Rivers',
#   u'PLUS_MINUS': -123,
#   u'PTS': 351,
#   u'REB': 83,
#   'SEC_PLAYED': 0.8366666666667015,
#   u'STL': 31,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'LAC',
#   u'TEAM_ID': 1610612746,
#   u'TOV': 38,
#   u'W': 29,
#   u'W_PCT': 0.659},
#  {u'AGE': 25.0,
#   u'AST': 89,
#   u'BLK': 11,
#   u'BLKA': 24,
#   u'CFID': 5,
#   u'CFPARAMS': u'202340,1610612738',
#   u'DD2': 0,
#   u'DREB': 85,
#   u'FG3A': 239,
#   u'FG3M': 86,
#   u'FG3_PCT': 0.36,
#   u'FGA': 570,
#   u'FGM': 251,
#   u'FG_PCT': 0.44,
#   u'FTA': 65,
#   u'FTM': 50,
#   u'FT_PCT': 0.769,
#   u'GP': 43,
#   u'L': 18,
#   u'MIN': 1400.9066666666668,
#   'MIN_PLAYED': 1400.0,
#   u'OREB': 26,
#   u'PF': 92,
#   u'PFD': 58,
#   u'PLAYER_ID': 202340,
#   u'PLAYER_NAME': u'Avery Bradley',
#   u'PLUS_MINUS': 167,
#   u'PTS': 638,
#   u'REB': 111,
#   'SEC_PLAYED': 0.9066666666667516,
#   u'STL': 70,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'BOS',
#   u'TEAM_ID': 1610612738,
#   u'TOV': 63,
#   u'W': 25,
#   u'W_PCT': 0.581},
#  {u'AGE': 22.0,
#   u'AST': 54,
#   u'BLK': 7,
#   u'BLKA': 11,
#   u'CFID': 5,
#   u'CFPARAMS': u'203463,1610612758',
#   u'DD2': 0,
#   u'DREB': 74,
#   u'FG3A': 113,
#   u'FG3M': 42,
#   u'FG3_PCT': 0.372,
#   u'FGA': 287,
#   u'FGM': 132,
#   u'FG_PCT': 0.46,
#   u'FTA': 73,
#   u'FTM': 52,
#   u'FT_PCT': 0.712,
#   u'GP': 46,
#   u'L': 26,
#   u'MIN': 975.1283333333333,
#   'MIN_PLAYED': 975.0,
#   u'OREB': 23,
#   u'PF': 93,
#   u'PFD': 61,
#   u'PLAYER_ID': 203463,
#   u'PLAYER_NAME': u'Ben McLemore',
#   u'PLUS_MINUS': 27,
#   u'PTS': 358,
#   u'REB': 97,
#   'SEC_PLAYED': 0.1283333333333303,
#   u'STL': 38,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'SAC',
#   u'TEAM_ID': 1610612758,
#   u'TOV': 67,
#   u'W': 20,
#   u'W_PCT': 0.435},
#  {u'AGE': 33.0,
#   u'AST': 95,
#   u'BLK': 1,
#   u'BLKA': 6,
#   u'CFID': 5,
#   u'CFPARAMS': u'2757,1610612748',
#   u'DD2': 1,
#   u'DREB': 52,
#   u'FG3A': 35,
#   u'FG3M': 14,
#   u'FG3_PCT': 0.4,
#   u'FGA': 148,
#   u'FGM': 64,
#   u'FG_PCT': 0.432,
#   u'FTA': 13,
#   u'FTM': 12,
#   u'FT_PCT': 0.923,
#   u'GP': 35,
#   u'L': 15,
#   u'MIN': 556.8466666666667,
#   'MIN_PLAYED': 556.0,
#   u'OREB': 4,
#   u'PF': 40,
#   u'PFD': 32,
#   u'PLAYER_ID': 2757,
#   u'PLAYER_NAME': u'Beno Udrih',
#   u'PLUS_MINUS': -4,
#   u'PTS': 154,
#   u'REB': 56,
#   'SEC_PLAYED': 0.8466666666666924,
#   u'STL': 13,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'MIA',
#   u'TEAM_ID': 1610612748,
#   u'TOV': 38,
#   u'W': 20,
#   u'W_PCT': 0.571},
#  {u'AGE': 23.0,
#   u'AST': 12,
#   u'BLK': 72,
#   u'BLKA': 27,
#   u'CFID': 5,
#   u'CFPARAMS': u'202687,1610612761',
#   u'DD2': 6,
#   u'DREB': 281,
#   u'FG3A': 0,
#   u'FG3M': 0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 172,
#   u'FGM': 88,
#   u'FG_PCT': 0.512,
#   u'FTA': 131,
#   u'FTM': 88,
#   u'FT_PCT': 0.672,
#   u'GP': 47,
#   u'L': 15,
#   u'MIN': 1063.5916666666667,
#   'MIN_PLAYED': 1063.0,
#   u'OREB': 108,
#   u'PF': 128,
#   u'PFD': 112,
#   u'PLAYER_ID': 202687,
#   u'PLAYER_NAME': u'Bismack Biyombo',
#   u'PLUS_MINUS': 31,
#   u'PTS': 264,
#   u'REB': 389,
#   'SEC_PLAYED': 0.591666666666697,
#   u'STL': 9,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'TOR',
#   u'TEAM_ID': 1610612761,
#   u'TOV': 48,
#   u'W': 32,
#   u'W_PCT': 0.681},
#  {u'AGE': 26.0,
#   u'AST': 149,
#   u'BLK': 17,
#   u'BLKA': 11,
#   u'CFID': 5,
#   u'CFPARAMS': u'201933,1610612746',
#   u'DD2': 12,
#   u'DREB': 211,
#   u'FG3A': 17,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.353,
#   u'FGA': 553,
#   u'FGM': 281,
#   u'FG_PCT': 0.508,
#   u'FTA': 178,
#   u'FTM': 129,
#   u'FT_PCT': 0.725,
#   u'GP': 30,
#   u'L': 13,
#   u'MIN': 1047.5833333333333,
#   'MIN_PLAYED': 1047.0,
#   u'OREB': 49,
#   u'PF': 85,
#   u'PFD': 169,
#   u'PLAYER_ID': 201933,
#   u'PLAYER_NAME': u'Blake Griffin',
#   u'PLUS_MINUS': 109,
#   u'PTS': 697,
#   u'REB': 260,
#   'SEC_PLAYED': 0.5833333333332575,
#   u'STL': 21,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'LAC',
#   u'TEAM_ID': 1610612746,
#   u'TOV': 71,
#   u'W': 17,
#   u'W_PCT': 0.567},
#  {u'AGE': 27.0,
#   u'AST': 9,
#   u'BLK': 13,
#   u'BLKA': 9,
#   u'CFID': 5,
#   u'CFPARAMS': u'1626246,1610612759',
#   u'DD2': 2,
#   u'DREB': 63,
#   u'FG3A': 0,
#   u'FG3M': 0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 100,
#   u'FGM': 61,
#   u'FG_PCT': 0.61,
#   u'FTA': 63,
#   u'FTM': 46,
#   u'FT_PCT': 0.73,
#   u'GP': 28,
#   u'L': 2,
#   u'MIN': 240.24666666666667,
#   'MIN_PLAYED': 240.0,
#   u'OREB': 39,
#   u'PF': 33,
#   u'PFD': 43,
#   u'PLAYER_ID': 1626246,
#   u'PLAYER_NAME': u'Boban Marjanovic',
#   u'PLUS_MINUS': 58,
#   u'PTS': 168,
#   u'REB': 102,
#   'SEC_PLAYED': 0.2466666666666697,
#   u'STL': 8,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'SAS',
#   u'TEAM_ID': 1610612759,
#   u'TOV': 17,
#   u'W': 26,
#   u'W_PCT': 0.929},
#  {u'AGE': 20.0,
#   u'AST': 12,
#   u'BLK': 10,
#   u'BLKA': 7,
#   u'CFID': 5,
#   u'CFPARAMS': u'1626171,1610612741',
#   u'DD2': 2,
#   u'DREB': 69,
#   u'FG3A': 19,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.316,
#   u'FGA': 151,
#   u'FGM': 67,
#   u'FG_PCT': 0.444,
#   u'FTA': 25,
#   u'FTM': 19,
#   u'FT_PCT': 0.76,
#   u'GP': 25,
#   u'L': 12,
#   u'MIN': 360.34833333333336,
#   'MIN_PLAYED': 360.0,
#   u'OREB': 38,
#   u'PF': 38,
#   u'PFD': 20,
#   u'PLAYER_ID': 1626171,
#   u'PLAYER_NAME': u'Bobby Portis',
#   u'PLUS_MINUS': -24,
#   u'PTS': 159,
#   u'REB': 107,
#   'SEC_PLAYED': 0.3483333333333576,
#   u'STL': 12,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'CHI',
#   u'TEAM_ID': 1610612741,
#   u'TOV': 28,
#   u'W': 13,
#   u'W_PCT': 0.52},
#  {u'AGE': 26.0,
#   u'AST': 50,
#   u'BLK': 3,
#   u'BLKA': 36,
#   u'CFID': 5,
#   u'CFPARAMS': u'202711,1610612751',
#   u'DD2': 1,
#   u'DREB': 136,
#   u'FG3A': 180,
#   u'FG3M': 61,
#   u'FG3_PCT': 0.339,
#   u'FGA': 394,
#   u'FGM': 165,
#   u'FG_PCT': 0.419,
#   u'FTA': 59,
#   u'FTM': 48,
#   u'FT_PCT': 0.814,
#   u'GP': 48,
#   u'L': 36,
#   u'MIN': 1280.4116666666666,
#   'MIN_PLAYED': 1280.0,
#   u'OREB': 24,
#   u'PF': 67,
#   u'PFD': 62,
#   u'PLAYER_ID': 202711,
#   u'PLAYER_NAME': u'Bojan Bogdanovic',
#   u'PLUS_MINUS': -269,
#   u'PTS': 439,
#   u'REB': 160,
#   'SEC_PLAYED': 0.4116666666666333,
#   u'STL': 22,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'BKN',
#   u'TEAM_ID': 1610612751,
#   u'TOV': 59,
#   u'W': 12,
#   u'W_PCT': 0.25},
#  {u'AGE': 33.0,
#   u'AST': 115,
#   u'BLK': 12,
#   u'BLKA': 9,
#   u'CFID': 5,
#   u'CFPARAMS': u'2564,1610612759',
#   u'DD2': 0,
#   u'DREB': 110,
#   u'FG3A': 48,
#   u'FG3M': 18,
#   u'FG3_PCT': 0.375,
#   u'FGA': 248,
#   u'FGM': 131,
#   u'FG_PCT': 0.528,
#   u'FTA': 53,
#   u'FTM': 40,
#   u'FT_PCT': 0.755,
#   u'GP': 46,
#   u'L': 7,
#   u'MIN': 876.5883333333334,
#   'MIN_PLAYED': 876.0,
#   u'OREB': 38,
#   u'PF': 67,
#   u'PFD': 61,
#   u'PLAYER_ID': 2564,
#   u'PLAYER_NAME': u'Boris Diaw',
#   u'PLUS_MINUS': 283,
#   u'PTS': 320,
#   u'REB': 148,
#   'SEC_PLAYED': 0.5883333333333667,
#   u'STL': 19,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'SAS',
#   u'TEAM_ID': 1610612759,
#   u'TOV': 60,
#   u'W': 39,
#   u'W_PCT': 0.848},
#  {u'AGE': 22.0,
#   u'AST': 69,
#   u'BLK': 6,
#   u'BLKA': 10,
#   u'CFID': 5,
#   u'CFPARAMS': u'203078,1610612764',
#   u'DD2': 0,
#   u'DREB': 73,
#   u'FG3A': 117,
#   u'FG3M': 47,
#   u'FG3_PCT': 0.402,
#   u'FGA': 352,
#   u'FGM': 158,
#   u'FG_PCT': 0.449,
#   u'FTA': 80,
#   u'FTM': 61,
#   u'FT_PCT': 0.763,
#   u'GP': 23,
#   u'L': 13,
#   u'MIN': 749.775,
#   'MIN_PLAYED': 749.0,
#   u'OREB': 21,
#   u'PF': 56,
#   u'PFD': 55,
#   u'PLAYER_ID': 203078,
#   u'PLAYER_NAME': u'Bradley Beal',
#   u'PLUS_MINUS': -67,
#   u'PTS': 424,
#   u'REB': 94,
#   'SEC_PLAYED': 0.7749999999999773,
#   u'STL': 24,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'WAS',
#   u'TEAM_ID': 1610612764,
#   u'TOV': 61,
#   u'W': 10,
#   u'W_PCT': 0.435},
#  {u'AGE': 28.0,
#   u'AST': 4,
#   u'BLK': 10,
#   u'BLKA': 0,
#   u'CFID': 5,
#   u'CFPARAMS': u'201148,1610612763',
#   u'DD2': 0,
#   u'DREB': 18,
#   u'FG3A': 0,
#   u'FG3M': 0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 30,
#   u'FGM': 18,
#   u'FG_PCT': 0.6,
#   u'FTA': 18,
#   u'FTM': 10,
#   u'FT_PCT': 0.556,
#   u'GP': 7,
#   u'L': 4,
#   u'MIN': 119.67833333333333,
#   'MIN_PLAYED': 119.0,
#   u'OREB': 6,
#   u'PF': 9,
#   u'PFD': 16,
#   u'PLAYER_ID': 201148,
#   u'PLAYER_NAME': u'Brandan Wright',
#   u'PLUS_MINUS': -52,
#   u'PTS': 46,
#   u'REB': 24,
#   'SEC_PLAYED': 0.6783333333333275,
#   u'STL': 1,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'MEM',
#   u'TEAM_ID': 1610612763,
#   u'TOV': 4,
#   u'W': 3,
#   u'W_PCT': 0.429},
#  {u'AGE': 22.0,
#   u'AST': 0,
#   u'BLK': 1,
#   u'BLKA': 2,
#   u'CFID': 5,
#   u'CFPARAMS': u'1626183,1610612746',
#   u'DD2': 0,
#   u'DREB': 1,
#   u'FG3A': 0,
#   u'FG3M': 0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 3,
#   u'FGM': 1,
#   u'FG_PCT': 0.333,
#   u'FTA': 0,
#   u'FTM': 0,
#   u'FT_PCT': 0.0,
#   u'GP': 2,
#   u'L': 0,
#   u'MIN': 12.6,
#   'MIN_PLAYED': 12.0,
#   u'OREB': 2,
#   u'PF': 2,
#   u'PFD': 0,
#   u'PLAYER_ID': 1626183,
#   u'PLAYER_NAME': u'Branden Dawson',
#   u'PLUS_MINUS': -14,
#   u'PTS': 2,
#   u'REB': 3,
#   'SEC_PLAYED': 0.5999999999999996,
#   u'STL': 0,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'LAC',
#   u'TEAM_ID': 1610612746,
#   u'TOV': 0,
#   u'W': 2,
#   u'W_PCT': 1.0},
#  {u'AGE': 30.0,
#   u'AST': 46,
#   u'BLK': 36,
#   u'BLKA': 16,
#   u'CFID': 5,
#   u'CFPARAMS': u'101138,1610612747',
#   u'DD2': 0,
#   u'DREB': 109,
#   u'FG3A': 1,
#   u'FG3M': 0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 182,
#   u'FGM': 101,
#   u'FG_PCT': 0.555,
#   u'FTA': 68,
#   u'FTM': 58,
#   u'FT_PCT': 0.853,
#   u'GP': 41,
#   u'L': 32,
#   u'MIN': 738.6666666666666,
#   'MIN_PLAYED': 738.0,
#   u'OREB': 63,
#   u'PF': 71,
#   u'PFD': 52,
#   u'PLAYER_ID': 101138,
#   u'PLAYER_NAME': u'Brandon Bass',
#   u'PLUS_MINUS': -81,
#   u'PTS': 260,
#   u'REB': 172,
#   'SEC_PLAYED': 0.6666666666666288,
#   u'STL': 20,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'LAL',
#   u'TEAM_ID': 1610612747,
#   u'TOV': 25,
#   u'W': 9,
#   u'W_PCT': 0.22},
#  {u'AGE': 26.0,
#   u'AST': 55,
#   u'BLK': 1,
#   u'BLKA': 5,
#   u'CFID': 5,
#   u'CFPARAMS': u'201943,1610612765',
#   u'DD2': 0,
#   u'DREB': 32,
#   u'FG3A': 56,
#   u'FG3M': 18,
#   u'FG3_PCT': 0.321,
#   u'FGA': 105,
#   u'FGM': 38,
#   u'FG_PCT': 0.362,
#   u'FTA': 34,
#   u'FTM': 24,
#   u'FT_PCT': 0.706,
#   u'GP': 17,
#   u'L': 9,
#   u'MIN': 298.97,
#   'MIN_PLAYED': 298.0,
#   u'OREB': 5,
#   u'PF': 18,
#   u'PFD': 26,
#   u'PLAYER_ID': 201943,
#   u'PLAYER_NAME': u'Brandon Jennings',
#   u'PLUS_MINUS': 56,
#   u'PTS': 118,
#   u'REB': 37,
#   'SEC_PLAYED': 0.9700000000000273,
#   u'STL': 9,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'DET',
#   u'TEAM_ID': 1610612765,
#   u'TOV': 16,
#   u'W': 8,
#   u'W_PCT': 0.471},
#  {u'AGE': 24.0,
#   u'AST': 215,
#   u'BLK': 13,
#   u'BLKA': 27,
#   u'CFID': 5,
#   u'CFPARAMS': u'202688,1610612756',
#   u'DD2': 4,
#   u'DREB': 130,
#   u'FG3A': 261,
#   u'FG3M': 87,
#   u'FG3_PCT': 0.333,
#   u'FGA': 728,
#   u'FGM': 309,
#   u'FG_PCT': 0.424,
#   u'FTA': 144,
#   u'FTM': 122,
#   u'FT_PCT': 0.847,
#   u'GP': 42,
#   u'L': 29,
#   u'MIN': 1523.0733333333333,
#   'MIN_PLAYED': 1523.0,
#   u'OREB': 27,
#   u'PF': 99,
#   u'PFD': 163,
#   u'PLAYER_ID': 202688,
#   u'PLAYER_NAME': u'Brandon Knight',
#   u'PLUS_MINUS': -152,
#   u'PTS': 827,
#   u'REB': 157,
#   'SEC_PLAYED': 0.07333333333326664,
#   u'STL': 54,
#   u'TD3': 1,
#   u'TEAM_ABBREVIATION': u'PHX',
#   u'TEAM_ID': 1610612756,
#   u'TOV': 145,
#   u'W': 13,
#   u'W_PCT': 0.31},
#  {u'AGE': 30.0,
#   u'AST': 34,
#   u'BLK': 11,
#   u'BLKA': 7,
#   u'CFID': 5,
#   u'CFPARAMS': u'201575,1610612744',
#   u'DD2': 0,
#   u'DREB': 90,
#   u'FG3A': 97,
#   u'FG3M': 44,
#   u'FG3_PCT': 0.454,
#   u'FGA': 162,
#   u'FGM': 74,
#   u'FG_PCT': 0.457,
#   u'FTA': 12,
#   u'FTM': 7,
#   u'FT_PCT': 0.583,
#   u'GP': 38,
#   u'L': 4,
#   u'MIN': 616.03,
#   'MIN_PLAYED': 616.0,
#   u'OREB': 14,
#   u'PF': 29,
#   u'PFD': 7,
#   u'PLAYER_ID': 201575,
#   u'PLAYER_NAME': u'Brandon Rush',
#   u'PLUS_MINUS': 21,
#   u'PTS': 199,
#   u'REB': 104,
#   'SEC_PLAYED': 0.029999999999972715,
#   u'STL': 13,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_ID': 1610612744,
#   u'TOV': 20,
#   u'W': 34,
#   u'W_PCT': 0.895},
#  {u'AGE': 30.0,
#   u'AST': 32,
#   u'BLK': 1,
#   u'BLKA': 3,
#   u'CFID': 5,
#   u'CFPARAMS': u'203148,1610612766',
#   u'DD2': 0,
#   u'DREB': 22,
#   u'FG3A': 24,
#   u'FG3M': 9,
#   u'FG3_PCT': 0.375,
#   u'FGA': 98,
#   u'FGM': 44,
#   u'FG_PCT': 0.449,
#   u'FTA': 30,
#   u'FTM': 28,
#   u'FT_PCT': 0.933,
#   u'GP': 27,
#   u'L': 15,
#   u'MIN': 292.2816666666667,
#   'MIN_PLAYED': 292.0,
#   u'OREB': 3,
#   u'PF': 18,
#   u'PFD': 32,
#   u'PLAYER_ID': 203148,
#   u'PLAYER_NAME': u'Brian Roberts',
#   u'PLUS_MINUS': -31,
#   u'PTS': 125,
#   u'REB': 25,
#   'SEC_PLAYED': 0.2816666666666947,
#   u'STL': 7,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'CHA',
#   u'TEAM_ID': 1610612766,
#   u'TOV': 16,
#   u'W': 12,
#   u'W_PCT': 0.444},
#  {u'AGE': 27.0,
#   u'AST': 76,
#   u'BLK': 92,
#   u'BLKA': 36,
#   u'CFID': 5,
#   u'CFPARAMS': u'201572,1610612751',
#   u'DD2': 21,
#   u'DREB': 268,
#   u'FG3A': 5,
#   u'FG3M': 0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 768,
#   u'FGM': 381,
#   u'FG_PCT': 0.496,
#   u'FTA': 259,
#   u'FTM': 201,
#   u'FT_PCT': 0.776,
#   u'GP': 48,
#   u'L': 36,
#   u'MIN': 1607.25,
#   'MIN_PLAYED': 1607.0,
#   u'OREB': 139,
#   u'PF': 146,
#   u'PFD': 217,
#   u'PLAYER_ID': 201572,
#   u'PLAYER_NAME': u'Brook Lopez',
#   u'PLUS_MINUS': -131,
#   u'PTS': 963,
#   u'REB': 407,
#   'SEC_PLAYED': 0.25,
#   u'STL': 37,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'BKN',
#   u'TEAM_ID': 1610612751,
#   u'TOV': 108,
#   u'W': 12,
#   u'W_PCT': 0.25},
#  {u'AGE': 20.0,
#   u'AST': 0,
#   u'BLK': 0,
#   u'BLKA': 0,
#   u'CFID': 5,
#   u'CFPARAMS': u'203998,1610612761',
#   u'DD2': 0,
#   u'DREB': 1,
#   u'FG3A': 0,
#   u'FG3M': 0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 1,
#   u'FGM': 0,
#   u'FG_PCT': 0.0,
#   u'FTA': 0,
#   u'FTM': 0,
#   u'FT_PCT': 0.0,
#   u'GP': 2,
#   u'L': 0,
#   u'MIN': 2.3,
#   'MIN_PLAYED': 2.0,
#   u'OREB': 0,
#   u'PF': 0,
#   u'PFD': 0,
#   u'PLAYER_ID': 203998,
#   u'PLAYER_NAME': u'Bruno Caboclo',
#   u'PLUS_MINUS': -3,
#   u'PTS': 0,
#   u'REB': 1,
#   'SEC_PLAYED': 0.2999999999999998,
#   u'STL': 1,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'TOR',
#   u'TEAM_ID': 1610612761,
#   u'TOV': 1,
#   u'W': 2,
#   u'W_PCT': 1.0},
#  {u'AGE': 23.0,
#   u'AST': 3,
#   u'BLK': 0,
#   u'BLKA': 0,
#   u'CFID': 5,
#   u'CFPARAMS': u'203955,1610612756',
#   u'DD2': 0,
#   u'DREB': 0,
#   u'FG3A': 3,
#   u'FG3M': 0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 8,
#   u'FGM': 2,
#   u'FG_PCT': 0.25,
#   u'FTA': 0,
#   u'FTM': 0,
#   u'FT_PCT': 0.0,
#   u'GP': 3,
#   u'L': 3,
#   u'MIN': 32.7,
#   'MIN_PLAYED': 32.0,
#   u'OREB': 0,
#   u'PF': 2,
#   u'PFD': 0,
#   u'PLAYER_ID': 203955,
#   u'PLAYER_NAME': u'Bryce Cotton',
#   u'PLUS_MINUS': -14,
#   u'PTS': 4,
#   u'REB': 0,
#   'SEC_PLAYED': 0.7000000000000028,
#   u'STL': 3,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'PHX',
#   u'TEAM_ID': 1610612756,
#   u'TOV': 5,
#   u'W': 0,
#   u'W_PCT': 0.0},
#  {u'AGE': 23.0,
#   u'AST': 3,
#   u'BLK': 1,
#   u'BLKA': 3,
#   u'CFID': 5,
#   u'CFPARAMS': u'1626214,1610612740',
#   u'DD2': 0,
#   u'DREB': 12,
#   u'FG3A': 11,
#   u'FG3M': 5,
#   u'FG3_PCT': 0.455,
#   u'FGA': 21,
#   u'FGM': 9,
#   u'FG_PCT': 0.429,
#   u'FTA': 7,
#   u'FTM': 2,
#   u'FT_PCT': 0.286,
#   u'GP': 5,
#   u'L': 1,
#   u'MIN': 78.85166666666667,
#   'MIN_PLAYED': 78.0,
#   u'OREB': 3,
#   u'PF': 5,
#   u'PFD': 5,
#   u'PLAYER_ID': 1626214,
#   u'PLAYER_NAME': u'Bryce Dejean-Jones',
#   u'PLUS_MINUS': -11,
#   u'PTS': 25,
#   u'REB': 15,
#   'SEC_PLAYED': 0.8516666666666737,
#   u'STL': 3,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'NOP',
#   u'TEAM_ID': 1610612740,
#   u'TOV': 2,
#   u'W': 4,
#   u'W_PCT': 0.8},
#  {u'AGE': 24.0,
#   u'AST': 201,
#   u'BLK': 9,
#   u'BLKA': 49,
#   u'CFID': 5,
#   u'CFPARAMS': u'203468,1610612757',
#   u'DD2': 2,
#   u'DREB': 138,
#   u'FG3A': 288,
#   u'FG3M': 113,
#   u'FG3_PCT': 0.392,
#   u'FGA': 842,
#   u'FGM': 371,
#   u'FG_PCT': 0.441,
#   u'FTA': 121,
#   u'FTM': 97,
#   u'FT_PCT': 0.802,
#   u'GP': 46,
#   u'L': 24,
#   u'MIN': 1614.5733333333333,
#   'MIN_PLAYED': 1614.0,
#   u'OREB': 27,
#   u'PF': 105,
#   u'PFD': 108,
#   u'PLAYER_ID': 203468,
#   u'PLAYER_NAME': u'CJ McCollum',
#   u'PLUS_MINUS': 76,
#   u'PTS': 952,
#   u'REB': 165,
#   'SEC_PLAYED': 0.5733333333332666,
#   u'STL': 51,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'POR',
#   u'TEAM_ID': 1610612757,
#   u'TOV': 101,
#   u'W': 22,
#   u'W_PCT': 0.478},
#  {u'AGE': 28.0,
#   u'AST': 46,
#   u'BLK': 20,
#   u'BLKA': 24,
#   u'CFID': 5,
#   u'CFPARAMS': u'101139,1610612754',
#   u'DD2': 0,
#   u'DREB': 115,
#   u'FG3A': 269,
#   u'FG3M': 94,
#   u'FG3_PCT': 0.349,
#   u'FGA': 437,
#   u'FGM': 171,
#   u'FG_PCT': 0.391,
#   u'FTA': 98,
#   u'FTM': 73,
#   u'FT_PCT': 0.745,
#   u'GP': 42,
#   u'L': 20,
#   u'MIN': 1089.6166666666666,
#   'MIN_PLAYED': 1089.0,
#   u'OREB': 20,
#   u'PF': 102,
#   u'PFD': 77,
#   u'PLAYER_ID': 101139,
#   u'PLAYER_NAME': u'CJ Miles',
#   u'PLUS_MINUS': 5,
#   u'PTS': 509,
#   u'REB': 135,
#   'SEC_PLAYED': 0.6166666666665606,
#   u'STL': 43,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'IND',
#   u'TEAM_ID': 1610612754,
#   u'TOV': 50,
#   u'W': 22,
#   u'W_PCT': 0.524},
#  {u'AGE': 31.0,
#   u'AST': 25,
#   u'BLK': 0,
#   u'BLKA': 1,
#   u'CFID': 5,
#   u'CFPARAMS': u'201228,1610612753',
#   u'DD2': 0,
#   u'DREB': 12,
#   u'FG3A': 16,
#   u'FG3M': 5,
#   u'FG3_PCT': 0.313,
#   u'FGA': 38,
#   u'FGM': 14,
#   u'FG_PCT': 0.368,
#   u'FTA': 7,
#   u'FTM': 5,
#   u'FT_PCT': 0.714,
#   u'GP': 8,
#   u'L': 5,
#   u'MIN': 156.45,
#   'MIN_PLAYED': 156.0,
#   u'OREB': 4,
#   u'PF': 10,
#   u'PFD': 12,
#   u'PLAYER_ID': 201228,
#   u'PLAYER_NAME': u'CJ Watson',
#   u'PLUS_MINUS': 27,
#   u'PTS': 38,
#   u'REB': 16,
#   'SEC_PLAYED': 0.44999999999998863,
#   u'STL': 8,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'ORL',
#   u'TEAM_ID': 1610612753,
#   u'TOV': 6,
#   u'W': 3,
#   u'W_PCT': 0.375},
#  {u'AGE': 25.0,
#   u'AST': 2,
#   u'BLK': 0,
#   u'BLKA': 2,
#   u'CFID': 5,
#   u'CFPARAMS': u'203912,1610612746',
#   u'DD2': 0,
#   u'DREB': 2,
#   u'FG3A': 0,
#   u'FG3M': 0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 8,
#   u'FGM': 3,
#   u'FG_PCT': 0.375,
#   u'FTA': 0,
#   u'FTM': 0,
#   u'FT_PCT': 0.0,
#   u'GP': 6,
#   u'L': 3,
#   u'MIN': 18.233333333333334,
#   'MIN_PLAYED': 18.0,
#   u'OREB': 0,
#   u'PF': 1,
#   u'PFD': 0,
#   u'PLAYER_ID': 203912,
#   u'PLAYER_NAME': u'CJ Wilcox',
#   u'PLUS_MINUS': 1,
#   u'PTS': 6,
#   u'REB': 2,
#   'SEC_PLAYED': 0.23333333333333428,
#   u'STL': 0,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'LAC',
#   u'TEAM_ID': 1610612746,
#   u'TOV': 0,
#   u'W': 3,
#   u'W_PCT': 0.5},
#  {u'AGE': 25.0,
#   u'AST': 1,
#   u'BLK': 1,
#   u'BLKA': 2,
#   u'CFID': 5,
#   u'CFPARAMS': u'203946,1610612741',
#   u'DD2': 0,
#   u'DREB': 10,
#   u'FG3A': 2,
#   u'FG3M': 0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 16,
#   u'FGM': 5,
#   u'FG_PCT': 0.313,
#   u'FTA': 0,
#   u'FTM': 0,
#   u'FT_PCT': 0.0,
#   u'GP': 10,
#   u'L': 6,
#   u'MIN': 38.233333333333334,
#   'MIN_PLAYED': 38.0,
#   u'OREB': 4,
#   u'PF': 8,
#   u'PFD': 1,
#   u'PLAYER_ID': 203946,
#   u'PLAYER_NAME': u'Cameron Bairstow',
#   u'PLUS_MINUS': 4,
#   u'PTS': 10,
#   u'REB': 14,
#   'SEC_PLAYED': 0.23333333333333428,
#   u'STL': 1,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'CHI',
#   u'TEAM_ID': 1610612741,
#   u'TOV': 2,
#   u'W': 4,
#   u'W_PCT': 0.4},
#  {u'AGE': 21.0,
#   u'AST': 58,
#   u'BLK': 4,
#   u'BLKA': 6,
#   u'CFID': 5,
#   u'CFPARAMS': u'1626166,1610612760',
#   u'DD2': 0,
#   u'DREB': 48,
#   u'FG3A': 63,
#   u'FG3M': 26,
#   u'FG3_PCT': 0.413,
#   u'FGA': 151,
#   u'FGM': 67,
#   u'FG_PCT': 0.444,
#   u'FTA': 8,
#   u'FTM': 6,
#   u'FT_PCT': 0.75,
#   u'GP': 32,
#   u'L': 5,
#   u'MIN': 365.395,
#   'MIN_PLAYED': 365.0,
#   u'OREB': 4,
#   u'PF': 42,
#   u'PFD': 14,
#   u'PLAYER_ID': 1626166,
#   u'PLAYER_NAME': u'Cameron Payne',
#   u'PLUS_MINUS': -32,
#   u'PTS': 166,
#   u'REB': 52,
#   'SEC_PLAYED': 0.3949999999999818,
#   u'STL': 23,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'OKC',
#   u'TEAM_ID': 1610612760,
#   u'TOV': 19,
#   u'W': 27,
#   u'W_PCT': 0.844},
#  {u'AGE': 32.0,
#   u'AST': 4,
#   u'BLK': 3,
#   u'BLKA': 3,
#   u'CFID': 5,
#   u'CFPARAMS': u'201171,1610612755',
#   u'DD2': 0,
#   u'DREB': 22,
#   u'FG3A': 2,
#   u'FG3M': 1,
#   u'FG3_PCT': 0.5,
#   u'FGA': 61,
#   u'FGM': 35,
#   u'FG_PCT': 0.574,
#   u'FTA': 23,
#   u'FTM': 15,
#   u'FT_PCT': 0.652,
#   u'GP': 11,
#   u'L': 8,
#   u'MIN': 141.13833333333332,
#   'MIN_PLAYED': 141.0,
#   u'OREB': 10,
#   u'PF': 19,
#   u'PFD': 18,
#   u'PLAYER_ID': 201171,
#   u'PLAYER_NAME': u'Carl Landry',
#   u'PLUS_MINUS': 12,
#   u'PTS': 86,
#   u'REB': 32,
#   'SEC_PLAYED': 0.1383333333333212,
#   u'STL': 5,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'PHI',
#   u'TEAM_ID': 1610612755,
#   u'TOV': 9,
#   u'W': 3,
#   u'W_PCT': 0.273},
#  {u'AGE': 31.0,
#   u'AST': 177,
#   u'BLK': 22,
#   u'BLKA': 50,
#   u'CFID': 5,
#   u'CFPARAMS': u'2546,1610612752',
#   u'DD2': 12,
#   u'DREB': 260,
#   u'FG3A': 175,
#   u'FG3M': 59,
#   u'FG3_PCT': 0.337,
#   u'FGA': 753,
#   u'FGM': 325,
#   u'FG_PCT': 0.432,
#   u'FTA': 248,
#   u'FTM': 204,
#   u'FT_PCT': 0.823,
#   u'GP': 43,
#   u'L': 20,
#   u'MIN': 1485.2016666666666,
#   'MIN_PLAYED': 1485.0,
#   u'OREB': 64,
#   u'PF': 103,
#   u'PFD': 196,
#   u'PLAYER_ID': 2546,
#   u'PLAYER_NAME': u'Carmelo Anthony',
#   u'PLUS_MINUS': 53,
#   u'PTS': 913,
#   u'REB': 324,
#   'SEC_PLAYED': 0.20166666666659694,
#   u'STL': 40,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'NYK',
#   u'TEAM_ID': 1610612752,
#   u'TOV': 106,
#   u'W': 23,
#   u'W_PCT': 0.535},
#  {u'AGE': 35.0,
#   u'AST': 3,
#   u'BLK': 0,
#   u'BLKA': 0,
#   u'CFID': 5,
#   u'CFPARAMS': u'2406,1610612758',
#   u'DD2': 0,
#   u'DREB': 8,
#   u'FG3A': 8,
#   u'FG3M': 1,
#   u'FG3_PCT': 0.125,
#   u'FGA': 26,
#   u'FGM': 11,
#   u'FG_PCT': 0.423,
#   u'FTA': 2,
#   u'FTM': 1,
#   u'FT_PCT': 0.5,
#   u'GP': 9,
#   u'L': 8,
#   u'MIN': 86.36833333333334,
#   'MIN_PLAYED': 86.0,
#   u'OREB': 3,
#   u'PF': 7,
#   u'PFD': 2,
#   u'PLAYER_ID': 2406,
#   u'PLAYER_NAME': u'Caron Butler',
#   u'PLUS_MINUS': -43,
#   u'PTS': 24,
#   u'REB': 11,
#   'SEC_PLAYED': 0.3683333333333394,
#   u'STL': 5,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'SAC',
#   u'TEAM_ID': 1610612758,
#   u'TOV': 2,
#   u'W': 1,
#   u'W_PCT': 0.111},
#  {u'AGE': 27.0,
#   u'AST': 101,
#   u'BLK': 14,
#   u'BLKA': 25,
#   u'CFID': 5,
#   u'CFPARAMS': u'202718,1610612742',
#   u'DD2': 1,
#   u'DREB': 161,
#   u'FG3A': 145,
#   u'FG3M': 58,
#   u'FG3_PCT': 0.4,
#   u'FGA': 390,
#   u'FGM': 190,
#   u'FG_PCT': 0.487,
#   u'FTA': 82,
#   u'FTM': 50,
#   u'FT_PCT': 0.61,
#   u'GP': 41,
#   u'L': 19,
#   u'MIN': 1124.8916666666667,
#   'MIN_PLAYED': 1124.0,
#   u'OREB': 15,
#   u'PF': 73,
#   u'PFD': 80,
#   u'PLAYER_ID': 202718,
#   u'PLAYER_NAME': u'Chandler Parsons',
#   u'PLUS_MINUS': -16,
#   u'PTS': 488,
#   u'REB': 176,
#   'SEC_PLAYED': 0.8916666666666515,
#   u'STL': 22,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'DAL',
#   u'TEAM_ID': 1610612742,
#   u'TOV': 57,
#   u'W': 22,
#   u'W_PCT': 0.537},
#  {u'AGE': 32.0,
#   u'AST': 43,
#   u'BLK': 19,
#   u'BLKA': 2,
#   u'CFID': 5,
#   u'CFPARAMS': u'101112,1610612753',
#   u'DD2': 0,
#   u'DREB': 106,
#   u'FG3A': 111,
#   u'FG3M': 46,
#   u'FG3_PCT': 0.414,
#   u'FGA': 169,
#   u'FGM': 75,
#   u'FG_PCT': 0.444,
#   u'FTA': 21,
#   u'FTM': 19,
#   u'FT_PCT': 0.905,
#   u'GP': 40,
#   u'L': 22,
#   u'MIN': 699.485,
#   'MIN_PLAYED': 699.0,
#   u'OREB': 20,
#   u'PF': 64,
#   u'PFD': 36,
#   u'PLAYER_ID': 101112,
#   u'PLAYER_NAME': u'Channing Frye',
#   u'PLUS_MINUS': 79,
#   u'PTS': 215,
#   u'REB': 126,
#   'SEC_PLAYED': 0.48500000000001364,
#   u'STL': 21,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'ORL',
#   u'TEAM_ID': 1610612753,
#   u'TOV': 29,
#   u'W': 18,
#   u'W_PCT': 0.45},
#  {u'AGE': 32.0,
#   u'AST': 2,
#   u'BLK': 0,
#   u'BLKA': 0,
#   u'CFID': 5,
#   u'CFPARAMS': u'101236,1610612745',
#   u'DD2': 0,
#   u'DREB': 8,
#   u'FG3A': 0,
#   u'FG3M': 0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 2,
#   u'FGM': 1,
#   u'FG_PCT': 0.5,
#   u'FTA': 2,
#   u'FTM': 2,
#   u'FT_PCT': 1.0,
#   u'GP': 2,
#   u'L': 1,
#   u'MIN': 23.833333333333332,
#   'MIN_PLAYED': 23.0,
#   u'OREB': 0,
#   u'PF': 6,
#   u'PFD': 1,
#   u'PLAYER_ID': 101236,
#   u'PLAYER_NAME': u'Charles Hayes',
#   u'PLUS_MINUS': -3,
#   u'PTS': 4,
#   u'REB': 8,
#   'SEC_PLAYED': 0.8333333333333321,
#   u'STL': 0,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'HOU',
#   u'TEAM_ID': 1610612745,
#   u'TOV': 3,
#   u'W': 1,
#   u'W_PCT': 0.5},
#  {u'AGE': 31.0,
#   u'AST': 17,
#   u'BLK': 11,
#   u'BLKA': 6,
#   u'CFID': 5,
#   u'CFPARAMS': u'101111,1610612742',
#   u'DD2': 0,
#   u'DREB': 94,
#   u'FG3A': 126,
#   u'FG3M': 31,
#   u'FG3_PCT': 0.246,
#   u'FGA': 243,
#   u'FGM': 92,
#   u'FG_PCT': 0.379,
#   u'FTA': 16,
#   u'FTM': 14,
#   u'FT_PCT': 0.875,
#   u'GP': 40,
#   u'L': 20,
#   u'MIN': 484.28333333333336,
#   'MIN_PLAYED': 484.0,
#   u'OREB': 14,
#   u'PF': 54,
#   u'PFD': 8,
#   u'PLAYER_ID': 101111,
#   u'PLAYER_NAME': u'Charlie Villanueva',
#   u'PLUS_MINUS': -92,
#   u'PTS': 229,
#   u'REB': 108,
#   'SEC_PLAYED': 0.28333333333335986,
#   u'STL': 12,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'DAL',
#   u'TEAM_ID': 1610612742,
#   u'TOV': 21,
#   u'W': 20,
#   u'W_PCT': 0.5},
#  {u'AGE': 27.0,
#   u'AST': 43,
#   u'BLK': 7,
#   u'BLKA': 8,
#   u'CFID': 5,
#   u'CFPARAMS': u'201978,1610612754',
#   u'DD2': 0,
#   u'DREB': 76,
#   u'FG3A': 61,
#   u'FG3M': 18,
#   u'FG3_PCT': 0.295,
#   u'FGA': 164,
#   u'FGM': 66,
#   u'FG_PCT': 0.402,
#   u'FTA': 44,
#   u'FTM': 31,
#   u'FT_PCT': 0.705,
#   u'GP': 40,
#   u'L': 19,
#   u'MIN': 626.0866666666667,
#   'MIN_PLAYED': 626.0,
#   u'OREB': 23,
#   u'PF': 37,
#   u'PFD': 36,
#   u'PLAYER_ID': 201978,
#   u'PLAYER_NAME': u'Chase Budinger',
#   u'PLUS_MINUS': 32,
#   u'PTS': 181,
#   u'REB': 99,
#   'SEC_PLAYED': 0.08666666666670153,
#   u'STL': 22,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'IND',
#   u'TEAM_ID': 1610612754,
#   u'TOV': 25,
#   u'W': 21,
#   u'W_PCT': 0.525},
#  {u'AGE': 37.0,
#   u'AST': 3,
#   u'BLK': 3,
#   u'BLKA': 1,
#   u'CFID': 5,
#   u'CFPARAMS': u'2365,1610612748',
#   u'DD2': 0,
#   u'DREB': 6,
#   u'FG3A': 5,
#   u'FG3M': 2,
#   u'FG3_PCT': 0.4,
#   u'FGA': 10,
#   u'FGM': 4,
#   u'FG_PCT': 0.4,
#   u'FTA': 4,
#   u'FTM': 3,
#   u'FT_PCT': 0.75,
#   u'GP': 7,
#   u'L': 3,
#   u'MIN': 36.083333333333336,
#   'MIN_PLAYED': 36.0,
#   u'OREB': 3,
#   u'PF': 4,
#   u'PFD': 4,
#   u'PLAYER_ID': 2365,
#   u'PLAYER_NAME': u'Chris Andersen',
#   u'PLUS_MINUS': -17,
#   u'PTS': 13,
#   u'REB': 9,
#   'SEC_PLAYED': 0.0833333333333357,
#   u'STL': 1,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'MIA',
#   u'TEAM_ID': 1610612748,
#   u'TOV': 2,
#   u'W': 4,
#   u'W_PCT': 0.571},
#  {u'AGE': 31.0,
#   u'AST': 118,
#   u'BLK': 33,
#   u'BLKA': 27,
#   u'CFID': 5,
#   u'CFPARAMS': u'2547,1610612748',
#   u'DD2': 15,
#   u'DREB': 312,
#   u'FG3A': 201,
#   u'FG3M': 75,
#   u'FG3_PCT': 0.373,
#   u'FGA': 670,
#   u'FGM': 319,
#   u'FG_PCT': 0.476,
#   u'FTA': 239,
#   u'FTM': 191,
#   u'FT_PCT': 0.799,
#   u'GP': 47,
#   u'L': 21,
#   u'MIN': 1580.1133333333332,
#   'MIN_PLAYED': 1580.0,
#   u'OREB': 44,
#   u'PF': 84,
#   u'PFD': 184,
#   u'PLAYER_ID': 2547,
#   u'PLAYER_NAME': u'Chris Bosh',
#   u'PLUS_MINUS': 48,
#   u'PTS': 904,
#   u'REB': 356,
#   'SEC_PLAYED': 0.11333333333323026,
#   u'STL': 35,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'MIA',
#   u'TEAM_ID': 1610612748,
#   u'TOV': 67,
#   u'W': 26,
#   u'W_PCT': 0.553},
#  {u'AGE': 31.0,
#   u'AST': 11,
#   u'BLK': 0,
#   u'BLKA': 2,
#   u'CFID': 5,
#   u'CFPARAMS': u'203142,1610612749',
#   u'DD2': 0,
#   u'DREB': 9,
#   u'FG3A': 36,
#   u'FG3M': 10,
#   u'FG3_PCT': 0.278,
#   u'FGA': 51,
#   u'FGM': 17,
#   u'FG_PCT': 0.333,
#   u'FTA': 7,
#   u'FTM': 6,
#   u'FT_PCT': 0.857,
#   u'GP': 23,
#   u'L': 13,
#   u'MIN': 153.16333333333333,
#   'MIN_PLAYED': 153.0,
#   u'OREB': 1,
#   u'PF': 16,
#   u'PFD': 7,
#   u'PLAYER_ID': 203142,
#   u'PLAYER_NAME': u'Chris Copeland',
#   u'PLUS_MINUS': -83,
#   u'PTS': 50,
#   u'REB': 10,
#   'SEC_PLAYED': 0.1633333333333269,
#   u'STL': 2,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'MIL',
#   u'TEAM_ID': 1610612749,
#   u'TOV': 6,
#   u'W': 10,
#   u'W_PCT': 0.435},
#  {u'AGE': 25.0,
#   u'AST': 30,
#   u'BLK': 7,
#   u'BLKA': 8,
#   u'CFID': 5,
#   u'CFPARAMS': u'203187,1610612762',
#   u'DD2': 0,
#   u'DREB': 53,
#   u'FG3A': 49,
#   u'FG3M': 14,
#   u'FG3_PCT': 0.286,
#   u'FGA': 101,
#   u'FGM': 39,
#   u'FG_PCT': 0.386,
#   u'FTA': 24,
#   u'FTM': 18,
#   u'FT_PCT': 0.75,
#   u'GP': 37,
#   u'L': 18,
#   u'MIN': 417.2783333333333,
#   'MIN_PLAYED': 417.0,
#   u'OREB': 11,
#   u'PF': 48,
#   u'PFD': 14,
#   u'PLAYER_ID': 203187,
#   u'PLAYER_NAME': u'Chris Johnson',
#   u'PLUS_MINUS': 10,
#   u'PTS': 110,
#   u'REB': 64,
#   'SEC_PLAYED': 0.27833333333330756,
#   u'STL': 22,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'UTA',
#   u'TEAM_ID': 1610612762,
#   u'TOV': 21,
#   u'W': 19,
#   u'W_PCT': 0.514},
#  {u'AGE': 33.0,
#   u'AST': 5,
#   u'BLK': 0,
#   u'BLKA': 2,
#   u'CFID': 5,
#   u'CFPARAMS': u'2549,1610612757',
#   u'DD2': 0,
# ...
#   u'GP': 44,
#   u'L': 25,
#   u'MIN': 801.2583333333333,
#   'MIN_PLAYED': 801.0,
#   u'OREB': 42,
#   u'PF': 64,
#   u'PFD': 40,
#   u'PLAYER_ID': 1626168,
#   u'PLAYER_NAME': u'Trey Lyles',
#   u'PLUS_MINUS': -22,
#   u'PTS': 208,
#   u'REB': 179,
#   'SEC_PLAYED': 0.25833333333332575,
#   u'STL': 12,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'UTA',
#   u'TEAM_ID': 1610612762,
#   u'TOV': 36,
#   u'W': 19,
#   u'W_PCT': 0.432},
#  {u'AGE': 24.0,
#   u'AST': 32,
#   u'BLK': 18,
#   u'BLKA': 23,
#   u'CFID': 5,
#   u'CFPARAMS': u'202684,1610612739',
#   u'DD2': 12,
#   u'DREB': 276,
#   u'FG3A': 0,
#   u'FG3M': 0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 241,
#   u'FGM': 136,
#   u'FG_PCT': 0.564,
#   u'FTA': 135,
#   u'FTM': 81,
#   u'FT_PCT': 0.6,
#   u'GP': 45,
#   u'L': 12,
#   u'MIN': 1236.7983333333334,
#   'MIN_PLAYED': 1236.0,
#   u'OREB': 148,
#   u'PF': 111,
#   u'PFD': 119,
#   u'PLAYER_ID': 202684,
#   u'PLAYER_NAME': u'Tristan Thompson',
#   u'PLUS_MINUS': 210,
#   u'PTS': 353,
#   u'REB': 424,
#   'SEC_PLAYED': 0.7983333333334031,
#   u'STL': 14,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'CLE',
#   u'TEAM_ID': 1610612739,
#   u'TOV': 33,
#   u'W': 33,
#   u'W_PCT': 0.733},
#  {u'AGE': 24.0,
#   u'AST': 8,
#   u'BLK': 1,
#   u'BLKA': 3,
#   u'CFID': 5,
#   u'CFPARAMS': u'203584,1610612766',
#   u'DD2': 0,
#   u'DREB': 26,
#   u'FG3A': 66,
#   u'FG3M': 34,
#   u'FG3_PCT': 0.515,
#   u'FGA': 104,
#   u'FGM': 49,
#   u'FG_PCT': 0.471,
#   u'FTA': 8,
#   u'FTM': 4,
#   u'FT_PCT': 0.5,
#   u'GP': 25,
#   u'L': 13,
#   u'MIN': 270.69166666666666,
#   'MIN_PLAYED': 270.0,
#   u'OREB': 5,
#   u'PF': 27,
#   u'PFD': 5,
#   u'PLAYER_ID': 203584,
#   u'PLAYER_NAME': u'Troy Daniels',
#   u'PLUS_MINUS': -23,
#   u'PTS': 136,
#   u'REB': 31,
#   'SEC_PLAYED': 0.6916666666666629,
#   u'STL': 6,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'CHA',
#   u'TEAM_ID': 1610612766,
#   u'TOV': 16,
#   u'W': 12,
#   u'W_PCT': 0.48},
#  {u'AGE': 28.0,
#   u'AST': 164,
#   u'BLK': 6,
#   u'BLKA': 21,
#   u'CFID': 5,
#   u'CFPARAMS': u'201951,1610612745',
#   u'DD2': 1,
#   u'DREB': 59,
#   u'FG3A': 79,
#   u'FG3M': 26,
#   u'FG3_PCT': 0.329,
#   u'FGA': 249,
#   u'FGM': 98,
#   u'FG_PCT': 0.394,
#   u'FTA': 74,
#   u'FTM': 52,
#   u'FT_PCT': 0.703,
#   u'GP': 42,
#   u'L': 24,
#   u'MIN': 1019.6183333333333,
#   'MIN_PLAYED': 1019.0,
#   u'OREB': 20,
#   u'PF': 63,
#   u'PFD': 63,
#   u'PLAYER_ID': 201951,
#   u'PLAYER_NAME': u'Ty Lawson',
#   u'PLUS_MINUS': -116,
#   u'PTS': 274,
#   u'REB': 79,
#   'SEC_PLAYED': 0.6183333333333394,
#   u'STL': 38,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'HOU',
#   u'TEAM_ID': 1610612745,
#   u'TOV': 70,
#   u'W': 18,
#   u'W_PCT': 0.429},
#  {u'AGE': 21.0,
#   u'AST': 21,
#   u'BLK': 1,
#   u'BLKA': 1,
#   u'CFID': 5,
#   u'CFPARAMS': u'203898,1610612749',
#   u'DD2': 0,
#   u'DREB': 18,
#   u'FG3A': 14,
#   u'FG3M': 4,
#   u'FG3_PCT': 0.286,
#   u'FGA': 60,
#   u'FGM': 24,
#   u'FG_PCT': 0.4,
#   u'FTA': 12,
#   u'FTM': 9,
#   u'FT_PCT': 0.75,
#   u'GP': 22,
#   u'L': 13,
#   u'MIN': 197.62166666666667,
#   'MIN_PLAYED': 197.0,
#   u'OREB': 3,
#   u'PF': 23,
#   u'PFD': 10,
#   u'PLAYER_ID': 203898,
#   u'PLAYER_NAME': u'Tyler Ennis',
#   u'PLUS_MINUS': -50,
#   u'PTS': 61,
#   u'REB': 21,
#   'SEC_PLAYED': 0.6216666666666697,
#   u'STL': 4,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'MIL',
#   u'TEAM_ID': 1610612749,
#   u'TOV': 14,
#   u'W': 9,
#   u'W_PCT': 0.409},
#  {u'AGE': 30.0,
#   u'AST': 7,
#   u'BLK': 6,
#   u'BLKA': 10,
#   u'CFID': 5,
#   u'CFPARAMS': u'201946,1610612766',
#   u'DD2': 1,
#   u'DREB': 37,
#   u'FG3A': 3,
#   u'FG3M': 2,
#   u'FG3_PCT': 0.667,
#   u'FGA': 52,
#   u'FGM': 22,
#   u'FG_PCT': 0.423,
#   u'FTA': 42,
#   u'FTM': 24,
#   u'FT_PCT': 0.571,
#   u'GP': 27,
#   u'L': 13,
#   u'MIN': 249.33166666666668,
#   'MIN_PLAYED': 249.0,
#   u'OREB': 34,
#   u'PF': 40,
#   u'PFD': 34,
#   u'PLAYER_ID': 201946,
#   u'PLAYER_NAME': u'Tyler Hansbrough',
#   u'PLUS_MINUS': -33,
#   u'PTS': 70,
#   u'REB': 71,
#   'SEC_PLAYED': 0.33166666666667766,
#   u'STL': 9,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'CHA',
#   u'TEAM_ID': 1610612766,
#   u'TOV': 11,
#   u'W': 14,
#   u'W_PCT': 0.519},
#  {u'AGE': 23.0,
#   u'AST': 79,
#   u'BLK': 14,
#   u'BLKA': 20,
#   u'CFID': 5,
#   u'CFPARAMS': u'204020,1610612748',
#   u'DD2': 0,
#   u'DREB': 81,
#   u'FG3A': 70,
#   u'FG3M': 27,
#   u'FG3_PCT': 0.386,
#   u'FGA': 242,
#   u'FGM': 118,
#   u'FG_PCT': 0.488,
#   u'FTA': 64,
#   u'FTM': 51,
#   u'FT_PCT': 0.797,
#   u'GP': 36,
#   u'L': 17,
#   u'MIN': 862.5733333333334,
#   'MIN_PLAYED': 862.0,
#   u'OREB': 28,
#   u'PF': 66,
#   u'PFD': 64,
#   u'PLAYER_ID': 204020,
#   u'PLAYER_NAME': u'Tyler Johnson',
#   u'PLUS_MINUS': 9,
#   u'PTS': 314,
#   u'REB': 109,
#   'SEC_PLAYED': 0.5733333333333803,
#   u'STL': 24,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'MIA',
#   u'TEAM_ID': 1610612748,
#   u'TOV': 47,
#   u'W': 19,
#   u'W_PCT': 0.528},
#  {u'AGE': 26.0,
#   u'AST': 10,
#   u'BLK': 4,
#   u'BLKA': 7,
#   u'CFID': 5,
#   u'CFPARAMS': u'203092,1610612738',
#   u'DD2': 0,
#   u'DREB': 46,
#   u'FG3A': 0,
#   u'FG3M': 0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 120,
#   u'FGM': 55,
#   u'FG_PCT': 0.458,
#   u'FTA': 38,
#   u'FTM': 26,
#   u'FT_PCT': 0.684,
#   u'GP': 31,
#   u'L': 11,
#   u'MIN': 273.77,
#   'MIN_PLAYED': 273.0,
#   u'OREB': 24,
#   u'PF': 44,
#   u'PFD': 31,
#   u'PLAYER_ID': 203092,
#   u'PLAYER_NAME': u'Tyler Zeller',
#   u'PLUS_MINUS': -22,
#   u'PTS': 136,
#   u'REB': 70,
#   'SEC_PLAYED': 0.7699999999999818,
#   u'STL': 6,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'BOS',
#   u'TEAM_ID': 1610612738,
#   u'TOV': 23,
#   u'W': 20,
#   u'W_PCT': 0.645},
#  {u'AGE': 26.0,
#   u'AST': 164,
#   u'BLK': 8,
#   u'BLKA': 23,
#   u'CFID': 5,
#   u'CFPARAMS': u'201936,1610612740',
#   u'DD2': 6,
#   u'DREB': 109,
#   u'FG3A': 85,
#   u'FG3M': 33,
#   u'FG3_PCT': 0.388,
#   u'FGA': 314,
#   u'FGM': 136,
#   u'FG_PCT': 0.433,
#   u'FTA': 93,
#   u'FTM': 74,
#   u'FT_PCT': 0.796,
#   u'GP': 25,
#   u'L': 14,
#   u'MIN': 765.335,
#   'MIN_PLAYED': 765.0,
#   u'OREB': 20,
#   u'PF': 66,
#   u'PFD': 74,
#   u'PLAYER_ID': 201936,
#   u'PLAYER_NAME': u'Tyreke Evans',
#   u'PLUS_MINUS': -14,
#   u'PTS': 379,
#   u'REB': 129,
#   'SEC_PLAYED': 0.3350000000000364,
#   u'STL': 32,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'NOP',
#   u'TEAM_ID': 1610612740,
#   u'TOV': 73,
#   u'W': 11,
#   u'W_PCT': 0.44},
#  {u'AGE': 33.0,
#   u'AST': 38,
#   u'BLK': 24,
#   u'BLKA': 15,
#   u'CFID': 5,
#   u'CFPARAMS': u'2199,1610612756',
#   u'DD2': 6,
#   u'DREB': 222,
#   u'FG3A': 1,
#   u'FG3M': 0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 155,
#   u'FGM': 75,
#   u'FG_PCT': 0.484,
#   u'FTA': 99,
#   u'FTM': 64,
#   u'FT_PCT': 0.646,
#   u'GP': 39,
#   u'L': 28,
#   u'MIN': 905.6016666666667,
#   'MIN_PLAYED': 905.0,
#   u'OREB': 100,
#   u'PF': 75,
#   u'PFD': 88,
#   u'PLAYER_ID': 2199,
#   u'PLAYER_NAME': u'Tyson Chandler',
#   u'PLUS_MINUS': -278,
#   u'PTS': 214,
#   u'REB': 322,
#   'SEC_PLAYED': 0.6016666666666879,
#   u'STL': 20,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'PHX',
#   u'TEAM_ID': 1610612756,
#   u'TOV': 48,
#   u'W': 11,
#   u'W_PCT': 0.282},
#  {u'AGE': 19.0,
#   u'AST': 14,
#   u'BLK': 1,
#   u'BLKA': 4,
#   u'CFID': 5,
#   u'CFPARAMS': u'1626145,1610612750',
#   u'DD2': 0,
#   u'DREB': 12,
#   u'FG3A': 4,
#   u'FG3M': 2,
#   u'FG3_PCT': 0.5,
#   u'FGA': 31,
#   u'FGM': 11,
#   u'FG_PCT': 0.355,
#   u'FTA': 5,
#   u'FTM': 3,
#   u'FT_PCT': 0.6,
#   u'GP': 9,
#   u'L': 8,
#   u'MIN': 98.02333333333333,
#   'MIN_PLAYED': 98.0,
#   u'OREB': 3,
#   u'PF': 6,
#   u'PFD': 6,
#   u'PLAYER_ID': 1626145,
#   u'PLAYER_NAME': u'Tyus Jones',
#   u'PLUS_MINUS': -83,
#   u'PTS': 27,
#   u'REB': 15,
#   'SEC_PLAYED': 0.023333333333326323,
#   u'STL': 4,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'MIN',
#   u'TEAM_ID': 1610612750,
#   u'TOV': 8,
#   u'W': 1,
#   u'W_PCT': 0.111},
#  {u'AGE': 35.0,
#   u'AST': 13,
#   u'BLK': 2,
#   u'BLKA': 1,
#   u'CFID': 5,
#   u'CFPARAMS': u'2617,1610612748',
#   u'DD2': 0,
#   u'DREB': 45,
#   u'FG3A': 6,
#   u'FG3M': 1,
#   u'FG3_PCT': 0.167,
#   u'FGA': 42,
#   u'FGM': 15,
#   u'FG_PCT': 0.357,
#   u'FTA': 7,
#   u'FTM': 7,
#   u'FT_PCT': 1.0,
#   u'GP': 23,
#   u'L': 9,
#   u'MIN': 196.19833333333332,
#   'MIN_PLAYED': 196.0,
#   u'OREB': 8,
#   u'PF': 15,
#   u'PFD': 16,
#   u'PLAYER_ID': 2617,
#   u'PLAYER_NAME': u'Udonis Haslem',
#   u'PLUS_MINUS': -26,
#   u'PTS': 38,
#   u'REB': 53,
#   'SEC_PLAYED': 0.19833333333332348,
#   u'STL': 4,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'MIA',
#   u'TEAM_ID': 1610612748,
#   u'TOV': 5,
#   u'W': 14,
#   u'W_PCT': 0.609},
#  {u'AGE': 23.0,
#   u'AST': 163,
#   u'BLK': 24,
#   u'BLKA': 40,
#   u'CFID': 5,
#   u'CFPARAMS': u'203506,1610612753',
#   u'DD2': 2,
#   u'DREB': 172,
#   u'FG3A': 156,
#   u'FG3M': 55,
#   u'FG3_PCT': 0.353,
#   u'FGA': 501,
#   u'FGM': 203,
#   u'FG_PCT': 0.405,
#   u'FTA': 121,
#   u'FTM': 100,
#   u'FT_PCT': 0.826,
#   u'GP': 41,
#   u'L': 22,
#   u'MIN': 1248.3933333333334,
#   'MIN_PLAYED': 1248.0,
#   u'OREB': 22,
#   u'PF': 93,
#   u'PFD': 109,
#   u'PLAYER_ID': 203506,
#   u'PLAYER_NAME': u'Victor Oladipo',
#   u'PLUS_MINUS': -17,
#   u'PTS': 561,
#   u'REB': 194,
#   'SEC_PLAYED': 0.39333333333343035,
#   u'STL': 51,
#   u'TD3': 1,
#   u'TEAM_ABBREVIATION': u'ORL',
#   u'TEAM_ID': 1610612753,
#   u'TOV': 88,
#   u'W': 19,
#   u'W_PCT': 0.463},
#  {u'AGE': 39.0,
#   u'AST': 20,
#   u'BLK': 9,
#   u'BLKA': 5,
#   u'CFID': 5,
#   u'CFPARAMS': u'1713,1610612763',
#   u'DD2': 0,
#   u'DREB': 39,
#   u'FG3A': 59,
#   u'FG3M': 14,
#   u'FG3_PCT': 0.237,
#   u'FGA': 108,
#   u'FGM': 33,
#   u'FG_PCT': 0.306,
#   u'FTA': 22,
#   u'FTM': 19,
#   u'FT_PCT': 0.864,
#   u'GP': 29,
#   u'L': 11,
#   u'MIN': 367.2733333333333,
#   'MIN_PLAYED': 367.0,
#   u'OREB': 9,
#   u'PF': 45,
#   u'PFD': 26,
#   u'PLAYER_ID': 1713,
#   u'PLAYER_NAME': u'Vince Carter',
#   u'PLUS_MINUS': -28,
#   u'PTS': 99,
#   u'REB': 48,
#   'SEC_PLAYED': 0.2733333333333121,
#   u'STL': 12,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'MEM',
#   u'TEAM_ID': 1610612763,
#   u'TOV': 12,
#   u'W': 18,
#   u'W_PCT': 0.621},
#  {u'AGE': 23.0,
#   u'AST': 2,
#   u'BLK': 5,
#   u'BLKA': 2,
#   u'CFID': 5,
#   u'CFPARAMS': u'204002,1610612737',
#   u'DD2': 0,
#   u'DREB': 9,
#   u'FG3A': 0,
#   u'FG3M': 0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 15,
#   u'FGM': 8,
#   u'FG_PCT': 0.533,
#   u'FTA': 8,
#   u'FTM': 3,
#   u'FT_PCT': 0.375,
#   u'GP': 8,
#   u'L': 4,
#   u'MIN': 57.96666666666667,
#   'MIN_PLAYED': 57.0,
#   u'OREB': 6,
#   u'PF': 5,
#   u'PFD': 4,
#   u'PLAYER_ID': 204002,
#   u'PLAYER_NAME': u'Walter Tavares',
#   u'PLUS_MINUS': -23,
#   u'PTS': 19,
#   u'REB': 15,
#   'SEC_PLAYED': 0.9666666666666686,
#   u'STL': 1,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'ATL',
#   u'TEAM_ID': 1610612737,
#   u'TOV': 4,
#   u'W': 4,
#   u'W_PCT': 0.5},
#  {u'AGE': 28.0,
#   u'AST': 41,
#   u'BLK': 3,
#   u'BLKA': 14,
#   u'CFID': 5,
#   u'CFPARAMS': u'201961,1610612751',
#   u'DD2': 0,
#   u'DREB': 91,
#   u'FG3A': 145,
#   u'FG3M': 48,
#   u'FG3_PCT': 0.331,
#   u'FGA': 317,
#   u'FGM': 121,
#   u'FG_PCT': 0.382,
#   u'FTA': 34,
#   u'FTM': 27,
#   u'FT_PCT': 0.794,
#   u'GP': 47,
#   u'L': 36,
#   u'MIN': 918.27,
#   'MIN_PLAYED': 918.0,
#   u'OREB': 11,
#   u'PF': 45,
#   u'PFD': 28,
#   u'PLAYER_ID': 201961,
#   u'PLAYER_NAME': u'Wayne Ellington',
#   u'PLUS_MINUS': -178,
#   u'PTS': 317,
#   u'REB': 102,
#   'SEC_PLAYED': 0.2699999999999818,
#   u'STL': 31,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'BKN',
#   u'TEAM_ID': 1610612751,
#   u'TOV': 28,
#   u'W': 11,
#   u'W_PCT': 0.234},
#  {u'AGE': 28.0,
#   u'AST': 26,
#   u'BLK': 26,
#   u'BLKA': 5,
#   u'CFID': 5,
#   u'CFPARAMS': u'202325,1610612746',
#   u'DD2': 0,
#   u'DREB': 99,
#   u'FG3A': 175,
#   u'FG3M': 59,
#   u'FG3_PCT': 0.337,
#   u'FGA': 273,
#   u'FGM': 116,
#   u'FG_PCT': 0.425,
#   u'FTA': 30,
#   u'FTM': 18,
#   u'FT_PCT': 0.6,
#   u'GP': 47,
#   u'L': 16,
#   u'MIN': 873.07,
#   'MIN_PLAYED': 873.0,
#   u'OREB': 20,
#   u'PF': 88,
#   u'PFD': 23,
#   u'PLAYER_ID': 202325,
#   u'PLAYER_NAME': u'Wesley Johnson',
#   u'PLUS_MINUS': 60,
#   u'PTS': 309,
#   u'REB': 119,
#   'SEC_PLAYED': 0.07000000000005002,
#   u'STL': 47,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'LAC',
#   u'TEAM_ID': 1610612746,
#   u'TOV': 28,
#   u'W': 31,
#   u'W_PCT': 0.66},
#  {u'AGE': 29.0,
#   u'AST': 83,
#   u'BLK': 12,
#   u'BLKA': 20,
#   u'CFID': 5,
#   u'CFPARAMS': u'202083,1610612742',
#   u'DD2': 0,
#   u'DREB': 119,
#   u'FG3A': 303,
#   u'FG3M': 107,
#   u'FG3_PCT': 0.353,
#   u'FGA': 497,
#   u'FGM': 193,
#   u'FG_PCT': 0.388,
#   u'FTA': 82,
#   u'FTM': 70,
#   u'FT_PCT': 0.854,
#   u'GP': 45,
#   u'L': 20,
#   u'MIN': 1486.9016666666666,
#   'MIN_PLAYED': 1486.0,
#   u'OREB': 19,
#   u'PF': 97,
#   u'PFD': 81,
#   u'PLAYER_ID': 202083,
#   u'PLAYER_NAME': u'Wesley Matthews',
#   u'PLUS_MINUS': 95,
#   u'PTS': 563,
#   u'REB': 138,
#   'SEC_PLAYED': 0.9016666666666424,
#   u'STL': 47,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'DAL',
#   u'TEAM_ID': 1610612742,
#   u'TOV': 47,
#   u'W': 25,
#   u'W_PCT': 0.556},
#  {u'AGE': 25.0,
#   u'AST': 114,
#   u'BLK': 20,
#   u'BLKA': 35,
#   u'CFID': 5,
#   u'CFPARAMS': u'203115,1610612743',
#   u'DD2': 3,
#   u'DREB': 243,
#   u'FG3A': 199,
#   u'FG3M': 76,
#   u'FG3_PCT': 0.382,
#   u'FGA': 604,
#   u'FGM': 269,
#   u'FG_PCT': 0.445,
#   u'FTA': 151,
#   u'FTM': 129,
#   u'FT_PCT': 0.854,
#   u'GP': 48,
#   u'L': 30,
#   u'MIN': 1382.0716666666667,
#   'MIN_PLAYED': 1382.0,
#   u'OREB': 42,
#   u'PF': 87,
#   u'PFD': 123,
#   u'PLAYER_ID': 203115,
#   u'PLAYER_NAME': u'Will Barton',
#   u'PLUS_MINUS': -81,
#   u'PTS': 743,
#   u'REB': 285,
#   'SEC_PLAYED': 0.07166666666671517,
#   u'STL': 43,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'DEN',
#   u'TEAM_ID': 1610612743,
#   u'TOV': 77,
#   u'W': 18,
#   u'W_PCT': 0.375},
#  {u'AGE': 22.0,
#   u'AST': 14,
#   u'BLK': 39,
#   u'BLKA': 7,
#   u'CFID': 5,
#   u'CFPARAMS': u'1626161,1610612758',
#   u'DD2': 2,
#   u'DREB': 113,
#   u'FG3A': 0,
#   u'FG3M': 0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 127,
#   u'FGM': 76,
#   u'FG_PCT': 0.598,
#   u'FTA': 63,
#   u'FTM': 36,
#   u'FT_PCT': 0.571,
#   u'GP': 32,
#   u'L': 18,
#   u'MIN': 636.0516666666666,
#   'MIN_PLAYED': 636.0,
#   u'OREB': 66,
#   u'PF': 76,
#   u'PFD': 40,
#   u'PLAYER_ID': 1626161,
#   u'PLAYER_NAME': u'Willie Cauley-Stein',
#   u'PLUS_MINUS': 39,
#   u'PTS': 188,
#   u'REB': 179,
#   'SEC_PLAYED': 0.051666666666619676,
#   u'STL': 21,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'SAC',
#   u'TEAM_ID': 1610612758,
#   u'TOV': 19,
#   u'W': 14,
#   u'W_PCT': 0.438},
#  {u'AGE': 25.0,
#   u'AST': 5,
#   u'BLK': 14,
#   u'BLKA': 4,
#   u'CFID': 5,
#   u'CFPARAMS': u'203186,1610612751',
#   u'DD2': 0,
#   u'DREB': 44,
#   u'FG3A': 0,
#   u'FG3M': 0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 80,
#   u'FGM': 47,
#   u'FG_PCT': 0.588,
#   u'FTA': 32,
#   u'FTM': 16,
#   u'FT_PCT': 0.5,
#   u'GP': 26,
#   u'L': 20,
#   u'MIN': 266.525,
#   'MIN_PLAYED': 266.0,
#   u'OREB': 26,
#   u'PF': 34,
#   u'PFD': 43,
#   u'PLAYER_ID': 203186,
#   u'PLAYER_NAME': u'Willie Reed',
#   u'PLUS_MINUS': -48,
#   u'PTS': 110,
#   u'REB': 70,
#   'SEC_PLAYED': 0.5249999999999773,
#   u'STL': 3,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'BKN',
#   u'TEAM_ID': 1610612751,
#   u'TOV': 13,
#   u'W': 6,
#   u'W_PCT': 0.231},
#  {u'AGE': 20.0,
#   u'AST': 151,
#   u'BLK': 5,
#   u'BLKA': 36,
#   u'CFID': 5,
#   u'CFPARAMS': u'203897,1610612750',
#   u'DD2': 0,
#   u'DREB': 125,
#   u'FG3A': 142,
#   u'FG3M': 49,
#   u'FG3_PCT': 0.345,
#   u'FGA': 522,
#   u'FGM': 229,
#   u'FG_PCT': 0.439,
#   u'FTA': 124,
#   u'FTM': 101,
#   u'FT_PCT': 0.815,
#   u'GP': 48,
#   u'L': 34,
#   u'MIN': 1126.8533333333332,
#   'MIN_PLAYED': 1126.0,
#   u'OREB': 20,
#   u'PF': 113,
#   u'PFD': 90,
#   u'PLAYER_ID': 203897,
#   u'PLAYER_NAME': u'Zach LaVine',
#   u'PLUS_MINUS': -179,
#   u'PTS': 608,
#   u'REB': 145,
#   'SEC_PLAYED': 0.8533333333332394,
#   u'STL': 31,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'MIN',
#   u'TEAM_ID': 1610612750,
#   u'TOV': 92,
#   u'W': 14,
#   u'W_PCT': 0.292},
#  {u'AGE': 34.0,
#   u'AST': 60,
#   u'BLK': 8,
#   u'BLKA': 40,
#   u'CFID': 5,
#   u'CFPARAMS': u'2216,1610612763',
#   u'DD2': 11,
#   u'DREB': 213,
#   u'FG3A': 6,
#   u'FG3M': 1,
#   u'FG3_PCT': 0.167,
#   u'FGA': 500,
#   u'FGM': 240,
#   u'FG_PCT': 0.48,
#   u'FTA': 127,
#   u'FTM': 96,
#   u'FT_PCT': 0.756,
#   u'GP': 42,
#   u'L': 18,
#   u'MIN': 1199.3783333333333,
#   'MIN_PLAYED': 1199.0,
#   u'OREB': 124,
#   u'PF': 82,
#   u'PFD': 116,
#   u'PLAYER_ID': 2216,
#   u'PLAYER_NAME': u'Zach Randolph',
#   u'PLUS_MINUS': -22,
#   u'PTS': 577,
#   u'REB': 337,
#   'SEC_PLAYED': 0.3783333333333303,
#   u'STL': 25,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'MEM',
#   u'TEAM_ID': 1610612763,
#   u'TOV': 59,
#   u'W': 24,
#   u'W_PCT': 0.571},
#  {u'AGE': 31.0,
#   u'AST': 84,
#   u'BLK': 16,
#   u'BLKA': 27,
#   u'CFID': 5,
#   u'CFPARAMS': u'2585,1610612742',
#   u'DD2': 21,
#   u'DREB': 311,
#   u'FG3A': 2,
#   u'FG3M': 0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 323,
#   u'FGM': 156,
#   u'FG_PCT': 0.483,
#   u'FTA': 190,
#   u'FTM': 150,
#   u'FT_PCT': 0.789,
#   u'GP': 44,
#   u'L': 19,
#   u'MIN': 1288.1483333333333,
#   'MIN_PLAYED': 1288.0,
#   u'OREB': 162,
#   u'PF': 118,
#   u'PFD': 178,
#   u'PLAYER_ID': 2585,
#   u'PLAYER_NAME': u'Zaza Pachulia',
#   u'PLUS_MINUS': 46,
#   u'PTS': 462,
#   u'REB': 473,
#   'SEC_PLAYED': 0.1483333333333121,
#   u'STL': 44,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'DAL',
#   u'TEAM_ID': 1610612742,
#   u'TOV': 83,
#   u'W': 25,
#   u'W_PCT': 0.568}]

# %%
adv_stats = parser.playerstats(scraper.playerstats(season='2015-16', MeasureType='Advanced'))

# %%
adv_stats
# Out:
# [{u'AGE': 31.0,
#   u'AST_PCT': 0.235,
#   u'AST_RATIO': 22.0,
#   u'AST_TO': 2.4,
#   u'CFID': 5,
#   u'CFPARAMS': u'201166,1610612741',
#   u'DEF_RATING': 99.5,
#   u'DREB_PCT': 0.092,
#   u'EFG_PCT': 0.494,
#   u'FGA': 247,
#   u'FGA_PG': 7.1,
#   u'FGM': 102,
#   u'FGM_PG': 2.9,
#   u'FG_PCT': 0.413,
#   u'GP': 35,
#   u'L': 14,
#   u'MIN': 16.4,
#   'MIN_PLAYED': 16.0,
#   u'NET_RATING': 4.3,
#   u'OFF_RATING': 103.8,
#   u'OREB_PCT': 0.027,
#   u'PACE': 97.59,
#   u'PIE': 0.087,
#   u'PLAYER_ID': 201166,
#   u'PLAYER_NAME': u'Aaron Brooks',
#   u'REB_PCT': 0.061,
#   'SEC_PLAYED': 0.3999999999999986,
#   u'TEAM_ABBREVIATION': u'CHI',
#   u'TEAM_ID': 1610612741,
#   u'TM_TOV_PCT': 9.2,
#   u'TS_PCT': 0.519,
#   u'USG_PCT': 0.226,
#   u'W': 21,
#   u'W_PCT': 0.6},
#  {u'AGE': 20.0,
#   u'AST_PCT': 0.102,
#   u'AST_RATIO': 14.5,
#   u'AST_TO': 1.47,
#   u'CFID': 5,
#   u'CFPARAMS': u'203932,1610612753',
#   u'DEF_RATING': 101.8,
#   u'DREB_PCT': 0.199,
#   u'EFG_PCT': 0.524,
#   u'FGA': 252,
#   u'FGA_PG': 5.7,
#   u'FGM': 121,
#   u'FGM_PG': 2.8,
#   u'FG_PCT': 0.48,
#   u'GP': 44,
#   u'L': 25,
#   u'MIN': 20.3,
#   'MIN_PLAYED': 20.0,
#   u'NET_RATING': -2.6,
#   u'OFF_RATING': 99.2,
#   u'OREB_PCT': 0.093,
#   u'PACE': 96.19,
#   u'PIE': 0.116,
#   u'PLAYER_ID': 203932,
#   u'PLAYER_NAME': u'Aaron Gordon',
#   u'REB_PCT': 0.145,
#   'SEC_PLAYED': 0.3000000000000007,
#   u'TEAM_ABBREVIATION': u'ORL',
#   u'TEAM_ID': 1610612753,
#   u'TM_TOV_PCT': 9.8,
#   u'TS_PCT': 0.562,
#   u'USG_PCT': 0.167,
#   u'W': 19,
#   u'W_PCT': 0.432},
#  {u'AGE': 21.0,
#   u'AST_PCT': 0.0,
#   u'AST_RATIO': 0.0,
#   u'AST_TO': 0.0,
#   u'CFID': 5,
#   u'CFPARAMS': u'1626151,1610612766',
#   u'DEF_RATING': 93.8,
#   u'DREB_PCT': 0.116,
#   u'EFG_PCT': 0.313,
#   u'FGA': 8,
#   u'FGA_PG': 0.7,
#   u'FGM': 2,
#   u'FGM_PG': 0.2,
#   u'FG_PCT': 0.25,
#   u'GP': 12,
#   u'L': 5,
#   u'MIN': 4.3,
#   'MIN_PLAYED': 4.0,
#   u'NET_RATING': 7.7,
#   u'OFF_RATING': 101.5,
#   u'OREB_PCT': 0.064,
#   u'PACE': 102.53,
#   u'PIE': 0.015,
#   u'PLAYER_ID': 1626151,
#   u'PLAYER_NAME': u'Aaron Harrison',
#   u'REB_PCT': 0.089,
#   'SEC_PLAYED': 0.2999999999999998,
#   u'TEAM_ABBREVIATION': u'CHA',
#   u'TEAM_ID': 1610612766,
#   u'TM_TOV_PCT': 15.8,
#   u'TS_PCT': 0.329,
#   u'USG_PCT': 0.112,
#   u'W': 7,
#   u'W_PCT': 0.583},
#  {u'AGE': 24.0,
#   u'AST_PCT': 0.077,
#   u'AST_RATIO': 11.7,
#   u'AST_TO': 0.74,
#   u'CFID': 5,
#   u'CFPARAMS': u'203940,1610612750',
#   u'DEF_RATING': 106.7,
#   u'DREB_PCT': 0.199,
#   u'EFG_PCT': 0.457,
#   u'FGA': 81,
#   u'FGA_PG': 2.7,
#   u'FGM': 33,
#   u'FGM_PG': 1.1,
#   u'FG_PCT': 0.407,
#   u'GP': 30,
#   u'L': 19,
#   u'MIN': 9.5,
#   'MIN_PLAYED': 9.0,
#   u'NET_RATING': -6.2,
#   u'OFF_RATING': 100.5,
#   u'OREB_PCT': 0.044,
#   u'PACE': 96.3,
#   u'PIE': 0.049,
#   u'PLAYER_ID': 203940,
#   u'PLAYER_NAME': u'Adreian Payne',
#   u'REB_PCT': 0.127,
#   'SEC_PLAYED': 0.5,
#   u'TEAM_ABBREVIATION': u'MIN',
#   u'TEAM_ID': 1610612750,
#   u'TM_TOV_PCT': 15.9,
#   u'TS_PCT': 0.475,
#   u'USG_PCT': 0.168,
#   u'W': 11,
#   u'W_PCT': 0.367},
#  {u'AGE': 29.0,
#   u'AST_PCT': 0.161,
#   u'AST_RATIO': 16.7,
#   u'AST_TO': 2.3,
#   u'CFID': 5,
#   u'CFPARAMS': u'201143,1610612737',
#   u'DEF_RATING': 99.6,
#   u'DREB_PCT': 0.171,
#   u'EFG_PCT': 0.537,
#   u'FGA': 623,
#   u'FGA_PG': 13.0,
#   u'FGM': 312,
#   u'FGM_PG': 6.5,
#   u'FG_PCT': 0.501,
#   u'GP': 48,
#   u'L': 21,
#   u'MIN': 31.5,
#   'MIN_PLAYED': 31.0,
#   u'NET_RATING': 3.0,
#   u'OFF_RATING': 102.6,
#   u'OREB_PCT': 0.075,
#   u'PACE': 99.28,
#   u'PIE': 0.133,
#   u'PLAYER_ID': 201143,
#   u'PLAYER_NAME': u'Al Horford',
#   u'REB_PCT': 0.123,
#   'SEC_PLAYED': 0.5,
#   u'TEAM_ABBREVIATION': u'ATL',
#   u'TEAM_ID': 1610612737,
#   u'TM_TOV_PCT': 7.3,
#   u'TS_PCT': 0.555,
#   u'USG_PCT': 0.214,
#   u'W': 27,
#   u'W_PCT': 0.563},
#  {u'AGE': 31.0,
#   u'AST_PCT': 0.112,
#   u'AST_RATIO': 10.5,
#   u'AST_TO': 2.14,
#   u'CFID': 5,
#   u'CFPARAMS': u'2744,1610612766',
#   u'DEF_RATING': 103.4,
#   u'DREB_PCT': 0.215,
#   u'EFG_PCT': 0.482,
#   u'FGA': 222,
#   u'FGA_PG': 11.7,
#   u'FGM': 107,
#   u'FGM_PG': 5.6,
#   u'FG_PCT': 0.482,
#   u'GP': 19,
#   u'L': 7,
#   u'MIN': 25.2,
#   'MIN_PLAYED': 25.0,
#   u'NET_RATING': 0.1,
#   u'OFF_RATING': 103.4,
#   u'OREB_PCT': 0.051,
#   u'PACE': 96.99,
#   u'PIE': 0.111,
#   u'PLAYER_ID': 2744,
#   u'PLAYER_NAME': u'Al Jefferson',
#   u'REB_PCT': 0.131,
#   'SEC_PLAYED': 0.1999999999999993,
#   u'TEAM_ABBREVIATION': u'CHA',
#   u'TEAM_ID': 1610612766,
#   u'TM_TOV_PCT': 4.9,
#   u'TS_PCT': 0.495,
#   u'USG_PCT': 0.244,
#   u'W': 12,
#   u'W_PCT': 0.632},
#  {u'AGE': 25.0,
#   u'AST_PCT': 0.078,
#   u'AST_RATIO': 11.5,
#   u'AST_TO': 0.94,
#   u'CFID': 5,
#   u'CFPARAMS': u'202329,1610612757',
#   u'DEF_RATING': 104.7,
#   u'DREB_PCT': 0.197,
#   u'EFG_PCT': 0.491,
#   u'FGA': 444,
#   u'FGA_PG': 9.3,
#   u'FGM': 183,
#   u'FGM_PG': 3.8,
#   u'FG_PCT': 0.412,
#   u'GP': 48,
#   u'L': 26,
#   u'MIN': 29.0,
#   'MIN_PLAYED': 29.0,
#   u'NET_RATING': 0.9,
#   u'OFF_RATING': 105.6,
#   u'OREB_PCT': 0.045,
#   u'PACE': 98.08,
#   u'PIE': 0.089,
#   u'PLAYER_ID': 202329,
#   u'PLAYER_NAME': u'Al-Farouq Aminu',
#   u'REB_PCT': 0.121,
#   'SEC_PLAYED': 0.0,
#   u'TEAM_ABBREVIATION': u'POR',
#   u'TEAM_ID': 1610612757,
#   u'TM_TOV_PCT': 12.2,
#   u'TS_PCT': 0.521,
#   u'USG_PCT': 0.178,
#   u'W': 22,
#   u'W_PCT': 0.458},
#  {u'AGE': 24.0,
#   u'AST_PCT': 0.138,
#   u'AST_RATIO': 11.9,
#   u'AST_TO': 1.2,
#   u'CFID': 5,
#   u'CFPARAMS': u'202692,1610612762',
#   u'DEF_RATING': 104.2,
#   u'DREB_PCT': 0.131,
#   u'EFG_PCT': 0.454,
#   u'FGA': 325,
#   u'FGA_PG': 11.6,
#   u'FGM': 133,
#   u'FGM_PG': 4.8,
#   u'FG_PCT': 0.409,
#   u'GP': 28,
#   u'L': 16,
#   u'MIN': 27.1,
#   'MIN_PLAYED': 27.0,
#   u'NET_RATING': -3.4,
#   u'OFF_RATING': 100.9,
#   u'OREB_PCT': 0.024,
#   u'PACE': 95.48,
#   u'PIE': 0.096,
#   u'PLAYER_ID': 202692,
#   u'PLAYER_NAME': u'Alec Burks',
#   u'REB_PCT': 0.076,
#   'SEC_PLAYED': 0.10000000000000142,
#   u'TEAM_ABBREVIATION': u'UTA',
#   u'TEAM_ID': 1610612762,
#   u'TM_TOV_PCT': 9.9,
#   u'TS_PCT': 0.518,
#   u'USG_PCT': 0.256,
#   u'W': 12,
#   u'W_PCT': 0.429},
#  {u'AGE': 22.0,
#   u'AST_PCT': 0.074,
#   u'AST_RATIO': 10.0,
#   u'AST_TO': 0.63,
#   u'CFID': 5,
#   u'CFPARAMS': u'203458,1610612756',
#   u'DEF_RATING': 103.5,
#   u'DREB_PCT': 0.237,
#   u'EFG_PCT': 0.458,
#   u'FGA': 259,
#   u'FGA_PG': 5.8,
#   u'FGM': 118,
#   u'FGM_PG': 2.6,
#   u'FG_PCT': 0.456,
#   u'GP': 45,
#   u'L': 31,
#   u'MIN': 19.6,
#   'MIN_PLAYED': 19.0,
#   u'NET_RATING': -5.2,
#   u'OFF_RATING': 98.2,
#   u'OREB_PCT': 0.099,
#   u'PACE': 99.68,
#   u'PIE': 0.087,
#   u'PLAYER_ID': 203458,
#   u'PLAYER_NAME': u'Alex Len',
#   u'REB_PCT': 0.167,
#   'SEC_PLAYED': 0.6000000000000014,
#   u'TEAM_ABBREVIATION': u'PHX',
#   u'TEAM_ID': 1610612756,
#   u'TM_TOV_PCT': 15.9,
#   u'TS_PCT': 0.51,
#   u'USG_PCT': 0.181,
#   u'W': 14,
#   u'W_PCT': 0.311},
#  {u'AGE': 27.0,
#   u'AST_PCT': 0.059,
#   u'AST_RATIO': 8.5,
#   u'AST_TO': 0.8,
#   u'CFID': 5,
#   u'CFPARAMS': u'201582,1610612740',
#   u'DEF_RATING': 102.2,
#   u'DREB_PCT': 0.268,
#   u'EFG_PCT': 0.517,
#   u'FGA': 143,
#   u'FGA_PG': 4.1,
#   u'FGM': 74,
#   u'FGM_PG': 2.1,
#   u'FG_PCT': 0.517,
#   u'GP': 35,
#   u'L': 25,
#   u'MIN': 12.2,
#   'MIN_PLAYED': 12.0,
#   u'NET_RATING': -1.3,
#   u'OFF_RATING': 101.0,
#   u'OREB_PCT': 0.102,
#   u'PACE': 99.15,
#   u'PIE': 0.102,
#   u'PLAYER_ID': 201582,
#   u'PLAYER_NAME': u'Alexis Ajinca',
#   u'REB_PCT': 0.184,
#   'SEC_PLAYED': 0.1999999999999993,
#   u'TEAM_ABBREVIATION': u'NOP',
#   u'TEAM_ID': 1610612740,
#   u'TM_TOV_PCT': 10.7,
#   u'TS_PCT': 0.548,
#   u'USG_PCT': 0.179,
#   u'W': 10,
#   u'W_PCT': 0.286},
#  {u'AGE': 23.0,
#   u'AST_PCT': 0.074,
#   u'AST_RATIO': 10.2,
#   u'AST_TO': 1.37,
#   u'CFID': 5,
#   u'CFPARAMS': u'203459,1610612757',
#   u'DEF_RATING': 106.0,
#   u'DREB_PCT': 0.1,
#   u'EFG_PCT': 0.546,
#   u'FGA': 447,
#   u'FGA_PG': 9.3,
#   u'FGM': 209,
#   u'FGM_PG': 4.4,
#   u'FG_PCT': 0.468,
#   u'GP': 48,
#   u'L': 26,
#   u'MIN': 26.2,
#   'MIN_PLAYED': 26.0,
#   u'NET_RATING': -2.2,
#   u'OFF_RATING': 103.8,
#   u'OREB_PCT': 0.011,
#   u'PACE': 97.95,
#   u'PIE': 0.079,
#   u'PLAYER_ID': 203459,
#   u'PLAYER_NAME': u'Allen Crabbe',
#   u'REB_PCT': 0.054,
#   'SEC_PLAYED': 0.1999999999999993,
#   u'TEAM_ABBREVIATION': u'POR',
#   u'TEAM_ID': 1610612757,
#   u'TM_TOV_PCT': 7.5,
#   u'TS_PCT': 0.57,
#   u'USG_PCT': 0.178,
#   u'W': 22,
#   u'W_PCT': 0.458},
#  {u'AGE': 28.0,
#   u'AST_PCT': 0.065,
#   u'AST_RATIO': 18.8,
#   u'AST_TO': 1.53,
#   u'CFID': 5,
#   u'CFPARAMS': u'202087,1610612740',
#   u'DEF_RATING': 103.8,
#   u'DREB_PCT': 0.13,
#   u'EFG_PCT': 0.535,
#   u'FGA': 155,
#   u'FGA_PG': 3.4,
#   u'FGM': 77,
#   u'FGM_PG': 1.7,
#   u'FG_PCT': 0.497,
#   u'GP': 46,
#   u'L': 28,
#   u'MIN': 21.7,
#   'MIN_PLAYED': 21.0,
#   u'NET_RATING': -3.3,
#   u'OFF_RATING': 100.5,
#   u'OREB_PCT': 0.039,
#   u'PACE': 98.8,
#   u'PIE': 0.056,
#   u'PLAYER_ID': 202087,
#   u'PLAYER_NAME': u'Alonzo Gee',
#   u'REB_PCT': 0.085,
#   'SEC_PLAYED': 0.6999999999999993,
#   u'TEAM_ABBREVIATION': u'NOP',
#   u'TEAM_ID': 1610612740,
#   u'TM_TOV_PCT': 12.3,
#   u'TS_PCT': 0.566,
#   u'USG_PCT': 0.089,
#   u'W': 18,
#   u'W_PCT': 0.391},
#  {u'AGE': 33.0,
#   u'AST_PCT': 0.084,
#   u'AST_RATIO': 11.1,
#   u'AST_TO': 0.75,
#   u'CFID': 5,
#   u'CFPARAMS': u'2405,1610612748',
#   u'DEF_RATING': 104.7,
#   u'DREB_PCT': 0.211,
#   u'EFG_PCT': 0.529,
#   u'FGA': 70,
#   u'FGA_PG': 3.7,
#   u'FGM': 37,
#   u'FGM_PG': 1.9,
#   u'FG_PCT': 0.529,
#   u'GP': 19,
#   u'L': 10,
#   u'MIN': 13.1,
#   'MIN_PLAYED': 13.0,
#   u'NET_RATING': -6.3,
#   u'OFF_RATING': 98.5,
#   u'OREB_PCT': 0.096,
#   u'PACE': 91.34,
#   u'PIE': 0.11,
#   u'PLAYER_ID': 2405,
#   u'PLAYER_NAME': u"Amar'e Stoudemire",
#   u'REB_PCT': 0.154,
#   'SEC_PLAYED': 0.09999999999999964,
#   u'TEAM_ABBREVIATION': u'MIA',
#   u'TEAM_ID': 1610612748,
#   u'TM_TOV_PCT': 14.8,
#   u'TS_PCT': 0.568,
#   u'USG_PCT': 0.188,
#   u'W': 9,
#   u'W_PCT': 0.474},
#  {u'AGE': 28.0,
#   u'AST_PCT': 0.11,
#   u'AST_RATIO': 18.9,
#   u'AST_TO': 1.56,
#   u'CFID': 5,
#   u'CFPARAMS': u'101161,1610612738',
#   u'DEF_RATING': 100.0,
#   u'DREB_PCT': 0.19,
#   u'EFG_PCT': 0.599,
#   u'FGA': 263,
#   u'FGA_PG': 5.8,
#   u'FGM': 153,
#   u'FGM_PG': 3.4,
#   u'FG_PCT': 0.582,
#   u'GP': 45,
#   u'L': 21,
#   u'MIN': 23.9,
#   'MIN_PLAYED': 23.0,
#   u'NET_RATING': 5.7,
#   u'OFF_RATING': 105.7,
#   u'OREB_PCT': 0.1,
#   u'PACE': 99.87,
#   u'PIE': 0.106,
#   u'PLAYER_ID': 101161,
#   u'PLAYER_NAME': u'Amir Johnson',
#   u'REB_PCT': 0.144,
#   'SEC_PLAYED': 0.8999999999999986,
#   u'TEAM_ABBREVIATION': u'BOS',
#   u'TEAM_ID': 1610612738,
#   u'TM_TOV_PCT': 12.2,
#   u'TS_PCT': 0.602,
#   u'USG_PCT': 0.139,
#   u'W': 24,
#   u'W_PCT': 0.533},
#  {u'AGE': 33.0,
#   u'AST_PCT': 0.101,
#   u'AST_RATIO': 17.3,
#   u'AST_TO': 1.31,
#   u'CFID': 5,
#   u'CFPARAMS': u'2760,1610612739',
#   u'DEF_RATING': 94.2,
#   u'DREB_PCT': 0.237,
#   u'EFG_PCT': 0.426,
#   u'FGA': 61,
#   u'FGA_PG': 2.3,
#   u'FGM': 26,
#   u'FGM_PG': 1.0,
#   u'FG_PCT': 0.426,
#   u'GP': 27,
#   u'L': 8,
#   u'MIN': 9.2,
#   'MIN_PLAYED': 9.0,
#   u'NET_RATING': 6.4,
#   u'OFF_RATING': 100.6,
#   u'OREB_PCT': 0.083,
#   u'PACE': 96.66,
#   u'PIE': 0.104,
#   u'PLAYER_ID': 2760,
#   u'PLAYER_NAME': u'Anderson Varejao',
#   u'REB_PCT': 0.159,
#   'SEC_PLAYED': 0.1999999999999993,
#   u'TEAM_ABBREVIATION': u'CLE',
#   u'TEAM_ID': 1610612739,
#   u'TM_TOV_PCT': 13.2,
#   u'TS_PCT': 0.475,
#   u'USG_PCT': 0.144,
#   u'W': 19,
#   u'W_PCT': 0.704},
#  {u'AGE': 22.0,
#   u'AST_PCT': 0.041,
#   u'AST_RATIO': 4.0,
#   u'AST_TO': 0.39,
#   u'CFID': 5,
#   u'CFPARAMS': u'203083,1610612765',
#   u'DEF_RATING': 100.9,
#   u'DREB_PCT': 0.332,
#   u'EFG_PCT': 0.522,
#   u'FGA': 666,
#   u'FGA_PG': 13.9,
#   u'FGM': 347,
#   u'FGM_PG': 7.2,
#   u'FG_PCT': 0.521,
#   u'GP': 48,
#   u'L': 23,
#   u'MIN': 33.6,
#   'MIN_PLAYED': 33.0,
#   u'NET_RATING': 3.3,
#   u'OFF_RATING': 104.2,
#   u'OREB_PCT': 0.158,
#   u'PACE': 97.99,
#   u'PIE': 0.143,
#   u'PLAYER_ID': 203083,
#   u'PLAYER_NAME': u'Andre Drummond',
#   u'REB_PCT': 0.24,
#   'SEC_PLAYED': 0.6000000000000014,
#   u'TEAM_ABBREVIATION': u'DET',
#   u'TEAM_ID': 1610612765,
#   u'TM_TOV_PCT': 10.2,
#   u'TS_PCT': 0.496,
#   u'USG_PCT': 0.247,
#   u'W': 25,
#   u'W_PCT': 0.521},
#  {u'AGE': 32.0,
#   u'AST_PCT': 0.17,
#   u'AST_RATIO': 31.6,
#   u'AST_TO': 2.88,
#   u'CFID': 5,
#   u'CFPARAMS': u'2738,1610612744',
#   u'DEF_RATING': 97.5,
#   u'DREB_PCT': 0.126,
#   u'EFG_PCT': 0.573,
#   u'FGA': 268,
#   u'FGA_PG': 5.8,
#   u'FGM': 132,
#   u'FGM_PG': 2.9,
#   u'FG_PCT': 0.493,
#   u'GP': 46,
#   u'L': 4,
#   u'MIN': 27.4,
#   'MIN_PLAYED': 27.0,
#   u'NET_RATING': 16.4,
#   u'OFF_RATING': 113.9,
#   u'OREB_PCT': 0.039,
#   u'PACE': 101.37,
#   u'PIE': 0.098,
#   u'PLAYER_ID': 2738,
#   u'PLAYER_NAME': u'Andre Iguodala',
#   u'REB_PCT': 0.085,
#   'SEC_PLAYED': 0.3999999999999986,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_ID': 1610612744,
#   u'TM_TOV_PCT': 11.0,
#   u'TS_PCT': 0.589,
#   u'USG_PCT': 0.119,
#   u'W': 42,
#   u'W_PCT': 0.913},
#  {u'AGE': 39.0,
#   u'AST_PCT': 0.311,
#   u'AST_RATIO': 39.9,
#   u'AST_TO': 2.76,
#   u'CFID': 5,
#   u'CFPARAMS': u'1889,1610612750',
#   u'DEF_RATING': 108.9,
#   u'DREB_PCT': 0.07,
#   u'EFG_PCT': 0.62,
#   u'FGA': 46,
#   u'FGA_PG': 2.3,
#   u'FGM': 28,
#   u'FGM_PG': 1.4,
#   u'FG_PCT': 0.609,
#   u'GP': 20,
#   u'L': 14,
#   u'MIN': 10.8,
#   'MIN_PLAYED': 10.0,
#   u'NET_RATING': 3.4,
#   u'OFF_RATING': 112.3,
#   u'OREB_PCT': 0.033,
#   u'PACE': 92.46,
#   u'PIE': 0.101,
#   u'PLAYER_ID': 1889,
#   u'PLAYER_NAME': u'Andre Miller',
#   u'REB_PCT': 0.053,
#   'SEC_PLAYED': 0.8000000000000007,
#   u'TEAM_ABBREVIATION': u'MIN',
#   u'TEAM_ID': 1610612750,
#   u'TM_TOV_PCT': 14.4,
#   u'TS_PCT': 0.658,
#   u'USG_PCT': 0.155,
#   u'W': 6,
#   u'W_PCT': 0.3},
#  {u'AGE': 24.0,
#   u'AST_PCT': 0.048,
#   u'AST_RATIO': 13.6,
#   u'AST_TO': 1.29,
#   u'CFID': 5,
#   u'CFPARAMS': u'203460,1610612760',
#   u'DEF_RATING': 97.5,
#   u'DREB_PCT': 0.103,
#   u'EFG_PCT': 0.541,
#   u'FGA': 184,
#   u'FGA_PG': 4.1,
#   u'FGM': 91,
#   u'FGM_PG': 2.0,
#   u'FG_PCT': 0.495,
#   u'GP': 45,
#   u'L': 12,
#   u'MIN': 21.7,
#   'MIN_PLAYED': 21.0,
#   u'NET_RATING': 12.5,
#   u'OFF_RATING': 110.0,
#   u'OREB_PCT': 0.061,
#   u'PACE': 98.73,
#   u'PIE': 0.061,
#   u'PLAYER_ID': 203460,
#   u'PLAYER_NAME': u'Andre Roberson',
#   u'REB_PCT': 0.083,
#   'SEC_PLAYED': 0.6999999999999993,
#   u'TEAM_ABBREVIATION': u'OKC',
#   u'TEAM_ID': 1610612760,
#   u'TM_TOV_PCT': 10.6,
#   u'TS_PCT': 0.553,
#   u'USG_PCT': 0.102,
#   u'W': 33,
#   u'W_PCT': 0.733},
#  {u'AGE': 30.0,
#   u'AST_PCT': 0.044,
#   u'AST_RATIO': 4.4,
#   u'AST_TO': 0.54,
#   u'CFID': 5,
#   u'CFPARAMS': u'200745,1610612751',
#   u'DEF_RATING': 111.5,
#   u'DREB_PCT': 0.134,
#   u'EFG_PCT': 0.461,
#   u'FGA': 255,
#   u'FGA_PG': 6.1,
#   u'FGM': 116,
#   u'FGM_PG': 2.8,
#   u'FG_PCT': 0.455,
#   u'GP': 42,
#   u'L': 32,
#   u'MIN': 13.8,
#   'MIN_PLAYED': 13.0,
#   u'NET_RATING': -17.1,
#   u'OFF_RATING': 94.4,
#   u'OREB_PCT': 0.048,
#   u'PACE': 96.79,
#   u'PIE': 0.069,
#   u'PLAYER_ID': 200745,
#   u'PLAYER_NAME': u'Andrea Bargnani',
#   u'REB_PCT': 0.087,
#   'SEC_PLAYED': 0.8000000000000007,
#   u'TEAM_ABBREVIATION': u'BKN',
#   u'TEAM_ID': 1610612751,
#   u'TM_TOV_PCT': 8.2,
#   u'TS_PCT': 0.499,
#   u'USG_PCT': 0.236,
#   u'W': 10,
#   u'W_PCT': 0.238},
#  {u'AGE': 31.0,
#   u'AST_PCT': 0.126,
#   u'AST_RATIO': 26.1,
#   u'AST_TO': 1.78,
#   u'CFID': 5,
#   u'CFPARAMS': u'101106,1610612744',
#   u'DEF_RATING': 96.1,
#   u'DREB_PCT': 0.257,
#   u'EFG_PCT': 0.627,
#   u'FGA': 169,
#   u'FGA_PG': 4.2,
#   u'FGM': 106,
#   u'FGM_PG': 2.7,
#   u'FG_PCT': 0.627,
#   u'GP': 40,
#   u'L': 4,
#   u'MIN': 20.9,
#   'MIN_PLAYED': 20.0,
#   u'NET_RATING': 16.3,
#   u'OFF_RATING': 112.5,
#   u'OREB_PCT': 0.097,
#   u'PACE': 100.49,
#   u'PIE': 0.109,
#   u'PLAYER_ID': 101106,
#   u'PLAYER_NAME': u'Andrew Bogut',
#   u'REB_PCT': 0.183,
#   'SEC_PLAYED': 0.8999999999999986,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_ID': 1610612744,
#   u'TM_TOV_PCT': 14.7,
#   u'TS_PCT': 0.616,
#   u'USG_PCT': 0.119,
#   u'W': 36,
#   u'W_PCT': 0.9},
#  {u'AGE': 26.0,
#   u'AST_PCT': 0.034,
#   u'AST_RATIO': 4.6,
#   u'AST_TO': 0.41,
#   u'CFID': 5,
#   u'CFPARAMS': u'203094,1610612753',
#   u'DEF_RATING': 97.8,
#   u'DREB_PCT': 0.21,
#   u'EFG_PCT': 0.508,
#   u'FGA': 189,
#   u'FGA_PG': 5.7,
#   u'FGM': 84,
#   u'FGM_PG': 2.5,
#   u'FG_PCT': 0.444,
#   u'GP': 33,
#   u'L': 17,
#   u'MIN': 16.0,
#   'MIN_PLAYED': 16.0,
#   u'NET_RATING': -0.2,
#   u'OFF_RATING': 97.6,
#   u'OREB_PCT': 0.048,
#   u'PACE': 96.04,
#   u'PIE': 0.103,
#   u'PLAYER_ID': 203094,
#   u'PLAYER_NAME': u'Andrew Nicholson',
#   u'REB_PCT': 0.13,
#   'SEC_PLAYED': 0.0,
#   u'TEAM_ABBREVIATION': u'ORL',
#   u'TEAM_ID': 1610612753,
#   u'TM_TOV_PCT': 11.2,
#   u'TS_PCT': 0.534,
#   u'USG_PCT': 0.197,
#   u'W': 16,
#   u'W_PCT': 0.485},
#  {u'AGE': 20.0,
#   u'AST_PCT': 0.092,
#   u'AST_RATIO': 7.8,
#   u'AST_TO': 0.84,
#   u'CFID': 5,
#   u'CFPARAMS': u'203952,1610612750',
#   u'DEF_RATING': 105.8,
#   u'DREB_PCT': 0.072,
#   u'EFG_PCT': 0.464,
#   u'FGA': 769,
#   u'FGA_PG': 16.4,
#   u'FGM': 343,
#   u'FGM_PG': 7.3,
#   u'FG_PCT': 0.446,
#   u'GP': 47,
#   u'L': 33,
#   u'MIN': 35.1,
#   'MIN_PLAYED': 35.0,
#   u'NET_RATING': -3.7,
#   u'OFF_RATING': 102.1,
#   u'OREB_PCT': 0.048,
#   u'PACE': 97.52,
#   u'PIE': 0.09,
#   u'PLAYER_ID': 203952,
#   u'PLAYER_NAME': u'Andrew Wiggins',
#   u'REB_PCT': 0.059,
#   'SEC_PLAYED': 0.10000000000000142,
#   u'TEAM_ABBREVIATION': u'MIN',
#   u'TEAM_ID': 1610612750,
#   u'TM_TOV_PCT': 9.2,
#   u'TS_PCT': 0.524,
#   u'USG_PCT': 0.274,
#   u'W': 14,
#   u'W_PCT': 0.298},
#  {u'AGE': 22.0,
#   u'AST_PCT': 0.0,
#   u'AST_RATIO': 0.0,
#   u'AST_TO': 0.0,
#   u'CFID': 5,
#   u'CFPARAMS': u'203461,1610612761',
#   u'DEF_RATING': 114.1,
#   u'DREB_PCT': 0.283,
#   u'EFG_PCT': 0.3,
#   u'FGA': 20,
#   u'FGA_PG': 1.5,
#   u'FGM': 5,
#   u'FGM_PG': 0.4,
#   u'FG_PCT': 0.25,
#   u'GP': 13,
#   u'L': 4,
#   u'MIN': 4.9,
#   'MIN_PLAYED': 4.0,
#   u'NET_RATING': -18.1,
#   u'OFF_RATING': 96.1,
#   u'OREB_PCT': 0.069,
#   u'PACE': 97.62,
#   u'PIE': 0.041,
#   u'PLAYER_ID': 203461,
#   u'PLAYER_NAME': u'Anthony Bennett',
#   u'REB_PCT': 0.153,
#   'SEC_PLAYED': 0.9000000000000004,
#   u'TEAM_ABBREVIATION': u'TOR',
#   u'TEAM_ID': 1610612761,
#   u'TM_TOV_PCT': 14.5,
#   u'TS_PCT': 0.404,
#   u'USG_PCT': 0.183,
#   u'W': 9,
#   u'W_PCT': 0.692},
#  {u'AGE': 23.0,
#   u'AST_PCT': 0.038,
#   u'AST_RATIO': 9.1,
#   u'AST_TO': 0.86,
#   u'CFID': 5,
#   u'CFPARAMS': u'1626148,1610612747',
#   u'DEF_RATING': 100.4,
#   u'DREB_PCT': 0.109,
#   u'EFG_PCT': 0.394,
#   u'FGA': 99,
#   u'FGA_PG': 4.1,
#   u'FGM': 31,
#   u'FGM_PG': 1.3,
#   u'FG_PCT': 0.313,
#   u'GP': 24,
#   u'L': 21,
#   u'MIN': 19.6,
#   'MIN_PLAYED': 19.0,
#   u'NET_RATING': -1.8,
#   u'OFF_RATING': 98.6,
#   u'OREB_PCT': 0.015,
#   u'PACE': 98.26,
#   u'PIE': 0.035,
#   u'PLAYER_ID': 1626148,
#   u'PLAYER_NAME': u'Anthony Brown',
#   u'REB_PCT': 0.06,
#   'SEC_PLAYED': 0.6000000000000014,
#   u'TEAM_ABBREVIATION': u'LAL',
#   u'TEAM_ID': 1610612747,
#   u'TM_TOV_PCT': 10.6,
#   u'TS_PCT': 0.432,
#   u'USG_PCT': 0.111,
#   u'W': 3,
#   u'W_PCT': 0.125},
#  {u'AGE': 22.0,
#   u'AST_PCT': 0.093,
#   u'AST_RATIO': 7.3,
#   u'AST_TO': 0.85,
#   u'CFID': 5,
#   u'CFPARAMS': u'203076,1610612740',
#   u'DEF_RATING': 105.6,
#   u'DREB_PCT': 0.255,
#   u'EFG_PCT': 0.504,
#   u'FGA': 709,
#   u'FGA_PG': 17.7,
#   u'FGM': 347,
#   u'FGM_PG': 8.7,
#   u'FG_PCT': 0.489,
#   u'GP': 40,
#   u'L': 23,
#   u'MIN': 35.4,
#   'MIN_PLAYED': 35.0,
#   u'NET_RATING': -1.3,
#   u'OFF_RATING': 104.3,
#   u'OREB_PCT': 0.066,
#   u'PACE': 97.98,
#   u'PIE': 0.161,
#   u'PLAYER_ID': 203076,
#   u'PLAYER_NAME': u'Anthony Davis',
#   u'REB_PCT': 0.16,
#   'SEC_PLAYED': 0.3999999999999986,
#   u'TEAM_ABBREVIATION': u'NOP',
#   u'TEAM_ID': 1610612740,
#   u'TM_TOV_PCT': 8.7,
#   u'TS_PCT': 0.555,
#   u'USG_PCT': 0.288,
#   u'W': 17,
#   u'W_PCT': 0.425},
#  {u'AGE': 30.0,
#   u'AST_PCT': 0.031,
#   u'AST_RATIO': 5.8,
#   u'AST_TO': 1.4,
#   u'CFID': 5,
#   u'CFPARAMS': u'201627,1610612760',
#   u'DEF_RATING': 104.8,
#   u'DREB_PCT': 0.071,
#   u'EFG_PCT': 0.552,
#   u'FGA': 210,
#   u'FGA_PG': 4.9,
#   u'FGM': 89,
#   u'FGM_PG': 2.1,
#   u'FG_PCT': 0.424,
#   u'GP': 43,
#   u'L': 12,
#   u'MIN': 14.9,
#   'MIN_PLAYED': 14.0,
#   u'NET_RATING': 4.7,
#   u'OFF_RATING': 109.4,
#   u'OREB_PCT': 0.015,
#   u'PACE': 98.91,
#   u'PIE': 0.063,
#   u'PLAYER_ID': 201627,
#   u'PLAYER_NAME': u'Anthony Morrow',
#   u'REB_PCT': 0.044,
#   'SEC_PLAYED': 0.9000000000000004,
#   u'TEAM_ABBREVIATION': u'OKC',
#   u'TEAM_ID': 1610612760,
#   u'TM_TOV_PCT': 4.1,
#   u'TS_PCT': 0.568,
#   u'USG_PCT': 0.155,
#   u'W': 31,
#   u'W_PCT': 0.721},
#  {u'AGE': 30.0,
#   u'AST_PCT': 0.064,
#   u'AST_RATIO': 13.9,
#   u'AST_TO': 2.67,
#   u'CFID': 5,
#   u'CFPARAMS': u'201229,1610612765',
#   u'DEF_RATING': 99.2,
#   u'DREB_PCT': 0.156,
#   u'EFG_PCT': 0.528,
#   u'FGA': 218,
#   u'FGA_PG': 4.6,
#   u'FGM': 83,
#   u'FGM_PG': 1.8,
#   u'FG_PCT': 0.381,
#   u'GP': 47,
#   u'L': 23,
#   u'MIN': 19.7,
#   'MIN_PLAYED': 19.0,
#   u'NET_RATING': 2.3,
#   u'OFF_RATING': 101.6,
#   u'OREB_PCT': 0.029,
#   u'PACE': 96.42,
#   u'PIE': 0.081,
#   u'PLAYER_ID': 201229,
#   u'PLAYER_NAME': u'Anthony Tolliver',
#   u'REB_PCT': 0.091,
#   'SEC_PLAYED': 0.6999999999999993,
#   u'TEAM_ABBREVIATION': u'DET',
#   u'TEAM_ID': 1610612765,
#   u'TM_TOV_PCT': 5.2,
#   u'TS_PCT': 0.542,
#   u'USG_PCT': 0.118,
#   u'W': 24,
#   u'W_PCT': 0.511},
#  {u'AGE': 21.0,
#   u'AST_PCT': 0.162,
#   u'AST_RATIO': 15.2,
#   u'AST_TO': 1.15,
#   u'CFID': 5,
#   u'CFPARAMS': u'203462,1610612756',
#   u'DEF_RATING': 110.6,
#   u'DREB_PCT': 0.137,
#   u'EFG_PCT': 0.449,
#   u'FGA': 168,
#   u'FGA_PG': 6.0,
#   u'FGM': 71,
#   u'FGM_PG': 2.5,
#   u'FG_PCT': 0.423,
#   u'GP': 28,
#   u'L': 21,
#   u'MIN': 16.2,
#   'MIN_PLAYED': 16.0,
#   u'NET_RATING': -7.2,
#   u'OFF_RATING': 103.3,
#   u'OREB_PCT': 0.023,
#   u'PACE': 99.66,
#   u'PIE': 0.082,
#   u'PLAYER_ID': 203462,
#   u'PLAYER_NAME': u'Archie Goodwin',
#   u'REB_PCT': 0.078,
#   'SEC_PLAYED': 0.1999999999999993,
#   u'TEAM_ABBREVIATION': u'PHX',
#   u'TEAM_ID': 1610612756,
#   u'TM_TOV_PCT': 13.2,
#   u'TS_PCT': 0.509,
#   u'USG_PCT': 0.235,
#   u'W': 7,
#   u'W_PCT': 0.25},
#  {u'AGE': 29.0,
#   u'AST_PCT': 0.095,
#   u'AST_RATIO': 11.5,
#   u'AST_TO': 0.9,
#   u'CFID': 5,
#   u'CFPARAMS': u'203382,1610612765',
#   u'DEF_RATING': 103.9,
#   u'DREB_PCT': 0.227,
#   u'EFG_PCT': 0.502,
#   u'FGA': 209,
#   u'FGA_PG': 4.4,
#   u'FGM': 105,
#   u'FGM_PG': 2.2,
#   u'FG_PCT': 0.502,
#   u'GP': 47,
#   u'L': 23,
#   u'MIN': 14.3,
#   'MIN_PLAYED': 14.0,
#   u'NET_RATING': -6.1,
#   u'OFF_RATING': 97.8,
#   u'OREB_PCT': 0.121,
#   u'PACE': 97.16,
#   u'PIE': 0.114,
#   u'PLAYER_ID': 203382,
#   u'PLAYER_NAME': u'Aron Baynes',
#   u'REB_PCT': 0.173,
#   'SEC_PLAYED': 0.3000000000000007,
#   u'TEAM_ABBREVIATION': u'DET',
#   u'TEAM_ID': 1610612765,
#   u'TM_TOV_PCT': 12.8,
#   u'TS_PCT': 0.552,
#   u'USG_PCT': 0.185,
#   u'W': 24,
#   u'W_PCT': 0.511},
#  {u'AGE': 30.0,
#   u'AST_PCT': 0.092,
#   u'AST_RATIO': 11.9,
#   u'AST_TO': 1.95,
#   u'CFID': 5,
#   u'CFPARAMS': u'201167,1610612752',
#   u'DEF_RATING': 106.1,
#   u'DREB_PCT': 0.106,
#   u'EFG_PCT': 0.508,
#   u'FGA': 503,
#   u'FGA_PG': 12.3,
#   u'FGM': 228,
#   u'FGM_PG': 5.6,
#   u'FG_PCT': 0.453,
#   u'GP': 41,
#   u'L': 22,
#   u'MIN': 33.2,
#   'MIN_PLAYED': 33.0,
#   u'NET_RATING': -0.3,
#   u'OFF_RATING': 105.8,
#   u'OREB_PCT': 0.011,
#   u'PACE': 94.4,
#   u'PIE': 0.081,
#   u'PLAYER_ID': 201167,
#   u'PLAYER_NAME': u'Arron Afflalo',
#   u'REB_PCT': 0.06,
#   'SEC_PLAYED': 0.20000000000000284,
#   u'TEAM_ABBREVIATION': u'NYK',
#   u'TEAM_ID': 1610612752,
#   u'TM_TOV_PCT': 6.1,
#   u'TS_PCT': 0.54,
#   u'USG_PCT': 0.195,
#   u'W': 19,
#   u'W_PCT': 0.463},
#  {u'AGE': 23.0,
#   u'AST_PCT': 0.106,
#   u'AST_RATIO': 13.1,
#   u'AST_TO': 1.55,
#   u'CFID': 5,
#   u'CFPARAMS': u'203085,1610612746',
#   u'DEF_RATING': 100.8,
#   u'DREB_PCT': 0.076,
#   u'EFG_PCT': 0.474,
#   u'FGA': 327,
#   u'FGA_PG': 7.4,
#   u'FGM': 141,
#   u'FGM_PG': 3.2,
#   u'FG_PCT': 0.431,
#   u'GP': 44,
#   u'L': 15,
#   u'MIN': 22.0,
#   'MIN_PLAYED': 22.0,
#   u'NET_RATING': -2.5,
#   u'OFF_RATING': 98.4,
#   u'OREB_PCT': 0.016,
#   u'PACE': 98.75,
#   u'PIE': 0.06,
#   u'PLAYER_ID': 203085,
#   u'PLAYER_NAME': u'Austin Rivers',
#   u'REB_PCT': 0.046,
#   'SEC_PLAYED': 0.0,
#   u'TEAM_ABBREVIATION': u'LAC',
#   u'TEAM_ID': 1610612746,
#   u'TM_TOV_PCT': 8.4,
#   u'TS_PCT': 0.497,
#   u'USG_PCT': 0.183,
#   u'W': 29,
#   u'W_PCT': 0.659},
#  {u'AGE': 25.0,
#   u'AST_PCT': 0.097,
#   u'AST_RATIO': 11.9,
#   u'AST_TO': 1.41,
#   u'CFID': 5,
#   u'CFPARAMS': u'202340,1610612738',
#   u'DEF_RATING': 100.4,
#   u'DREB_PCT': 0.065,
#   u'EFG_PCT': 0.516,
#   u'FGA': 570,
#   u'FGA_PG': 13.3,
#   u'FGM': 251,
#   u'FGM_PG': 5.8,
#   u'FG_PCT': 0.44,
#   u'GP': 43,
#   u'L': 18,
#   u'MIN': 32.6,
#   'MIN_PLAYED': 32.0,
#   u'NET_RATING': 5.9,
#   u'OFF_RATING': 106.3,
#   u'OREB_PCT': 0.02,
#   u'PACE': 101.28,
#   u'PIE': 0.08,
#   u'PLAYER_ID': 202340,
#   u'PLAYER_NAME': u'Avery Bradley',
#   u'REB_PCT': 0.042,
#   'SEC_PLAYED': 0.6000000000000014,
#   u'TEAM_ABBREVIATION': u'BOS',
#   u'TEAM_ID': 1610612738,
#   u'TM_TOV_PCT': 8.4,
#   u'TS_PCT': 0.533,
#   u'USG_PCT': 0.202,
#   u'W': 25,
#   u'W_PCT': 0.581},
#  {u'AGE': 22.0,
#   u'AST_PCT': 0.076,
#   u'AST_RATIO': 12.3,
#   u'AST_TO': 0.81,
#   u'CFID': 5,
#   u'CFPARAMS': u'203463,1610612758',
#   u'DEF_RATING': 106.0,
#   u'DREB_PCT': 0.081,
#   u'EFG_PCT': 0.533,
#   u'FGA': 287,
#   u'FGA_PG': 6.2,
#   u'FGM': 132,
#   u'FGM_PG': 2.9,
#   u'FG_PCT': 0.46,
#   u'GP': 46,
#   u'L': 26,
#   u'MIN': 21.2,
#   'MIN_PLAYED': 21.0,
#   u'NET_RATING': 0.1,
#   u'OFF_RATING': 106.1,
#   u'OREB_PCT': 0.026,
#   u'PACE': 103.59,
#   u'PIE': 0.052,
#   u'PLAYER_ID': 203463,
#   u'PLAYER_NAME': u'Ben McLemore',
#   u'REB_PCT': 0.054,
#   'SEC_PLAYED': 0.1999999999999993,
#   u'TEAM_ABBREVIATION': u'SAC',
#   u'TEAM_ID': 1610612758,
#   u'TM_TOV_PCT': 15.2,
#   u'TS_PCT': 0.561,
#   u'USG_PCT': 0.166,
#   u'W': 20,
#   u'W_PCT': 0.435},
#  {u'AGE': 33.0,
#   u'AST_PCT': 0.264,
#   u'AST_RATIO': 33.1,
#   u'AST_TO': 2.5,
#   u'CFID': 5,
#   u'CFPARAMS': u'2757,1610612748',
#   u'DEF_RATING': 101.3,
#   u'DREB_PCT': 0.104,
#   u'EFG_PCT': 0.48,
#   u'FGA': 148,
#   u'FGA_PG': 4.2,
#   u'FGM': 64,
#   u'FGM_PG': 1.8,
#   u'FG_PCT': 0.432,
#   u'GP': 35,
#   u'L': 15,
#   u'MIN': 15.9,
#   'MIN_PLAYED': 15.0,
#   u'NET_RATING': 0.7,
#   u'OFF_RATING': 102.0,
#   u'OREB_PCT': 0.008,
#   u'PACE': 94.25,
#   u'PIE': 0.08,
#   u'PLAYER_ID': 2757,
#   u'PLAYER_NAME': u'Beno Udrih',
#   u'REB_PCT': 0.058,
#   'SEC_PLAYED': 0.9000000000000004,
#   u'TEAM_ABBREVIATION': u'MIA',
#   u'TEAM_ID': 1610612748,
#   u'TM_TOV_PCT': 13.3,
#   u'TS_PCT': 0.501,
#   u'USG_PCT': 0.163,
#   u'W': 20,
#   u'W_PCT': 0.571},
#  {u'AGE': 23.0,
#   u'AST_PCT': 0.018,
#   u'AST_RATIO': 4.1,
#   u'AST_TO': 0.25,
#   u'CFID': 5,
#   u'CFPARAMS': u'202687,1610612761',
#   u'DEF_RATING': 98.8,
#   u'DREB_PCT': 0.285,
#   u'EFG_PCT': 0.512,
#   u'FGA': 172,
#   u'FGA_PG': 3.7,
#   u'FGM': 88,
#   u'FGM_PG': 1.9,
#   u'FG_PCT': 0.512,
#   u'GP': 47,
#   u'L': 15,
#   u'MIN': 22.6,
#   'MIN_PLAYED': 22.0,
#   u'NET_RATING': 2.7,
#   u'OFF_RATING': 101.5,
#   u'OREB_PCT': 0.116,
#   u'PACE': 95.08,
#   u'PIE': 0.103,
#   u'PLAYER_ID': 202687,
#   u'PLAYER_NAME': u'Bismack Biyombo',
#   u'REB_PCT': 0.203,
#   'SEC_PLAYED': 0.6000000000000014,
#   u'TEAM_ABBREVIATION': u'TOR',
#   u'TEAM_ID': 1610612761,
#   u'TM_TOV_PCT': 16.6,
#   u'TS_PCT': 0.575,
#   u'USG_PCT': 0.12,
#   u'W': 32,
#   u'W_PCT': 0.681},
#  {u'AGE': 26.0,
#   u'AST_PCT': 0.26,
#   u'AST_RATIO': 17.5,
#   u'AST_TO': 2.1,
#   u'CFID': 5,
#   u'CFPARAMS': u'201933,1610612746',
#   u'DEF_RATING': 102.1,
#   u'DREB_PCT': 0.217,
#   u'EFG_PCT': 0.514,
#   u'FGA': 553,
#   u'FGA_PG': 18.4,
#   u'FGM': 281,
#   u'FGM_PG': 9.4,
#   u'FG_PCT': 0.508,
#   u'GP': 30,
#   u'L': 13,
#   u'MIN': 34.9,
#   'MIN_PLAYED': 34.0,
#   u'NET_RATING': 5.8,
#   u'OFF_RATING': 107.8,
#   u'OREB_PCT': 0.051,
#   u'PACE': 99.23,
#   u'PIE': 0.174,
#   u'PLAYER_ID': 201933,
#   u'PLAYER_NAME': u'Blake Griffin',
#   u'REB_PCT': 0.134,
#   'SEC_PLAYED': 0.8999999999999986,
#   u'TEAM_ABBREVIATION': u'LAC',
#   u'TEAM_ID': 1610612746,
#   u'TM_TOV_PCT': 8.3,
#   u'TS_PCT': 0.552,
#   u'USG_PCT': 0.296,
#   u'W': 17,
#   u'W_PCT': 0.567},
#  {u'AGE': 27.0,
#   u'AST_PCT': 0.066,
#   u'AST_RATIO': 5.9,
#   u'AST_TO': 0.53,
#   u'CFID': 5,
#   u'CFPARAMS': u'1626246,1610612759',
#   u'DEF_RATING': 98.8,
#   u'DREB_PCT': 0.29,
#   u'EFG_PCT': 0.61,
#   u'FGA': 100,
#   u'FGA_PG': 3.6,
#   u'FGM': 61,
#   u'FGM_PG': 2.2,
#   u'FG_PCT': 0.61,
#   u'GP': 28,
#   u'L': 2,
#   u'MIN': 8.6,
#   'MIN_PLAYED': 8.0,
#   u'NET_RATING': 13.3,
#   u'OFF_RATING': 112.1,
#   u'OREB_PCT': 0.201,
#   u'PACE': 94.39,
#   u'PIE': 0.2,
#   u'PLAYER_ID': 1626246,
#   u'PLAYER_NAME': u'Boban Marjanovic',
#   u'REB_PCT': 0.248,
#   'SEC_PLAYED': 0.5999999999999996,
#   u'TEAM_ABBREVIATION': u'SAS',
#   u'TEAM_ID': 1610612759,
#   u'TM_TOV_PCT': 11.1,
#   u'TS_PCT': 0.658,
#   u'USG_PCT': 0.274,
#   u'W': 26,
#   u'W_PCT': 0.929},
#  {u'AGE': 20.0,
#   u'AST_PCT': 0.055,
#   u'AST_RATIO': 5.9,
#   u'AST_TO': 0.43,
#   u'CFID': 5,
#   u'CFPARAMS': u'1626171,1610612741',
#   u'DEF_RATING': 102.7,
#   u'DREB_PCT': 0.192,
#   u'EFG_PCT': 0.464,
#   u'FGA': 151,
#   u'FGA_PG': 6.0,
#   u'FGM': 67,
#   u'FGM_PG': 2.7,
#   u'FG_PCT': 0.444,
#   u'GP': 25,
#   u'L': 12,
#   u'MIN': 14.4,
#   'MIN_PLAYED': 14.0,
#   u'NET_RATING': -3.7,
#   u'OFF_RATING': 99.0,
#   u'OREB_PCT': 0.106,
#   u'PACE': 98.81,
#   u'PIE': 0.097,
#   u'PLAYER_ID': 1626171,
#   u'PLAYER_NAME': u'Bobby Portis',
#   u'REB_PCT': 0.149,
#   'SEC_PLAYED': 0.40000000000000036,
#   u'TEAM_ABBREVIATION': u'CHI',
#   u'TEAM_ID': 1610612741,
#   u'TM_TOV_PCT': 13.9,
#   u'TS_PCT': 0.491,
#   u'USG_PCT': 0.224,
#   u'W': 13,
#   u'W_PCT': 0.52},
#  {u'AGE': 26.0,
#   u'AST_PCT': 0.061,
#   u'AST_RATIO': 9.5,
#   u'AST_TO': 0.85,
#   u'CFID': 5,
#   u'CFPARAMS': u'202711,1610612751',
#   u'DEF_RATING': 106.9,
#   u'DREB_PCT': 0.121,
#   u'EFG_PCT': 0.496,
#   u'FGA': 394,
#   u'FGA_PG': 8.2,
#   u'FGM': 165,
#   u'FGM_PG': 3.4,
#   u'FG_PCT': 0.419,
#   u'GP': 48,
#   u'L': 36,
#   u'MIN': 26.7,
#   'MIN_PLAYED': 26.0,
#   u'NET_RATING': -10.0,
#   u'OFF_RATING': 96.9,
#   u'OREB_PCT': 0.02,
#   u'PACE': 96.75,
#   u'PIE': 0.065,
#   u'PLAYER_ID': 202711,
#   u'PLAYER_NAME': u'Bojan Bogdanovic',
#   u'REB_PCT': 0.07,
#   'SEC_PLAYED': 0.6999999999999993,
#   u'TEAM_ABBREVIATION': u'BKN',
#   u'TEAM_ID': 1610612751,
#   u'TM_TOV_PCT': 11.2,
#   u'TS_PCT': 0.523,
#   u'USG_PCT': 0.167,
#   u'W': 12,
#   u'W_PCT': 0.25},
#  {u'AGE': 33.0,
#   u'AST_PCT': 0.186,
#   u'AST_RATIO': 25.8,
#   u'AST_TO': 1.92,
#   u'CFID': 5,
#   u'CFPARAMS': u'2564,1610612759',
#   u'DEF_RATING': 92.1,
#   u'DREB_PCT': 0.133,
#   u'EFG_PCT': 0.565,
#   u'FGA': 248,
#   u'FGA_PG': 5.4,
#   u'FGM': 131,
#   u'FGM_PG': 2.8,
#   u'FG_PCT': 0.528,
#   u'GP': 46,
#   u'L': 7,
#   u'MIN': 19.1,
#   'MIN_PLAYED': 19.0,
#   u'NET_RATING': 15.3,
#   u'OFF_RATING': 107.4,
#   u'OREB_PCT': 0.052,
#   u'PACE': 98.68,
#   u'PIE': 0.106,
#   u'PLAYER_ID': 2564,
#   u'PLAYER_NAME': u'Boris Diaw',
#   u'REB_PCT': 0.095,
#   'SEC_PLAYED': 0.10000000000000142,
#   u'TEAM_ABBREVIATION': u'SAS',
#   u'TEAM_ID': 1610612759,
#   u'TM_TOV_PCT': 13.4,
#   u'TS_PCT': 0.59,
#   u'USG_PCT': 0.17,
#   u'W': 39,
#   u'W_PCT': 0.848},
#  {u'AGE': 22.0,
#   u'AST_PCT': 0.158,
#   u'AST_RATIO': 13.3,
#   u'AST_TO': 1.13,
#   u'CFID': 5,
#   u'CFPARAMS': u'203078,1610612764',
#   u'DEF_RATING': 105.2,
#   u'DREB_PCT': 0.114,
#   u'EFG_PCT': 0.516,
#   u'FGA': 352,
#   u'FGA_PG': 15.3,
#   u'FGM': 158,
#   u'FGM_PG': 6.9,
#   u'FG_PCT': 0.449,
#   u'GP': 23,
#   u'L': 13,
#   u'MIN': 32.6,
#   'MIN_PLAYED': 32.0,
#   u'NET_RATING': -5.1,
#   u'OFF_RATING': 100.1,
#   u'OREB_PCT': 0.03,
#   u'PACE': 101.85,
#   u'PIE': 0.099,
#   u'PLAYER_ID': 203078,
#   u'PLAYER_NAME': u'Bradley Beal',
#   u'REB_PCT': 0.071,
#   'SEC_PLAYED': 0.6000000000000014,
#   u'TEAM_ABBREVIATION': u'WAS',
#   u'TEAM_ID': 1610612764,
#   u'TM_TOV_PCT': 11.8,
#   u'TS_PCT': 0.548,
#   u'USG_PCT': 0.256,
#   u'W': 10,
#   u'W_PCT': 0.435},
#  {u'AGE': 28.0,
#   u'AST_PCT': 0.061,
#   u'AST_RATIO': 8.7,
#   u'AST_TO': 1.0,
#   u'CFID': 5,
#   u'CFPARAMS': u'201148,1610612763',
#   u'DEF_RATING': 114.7,
#   u'DREB_PCT': 0.165,
#   u'EFG_PCT': 0.6,
#   u'FGA': 30,
#   u'FGA_PG': 4.3,
#   u'FGM': 18,
#   u'FGM_PG': 2.6,
#   u'FG_PCT': 0.6,
#   u'GP': 7,
#   u'L': 4,
#   u'MIN': 17.1,
#   'MIN_PLAYED': 17.0,
#   u'NET_RATING': -21.7,
#   u'OFF_RATING': 92.9,
#   u'OREB_PCT': 0.054,
#   u'PACE': 96.21,
#   u'PIE': 0.11,
#   u'PLAYER_ID': 201148,
#   u'PLAYER_NAME': u'Brandan Wright',
#   u'REB_PCT': 0.109,
#   'SEC_PLAYED': 0.10000000000000142,
#   u'TEAM_ABBREVIATION': u'MEM',
#   u'TEAM_ID': 1610612763,
#   u'TM_TOV_PCT': 8.7,
#   u'TS_PCT': 0.607,
#   u'USG_PCT': 0.158,
#   u'W': 3,
#   u'W_PCT': 0.429},
#  {u'AGE': 22.0,
#   u'AST_PCT': 0.0,
#   u'AST_RATIO': 0.0,
#   u'AST_TO': 0.0,
#   u'CFID': 5,
#   u'CFPARAMS': u'1626183,1610612746',
#   u'DEF_RATING': 131.8,
#   u'DREB_PCT': 0.111,
#   u'EFG_PCT': 0.333,
#   u'FGA': 3,
#   u'FGA_PG': 1.5,
#   u'FGM': 1,
#   u'FGM_PG': 0.5,
#   u'FG_PCT': 0.333,
#   u'GP': 2,
#   u'L': 0,
#   u'MIN': 6.3,
#   'MIN_PLAYED': 6.0,
#   u'NET_RATING': -63.5,
#   u'OFF_RATING': 68.3,
#   u'OREB_PCT': 0.2,
#   u'PACE': 92.19,
#   u'PIE': 0.011,
#   u'PLAYER_ID': 1626183,
#   u'PLAYER_NAME': u'Branden Dawson',
#   u'REB_PCT': 0.158,
#   'SEC_PLAYED': 0.2999999999999998,
#   u'TEAM_ABBREVIATION': u'LAC',
#   u'TEAM_ID': 1610612746,
#   u'TM_TOV_PCT': 0.0,
#   u'TS_PCT': 0.333,
#   u'USG_PCT': 0.108,
#   u'W': 2,
#   u'W_PCT': 1.0},
#  {u'AGE': 30.0,
#   u'AST_PCT': 0.105,
#   u'AST_RATIO': 16.3,
#   u'AST_TO': 1.84,
#   u'CFID': 5,
#   u'CFPARAMS': u'101138,1610612747',
#   u'DEF_RATING': 105.0,
#   u'DREB_PCT': 0.168,
#   u'EFG_PCT': 0.555,
#   u'FGA': 182,
#   u'FGA_PG': 4.4,
#   u'FGM': 101,
#   u'FGM_PG': 2.5,
#   u'FG_PCT': 0.555,
#   u'GP': 41,
#   u'L': 32,
#   u'MIN': 18.0,
#   'MIN_PLAYED': 18.0,
#   u'NET_RATING': -6.4,
#   u'OFF_RATING': 98.6,
#   u'OREB_PCT': 0.091,
#   u'PACE': 99.22,
#   u'PIE': 0.114,
#   u'PLAYER_ID': 101138,
#   u'PLAYER_NAME': u'Brandon Bass',
#   u'REB_PCT': 0.129,
#   'SEC_PLAYED': 0.0,
#   u'TEAM_ABBREVIATION': u'LAL',
#   u'TEAM_ID': 1610612747,
#   u'TM_TOV_PCT': 8.8,
#   u'TS_PCT': 0.613,
#   u'USG_PCT': 0.14,
#   u'W': 9,
#   u'W_PCT': 0.22},
#  {u'AGE': 26.0,
#   u'AST_PCT': 0.289,
#   u'AST_RATIO': 28.8,
#   u'AST_TO': 3.44,
#   u'CFID': 5,
#   u'CFPARAMS': u'201943,1610612765',
#   u'DEF_RATING': 97.5,
#   u'DREB_PCT': 0.113,
#   u'EFG_PCT': 0.448,
#   u'FGA': 105,
#   u'FGA_PG': 6.2,
#   u'FGM': 38,
#   u'FGM_PG': 2.2,
#   u'FG_PCT': 0.362,
#   u'GP': 17,
#   u'L': 9,
#   u'MIN': 17.6,
#   'MIN_PLAYED': 17.0,
#   u'NET_RATING': 9.3,
#   u'OFF_RATING': 106.9,
#   u'OREB_PCT': 0.018,
#   u'PACE': 97.57,
#   u'PIE': 0.11,
#   u'PLAYER_ID': 201943,
#   u'PLAYER_NAME': u'Brandon Jennings',
#   u'REB_PCT': 0.066,
#   'SEC_PLAYED': 0.6000000000000014,
#   u'TEAM_ABBREVIATION': u'DET',
#   u'TEAM_ID': 1610612765,
#   u'TM_TOV_PCT': 8.4,
#   u'TS_PCT': 0.492,
#   u'USG_PCT': 0.198,
#   u'W': 8,
#   u'W_PCT': 0.471},
#  {u'AGE': 24.0,
#   u'AST_PCT': 0.235,
#   u'AST_RATIO': 18.7,
#   u'AST_TO': 1.48,
#   u'CFID': 5,
#   u'CFPARAMS': u'202688,1610612756',
#   u'DEF_RATING': 107.1,
#   u'DREB_PCT': 0.097,
#   u'EFG_PCT': 0.484,
#   u'FGA': 728,
#   u'FGA_PG': 17.3,
#   u'FGM': 309,
#   u'FGM_PG': 7.4,
#   u'FG_PCT': 0.424,
#   u'GP': 42,
#   u'L': 29,
#   u'MIN': 36.3,
#   'MIN_PLAYED': 36.0,
#   u'NET_RATING': -6.1,
#   u'OFF_RATING': 101.0,
#   u'OREB_PCT': 0.019,
#   u'PACE': 100.34,
#   u'PIE': 0.102,
#   u'PLAYER_ID': 202688,
#   u'PLAYER_NAME': u'Brandon Knight',
#   u'REB_PCT': 0.057,
#   'SEC_PLAYED': 0.29999999999999716,
#   u'TEAM_ABBREVIATION': u'PHX',
#   u'TEAM_ID': 1610612756,
#   u'TM_TOV_PCT': 12.6,
#   u'TS_PCT': 0.523,
#   u'USG_PCT': 0.264,
#   u'W': 13,
#   u'W_PCT': 0.31},
#  {u'AGE': 30.0,
#   u'AST_PCT': 0.073,
#   u'AST_RATIO': 15.4,
#   u'AST_TO': 1.7,
#   u'CFID': 5,
#   u'CFPARAMS': u'201575,1610612744',
#   u'DEF_RATING': 104.7,
#   u'DREB_PCT': 0.143,
#   u'EFG_PCT': 0.593,
#   u'FGA': 162,
#   u'FGA_PG': 4.3,
#   u'FGM': 74,
#   u'FGM_PG': 1.9,
#   u'FG_PCT': 0.457,
#   u'GP': 38,
#   u'L': 4,
#   u'MIN': 16.2,
#   'MIN_PLAYED': 16.0,
#   u'NET_RATING': 3.9,
#   u'OFF_RATING': 108.6,
#   u'OREB_PCT': 0.026,
#   u'PACE': 101.9,
#   u'PIE': 0.081,
#   u'PLAYER_ID': 201575,
#   u'PLAYER_NAME': u'Brandon Rush',
#   u'REB_PCT': 0.089,
#   'SEC_PLAYED': 0.1999999999999993,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_ID': 1610612744,
#   u'TM_TOV_PCT': 9.0,
#   u'TS_PCT': 0.595,
#   u'USG_PCT': 0.134,
#   u'W': 34,
#   u'W_PCT': 0.895},
#  {u'AGE': 30.0,
#   u'AST_PCT': 0.199,
#   u'AST_RATIO': 20.1,
#   u'AST_TO': 2.0,
#   u'CFID': 5,
#   u'CFPARAMS': u'203148,1610612766',
#   u'DEF_RATING': 104.6,
#   u'DREB_PCT': 0.093,
#   u'EFG_PCT': 0.495,
#   u'FGA': 98,
#   u'FGA_PG': 3.6,
#   u'FGM': 44,
#   u'FGM_PG': 1.6,
#   u'FG_PCT': 0.449,
#   u'GP': 27,
#   u'L': 15,
#   u'MIN': 10.8,
#   'MIN_PLAYED': 10.0,
#   u'NET_RATING': -3.3,
#   u'OFF_RATING': 101.3,
#   u'OREB_PCT': 0.01,
#   u'PACE': 97.19,
#   u'PIE': 0.098,
#   u'PLAYER_ID': 203148,
#   u'PLAYER_NAME': u'Brian Roberts',
#   u'REB_PCT': 0.047,
#   'SEC_PLAYED': 0.8000000000000007,
#   u'TEAM_ABBREVIATION': u'CHA',
#   u'TEAM_ID': 1610612766,
#   u'TM_TOV_PCT': 10.1,
#   u'TS_PCT': 0.562,
#   u'USG_PCT': 0.194,
#   u'W': 12,
#   u'W_PCT': 0.444},
#  {u'AGE': 27.0,
#   u'AST_PCT': 0.086,
#   u'AST_RATIO': 7.1,
#   u'AST_TO': 0.7,
#   u'CFID': 5,
#   u'CFPARAMS': u'201572,1610612751',
#   u'DEF_RATING': 105.4,
#   u'DREB_PCT': 0.183,
#   u'EFG_PCT': 0.496,
#   u'FGA': 768,
#   u'FGA_PG': 16.0,
#   u'FGM': 381,
#   u'FGM_PG': 7.9,
#   u'FG_PCT': 0.496,
#   u'GP': 48,
#   u'L': 36,
#   u'MIN': 33.5,
#   'MIN_PLAYED': 33.0,
#   u'NET_RATING': -5.0,
#   u'OFF_RATING': 100.4,
#   u'OREB_PCT': 0.095,
#   u'PACE': 96.17,
#   u'PIE': 0.127,
#   u'PLAYER_ID': 201572,
#   u'PLAYER_NAME': u'Brook Lopez',
#   u'REB_PCT': 0.139,
#   'SEC_PLAYED': 0.5,
#   u'TEAM_ABBREVIATION': u'BKN',
#   u'TEAM_ID': 1610612751,
#   u'TM_TOV_PCT': 10.1,
#   u'TS_PCT': 0.546,
#   u'USG_PCT': 0.277,
#   u'W': 12,
#   u'W_PCT': 0.25},
#  {u'AGE': 20.0,
#   u'AST_PCT': 0.0,
#   u'AST_RATIO': 0.0,
#   u'AST_TO': 0.0,
#   u'CFID': 5,
#   u'CFPARAMS': u'203998,1610612761',
#   u'DEF_RATING': 85.0,
#   u'DREB_PCT': 0.333,
#   u'EFG_PCT': 0.0,
#   u'FGA': 1,
#   u'FGA_PG': 0.5,
#   u'FGM': 0,
#   u'FGM_PG': 0.0,
#   u'FG_PCT': 0.0,
#   u'GP': 2,
#   u'L': 0,
#   u'MIN': 1.2,
#   'MIN_PLAYED': 1.0,
#   u'NET_RATING': -45.0,
#   u'OFF_RATING': 40.0,
#   u'OREB_PCT': 0.0,
#   u'PACE': 113.53,
#   u'PIE': 0.0,
#   u'PLAYER_ID': 203998,
#   u'PLAYER_NAME': u'Bruno Caboclo',
#   u'REB_PCT': 0.143,
#   'SEC_PLAYED': 0.19999999999999996,
#   u'TEAM_ABBREVIATION': u'TOR',
#   u'TEAM_ID': 1610612761,
#   u'TM_TOV_PCT': 50.0,
#   u'TS_PCT': 0.0,
#   u'USG_PCT': 0.333,
#   u'W': 2,
#   u'W_PCT': 1.0},
#  {u'AGE': 23.0,
#   u'AST_PCT': 0.143,
#   u'AST_RATIO': 18.8,
#   u'AST_TO': 0.6,
#   u'CFID': 5,
#   u'CFPARAMS': u'203955,1610612756',
#   u'DEF_RATING': 126.4,
#   u'DREB_PCT': 0.0,
#   u'EFG_PCT': 0.25,
#   u'FGA': 8,
#   u'FGA_PG': 2.7,
#   u'FGM': 2,
#   u'FGM_PG': 0.7,
#   u'FG_PCT': 0.25,
#   u'GP': 3,
#   u'L': 3,
#   u'MIN': 10.9,
#   'MIN_PLAYED': 10.0,
#   u'NET_RATING': -20.6,
#   u'OFF_RATING': 105.8,
#   u'OREB_PCT': 0.0,
#   u'PACE': 96.09,
#   u'PIE': -0.024,
#   u'PLAYER_ID': 203955,
#   u'PLAYER_NAME': u'Bryce Cotton',
#   u'REB_PCT': 0.0,
#   'SEC_PLAYED': 0.9000000000000004,
#   u'TEAM_ABBREVIATION': u'PHX',
#   u'TEAM_ID': 1610612756,
#   u'TM_TOV_PCT': 31.3,
#   u'TS_PCT': 0.25,
#   u'USG_PCT': 0.177,
#   u'W': 0,
#   u'W_PCT': 0.0},
#  {u'AGE': 23.0,
#   u'AST_PCT': 0.054,
#   u'AST_RATIO': 10.3,
#   u'AST_TO': 1.5,
#   u'CFID': 5,
#   u'CFPARAMS': u'1626214,1610612740',
#   u'DEF_RATING': 105.6,
#   u'DREB_PCT': 0.182,
#   u'EFG_PCT': 0.548,
#   u'FGA': 21,
#   u'FGA_PG': 4.2,
#   u'FGM': 9,
#   u'FGM_PG': 1.8,
#   u'FG_PCT': 0.429,
#   u'GP': 5,
#   u'L': 1,
#   u'MIN': 15.8,
#   'MIN_PLAYED': 15.0,
#   u'NET_RATING': -4.6,
#   u'OFF_RATING': 101.0,
#   u'OREB_PCT': 0.034,
#   u'PACE': 99.31,
#   u'PIE': 0.072,
#   u'PLAYER_ID': 1626214,
#   u'PLAYER_NAME': u'Bryce Dejean-Jones',
#   u'REB_PCT': 0.098,
#   'SEC_PLAYED': 0.8000000000000007,
#   u'TEAM_ABBREVIATION': u'NOP',
#   u'TEAM_ID': 1610612740,
#   u'TM_TOV_PCT': 6.9,
#   u'TS_PCT': 0.519,
#   u'USG_PCT': 0.141,
#   u'W': 4,
#   u'W_PCT': 0.8},
#  {u'AGE': 24.0,
#   u'AST_PCT': 0.215,
#   u'AST_RATIO': 16.8,
#   u'AST_TO': 1.99,
#   u'CFID': 5,
#   u'CFPARAMS': u'203468,1610612757',
#   u'DEF_RATING': 103.5,
#   u'DREB_PCT': 0.093,
#   u'EFG_PCT': 0.508,
#   u'FGA': 842,
#   u'FGA_PG': 18.3,
#   u'FGM': 371,
#   u'FGM_PG': 8.1,
#   u'FG_PCT': 0.441,
#   u'GP': 46,
#   u'L': 24,
#   u'MIN': 35.1,
#   'MIN_PLAYED': 35.0,
#   u'NET_RATING': 1.7,
#   u'OFF_RATING': 105.2,
#   u'OREB_PCT': 0.018,
#   u'PACE': 97.73,
#   u'PIE': 0.115,
#   u'PLAYER_ID': 203468,
#   u'PLAYER_NAME': u'CJ McCollum',
#   u'REB_PCT': 0.055,
#   'SEC_PLAYED': 0.10000000000000142,
#   u'TEAM_ABBREVIATION': u'POR',
#   u'TEAM_ID': 1610612757,
#   u'TM_TOV_PCT': 8.4,
#   u'TS_PCT': 0.532,
#   u'USG_PCT': 0.27,
#   u'W': 22,
#   u'W_PCT': 0.478},
#  {u'AGE': 28.0,
#   u'AST_PCT': 0.066,
#   u'AST_RATIO': 8.0,
#   u'AST_TO': 0.92,
#   u'CFID': 5,
#   u'CFPARAMS': u'101139,1610612754',
#   u'DEF_RATING': 101.9,
#   u'DREB_PCT': 0.118,
#   u'EFG_PCT': 0.499,
#   u'FGA': 437,
#   u'FGA_PG': 10.4,
#   u'FGM': 171,
#   u'FGM_PG': 4.1,
#   u'FG_PCT': 0.391,
#   u'GP': 42,
#   u'L': 20,
#   u'MIN': 25.9,
#   'MIN_PLAYED': 25.0,
#   u'NET_RATING': 0.0,
#   u'OFF_RATING': 101.9,
#   u'OREB_PCT': 0.02,
#   u'PACE': 102.09,
#   u'PIE': 0.075,
#   u'PLAYER_ID': 101139,
#   u'PLAYER_NAME': u'CJ Miles',
#   u'REB_PCT': 0.067,
#   'SEC_PLAYED': 0.8999999999999986,
#   u'TEAM_ABBREVIATION': u'IND',
#   u'TEAM_ID': 1610612754,
#   u'TM_TOV_PCT': 8.7,
#   u'TS_PCT': 0.53,
#   u'USG_PCT': 0.21,
#   u'W': 22,
#   u'W_PCT': 0.524},
#  {u'AGE': 31.0,
#   u'AST_PCT': 0.21,
#   u'AST_RATIO': 34.7,
#   u'AST_TO': 4.17,
#   u'CFID': 5,
#   u'CFPARAMS': u'201228,1610612753',
#   u'DEF_RATING': 94.9,
#   u'DREB_PCT': 0.075,
#   u'EFG_PCT': 0.434,
#   u'FGA': 38,
#   u'FGA_PG': 4.8,
#   u'FGM': 14,
#   u'FGM_PG': 1.8,
#   u'FG_PCT': 0.368,
#   u'GP': 8,
#   u'L': 5,
#   u'MIN': 19.6,
#   'MIN_PLAYED': 19.0,
#   u'NET_RATING': 9.3,
#   u'OFF_RATING': 104.2,
#   u'OREB_PCT': 0.033,
#   u'PACE': 99.75,
#   u'PIE': 0.085,
#   u'PLAYER_ID': 201228,
#   u'PLAYER_NAME': u'CJ Watson',
#   u'REB_PCT': 0.057,
#   'SEC_PLAYED': 0.6000000000000014,
#   u'TEAM_ABBREVIATION': u'ORL',
#   u'TEAM_ID': 1610612753,
#   u'TM_TOV_PCT': 8.3,
#   u'TS_PCT': 0.463,
#   u'USG_PCT': 0.133,
#   u'W': 3,
#   u'W_PCT': 0.375},
#  {u'AGE': 25.0,
#   u'AST_PCT': 0.143,
#   u'AST_RATIO': 20.0,
#   u'AST_TO': 0.0,
#   u'CFID': 5,
#   u'CFPARAMS': u'203912,1610612746',
#   u'DEF_RATING': 92.5,
#   u'DREB_PCT': 0.133,
#   u'EFG_PCT': 0.375,
#   u'FGA': 8,
#   u'FGA_PG': 1.3,
#   u'FGM': 3,
#   u'FGM_PG': 0.5,
#   u'FG_PCT': 0.375,
#   u'GP': 6,
#   u'L': 3,
#   u'MIN': 3.0,
#   'MIN_PLAYED': 3.0,
#   u'NET_RATING': 8.4,
#   u'OFF_RATING': 100.9,
#   u'OREB_PCT': 0.0,
#   u'PACE': 107.67,
#   u'PIE': 0.059,
#   u'PLAYER_ID': 203912,
#   u'PLAYER_NAME': u'CJ Wilcox',
#   u'REB_PCT': 0.063,
#   'SEC_PLAYED': 0.0,
#   u'TEAM_ABBREVIATION': u'LAC',
#   u'TEAM_ID': 1610612746,
#   u'TM_TOV_PCT': 0.0,
#   u'TS_PCT': 0.375,
#   u'USG_PCT': 0.188,
#   u'W': 3,
#   u'W_PCT': 0.5},
#  {u'AGE': 25.0,
#   u'AST_PCT': 0.03,
#   u'AST_RATIO': 5.3,
#   u'AST_TO': 0.5,
#   u'CFID': 5,
#   u'CFPARAMS': u'203946,1610612741',
#   u'DEF_RATING': 100.3,
#   u'DREB_PCT': 0.238,
#   u'EFG_PCT': 0.313,
#   u'FGA': 16,
#   u'FGA_PG': 1.6,
#   u'FGM': 5,
#   u'FGM_PG': 0.5,
#   u'FG_PCT': 0.313,
#   u'GP': 10,
#   u'L': 6,
#   u'MIN': 3.8,
#   'MIN_PLAYED': 3.0,
#   u'NET_RATING': 1.7,
#   u'OFF_RATING': 101.9,
#   u'OREB_PCT': 0.121,
#   u'PACE': 109.25,
#   u'PIE': 0.024,
#   u'PLAYER_ID': 203946,
#   u'PLAYER_NAME': u'Cameron Bairstow',
#   u'REB_PCT': 0.187,
#   'SEC_PLAYED': 0.7999999999999998,
#   u'TEAM_ABBREVIATION': u'CHI',
#   u'TEAM_ID': 1610612741,
#   u'TM_TOV_PCT': 10.5,
#   u'TS_PCT': 0.313,
#   u'USG_PCT': 0.185,
#   u'W': 4,
#   u'W_PCT': 0.4},
#  {u'AGE': 21.0,
#   u'AST_PCT': 0.254,
#   u'AST_RATIO': 25.1,
#   u'AST_TO': 3.05,
#   u'CFID': 5,
#   u'CFPARAMS': u'1626166,1610612760',
#   u'DEF_RATING': 107.3,
#   u'DREB_PCT': 0.149,
#   u'EFG_PCT': 0.53,
#   u'FGA': 151,
#   u'FGA_PG': 4.7,
#   u'FGM': 67,
#   u'FGM_PG': 2.1,
#   u'FG_PCT': 0.444,
#   u'GP': 32,
#   u'L': 5,
#   u'MIN': 11.4,
#   'MIN_PLAYED': 11.0,
#   u'NET_RATING': -3.9,
#   u'OFF_RATING': 103.4,
#   u'OREB_PCT': 0.012,
#   u'PACE': 98.24,
#   u'PIE': 0.117,
#   u'PLAYER_ID': 1626166,
#   u'PLAYER_NAME': u'Cameron Payne',
#   u'REB_PCT': 0.078,
#   'SEC_PLAYED': 0.40000000000000036,
#   u'TEAM_ABBREVIATION': u'OKC',
#   u'TEAM_ID': 1610612760,
#   u'TM_TOV_PCT': 8.2,
#   u'TS_PCT': 0.537,
#   u'USG_PCT': 0.206,
#   u'W': 27,
#   u'W_PCT': 0.844},
#  {u'AGE': 32.0,
#   u'AST_PCT': 0.048,
#   u'AST_RATIO': 4.8,
#   u'AST_TO': 0.44,
#   u'CFID': 5,
#   u'CFPARAMS': u'201171,1610612755',
#   u'DEF_RATING': 103.0,
#   u'DREB_PCT': 0.183,
#   u'EFG_PCT': 0.582,
#   u'FGA': 61,
#   u'FGA_PG': 5.5,
#   u'FGM': 35,
#   u'FGM_PG': 3.2,
#   u'FG_PCT': 0.574,
#   u'GP': 11,
#   u'L': 8,
#   u'MIN': 12.8,
#   'MIN_PLAYED': 12.0,
#   u'NET_RATING': 2.4,
#   u'OFF_RATING': 105.3,
#   u'OREB_PCT': 0.087,
#   u'PACE': 102.51,
#   u'PIE': 0.117,
#   u'PLAYER_ID': 201171,
#   u'PLAYER_NAME': u'Carl Landry',
#   u'REB_PCT': 0.136,
#   'SEC_PLAYED': 0.8000000000000007,
#   u'TEAM_ABBREVIATION': u'PHI',
#   u'TEAM_ID': 1610612755,
#   u'TM_TOV_PCT': 10.7,
#   u'TS_PCT': 0.605,
#   u'USG_PCT': 0.247,
#   u'W': 3,
#   u'W_PCT': 0.273},
#  {u'AGE': 31.0,
#   u'AST_PCT': 0.207,
#   u'AST_RATIO': 15.5,
#   u'AST_TO': 1.67,
#   u'CFID': 5,
#   u'CFPARAMS': u'2546,1610612752',
#   u'DEF_RATING': 103.6,
#   u'DREB_PCT': 0.189,
#   u'EFG_PCT': 0.471,
#   u'FGA': 753,
#   u'FGA_PG': 17.5,
#   u'FGM': 325,
#   u'FGM_PG': 7.6,
#   u'FG_PCT': 0.432,
#   u'GP': 43,
#   u'L': 20,
#   u'MIN': 34.5,
#   'MIN_PLAYED': 34.0,
#   u'NET_RATING': 1.7,
#   u'OFF_RATING': 105.3,
#   u'OREB_PCT': 0.049,
#   u'PACE': 96.18,
#   u'PIE': 0.145,
#   u'PLAYER_ID': 2546,
#   u'PLAYER_NAME': u'Carmelo Anthony',
#   u'REB_PCT': 0.12,
#   'SEC_PLAYED': 0.5,
#   u'TEAM_ABBREVIATION': u'NYK',
#   u'TEAM_ID': 1610612752,
#   u'TM_TOV_PCT': 9.3,
#   u'TS_PCT': 0.53,
#   u'USG_PCT': 0.291,
#   u'W': 23,
#   u'W_PCT': 0.535},
#  {u'AGE': 35.0,
#   u'AST_PCT': 0.07,
#   u'AST_RATIO': 9.4,
#   u'AST_TO': 1.5,
#   u'CFID': 5,
#   u'CFPARAMS': u'2406,1610612758',
#   u'DEF_RATING': 111.9,
#   u'DREB_PCT': 0.127,
#   u'EFG_PCT': 0.442,
#   u'FGA': 26,
#   u'FGA_PG': 2.9,
#   u'FGM': 11,
#   u'FGM_PG': 1.2,
#   u'FG_PCT': 0.423,
#   u'GP': 9,
#   u'L': 8,
#   u'MIN': 9.6,
#   'MIN_PLAYED': 9.0,
#   u'NET_RATING': -26.8,
#   u'OFF_RATING': 85.0,
#   u'OREB_PCT': 0.033,
#   u'PACE': 102.72,
#   u'PIE': 0.06,
#   u'PLAYER_ID': 2406,
#   u'PLAYER_NAME': u'Caron Butler',
#   u'REB_PCT': 0.072,
#   'SEC_PLAYED': 0.5999999999999996,
#   u'TEAM_ABBREVIATION': u'SAC',
#   u'TEAM_ID': 1610612758,
#   u'TM_TOV_PCT': 6.3,
#   u'TS_PCT': 0.446,
#   u'USG_PCT': 0.138,
#   u'W': 1,
#   u'W_PCT': 0.111},
#  {u'AGE': 27.0,
#   u'AST_PCT': 0.153,
#   u'AST_RATIO': 17.3,
#   u'AST_TO': 1.77,
#   u'CFID': 5,
#   u'CFPARAMS': u'202718,1610612742',
#   u'DEF_RATING': 102.1,
#   u'DREB_PCT': 0.158,
#   u'EFG_PCT': 0.562,
#   u'FGA': 390,
#   u'FGA_PG': 9.5,
#   u'FGM': 190,
#   u'FGM_PG': 4.6,
#   u'FG_PCT': 0.487,
#   u'GP': 41,
#   u'L': 19,
#   u'MIN': 27.4,
#   'MIN_PLAYED': 27.0,
#   u'NET_RATING': 0.7,
#   u'OFF_RATING': 102.7,
#   u'OREB_PCT': 0.015,
#   u'PACE': 96.24,
#   u'PIE': 0.107,
#   u'PLAYER_ID': 202718,
#   u'PLAYER_NAME': u'Chandler Parsons',
#   u'REB_PCT': 0.087,
#   'SEC_PLAYED': 0.3999999999999986,
#   u'TEAM_ABBREVIATION': u'DAL',
#   u'TEAM_ID': 1610612742,
#   u'TM_TOV_PCT': 9.8,
#   u'TS_PCT': 0.573,
#   u'USG_PCT': 0.198,
#   u'W': 22,
#   u'W_PCT': 0.537},
#  {u'AGE': 32.0,
#   u'AST_PCT': 0.084,
#   u'AST_RATIO': 17.2,
#   u'AST_TO': 1.48,
#   u'CFID': 5,
#   u'CFPARAMS': u'101112,1610612753',
#   u'DEF_RATING': 100.5,
#   u'DREB_PCT': 0.176,
#   u'EFG_PCT': 0.58,
#   u'FGA': 169,
#   u'FGA_PG': 4.2,
#   u'FGM': 75,
#   u'FGM_PG': 1.9,
#   u'FG_PCT': 0.444,
#   u'GP': 40,
#   u'L': 22,
#   u'MIN': 17.5,
#   'MIN_PLAYED': 17.0,
#   u'NET_RATING': 5.5,
#   u'OFF_RATING': 106.0,
#   u'OREB_PCT': 0.033,
#   u'PACE': 94.69,
#   u'PIE': 0.082,
#   u'PLAYER_ID': 101112,
#   u'PLAYER_NAME': u'Channing Frye',
#   u'REB_PCT': 0.104,
#   'SEC_PLAYED': 0.5,
#   u'TEAM_ABBREVIATION': u'ORL',
#   u'TEAM_ID': 1610612753,
#   u'TM_TOV_PCT': 11.6,
#   u'TS_PCT': 0.603,
#   u'USG_PCT': 0.137,
#   u'W': 18,
#   u'W_PCT': 0.45},
#  {u'AGE': 32.0,
#   u'AST_PCT': 0.133,
#   u'AST_RATIO': 25.4,
#   u'AST_TO': 0.67,
#   u'CFID': 5,
#   u'CFPARAMS': u'101236,1610612745',
#   u'DEF_RATING': 91.0,
#   u'DREB_PCT': 0.286,
#   u'EFG_PCT': 0.5,
#   u'FGA': 2,
#   u'FGA_PG': 1.0,
#   u'FGM': 1,
#   u'FGM_PG': 0.5,
#   u'FG_PCT': 0.5,
#   u'GP': 2,
#   u'L': 1,
#   u'MIN': 11.9,
#   'MIN_PLAYED': 11.0,
#   u'NET_RATING': -2.0,
#   u'OFF_RATING': 89.1,
#   u'OREB_PCT': 0.0,
#   u'PACE': 103.96,
#   u'PIE': 0.054,
#   u'PLAYER_ID': 101236,
#   u'PLAYER_NAME': u'Charles Hayes',
#   u'REB_PCT': 0.16,
#   'SEC_PLAYED': 0.9000000000000004,
#   u'TEAM_ABBREVIATION': u'HOU',
#   u'TEAM_ID': 1610612745,
#   u'TM_TOV_PCT': 38.1,
#   u'TS_PCT': 0.694,
#   u'USG_PCT': 0.112,
#   u'W': 1,
#   u'W_PCT': 0.5},
#  {u'AGE': 31.0,
#   u'AST_PCT': 0.061,
#   u'AST_RATIO': 5.9,
#   u'AST_TO': 0.81,
#   u'CFID': 5,
#   u'CFPARAMS': u'101111,1610612742',
#   u'DEF_RATING': 107.7,
#   u'DREB_PCT': 0.216,
#   u'EFG_PCT': 0.442,
#   u'FGA': 243,
#   u'FGA_PG': 6.1,
#   u'FGM': 92,
#   u'FGM_PG': 2.3,
#   u'FG_PCT': 0.379,
#   u'GP': 40,
#   u'L': 20,
#   u'MIN': 12.1,
#   'MIN_PLAYED': 12.0,
#   u'NET_RATING': -10.7,
#   u'OFF_RATING': 97.0,
#   u'OREB_PCT': 0.029,
#   u'PACE': 98.26,
#   u'PIE': 0.078,
#   u'PLAYER_ID': 101111,
#   u'PLAYER_NAME': u'Charlie Villanueva',
#   u'REB_PCT': 0.118,
#   'SEC_PLAYED': 0.09999999999999964,
#   u'TEAM_ABBREVIATION': u'DAL',
#   u'TEAM_ID': 1610612742,
#   u'TM_TOV_PCT': 7.3,
#   u'TS_PCT': 0.458,
#   u'USG_PCT': 0.249,
#   u'W': 20,
#   u'W_PCT': 0.5},
#  {u'AGE': 27.0,
#   u'AST_PCT': 0.097,
#   u'AST_RATIO': 17.1,
#   u'AST_TO': 1.72,
#   u'CFID': 5,
#   u'CFPARAMS': u'201978,1610612754',
#   u'DEF_RATING': 99.9,
#   u'DREB_PCT': 0.138,
#   u'EFG_PCT': 0.457,
#   u'FGA': 164,
#   u'FGA_PG': 4.1,
#   u'FGM': 66,
#   u'FGM_PG': 1.7,
#   u'FG_PCT': 0.402,
#   u'GP': 40,
#   u'L': 19,
#   u'MIN': 15.7,
#   'MIN_PLAYED': 15.0,
#   u'NET_RATING': 2.4,
#   u'OFF_RATING': 102.4,
#   u'OREB_PCT': 0.039,
#   u'PACE': 100.27,
#   u'PIE': 0.076,
#   u'PLAYER_ID': 201978,
#   u'PLAYER_NAME': u'Chase Budinger',
#   u'REB_PCT': 0.087,
#   'SEC_PLAYED': 0.6999999999999993,
#   u'TEAM_ABBREVIATION': u'IND',
#   u'TEAM_ID': 1610612754,
#   u'TM_TOV_PCT': 9.9,
#   u'TS_PCT': 0.494,
#   u'USG_PCT': 0.143,
#   u'W': 21,
#   u'W_PCT': 0.525},
#  {u'AGE': 37.0,
#   u'AST_PCT': 0.136,
#   u'AST_RATIO': 17.9,
#   u'AST_TO': 1.5,
#   u'CFID': 5,
#   u'CFPARAMS': u'2365,1610612748',
#   u'DEF_RATING': 118.8,
#   u'DREB_PCT': 0.2,
#   u'EFG_PCT': 0.5,
#   u'FGA': 10,
#   u'FGA_PG': 1.4,
#   u'FGM': 4,
#   u'FGM_PG': 0.6,
#   u'FG_PCT': 0.4,
#   u'GP': 7,
# ...
#   u'OFF_RATING': 107.3,
#   u'OREB_PCT': 0.135,
#   u'PACE': 95.26,
#   u'PIE': 0.112,
#   u'PLAYER_ID': 202684,
#   u'PLAYER_NAME': u'Tristan Thompson',
#   u'REB_PCT': 0.192,
#   'SEC_PLAYED': 0.5,
#   u'TEAM_ABBREVIATION': u'CLE',
#   u'TEAM_ID': 1610612739,
#   u'TM_TOV_PCT': 9.0,
#   u'TS_PCT': 0.588,
#   u'USG_PCT': 0.122,
#   u'W': 33,
#   u'W_PCT': 0.733},
#  {u'AGE': 24.0,
#   u'AST_PCT': 0.058,
#   u'AST_RATIO': 6.1,
#   u'AST_TO': 0.5,
#   u'CFID': 5,
#   u'CFPARAMS': u'203584,1610612766',
#   u'DEF_RATING': 105.1,
#   u'DREB_PCT': 0.117,
#   u'EFG_PCT': 0.635,
#   u'FGA': 104,
#   u'FGA_PG': 4.2,
#   u'FGM': 49,
#   u'FGM_PG': 2.0,
#   u'FG_PCT': 0.471,
#   u'GP': 25,
#   u'L': 13,
#   u'MIN': 10.8,
#   'MIN_PLAYED': 10.0,
#   u'NET_RATING': -3.5,
#   u'OFF_RATING': 101.6,
#   u'OREB_PCT': 0.02,
#   u'PACE': 97.36,
#   u'PIE': 0.083,
#   u'PLAYER_ID': 203584,
#   u'PLAYER_NAME': u'Troy Daniels',
#   u'REB_PCT': 0.065,
#   'SEC_PLAYED': 0.8000000000000007,
#   u'TEAM_ABBREVIATION': u'CHA',
#   u'TEAM_ID': 1610612766,
#   u'TM_TOV_PCT': 12.2,
#   u'TS_PCT': 0.632,
#   u'USG_PCT': 0.206,
#   u'W': 12,
#   u'W_PCT': 0.48},
#  {u'AGE': 28.0,
#   u'AST_PCT': 0.242,
#   u'AST_RATIO': 31.8,
#   u'AST_TO': 2.34,
#   u'CFID': 5,
#   u'CFPARAMS': u'201951,1610612745',
#   u'DEF_RATING': 106.5,
#   u'DREB_PCT': 0.064,
#   u'EFG_PCT': 0.446,
#   u'FGA': 249,
#   u'FGA_PG': 5.9,
#   u'FGM': 98,
#   u'FGM_PG': 2.3,
#   u'FG_PCT': 0.394,
#   u'GP': 42,
#   u'L': 24,
#   u'MIN': 24.3,
#   'MIN_PLAYED': 24.0,
#   u'NET_RATING': -6.8,
#   u'OFF_RATING': 99.7,
#   u'OREB_PCT': 0.021,
#   u'PACE': 101.61,
#   u'PIE': 0.065,
#   u'PLAYER_ID': 201951,
#   u'PLAYER_NAME': u'Ty Lawson',
#   u'REB_PCT': 0.042,
#   'SEC_PLAYED': 0.3000000000000007,
#   u'TEAM_ABBREVIATION': u'HOU',
#   u'TEAM_ID': 1610612745,
#   u'TM_TOV_PCT': 13.6,
#   u'TS_PCT': 0.487,
#   u'USG_PCT': 0.147,
#   u'W': 18,
#   u'W_PCT': 0.429},
#  {u'AGE': 21.0,
#   u'AST_PCT': 0.188,
#   u'AST_RATIO': 20.9,
#   u'AST_TO': 1.5,
#   u'CFID': 5,
#   u'CFPARAMS': u'203898,1610612749',
#   u'DEF_RATING': 105.8,
#   u'DREB_PCT': 0.101,
#   u'EFG_PCT': 0.433,
#   u'FGA': 60,
#   u'FGA_PG': 2.7,
#   u'FGM': 24,
#   u'FGM_PG': 1.1,
#   u'FG_PCT': 0.4,
#   u'GP': 22,
#   u'L': 13,
#   u'MIN': 9.0,
#   'MIN_PLAYED': 9.0,
#   u'NET_RATING': -12.8,
#   u'OFF_RATING': 93.0,
#   u'OREB_PCT': 0.017,
#   u'PACE': 92.39,
#   u'PIE': 0.044,
#   u'PLAYER_ID': 203898,
#   u'PLAYER_NAME': u'Tyler Ennis',
#   u'REB_PCT': 0.059,
#   'SEC_PLAYED': 0.0,
#   u'TEAM_ABBREVIATION': u'MIL',
#   u'TEAM_ID': 1610612749,
#   u'TM_TOV_PCT': 14.0,
#   u'TS_PCT': 0.467,
#   u'USG_PCT': 0.192,
#   u'W': 9,
#   u'W_PCT': 0.409},
#  {u'AGE': 30.0,
#   u'AST_PCT': 0.048,
#   u'AST_RATIO': 7.9,
#   u'AST_TO': 0.64,
#   u'CFID': 5,
#   u'CFPARAMS': u'201946,1610612766',
#   u'DEF_RATING': 108.3,
#   u'DREB_PCT': 0.189,
#   u'EFG_PCT': 0.442,
#   u'FGA': 52,
#   u'FGA_PG': 1.9,
#   u'FGM': 22,
#   u'FGM_PG': 0.8,
#   u'FG_PCT': 0.423,
#   u'GP': 27,
#   u'L': 13,
#   u'MIN': 9.2,
#   'MIN_PLAYED': 9.0,
#   u'NET_RATING': -3.3,
#   u'OFF_RATING': 104.9,
#   u'OREB_PCT': 0.134,
#   u'PACE': 94.89,
#   u'PIE': 0.053,
#   u'PLAYER_ID': 201946,
#   u'PLAYER_NAME': u'Tyler Hansbrough',
#   u'REB_PCT': 0.158,
#   'SEC_PLAYED': 0.1999999999999993,
#   u'TEAM_ABBREVIATION': u'CHA',
#   u'TEAM_ID': 1610612766,
#   u'TM_TOV_PCT': 12.4,
#   u'TS_PCT': 0.497,
#   u'USG_PCT': 0.148,
#   u'W': 14,
#   u'W_PCT': 0.519},
#  {u'AGE': 23.0,
#   u'AST_PCT': 0.151,
#   u'AST_RATIO': 19.9,
#   u'AST_TO': 1.68,
#   u'CFID': 5,
#   u'CFPARAMS': u'204020,1610612748',
#   u'DEF_RATING': 98.4,
#   u'DREB_PCT': 0.104,
#   u'EFG_PCT': 0.543,
#   u'FGA': 242,
#   u'FGA_PG': 6.7,
#   u'FGM': 118,
#   u'FGM_PG': 3.3,
#   u'FG_PCT': 0.488,
#   u'GP': 36,
#   u'L': 17,
#   u'MIN': 24.0,
#   'MIN_PLAYED': 24.0,
#   u'NET_RATING': 2.4,
#   u'OFF_RATING': 100.8,
#   u'OREB_PCT': 0.038,
#   u'PACE': 94.35,
#   u'PIE': 0.098,
#   u'PLAYER_ID': 204020,
#   u'PLAYER_NAME': u'Tyler Johnson',
#   u'REB_PCT': 0.072,
#   'SEC_PLAYED': 0.0,
#   u'TEAM_ABBREVIATION': u'MIA',
#   u'TEAM_ID': 1610612748,
#   u'TM_TOV_PCT': 11.9,
#   u'TS_PCT': 0.581,
#   u'USG_PCT': 0.171,
#   u'W': 19,
#   u'W_PCT': 0.528},
#  {u'AGE': 26.0,
#   u'AST_PCT': 0.065,
#   u'AST_RATIO': 5.9,
#   u'AST_TO': 0.43,
#   u'CFID': 5,
#   u'CFPARAMS': u'203092,1610612738',
#   u'DEF_RATING': 98.7,
#   u'DREB_PCT': 0.167,
#   u'EFG_PCT': 0.458,
#   u'FGA': 120,
#   u'FGA_PG': 3.9,
#   u'FGM': 55,
#   u'FGM_PG': 1.8,
#   u'FG_PCT': 0.458,
#   u'GP': 31,
#   u'L': 11,
#   u'MIN': 8.8,
#   'MIN_PLAYED': 8.0,
#   u'NET_RATING': -2.2,
#   u'OFF_RATING': 96.5,
#   u'OREB_PCT': 0.089,
#   u'PACE': 103.49,
#   u'PIE': 0.074,
#   u'PLAYER_ID': 203092,
#   u'PLAYER_NAME': u'Tyler Zeller',
#   u'REB_PCT': 0.129,
#   'SEC_PLAYED': 0.8000000000000007,
#   u'TEAM_ABBREVIATION': u'BOS',
#   u'TEAM_ID': 1610612738,
#   u'TM_TOV_PCT': 13.6,
#   u'TS_PCT': 0.497,
#   u'USG_PCT': 0.245,
#   u'W': 20,
#   u'W_PCT': 0.645},
#  {u'AGE': 26.0,
#   u'AST_PCT': 0.366,
#   u'AST_RATIO': 27.7,
#   u'AST_TO': 2.25,
#   u'CFID': 5,
#   u'CFPARAMS': u'201936,1610612740',
#   u'DEF_RATING': 105.4,
#   u'DREB_PCT': 0.159,
#   u'EFG_PCT': 0.486,
#   u'FGA': 314,
#   u'FGA_PG': 12.6,
#   u'FGM': 136,
#   u'FGM_PG': 5.4,
#   u'FG_PCT': 0.433,
#   u'GP': 25,
#   u'L': 14,
#   u'MIN': 30.6,
#   'MIN_PLAYED': 30.0,
#   u'NET_RATING': -0.9,
#   u'OFF_RATING': 104.5,
#   u'OREB_PCT': 0.029,
#   u'PACE': 95.42,
#   u'PIE': 0.131,
#   u'PLAYER_ID': 201936,
#   u'PLAYER_NAME': u'Tyreke Evans',
#   u'REB_PCT': 0.094,
#   'SEC_PLAYED': 0.6000000000000014,
#   u'TEAM_ABBREVIATION': u'NOP',
#   u'TEAM_ID': 1610612740,
#   u'TM_TOV_PCT': 12.3,
#   u'TS_PCT': 0.534,
#   u'USG_PCT': 0.254,
#   u'W': 11,
#   u'W_PCT': 0.44},
#  {u'AGE': 33.0,
#   u'AST_PCT': 0.065,
#   u'AST_RATIO': 13.4,
#   u'AST_TO': 0.79,
#   u'CFID': 5,
#   u'CFPARAMS': u'2199,1610612756',
#   u'DEF_RATING': 109.0,
#   u'DREB_PCT': 0.275,
#   u'EFG_PCT': 0.484,
#   u'FGA': 155,
#   u'FGA_PG': 4.0,
#   u'FGM': 75,
#   u'FGM_PG': 1.9,
#   u'FG_PCT': 0.484,
#   u'GP': 39,
#   u'L': 28,
#   u'MIN': 23.2,
#   'MIN_PLAYED': 23.0,
#   u'NET_RATING': -15.5,
#   u'OFF_RATING': 93.5,
#   u'OREB_PCT': 0.117,
#   u'PACE': 99.24,
#   u'PIE': 0.101,
#   u'PLAYER_ID': 2199,
#   u'PLAYER_NAME': u'Tyson Chandler',
#   u'REB_PCT': 0.193,
#   'SEC_PLAYED': 0.1999999999999993,
#   u'TEAM_ABBREVIATION': u'PHX',
#   u'TEAM_ID': 1610612756,
#   u'TM_TOV_PCT': 16.9,
#   u'TS_PCT': 0.539,
#   u'USG_PCT': 0.118,
#   u'W': 11,
#   u'W_PCT': 0.282},
#  {u'AGE': 19.0,
#   u'AST_PCT': 0.28,
#   u'AST_RATIO': 25.4,
#   u'AST_TO': 1.75,
#   u'CFID': 5,
#   u'CFPARAMS': u'1626145,1610612750',
#   u'DEF_RATING': 125.6,
#   u'DREB_PCT': 0.171,
#   u'EFG_PCT': 0.387,
#   u'FGA': 31,
#   u'FGA_PG': 3.4,
#   u'FGM': 11,
#   u'FGM_PG': 1.2,
#   u'FG_PCT': 0.355,
#   u'GP': 9,
#   u'L': 8,
#   u'MIN': 10.9,
#   'MIN_PLAYED': 10.0,
#   u'NET_RATING': -41.7,
#   u'OFF_RATING': 83.9,
#   u'OREB_PCT': 0.035,
#   u'PACE': 94.53,
#   u'PIE': 0.067,
#   u'PLAYER_ID': 1626145,
#   u'PLAYER_NAME': u'Tyus Jones',
#   u'REB_PCT': 0.096,
#   'SEC_PLAYED': 0.9000000000000004,
#   u'TEAM_ABBREVIATION': u'MIN',
#   u'TEAM_ID': 1610612750,
#   u'TM_TOV_PCT': 14.5,
#   u'TS_PCT': 0.407,
#   u'USG_PCT': 0.195,
#   u'W': 1,
#   u'W_PCT': 0.111},
#  {u'AGE': 35.0,
#   u'AST_PCT': 0.102,
#   u'AST_RATIO': 20.6,
#   u'AST_TO': 2.6,
#   u'CFID': 5,
#   u'CFPARAMS': u'2617,1610612748',
#   u'DEF_RATING': 100.3,
#   u'DREB_PCT': 0.28,
#   u'EFG_PCT': 0.369,
#   u'FGA': 42,
#   u'FGA_PG': 1.8,
#   u'FGM': 15,
#   u'FGM_PG': 0.7,
#   u'FG_PCT': 0.357,
#   u'GP': 23,
#   u'L': 9,
#   u'MIN': 8.5,
#   'MIN_PLAYED': 8.0,
#   u'NET_RATING': -2.5,
#   u'OFF_RATING': 97.8,
#   u'OREB_PCT': 0.053,
#   u'PACE': 93.56,
#   u'PIE': 0.089,
#   u'PLAYER_ID': 2617,
#   u'PLAYER_NAME': u'Udonis Haslem',
#   u'REB_PCT': 0.169,
#   'SEC_PLAYED': 0.5,
#   u'TEAM_ABBREVIATION': u'MIA',
#   u'TEAM_ID': 1610612748,
#   u'TM_TOV_PCT': 7.9,
#   u'TS_PCT': 0.421,
#   u'USG_PCT': 0.127,
#   u'W': 14,
#   u'W_PCT': 0.609},
#  {u'AGE': 23.0,
#   u'AST_PCT': 0.206,
#   u'AST_RATIO': 20.2,
#   u'AST_TO': 1.85,
#   u'CFID': 5,
#   u'CFPARAMS': u'203506,1610612753',
#   u'DEF_RATING': 102.8,
#   u'DREB_PCT': 0.148,
#   u'EFG_PCT': 0.46,
#   u'FGA': 501,
#   u'FGA_PG': 12.2,
#   u'FGM': 203,
#   u'FGM_PG': 5.0,
#   u'FG_PCT': 0.405,
#   u'GP': 41,
#   u'L': 22,
#   u'MIN': 30.4,
#   'MIN_PLAYED': 30.0,
#   u'NET_RATING': -1.5,
#   u'OFF_RATING': 101.3,
#   u'OREB_PCT': 0.02,
#   u'PACE': 96.71,
#   u'PIE': 0.108,
#   u'PLAYER_ID': 203506,
#   u'PLAYER_NAME': u'Victor Oladipo',
#   u'REB_PCT': 0.086,
#   'SEC_PLAYED': 0.3999999999999986,
#   u'TEAM_ABBREVIATION': u'ORL',
#   u'TEAM_ID': 1610612753,
#   u'TM_TOV_PCT': 10.9,
#   u'TS_PCT': 0.506,
#   u'USG_PCT': 0.23,
#   u'W': 19,
#   u'W_PCT': 0.463},
#  {u'AGE': 39.0,
#   u'AST_PCT': 0.086,
#   u'AST_RATIO': 13.4,
#   u'AST_TO': 1.67,
#   u'CFID': 5,
#   u'CFPARAMS': u'1713,1610612763',
#   u'DEF_RATING': 100.1,
#   u'DREB_PCT': 0.114,
#   u'EFG_PCT': 0.37,
#   u'FGA': 108,
#   u'FGA_PG': 3.7,
#   u'FGM': 33,
#   u'FGM_PG': 1.1,
#   u'FG_PCT': 0.306,
#   u'GP': 29,
#   u'L': 11,
#   u'MIN': 12.7,
#   'MIN_PLAYED': 12.0,
#   u'NET_RATING': -3.5,
#   u'OFF_RATING': 96.7,
#   u'OREB_PCT': 0.026,
#   u'PACE': 97.88,
#   u'PIE': 0.04,
#   u'PLAYER_ID': 1713,
#   u'PLAYER_NAME': u'Vince Carter',
#   u'REB_PCT': 0.07,
#   'SEC_PLAYED': 0.6999999999999993,
#   u'TEAM_ABBREVIATION': u'MEM',
#   u'TEAM_ID': 1610612763,
#   u'TM_TOV_PCT': 8.0,
#   u'TS_PCT': 0.421,
#   u'USG_PCT': 0.159,
#   u'W': 18,
#   u'W_PCT': 0.621},
#  {u'AGE': 23.0,
#   u'AST_PCT': 0.05,
#   u'AST_RATIO': 8.2,
#   u'AST_TO': 0.5,
#   u'CFID': 5,
#   u'CFPARAMS': u'204002,1610612737',
#   u'DEF_RATING': 120.2,
#   u'DREB_PCT': 0.196,
#   u'EFG_PCT': 0.533,
#   u'FGA': 15,
#   u'FGA_PG': 1.9,
#   u'FGM': 8,
#   u'FGM_PG': 1.0,
#   u'FG_PCT': 0.533,
#   u'GP': 8,
#   u'L': 4,
#   u'MIN': 7.2,
#   'MIN_PLAYED': 7.0,
#   u'NET_RATING': -14.0,
#   u'OFF_RATING': 106.2,
#   u'OREB_PCT': 0.133,
#   u'PACE': 99.7,
#   u'PIE': 0.059,
#   u'PLAYER_ID': 204002,
#   u'PLAYER_NAME': u'Walter Tavares',
#   u'REB_PCT': 0.165,
#   'SEC_PLAYED': 0.20000000000000018,
#   u'TEAM_ABBREVIATION': u'ATL',
#   u'TEAM_ID': 1610612737,
#   u'TM_TOV_PCT': 16.3,
#   u'TS_PCT': 0.513,
#   u'USG_PCT': 0.176,
#   u'W': 4,
#   u'W_PCT': 0.5},
#  {u'AGE': 28.0,
#   u'AST_PCT': 0.074,
#   u'AST_RATIO': 10.2,
#   u'AST_TO': 1.46,
#   u'CFID': 5,
#   u'CFPARAMS': u'201961,1610612751',
#   u'DEF_RATING': 103.4,
#   u'DREB_PCT': 0.11,
#   u'EFG_PCT': 0.457,
#   u'FGA': 317,
#   u'FGA_PG': 6.7,
#   u'FGM': 121,
#   u'FGM_PG': 2.6,
#   u'FG_PCT': 0.382,
#   u'GP': 47,
#   u'L': 36,
#   u'MIN': 19.5,
#   'MIN_PLAYED': 19.0,
#   u'NET_RATING': -10.5,
#   u'OFF_RATING': 92.9,
#   u'OREB_PCT': 0.013,
#   u'PACE': 95.76,
#   u'PIE': 0.067,
#   u'PLAYER_ID': 201961,
#   u'PLAYER_NAME': u'Wayne Ellington',
#   u'REB_PCT': 0.06,
#   'SEC_PLAYED': 0.5,
#   u'TEAM_ABBREVIATION': u'BKN',
#   u'TEAM_ID': 1610612751,
#   u'TM_TOV_PCT': 7.0,
#   u'TS_PCT': 0.477,
#   u'USG_PCT': 0.178,
#   u'W': 11,
#   u'W_PCT': 0.234},
#  {u'AGE': 28.0,
#   u'AST_PCT': 0.047,
#   u'AST_RATIO': 7.6,
#   u'AST_TO': 0.93,
#   u'CFID': 5,
#   u'CFPARAMS': u'202325,1610612746',
#   u'DEF_RATING': 99.0,
#   u'DREB_PCT': 0.125,
#   u'EFG_PCT': 0.533,
#   u'FGA': 273,
#   u'FGA_PG': 5.8,
#   u'FGM': 116,
#   u'FGM_PG': 2.5,
#   u'FG_PCT': 0.425,
#   u'GP': 47,
#   u'L': 16,
#   u'MIN': 18.6,
#   'MIN_PLAYED': 18.0,
#   u'NET_RATING': 2.3,
#   u'OFF_RATING': 101.3,
#   u'OREB_PCT': 0.024,
#   u'PACE': 98.95,
#   u'PIE': 0.075,
#   u'PLAYER_ID': 202325,
#   u'PLAYER_NAME': u'Wesley Johnson',
#   u'REB_PCT': 0.074,
#   'SEC_PLAYED': 0.6000000000000014,
#   u'TEAM_ABBREVIATION': u'LAC',
#   u'TEAM_ID': 1610612746,
#   u'TM_TOV_PCT': 8.2,
#   u'TS_PCT': 0.54,
#   u'USG_PCT': 0.16,
#   u'W': 31,
#   u'W_PCT': 0.66},
#  {u'AGE': 29.0,
#   u'AST_PCT': 0.086,
#   u'AST_RATIO': 12.5,
#   u'AST_TO': 1.77,
#   u'CFID': 5,
#   u'CFPARAMS': u'202083,1610612742',
#   u'DEF_RATING': 104.6,
#   u'DREB_PCT': 0.088,
#   u'EFG_PCT': 0.496,
#   u'FGA': 497,
#   u'FGA_PG': 11.0,
#   u'FGM': 193,
#   u'FGM_PG': 4.3,
#   u'FG_PCT': 0.388,
#   u'GP': 45,
#   u'L': 20,
#   u'MIN': 33.0,
#   'MIN_PLAYED': 33.0,
#   u'NET_RATING': 3.4,
#   u'OFF_RATING': 108.0,
#   u'OREB_PCT': 0.014,
#   u'PACE': 95.14,
#   u'PIE': 0.067,
#   u'PLAYER_ID': 202083,
#   u'PLAYER_NAME': u'Wesley Matthews',
#   u'REB_PCT': 0.052,
#   'SEC_PLAYED': 0.0,
#   u'TEAM_ABBREVIATION': u'DAL',
#   u'TEAM_ID': 1610612742,
#   u'TM_TOV_PCT': 7.1,
#   u'TS_PCT': 0.528,
#   u'USG_PCT': 0.18,
#   u'W': 25,
#   u'W_PCT': 0.556},
#  {u'AGE': 25.0,
#   u'AST_PCT': 0.148,
#   u'AST_RATIO': 13.2,
#   u'AST_TO': 1.48,
#   u'CFID': 5,
#   u'CFPARAMS': u'203115,1610612743',
#   u'DEF_RATING': 104.3,
#   u'DREB_PCT': 0.2,
#   u'EFG_PCT': 0.508,
#   u'FGA': 604,
#   u'FGA_PG': 12.6,
#   u'FGM': 269,
#   u'FGM_PG': 5.6,
#   u'FG_PCT': 0.445,
#   u'GP': 48,
#   u'L': 30,
#   u'MIN': 28.8,
#   'MIN_PLAYED': 28.0,
#   u'NET_RATING': -3.0,
#   u'OFF_RATING': 101.2,
#   u'OREB_PCT': 0.032,
#   u'PACE': 98.31,
#   u'PIE': 0.139,
#   u'PLAYER_ID': 203115,
#   u'PLAYER_NAME': u'Will Barton',
#   u'REB_PCT': 0.114,
#   'SEC_PLAYED': 0.8000000000000007,
#   u'TEAM_ABBREVIATION': u'DEN',
#   u'TEAM_ID': 1610612743,
#   u'TM_TOV_PCT': 8.9,
#   u'TS_PCT': 0.554,
#   u'USG_PCT': 0.237,
#   u'W': 18,
#   u'W_PCT': 0.375},
#  {u'AGE': 22.0,
#   u'AST_PCT': 0.032,
#   u'AST_RATIO': 7.5,
#   u'AST_TO': 0.74,
#   u'CFID': 5,
#   u'CFPARAMS': u'1626161,1610612758',
#   u'DEF_RATING': 103.9,
#   u'DREB_PCT': 0.191,
#   u'EFG_PCT': 0.598,
#   u'FGA': 127,
#   u'FGA_PG': 4.0,
#   u'FGM': 76,
#   u'FGM_PG': 2.4,
#   u'FG_PCT': 0.598,
#   u'GP': 32,
#   u'L': 18,
#   u'MIN': 19.9,
#   'MIN_PLAYED': 19.0,
#   u'NET_RATING': 2.1,
#   u'OFF_RATING': 106.0,
#   u'OREB_PCT': 0.116,
#   u'PACE': 99.89,
#   u'PIE': 0.092,
#   u'PLAYER_ID': 1626161,
#   u'PLAYER_NAME': u'Willie Cauley-Stein',
#   u'REB_PCT': 0.154,
#   'SEC_PLAYED': 0.8999999999999986,
#   u'TEAM_ABBREVIATION': u'SAC',
#   u'TEAM_ID': 1610612758,
#   u'TM_TOV_PCT': 10.1,
#   u'TS_PCT': 0.608,
#   u'USG_PCT': 0.117,
#   u'W': 14,
#   u'W_PCT': 0.438},
#  {u'AGE': 25.0,
#   u'AST_PCT': 0.032,
#   u'AST_RATIO': 4.5,
#   u'AST_TO': 0.38,
#   u'CFID': 5,
#   u'CFPARAMS': u'203186,1610612751',
#   u'DEF_RATING': 101.1,
#   u'DREB_PCT': 0.2,
#   u'EFG_PCT': 0.588,
#   u'FGA': 80,
#   u'FGA_PG': 3.1,
#   u'FGM': 47,
#   u'FGM_PG': 1.8,
#   u'FG_PCT': 0.588,
#   u'GP': 26,
#   u'L': 20,
#   u'MIN': 10.3,
#   'MIN_PLAYED': 10.0,
#   u'NET_RATING': -7.3,
#   u'OFF_RATING': 93.8,
#   u'OREB_PCT': 0.109,
#   u'PACE': 96.99,
#   u'PIE': 0.102,
#   u'PLAYER_ID': 203186,
#   u'PLAYER_NAME': u'Willie Reed',
#   u'REB_PCT': 0.153,
#   'SEC_PLAYED': 0.3000000000000007,
#   u'TEAM_ABBREVIATION': u'BKN',
#   u'TEAM_ID': 1610612751,
#   u'TM_TOV_PCT': 11.6,
#   u'TS_PCT': 0.585,
#   u'USG_PCT': 0.181,
#   u'W': 6,
#   u'W_PCT': 0.231},
#  {u'AGE': 20.0,
#   u'AST_PCT': 0.247,
#   u'AST_RATIO': 18.4,
#   u'AST_TO': 1.64,
#   u'CFID': 5,
#   u'CFPARAMS': u'203897,1610612750',
#   u'DEF_RATING': 107.7,
#   u'DREB_PCT': 0.127,
#   u'EFG_PCT': 0.486,
#   u'FGA': 522,
#   u'FGA_PG': 10.9,
#   u'FGM': 229,
#   u'FGM_PG': 4.8,
#   u'FG_PCT': 0.439,
#   u'GP': 48,
#   u'L': 34,
#   u'MIN': 23.5,
#   'MIN_PLAYED': 23.0,
#   u'NET_RATING': -7.5,
#   u'OFF_RATING': 100.2,
#   u'OREB_PCT': 0.021,
#   u'PACE': 99.07,
#   u'PIE': 0.103,
#   u'PLAYER_ID': 203897,
#   u'PLAYER_NAME': u'Zach LaVine',
#   u'REB_PCT': 0.074,
#   'SEC_PLAYED': 0.5,
#   u'TEAM_ABBREVIATION': u'MIN',
#   u'TEAM_ID': 1610612750,
#   u'TM_TOV_PCT': 11.2,
#   u'TS_PCT': 0.527,
#   u'USG_PCT': 0.263,
#   u'W': 14,
#   u'W_PCT': 0.292},
#  {u'AGE': 34.0,
#   u'AST_PCT': 0.091,
#   u'AST_RATIO': 8.9,
#   u'AST_TO': 1.02,
#   u'CFID': 5,
#   u'CFPARAMS': u'2216,1610612763',
#   u'DEF_RATING': 103.8,
#   u'DREB_PCT': 0.221,
#   u'EFG_PCT': 0.481,
#   u'FGA': 500,
#   u'FGA_PG': 11.9,
#   u'FGM': 240,
#   u'FGM_PG': 5.7,
#   u'FG_PCT': 0.48,
#   u'GP': 42,
#   u'L': 18,
#   u'MIN': 28.6,
#   'MIN_PLAYED': 28.0,
#   u'NET_RATING': -2.7,
#   u'OFF_RATING': 101.1,
#   u'OREB_PCT': 0.114,
#   u'PACE': 94.3,
#   u'PIE': 0.129,
#   u'PLAYER_ID': 2216,
#   u'PLAYER_NAME': u'Zach Randolph',
#   u'REB_PCT': 0.164,
#   'SEC_PLAYED': 0.6000000000000014,
#   u'TEAM_ABBREVIATION': u'MEM',
#   u'TEAM_ID': 1610612763,
#   u'TM_TOV_PCT': 8.7,
#   u'TS_PCT': 0.519,
#   u'USG_PCT': 0.23,
#   u'W': 24,
#   u'W_PCT': 0.571},
#  {u'AGE': 31.0,
#   u'AST_PCT': 0.103,
#   u'AST_RATIO': 14.6,
#   u'AST_TO': 1.01,
#   u'CFID': 5,
#   u'CFPARAMS': u'2585,1610612742',
#   u'DEF_RATING': 101.4,
#   u'DREB_PCT': 0.267,
#   u'EFG_PCT': 0.483,
#   u'FGA': 323,
#   u'FGA_PG': 7.3,
#   u'FGM': 156,
#   u'FGM_PG': 3.5,
#   u'FG_PCT': 0.483,
#   u'GP': 44,
#   u'L': 19,
#   u'MIN': 29.3,
#   'MIN_PLAYED': 29.0,
#   u'NET_RATING': 3.0,
#   u'OFF_RATING': 104.4,
#   u'OREB_PCT': 0.143,
#   u'PACE': 95.77,
#   u'PIE': 0.128,
#   u'PLAYER_ID': 2585,
#   u'PLAYER_NAME': u'Zaza Pachulia',
#   u'REB_PCT': 0.206,
#   'SEC_PLAYED': 0.3000000000000007,
#   u'TEAM_ABBREVIATION': u'DAL',
#   u'TEAM_ID': 1610612742,
#   u'TM_TOV_PCT': 14.5,
#   u'TS_PCT': 0.568,
#   u'USG_PCT': 0.175,
#   u'W': 25,
#   u'W_PCT': 0.568}]

# %%
avg_stats = parser.playerstats(scraper.playerstats(season='2015-16', PerMode='PerGame'))

# %%
avg_stats
# Out:
# [{u'AGE': 31.0,
#   u'AST': 2.4,
#   u'BLK': 0.2,
#   u'BLKA': 0.5,
#   u'CFID': 5,
#   u'CFPARAMS': u'201166,1610612741',
#   u'DD2': 0,
#   u'DREB': 1.5,
#   u'FG3A': 3.0,
#   u'FG3M': 1.1,
#   u'FG3_PCT': 0.381,
#   u'FGA': 7.1,
#   u'FGM': 2.9,
#   u'FG_PCT': 0.413,
#   u'FTA': 1.0,
#   u'FTM': 0.8,
#   u'FT_PCT': 0.824,
#   u'GP': 35,
#   u'L': 14,
#   u'MIN': 16.4,
#   'MIN_PLAYED': 16.0,
#   u'OREB': 0.4,
#   u'PF': 2.1,
#   u'PFD': 1.2,
#   u'PLAYER_ID': 201166,
#   u'PLAYER_NAME': u'Aaron Brooks',
#   u'PLUS_MINUS': 1.7,
#   u'PTS': 7.8,
#   u'REB': 1.9,
#   'SEC_PLAYED': 0.3999999999999986,
#   u'STL': 0.3,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'CHI',
#   u'TEAM_ID': 1610612741,
#   u'TOV': 1.0,
#   u'W': 21,
#   u'W_PCT': 0.6},
#  {u'AGE': 20.0,
#   u'AST': 1.3,
#   u'BLK': 0.6,
#   u'BLKA': 0.3,
#   u'CFID': 5,
#   u'CFPARAMS': u'203932,1610612753',
#   u'DD2': 1,
#   u'DREB': 3.6,
#   u'FG3A': 1.5,
#   u'FG3M': 0.5,
#   u'FG3_PCT': 0.338,
#   u'FGA': 5.7,
#   u'FGM': 2.8,
#   u'FG_PCT': 0.48,
#   u'FTA': 2.1,
#   u'FTM': 1.5,
#   u'FT_PCT': 0.707,
#   u'GP': 44,
#   u'L': 25,
#   u'MIN': 20.3,
#   'MIN_PLAYED': 20.0,
#   u'OREB': 1.7,
#   u'PF': 1.8,
#   u'PFD': 1.7,
#   u'PLAYER_ID': 203932,
#   u'PLAYER_NAME': u'Aaron Gordon',
#   u'PLUS_MINUS': -1.6,
#   u'PTS': 7.5,
#   u'REB': 5.3,
#   'SEC_PLAYED': 0.3000000000000007,
#   u'STL': 0.6,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'ORL',
#   u'TEAM_ID': 1610612753,
#   u'TOV': 0.9,
#   u'W': 19,
#   u'W_PCT': 0.432},
#  {u'AGE': 21.0,
#   u'AST': 0.0,
#   u'BLK': 0.0,
#   u'BLKA': 0.0,
#   u'CFID': 5,
#   u'CFPARAMS': u'1626151,1610612766',
#   u'DD2': 0,
#   u'DREB': 0.4,
#   u'FG3A': 0.3,
#   u'FG3M': 0.1,
#   u'FG3_PCT': 0.333,
#   u'FGA': 0.7,
#   u'FGM': 0.2,
#   u'FG_PCT': 0.25,
#   u'FTA': 0.5,
#   u'FTM': 0.2,
#   u'FT_PCT': 0.333,
#   u'GP': 12,
#   u'L': 5,
#   u'MIN': 4.3,
#   'MIN_PLAYED': 4.0,
#   u'OREB': 0.3,
#   u'PF': 0.2,
#   u'PFD': 0.4,
#   u'PLAYER_ID': 1626151,
#   u'PLAYER_NAME': u'Aaron Harrison',
#   u'PLUS_MINUS': 0.4,
#   u'PTS': 0.6,
#   u'REB': 0.7,
#   'SEC_PLAYED': 0.2999999999999998,
#   u'STL': 0.3,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'CHA',
#   u'TEAM_ID': 1610612766,
#   u'TOV': 0.2,
#   u'W': 7,
#   u'W_PCT': 0.583},
#  {u'AGE': 24.0,
#   u'AST': 0.5,
#   u'BLK': 0.3,
#   u'BLKA': 0.2,
#   u'CFID': 5,
#   u'CFPARAMS': u'203940,1610612750',
#   u'DD2': 0,
#   u'DREB': 1.7,
#   u'FG3A': 0.7,
#   u'FG3M': 0.3,
#   u'FG3_PCT': 0.381,
#   u'FGA': 2.7,
#   u'FGM': 1.1,
#   u'FG_PCT': 0.407,
#   u'FTA': 0.4,
#   u'FTM': 0.3,
#   u'FT_PCT': 0.667,
#   u'GP': 30,
#   u'L': 19,
#   u'MIN': 9.5,
#   'MIN_PLAYED': 9.0,
#   u'OREB': 0.3,
#   u'PF': 1.5,
#   u'PFD': 0.6,
#   u'PLAYER_ID': 203940,
#   u'PLAYER_NAME': u'Adreian Payne',
#   u'PLUS_MINUS': -1.4,
#   u'PTS': 2.7,
#   u'REB': 2.0,
#   'SEC_PLAYED': 0.5,
#   u'STL': 0.3,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'MIN',
#   u'TEAM_ID': 1610612750,
#   u'TOV': 0.6,
#   u'W': 11,
#   u'W_PCT': 0.367},
#  {u'AGE': 29.0,
#   u'AST': 3.0,
#   u'BLK': 1.5,
#   u'BLKA': 0.5,
#   u'CFID': 5,
#   u'CFPARAMS': u'201143,1610612737',
#   u'DD2': 10,
#   u'DREB': 5.0,
#   u'FG3A': 3.0,
#   u'FG3M': 0.9,
#   u'FG3_PCT': 0.317,
#   u'FGA': 13.0,
#   u'FGM': 6.5,
#   u'FG_PCT': 0.501,
#   u'FTA': 1.7,
#   u'FTM': 1.3,
#   u'FT_PCT': 0.763,
#   u'GP': 48,
#   u'L': 21,
#   u'MIN': 31.5,
#   'MIN_PLAYED': 31.0,
#   u'OREB': 2.1,
#   u'PF': 1.9,
#   u'PFD': 1.4,
#   u'PLAYER_ID': 201143,
#   u'PLAYER_NAME': u'Al Horford',
#   u'PLUS_MINUS': 1.3,
#   u'PTS': 15.2,
#   u'REB': 7.1,
#   'SEC_PLAYED': 0.5,
#   u'STL': 0.9,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'ATL',
#   u'TEAM_ID': 1610612737,
#   u'TOV': 1.3,
#   u'W': 27,
#   u'W_PCT': 0.563},
#  {u'AGE': 31.0,
#   u'AST': 1.6,
#   u'BLK': 1.1,
#   u'BLKA': 0.8,
#   u'CFID': 5,
#   u'CFPARAMS': u'2744,1610612766',
#   u'DD2': 4,
#   u'DREB': 4.9,
#   u'FG3A': 0.0,
#   u'FG3M': 0.0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 11.7,
#   u'FGM': 5.6,
#   u'FG_PCT': 0.482,
#   u'FTA': 2.2,
#   u'FTM': 1.3,
#   u'FT_PCT': 0.571,
#   u'GP': 19,
#   u'L': 7,
#   u'MIN': 25.2,
#   'MIN_PLAYED': 25.0,
#   u'OREB': 1.2,
#   u'PF': 2.4,
#   u'PFD': 1.7,
#   u'PLAYER_ID': 2744,
#   u'PLAYER_NAME': u'Al Jefferson',
#   u'PLUS_MINUS': -0.6,
#   u'PTS': 12.5,
#   u'REB': 6.1,
#   'SEC_PLAYED': 0.1999999999999993,
#   u'STL': 0.7,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'CHA',
#   u'TEAM_ID': 1610612766,
#   u'TOV': 0.7,
#   u'W': 12,
#   u'W_PCT': 0.632},
#  {u'AGE': 25.0,
#   u'AST': 1.5,
#   u'BLK': 0.7,
#   u'BLKA': 0.5,
#   u'CFID': 5,
#   u'CFPARAMS': u'202329,1610612757',
#   u'DD2': 7,
#   u'DREB': 5.3,
#   u'FG3A': 4.2,
#   u'FG3M': 1.5,
#   u'FG3_PCT': 0.348,
#   u'FGA': 9.3,
#   u'FGM': 3.8,
#   u'FG_PCT': 0.412,
#   u'FTA': 2.0,
#   u'FTM': 1.5,
#   u'FT_PCT': 0.737,
#   u'GP': 48,
#   u'L': 26,
#   u'MIN': 29.0,
#   'MIN_PLAYED': 29.0,
#   u'OREB': 1.2,
#   u'PF': 2.3,
#   u'PFD': 1.8,
#   u'PLAYER_ID': 202329,
#   u'PLAYER_NAME': u'Al-Farouq Aminu',
#   u'PLUS_MINUS': 0.5,
#   u'PTS': 10.5,
#   u'REB': 6.5,
#   'SEC_PLAYED': 0.0,
#   u'STL': 0.9,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'POR',
#   u'TEAM_ID': 1610612757,
#   u'TOV': 1.6,
#   u'W': 22,
#   u'W_PCT': 0.458},
#  {u'AGE': 24.0,
#   u'AST': 2.1,
#   u'BLK': 0.1,
#   u'BLKA': 0.9,
#   u'CFID': 5,
#   u'CFPARAMS': u'202692,1610612762',
#   u'DD2': 0,
#   u'DREB': 3.0,
#   u'FG3A': 2.7,
#   u'FG3M': 1.0,
#   u'FG3_PCT': 0.387,
#   u'FGA': 11.6,
#   u'FGM': 4.8,
#   u'FG_PCT': 0.409,
#   u'FTA': 5.0,
#   u'FTM': 3.8,
#   u'FT_PCT': 0.752,
#   u'GP': 28,
#   u'L': 16,
#   u'MIN': 27.1,
#   'MIN_PLAYED': 27.0,
#   u'OREB': 0.6,
#   u'PF': 2.5,
#   u'PFD': 3.9,
#   u'PLAYER_ID': 202692,
#   u'PLAYER_NAME': u'Alec Burks',
#   u'PLUS_MINUS': -0.9,
#   u'PTS': 14.3,
#   u'REB': 3.6,
#   'SEC_PLAYED': 0.10000000000000142,
#   u'STL': 0.6,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'UTA',
#   u'TEAM_ID': 1610612762,
#   u'TOV': 1.8,
#   u'W': 12,
#   u'W_PCT': 0.429},
#  {u'AGE': 22.0,
#   u'AST': 0.9,
#   u'BLK': 0.9,
#   u'BLKA': 0.4,
#   u'CFID': 5,
#   u'CFPARAMS': u'203458,1610612756',
#   u'DD2': 5,
#   u'DREB': 4.2,
#   u'FG3A': 0.1,
#   u'FG3M': 0.0,
#   u'FG3_PCT': 0.25,
#   u'FGA': 5.8,
#   u'FGM': 2.6,
#   u'FG_PCT': 0.456,
#   u'FTA': 2.2,
#   u'FTM': 1.6,
#   u'FT_PCT': 0.72,
#   u'GP': 45,
#   u'L': 31,
#   u'MIN': 19.6,
#   'MIN_PLAYED': 19.0,
#   u'OREB': 1.8,
#   u'PF': 2.6,
#   u'PFD': 1.4,
#   u'PLAYER_ID': 203458,
#   u'PLAYER_NAME': u'Alex Len',
#   u'PLUS_MINUS': -2.4,
#   u'PTS': 6.9,
#   u'REB': 6.0,
#   'SEC_PLAYED': 0.6000000000000014,
#   u'STL': 0.5,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'PHX',
#   u'TEAM_ID': 1610612756,
#   u'TOV': 1.4,
#   u'W': 14,
#   u'W_PCT': 0.311},
#  {u'AGE': 27.0,
#   u'AST': 0.5,
#   u'BLK': 0.5,
#   u'BLKA': 0.1,
#   u'CFID': 5,
#   u'CFPARAMS': u'201582,1610612740',
#   u'DD2': 2,
#   u'DREB': 2.9,
#   u'FG3A': 0.0,
#   u'FG3M': 0.0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 4.1,
#   u'FGM': 2.1,
#   u'FG_PCT': 0.517,
#   u'FTA': 0.5,
#   u'FTM': 0.5,
#   u'FT_PCT': 0.947,
#   u'GP': 35,
#   u'L': 25,
#   u'MIN': 12.2,
#   'MIN_PLAYED': 12.0,
#   u'OREB': 1.1,
#   u'PF': 2.2,
#   u'PFD': 0.7,
#   u'PLAYER_ID': 201582,
#   u'PLAYER_NAME': u'Alexis Ajinca',
#   u'PLUS_MINUS': -0.5,
#   u'PTS': 4.7,
#   u'REB': 4.0,
#   'SEC_PLAYED': 0.1999999999999993,
#   u'STL': 0.3,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'NOP',
#   u'TEAM_ID': 1610612740,
#   u'TOV': 0.6,
#   u'W': 10,
#   u'W_PCT': 0.286},
#  {u'AGE': 23.0,
#   u'AST': 1.2,
#   u'BLK': 0.1,
#   u'BLKA': 0.1,
#   u'CFID': 5,
#   u'CFPARAMS': u'203459,1610612757',
#   u'DD2': 0,
#   u'DREB': 2.4,
#   u'FG3A': 3.8,
#   u'FG3M': 1.5,
#   u'FG3_PCT': 0.383,
#   u'FGA': 9.3,
#   u'FGM': 4.4,
#   u'FG_PCT': 0.468,
#   u'FTA': 1.3,
#   u'FTM': 1.1,
#   u'FT_PCT': 0.852,
#   u'GP': 48,
#   u'L': 26,
#   u'MIN': 26.2,
#   'MIN_PLAYED': 26.0,
#   u'OREB': 0.3,
#   u'PF': 2.6,
#   u'PFD': 0.9,
#   u'PLAYER_ID': 203459,
#   u'PLAYER_NAME': u'Allen Crabbe',
#   u'PLUS_MINUS': -0.4,
#   u'PTS': 11.3,
#   u'REB': 2.6,
#   'SEC_PLAYED': 0.1999999999999993,
#   u'STL': 0.8,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'POR',
#   u'TEAM_ID': 1610612757,
#   u'TOV': 0.9,
#   u'W': 22,
#   u'W_PCT': 0.458},
#  {u'AGE': 28.0,
#   u'AST': 1.0,
#   u'BLK': 0.2,
#   u'BLKA': 0.3,
#   u'CFID': 5,
#   u'CFPARAMS': u'202087,1610612740',
#   u'DD2': 0,
#   u'DREB': 2.6,
#   u'FG3A': 0.9,
#   u'FG3M': 0.3,
#   u'FG3_PCT': 0.286,
#   u'FGA': 3.4,
#   u'FGM': 1.7,
#   u'FG_PCT': 0.497,
#   u'FTA': 0.7,
#   u'FTM': 0.5,
#   u'FT_PCT': 0.806,
#   u'GP': 46,
#   u'L': 28,
#   u'MIN': 21.7,
#   'MIN_PLAYED': 21.0,
#   u'OREB': 0.8,
#   u'PF': 2.3,
#   u'PFD': 0.7,
#   u'PLAYER_ID': 202087,
#   u'PLAYER_NAME': u'Alonzo Gee',
#   u'PLUS_MINUS': -2.1,
#   u'PTS': 4.2,
#   u'REB': 3.4,
#   'SEC_PLAYED': 0.6999999999999993,
#   u'STL': 0.9,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'NOP',
#   u'TEAM_ID': 1610612740,
#   u'TOV': 0.7,
#   u'W': 18,
#   u'W_PCT': 0.391},
#  {u'AGE': 33.0,
#   u'AST': 0.6,
#   u'BLK': 0.5,
#   u'BLKA': 0.5,
#   u'CFID': 5,
#   u'CFPARAMS': u'2405,1610612748',
#   u'DD2': 0,
#   u'DREB': 2.4,
#   u'FG3A': 0.0,
#   u'FG3M': 0.0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 3.7,
#   u'FGM': 1.9,
#   u'FG_PCT': 0.529,
#   u'FTA': 1.2,
#   u'FTM': 0.9,
#   u'FT_PCT': 0.739,
#   u'GP': 19,
#   u'L': 10,
#   u'MIN': 13.1,
#   'MIN_PLAYED': 13.0,
#   u'OREB': 1.1,
#   u'PF': 1.2,
#   u'PFD': 1.5,
#   u'PLAYER_ID': 2405,
#   u'PLAYER_NAME': u"Amar'e Stoudemire",
#   u'PLUS_MINUS': -1.9,
#   u'PTS': 4.8,
#   u'REB': 3.4,
#   'SEC_PLAYED': 0.09999999999999964,
#   u'STL': 0.3,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'MIA',
#   u'TEAM_ID': 1610612748,
#   u'TOV': 0.8,
#   u'W': 9,
#   u'W_PCT': 0.474},
#  {u'AGE': 28.0,
#   u'AST': 1.8,
#   u'BLK': 1.2,
#   u'BLKA': 0.3,
#   u'CFID': 5,
#   u'CFPARAMS': u'101161,1610612738',
#   u'DD2': 4,
#   u'DREB': 4.2,
#   u'FG3A': 0.8,
#   u'FG3M': 0.2,
#   u'FG3_PCT': 0.265,
#   u'FGA': 5.8,
#   u'FGM': 3.4,
#   u'FG_PCT': 0.582,
#   u'FTA': 1.6,
#   u'FTM': 0.9,
#   u'FT_PCT': 0.556,
#   u'GP': 45,
#   u'L': 21,
#   u'MIN': 23.9,
#   'MIN_PLAYED': 23.0,
#   u'OREB': 2.3,
#   u'PF': 2.8,
#   u'PFD': 1.7,
#   u'PLAYER_ID': 101161,
#   u'PLAYER_NAME': u'Amir Johnson',
#   u'PLUS_MINUS': 2.4,
#   u'PTS': 7.9,
#   u'REB': 6.4,
#   'SEC_PLAYED': 0.8999999999999986,
#   u'STL': 0.7,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'BOS',
#   u'TEAM_ID': 1610612738,
#   u'TOV': 1.2,
#   u'W': 24,
#   u'W_PCT': 0.533},
#  {u'AGE': 33.0,
#   u'AST': 0.6,
#   u'BLK': 0.1,
#   u'BLKA': 0.1,
#   u'CFID': 5,
#   u'CFPARAMS': u'2760,1610612739',
#   u'DD2': 0,
#   u'DREB': 2.0,
#   u'FG3A': 0.0,
#   u'FG3M': 0.0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 2.3,
#   u'FGM': 1.0,
#   u'FG_PCT': 0.426,
#   u'FTA': 0.6,
#   u'FTM': 0.5,
#   u'FT_PCT': 0.765,
#   u'GP': 27,
#   u'L': 8,
#   u'MIN': 9.2,
#   'MIN_PLAYED': 9.0,
#   u'OREB': 0.7,
#   u'PF': 1.0,
#   u'PFD': 1.1,
#   u'PLAYER_ID': 2760,
#   u'PLAYER_NAME': u'Anderson Varejao',
#   u'PLUS_MINUS': 1.8,
#   u'PTS': 2.4,
#   u'REB': 2.7,
#   'SEC_PLAYED': 0.1999999999999993,
#   u'STL': 0.3,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'CLE',
#   u'TEAM_ID': 1610612739,
#   u'TOV': 0.5,
#   u'W': 19,
#   u'W_PCT': 0.704},
#  {u'AGE': 22.0,
#   u'AST': 0.8,
#   u'BLK': 1.5,
#   u'BLKA': 1.0,
#   u'CFID': 5,
#   u'CFPARAMS': u'203083,1610612765',
#   u'DD2': 39,
#   u'DREB': 9.8,
#   u'FG3A': 0.1,
#   u'FG3M': 0.0,
#   u'FG3_PCT': 0.333,
#   u'FGA': 13.9,
#   u'FGM': 7.2,
#   u'FG_PCT': 0.521,
#   u'FTA': 7.9,
#   u'FTM': 2.7,
#   u'FT_PCT': 0.347,
#   u'GP': 48,
#   u'L': 23,
#   u'MIN': 33.6,
#   'MIN_PLAYED': 33.0,
#   u'OREB': 5.2,
#   u'PF': 3.1,
#   u'PFD': 5.4,
#   u'PLAYER_ID': 203083,
#   u'PLAYER_NAME': u'Andre Drummond',
#   u'PLUS_MINUS': 2.4,
#   u'PTS': 17.2,
#   u'REB': 15.0,
#   'SEC_PLAYED': 0.6000000000000014,
#   u'STL': 1.7,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'DET',
#   u'TEAM_ID': 1610612765,
#   u'TOV': 2.1,
#   u'W': 25,
#   u'W_PCT': 0.521},
#  {u'AGE': 32.0,
#   u'AST': 3.5,
#   u'BLK': 0.3,
#   u'BLKA': 0.1,
#   u'CFID': 5,
#   u'CFPARAMS': u'2738,1610612744',
#   u'DD2': 1,
#   u'DREB': 3.4,
#   u'FG3A': 2.5,
#   u'FG3M': 0.9,
#   u'FG3_PCT': 0.381,
#   u'FGA': 5.8,
#   u'FGM': 2.9,
#   u'FG_PCT': 0.493,
#   u'FTA': 1.2,
#   u'FTM': 0.8,
#   u'FT_PCT': 0.667,
#   u'GP': 46,
#   u'L': 4,
#   u'MIN': 27.4,
#   'MIN_PLAYED': 27.0,
#   u'OREB': 0.9,
#   u'PF': 1.6,
#   u'PFD': 1.4,
#   u'PLAYER_ID': 2738,
#   u'PLAYER_NAME': u'Andre Iguodala',
#   u'PLUS_MINUS': 8.2,
#   u'PTS': 7.5,
#   u'REB': 4.3,
#   'SEC_PLAYED': 0.3999999999999986,
#   u'STL': 1.2,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_ID': 1610612744,
#   u'TOV': 1.2,
#   u'W': 42,
#   u'W_PCT': 0.913},
#  {u'AGE': 39.0,
#   u'AST': 2.4,
#   u'BLK': 0.0,
#   u'BLKA': 0.3,
#   u'CFID': 5,
#   u'CFPARAMS': u'1889,1610612750',
#   u'DD2': 0,
#   u'DREB': 0.6,
#   u'FG3A': 0.1,
#   u'FG3M': 0.1,
#   u'FG3_PCT': 0.5,
#   u'FGA': 2.3,
#   u'FGM': 1.4,
#   u'FG_PCT': 0.609,
#   u'FTA': 0.9,
#   u'FTM': 0.7,
#   u'FT_PCT': 0.778,
#   u'GP': 20,
#   u'L': 14,
#   u'MIN': 10.8,
#   'MIN_PLAYED': 10.0,
#   u'OREB': 0.3,
#   u'PF': 1.4,
#   u'PFD': 0.7,
#   u'PLAYER_ID': 1889,
#   u'PLAYER_NAME': u'Andre Miller',
#   u'PLUS_MINUS': 0.5,
#   u'PTS': 3.6,
#   u'REB': 0.9,
#   'SEC_PLAYED': 0.8000000000000007,
#   u'STL': 0.5,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'MIN',
#   u'TEAM_ID': 1610612750,
#   u'TOV': 0.9,
#   u'W': 6,
#   u'W_PCT': 0.3},
#  {u'AGE': 24.0,
#   u'AST': 0.8,
#   u'BLK': 0.7,
#   u'BLKA': 0.3,
#   u'CFID': 5,
#   u'CFPARAMS': u'203460,1610612760',
#   u'DD2': 0,
#   u'DREB': 2.2,
#   u'FG3A': 1.4,
#   u'FG3M': 0.4,
#   u'FG3_PCT': 0.274,
#   u'FGA': 4.1,
#   u'FGM': 2.0,
#   u'FG_PCT': 0.495,
#   u'FTA': 0.8,
#   u'FTM': 0.5,
#   u'FT_PCT': 0.611,
#   u'GP': 45,
#   u'L': 12,
#   u'MIN': 21.7,
#   'MIN_PLAYED': 21.0,
#   u'OREB': 1.1,
#   u'PF': 1.8,
#   u'PFD': 0.7,
#   u'PLAYER_ID': 203460,
#   u'PLAYER_NAME': u'Andre Roberson',
#   u'PLUS_MINUS': 4.6,
#   u'PTS': 4.9,
#   u'REB': 3.3,
#   'SEC_PLAYED': 0.6999999999999993,
#   u'STL': 0.9,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'OKC',
#   u'TEAM_ID': 1610612760,
#   u'TOV': 0.6,
#   u'W': 33,
#   u'W_PCT': 0.733},
#  {u'AGE': 30.0,
#   u'AST': 0.3,
#   u'BLK': 0.2,
#   u'BLKA': 0.3,
#   u'CFID': 5,
#   u'CFPARAMS': u'200745,1610612751',
#   u'DD2': 0,
#   u'DREB': 1.5,
#   u'FG3A': 0.4,
#   u'FG3M': 0.1,
#   u'FG3_PCT': 0.188,
#   u'FGA': 6.1,
#   u'FGM': 2.8,
#   u'FG_PCT': 0.455,
#   u'FTA': 1.3,
#   u'FTM': 1.0,
#   u'FT_PCT': 0.811,
#   u'GP': 42,
#   u'L': 32,
#   u'MIN': 13.8,
#   'MIN_PLAYED': 13.0,
#   u'OREB': 0.6,
#   u'PF': 1.4,
#   u'PFD': 1.2,
#   u'PLAYER_ID': 200745,
#   u'PLAYER_NAME': u'Andrea Bargnani',
#   u'PLUS_MINUS': -4.5,
#   u'PTS': 6.6,
#   u'REB': 2.1,
#   'SEC_PLAYED': 0.8000000000000007,
#   u'STL': 0.1,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'BKN',
#   u'TEAM_ID': 1610612751,
#   u'TOV': 0.6,
#   u'W': 10,
#   u'W_PCT': 0.238},
#  {u'AGE': 31.0,
#   u'AST': 2.0,
#   u'BLK': 1.7,
#   u'BLKA': 0.1,
#   u'CFID': 5,
#   u'CFPARAMS': u'101106,1610612744',
#   u'DD2': 3,
#   u'DREB': 5.6,
#   u'FG3A': 0.0,
#   u'FG3M': 0.0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 4.2,
#   u'FGM': 2.7,
#   u'FG_PCT': 0.627,
#   u'FTA': 0.7,
#   u'FTM': 0.3,
#   u'FT_PCT': 0.414,
#   u'GP': 40,
#   u'L': 4,
#   u'MIN': 20.9,
#   'MIN_PLAYED': 20.0,
#   u'OREB': 1.8,
#   u'PF': 3.1,
#   u'PFD': 1.0,
#   u'PLAYER_ID': 101106,
#   u'PLAYER_NAME': u'Andrew Bogut',
#   u'PLUS_MINUS': 6.4,
#   u'PTS': 5.6,
#   u'REB': 7.4,
#   'SEC_PLAYED': 0.8999999999999986,
#   u'STL': 0.3,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_ID': 1610612744,
#   u'TOV': 1.1,
#   u'W': 36,
#   u'W_PCT': 0.9},
#  {u'AGE': 26.0,
#   u'AST': 0.3,
#   u'BLK': 0.3,
#   u'BLKA': 0.2,
#   u'CFID': 5,
#   u'CFPARAMS': u'203094,1610612753',
#   u'DD2': 0,
#   u'DREB': 3.1,
#   u'FG3A': 2.1,
#   u'FG3M': 0.7,
#   u'FG3_PCT': 0.348,
#   u'FGA': 5.7,
#   u'FGM': 2.5,
#   u'FG_PCT': 0.444,
#   u'FTA': 1.0,
#   u'FTM': 0.8,
#   u'FT_PCT': 0.781,
#   u'GP': 33,
#   u'L': 17,
#   u'MIN': 16.0,
#   'MIN_PLAYED': 16.0,
#   u'OREB': 0.7,
#   u'PF': 1.3,
#   u'PFD': 1.0,
#   u'PLAYER_ID': 203094,
#   u'PLAYER_NAME': u'Andrew Nicholson',
#   u'PLUS_MINUS': 0.4,
#   u'PTS': 6.6,
#   u'REB': 3.8,
#   'SEC_PLAYED': 0.0,
#   u'STL': 0.2,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'ORL',
#   u'TEAM_ID': 1610612753,
#   u'TOV': 0.8,
#   u'W': 16,
#   u'W_PCT': 0.485},
#  {u'AGE': 20.0,
#   u'AST': 1.8,
#   u'BLK': 0.5,
#   u'BLKA': 1.2,
#   u'CFID': 5,
#   u'CFPARAMS': u'203952,1610612750',
#   u'DD2': 1,
#   u'DREB': 2.2,
#   u'FG3A': 2.4,
#   u'FG3M': 0.6,
#   u'FG3_PCT': 0.243,
#   u'FGA': 16.4,
#   u'FGM': 7.3,
#   u'FG_PCT': 0.446,
#   u'FTA': 7.2,
#   u'FTM': 5.3,
#   u'FT_PCT': 0.739,
#   u'GP': 47,
#   u'L': 33,
#   u'MIN': 35.1,
#   'MIN_PLAYED': 35.0,
#   u'OREB': 1.5,
#   u'PF': 2.1,
#   u'PFD': 5.2,
#   u'PLAYER_ID': 203952,
#   u'PLAYER_NAME': u'Andrew Wiggins',
#   u'PLUS_MINUS': -2.4,
#   u'PTS': 20.5,
#   u'REB': 3.7,
#   'SEC_PLAYED': 0.10000000000000142,
#   u'STL': 0.9,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'MIN',
#   u'TEAM_ID': 1610612750,
#   u'TOV': 2.2,
#   u'W': 14,
#   u'W_PCT': 0.298},
#  {u'AGE': 22.0,
#   u'AST': 0.0,
#   u'BLK': 0.0,
#   u'BLKA': 0.1,
#   u'CFID': 5,
#   u'CFPARAMS': u'203461,1610612761',
#   u'DD2': 0,
#   u'DREB': 1.0,
#   u'FG3A': 0.9,
#   u'FG3M': 0.2,
#   u'FG3_PCT': 0.167,
#   u'FGA': 1.5,
#   u'FGM': 0.4,
#   u'FG_PCT': 0.25,
#   u'FTA': 0.6,
#   u'FTM': 0.5,
#   u'FT_PCT': 0.875,
#   u'GP': 13,
#   u'L': 4,
#   u'MIN': 4.9,
#   'MIN_PLAYED': 4.0,
#   u'OREB': 0.4,
#   u'PF': 0.6,
#   u'PFD': 0.3,
#   u'PLAYER_ID': 203461,
#   u'PLAYER_NAME': u'Anthony Bennett',
#   u'PLUS_MINUS': -2.2,
#   u'PTS': 1.5,
#   u'REB': 1.4,
#   'SEC_PLAYED': 0.9000000000000004,
#   u'STL': 0.2,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'TOR',
#   u'TEAM_ID': 1610612761,
#   u'TOV': 0.3,
#   u'W': 9,
#   u'W_PCT': 0.692},
#  {u'AGE': 23.0,
#   u'AST': 0.5,
#   u'BLK': 0.2,
#   u'BLKA': 0.4,
#   u'CFID': 5,
#   u'CFPARAMS': u'1626148,1610612747',
#   u'DD2': 0,
#   u'DREB': 2.0,
#   u'FG3A': 2.3,
#   u'FG3M': 0.7,
#   u'FG3_PCT': 0.291,
#   u'FGA': 4.1,
#   u'FGM': 1.3,
#   u'FG_PCT': 0.313,
#   u'FTA': 0.7,
#   u'FTM': 0.6,
#   u'FT_PCT': 0.824,
#   u'GP': 24,
#   u'L': 21,
#   u'MIN': 19.6,
#   'MIN_PLAYED': 19.0,
#   u'OREB': 0.3,
#   u'PF': 1.1,
#   u'PFD': 0.6,
#   u'PLAYER_ID': 1626148,
#   u'PLAYER_NAME': u'Anthony Brown',
#   u'PLUS_MINUS': 0.0,
#   u'PTS': 3.8,
#   u'REB': 2.3,
#   'SEC_PLAYED': 0.6000000000000014,
#   u'STL': 0.4,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'LAL',
#   u'TEAM_ID': 1610612747,
#   u'TOV': 0.6,
#   u'W': 3,
#   u'W_PCT': 0.125},
#  {u'AGE': 22.0,
#   u'AST': 1.8,
#   u'BLK': 2.4,
#   u'BLKA': 0.7,
#   u'CFID': 5,
#   u'CFPARAMS': u'203076,1610612740',
#   u'DD2': 24,
#   u'DREB': 8.2,
#   u'FG3A': 1.7,
#   u'FG3M': 0.5,
#   u'FG3_PCT': 0.294,
#   u'FGA': 17.7,
#   u'FGM': 8.7,
#   u'FG_PCT': 0.489,
#   u'FTA': 6.6,
#   u'FTM': 5.0,
#   u'FT_PCT': 0.764,
#   u'GP': 40,
#   u'L': 23,
#   u'MIN': 35.4,
#   'MIN_PLAYED': 35.0,
#   u'OREB': 2.1,
#   u'PF': 2.4,
#   u'PFD': 5.5,
#   u'PLAYER_ID': 203076,
#   u'PLAYER_NAME': u'Anthony Davis',
#   u'PLUS_MINUS': -0.8,
#   u'PTS': 22.9,
#   u'REB': 10.3,
#   'SEC_PLAYED': 0.3999999999999986,
#   u'STL': 1.3,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'NOP',
#   u'TEAM_ID': 1610612740,
#   u'TOV': 2.1,
#   u'W': 17,
#   u'W_PCT': 0.425},
#  {u'AGE': 30.0,
#   u'AST': 0.3,
#   u'BLK': 0.1,
#   u'BLKA': 0.1,
#   u'CFID': 5,
#   u'CFPARAMS': u'201627,1610612760',
#   u'DD2': 0,
#   u'DREB': 1.0,
#   u'FG3A': 3.0,
#   u'FG3M': 1.3,
#   u'FG3_PCT': 0.415,
#   u'FGA': 4.9,
#   u'FGM': 2.1,
#   u'FG_PCT': 0.424,
#   u'FTA': 0.5,
#   u'FTM': 0.4,
#   u'FT_PCT': 0.81,
#   u'GP': 43,
#   u'L': 12,
#   u'MIN': 14.9,
#   'MIN_PLAYED': 14.0,
#   u'OREB': 0.2,
#   u'PF': 1.0,
#   u'PFD': 0.4,
#   u'PLAYER_ID': 201627,
#   u'PLAYER_NAME': u'Anthony Morrow',
#   u'PLUS_MINUS': 1.8,
#   u'PTS': 5.8,
#   u'REB': 1.2,
#   'SEC_PLAYED': 0.9000000000000004,
#   u'STL': 0.4,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'OKC',
#   u'TEAM_ID': 1610612760,
#   u'TOV': 0.2,
#   u'W': 31,
#   u'W_PCT': 0.721},
#  {u'AGE': 30.0,
#   u'AST': 0.9,
#   u'BLK': 0.3,
#   u'BLKA': 0.2,
#   u'CFID': 5,
#   u'CFPARAMS': u'201229,1610612765',
#   u'DD2': 0,
#   u'DREB': 2.8,
#   u'FG3A': 3.7,
#   u'FG3M': 1.4,
#   u'FG3_PCT': 0.366,
#   u'FGA': 4.6,
#   u'FGM': 1.8,
#   u'FG_PCT': 0.381,
#   u'FTA': 0.7,
#   u'FTM': 0.5,
#   u'FT_PCT': 0.657,
#   u'GP': 47,
#   u'L': 23,
#   u'MIN': 19.7,
#   'MIN_PLAYED': 19.0,
#   u'OREB': 0.6,
#   u'PF': 1.2,
#   u'PFD': 0.7,
#   u'PLAYER_ID': 201229,
#   u'PLAYER_NAME': u'Anthony Tolliver',
#   u'PLUS_MINUS': 1.4,
#   u'PTS': 5.4,
#   u'REB': 3.3,
#   'SEC_PLAYED': 0.6999999999999993,
#   u'STL': 0.4,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'DET',
#   u'TEAM_ID': 1610612765,
#   u'TOV': 0.3,
#   u'W': 24,
#   u'W_PCT': 0.511},
#  {u'AGE': 21.0,
#   u'AST': 1.6,
#   u'BLK': 0.3,
#   u'BLKA': 0.9,
#   u'CFID': 5,
#   u'CFPARAMS': u'203462,1610612756',
#   u'DD2': 0,
#   u'DREB': 1.9,
#   u'FG3A': 1.3,
#   u'FG3M': 0.3,
#   u'FG3_PCT': 0.257,
#   u'FGA': 6.0,
#   u'FGM': 2.5,
#   u'FG_PCT': 0.423,
#   u'FTA': 3.5,
#   u'FTM': 2.3,
#   u'FT_PCT': 0.653,
#   u'GP': 28,
#   u'L': 21,
#   u'MIN': 16.2,
#   'MIN_PLAYED': 16.0,
#   u'OREB': 0.4,
#   u'PF': 1.0,
#   u'PFD': 2.7,
#   u'PLAYER_ID': 203462,
#   u'PLAYER_NAME': u'Archie Goodwin',
#   u'PLUS_MINUS': -1.9,
#   u'PTS': 7.7,
#   u'REB': 2.3,
#   'SEC_PLAYED': 0.1999999999999993,
#   u'STL': 0.5,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'PHX',
#   u'TEAM_ID': 1610612756,
#   u'TOV': 1.4,
#   u'W': 7,
#   u'W_PCT': 0.25},
#  {u'AGE': 29.0,
#   u'AST': 0.8,
#   u'BLK': 0.5,
#   u'BLKA': 0.3,
#   u'CFID': 5,
#   u'CFPARAMS': u'203382,1610612765',
#   u'DD2': 1,
#   u'DREB': 2.9,
#   u'FG3A': 0.0,
#   u'FG3M': 0.0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 4.4,
#   u'FGM': 2.2,
#   u'FG_PCT': 0.502,
#   u'FTA': 1.6,
#   u'FTM': 1.2,
#   u'FT_PCT': 0.753,
#   u'GP': 47,
#   u'L': 23,
#   u'MIN': 14.3,
#   'MIN_PLAYED': 14.0,
#   u'OREB': 1.6,
#   u'PF': 1.9,
#   u'PFD': 1.6,
#   u'PLAYER_ID': 203382,
#   u'PLAYER_NAME': u'Aron Baynes',
#   u'PLUS_MINUS': -1.0,
#   u'PTS': 5.7,
#   u'REB': 4.5,
#   'SEC_PLAYED': 0.3000000000000007,
#   u'STL': 0.3,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'DET',
#   u'TEAM_ID': 1610612765,
#   u'TOV': 0.9,
#   u'W': 24,
#   u'W_PCT': 0.511},
#  {u'AGE': 30.0,
#   u'AST': 1.9,
#   u'BLK': 0.2,
#   u'BLKA': 0.8,
#   u'CFID': 5,
#   u'CFPARAMS': u'201167,1610612752',
#   u'DD2': 0,
#   u'DREB': 3.3,
#   u'FG3A': 3.6,
#   u'FG3M': 1.3,
#   u'FG3_PCT': 0.377,
#   u'FGA': 12.3,
#   u'FGM': 5.6,
#   u'FG_PCT': 0.453,
#   u'FTA': 1.9,
#   u'FTM': 1.7,
#   u'FT_PCT': 0.886,
#   u'GP': 41,
#   u'L': 22,
#   u'MIN': 33.2,
#   'MIN_PLAYED': 33.0,
#   u'OREB': 0.3,
#   u'PF': 2.3,
#   u'PFD': 1.7,
#   u'PLAYER_ID': 201167,
#   u'PLAYER_NAME': u'Arron Afflalo',
#   u'PLUS_MINUS': 0.1,
#   u'PTS': 14.2,
#   u'REB': 3.6,
#   'SEC_PLAYED': 0.20000000000000284,
#   u'STL': 0.3,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'NYK',
#   u'TEAM_ID': 1610612752,
#   u'TOV': 1.0,
#   u'W': 19,
#   u'W_PCT': 0.463},
#  {u'AGE': 23.0,
#   u'AST': 1.3,
#   u'BLK': 0.2,
#   u'BLKA': 0.4,
#   u'CFID': 5,
#   u'CFPARAMS': u'203085,1610612746',
#   u'DD2': 0,
#   u'DREB': 1.5,
#   u'FG3A': 2.5,
#   u'FG3M': 0.6,
#   u'FG3_PCT': 0.257,
#   u'FGA': 7.4,
#   u'FGM': 3.2,
#   u'FG_PCT': 0.431,
#   u'FTA': 1.4,
#   u'FTM': 0.9,
#   u'FT_PCT': 0.683,
#   u'GP': 44,
#   u'L': 15,
#   u'MIN': 22.0,
#   'MIN_PLAYED': 22.0,
#   u'OREB': 0.3,
#   u'PF': 2.2,
#   u'PFD': 1.3,
#   u'PLAYER_ID': 203085,
#   u'PLAYER_NAME': u'Austin Rivers',
#   u'PLUS_MINUS': -2.8,
#   u'PTS': 8.0,
#   u'REB': 1.9,
#   'SEC_PLAYED': 0.0,
#   u'STL': 0.7,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'LAC',
#   u'TEAM_ID': 1610612746,
#   u'TOV': 0.9,
#   u'W': 29,
#   u'W_PCT': 0.659},
#  {u'AGE': 25.0,
#   u'AST': 2.1,
#   u'BLK': 0.3,
#   u'BLKA': 0.6,
#   u'CFID': 5,
#   u'CFPARAMS': u'202340,1610612738',
#   u'DD2': 0,
#   u'DREB': 2.0,
#   u'FG3A': 5.6,
#   u'FG3M': 2.0,
#   u'FG3_PCT': 0.36,
#   u'FGA': 13.3,
#   u'FGM': 5.8,
#   u'FG_PCT': 0.44,
#   u'FTA': 1.5,
#   u'FTM': 1.2,
#   u'FT_PCT': 0.769,
#   u'GP': 43,
#   u'L': 18,
#   u'MIN': 32.6,
#   'MIN_PLAYED': 32.0,
#   u'OREB': 0.6,
#   u'PF': 2.1,
#   u'PFD': 1.3,
#   u'PLAYER_ID': 202340,
#   u'PLAYER_NAME': u'Avery Bradley',
#   u'PLUS_MINUS': 3.9,
#   u'PTS': 14.8,
#   u'REB': 2.6,
#   'SEC_PLAYED': 0.6000000000000014,
#   u'STL': 1.6,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'BOS',
#   u'TEAM_ID': 1610612738,
#   u'TOV': 1.5,
#   u'W': 25,
#   u'W_PCT': 0.581},
#  {u'AGE': 22.0,
#   u'AST': 1.2,
#   u'BLK': 0.2,
#   u'BLKA': 0.2,
#   u'CFID': 5,
#   u'CFPARAMS': u'203463,1610612758',
#   u'DD2': 0,
#   u'DREB': 1.6,
#   u'FG3A': 2.5,
#   u'FG3M': 0.9,
#   u'FG3_PCT': 0.372,
#   u'FGA': 6.2,
#   u'FGM': 2.9,
#   u'FG_PCT': 0.46,
#   u'FTA': 1.6,
#   u'FTM': 1.1,
#   u'FT_PCT': 0.712,
#   u'GP': 46,
#   u'L': 26,
#   u'MIN': 21.2,
#   'MIN_PLAYED': 21.0,
#   u'OREB': 0.5,
#   u'PF': 2.0,
#   u'PFD': 1.3,
#   u'PLAYER_ID': 203463,
#   u'PLAYER_NAME': u'Ben McLemore',
#   u'PLUS_MINUS': 0.6,
#   u'PTS': 7.8,
#   u'REB': 2.1,
#   'SEC_PLAYED': 0.1999999999999993,
#   u'STL': 0.8,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'SAC',
#   u'TEAM_ID': 1610612758,
#   u'TOV': 1.5,
#   u'W': 20,
#   u'W_PCT': 0.435},
#  {u'AGE': 33.0,
#   u'AST': 2.7,
#   u'BLK': 0.0,
#   u'BLKA': 0.2,
#   u'CFID': 5,
#   u'CFPARAMS': u'2757,1610612748',
#   u'DD2': 1,
#   u'DREB': 1.5,
#   u'FG3A': 1.0,
#   u'FG3M': 0.4,
#   u'FG3_PCT': 0.4,
#   u'FGA': 4.2,
#   u'FGM': 1.8,
#   u'FG_PCT': 0.432,
#   u'FTA': 0.4,
#   u'FTM': 0.3,
#   u'FT_PCT': 0.923,
#   u'GP': 35,
#   u'L': 15,
#   u'MIN': 15.9,
#   'MIN_PLAYED': 15.0,
#   u'OREB': 0.1,
#   u'PF': 1.1,
#   u'PFD': 0.9,
#   u'PLAYER_ID': 2757,
#   u'PLAYER_NAME': u'Beno Udrih',
#   u'PLUS_MINUS': -0.1,
#   u'PTS': 4.4,
#   u'REB': 1.6,
#   'SEC_PLAYED': 0.9000000000000004,
#   u'STL': 0.4,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'MIA',
#   u'TEAM_ID': 1610612748,
#   u'TOV': 1.1,
#   u'W': 20,
#   u'W_PCT': 0.571},
#  {u'AGE': 23.0,
#   u'AST': 0.3,
#   u'BLK': 1.5,
#   u'BLKA': 0.6,
#   u'CFID': 5,
#   u'CFPARAMS': u'202687,1610612761',
#   u'DD2': 6,
#   u'DREB': 6.0,
#   u'FG3A': 0.0,
#   u'FG3M': 0.0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 3.7,
#   u'FGM': 1.9,
#   u'FG_PCT': 0.512,
#   u'FTA': 2.8,
#   u'FTM': 1.9,
#   u'FT_PCT': 0.672,
#   u'GP': 47,
#   u'L': 15,
#   u'MIN': 22.6,
#   'MIN_PLAYED': 22.0,
#   u'OREB': 2.3,
#   u'PF': 2.7,
#   u'PFD': 2.4,
#   u'PLAYER_ID': 202687,
#   u'PLAYER_NAME': u'Bismack Biyombo',
#   u'PLUS_MINUS': 0.7,
#   u'PTS': 5.6,
#   u'REB': 8.3,
#   'SEC_PLAYED': 0.6000000000000014,
#   u'STL': 0.2,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'TOR',
#   u'TEAM_ID': 1610612761,
#   u'TOV': 1.0,
#   u'W': 32,
#   u'W_PCT': 0.681},
#  {u'AGE': 26.0,
#   u'AST': 5.0,
#   u'BLK': 0.6,
#   u'BLKA': 0.4,
#   u'CFID': 5,
#   u'CFPARAMS': u'201933,1610612746',
#   u'DD2': 12,
#   u'DREB': 7.0,
#   u'FG3A': 0.6,
#   u'FG3M': 0.2,
#   u'FG3_PCT': 0.353,
#   u'FGA': 18.4,
#   u'FGM': 9.4,
#   u'FG_PCT': 0.508,
#   u'FTA': 5.9,
#   u'FTM': 4.3,
#   u'FT_PCT': 0.725,
#   u'GP': 30,
#   u'L': 13,
#   u'MIN': 34.9,
#   'MIN_PLAYED': 34.0,
#   u'OREB': 1.6,
#   u'PF': 2.8,
#   u'PFD': 5.6,
#   u'PLAYER_ID': 201933,
#   u'PLAYER_NAME': u'Blake Griffin',
#   u'PLUS_MINUS': 3.6,
#   u'PTS': 23.2,
#   u'REB': 8.7,
#   'SEC_PLAYED': 0.8999999999999986,
#   u'STL': 0.7,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'LAC',
#   u'TEAM_ID': 1610612746,
#   u'TOV': 2.4,
#   u'W': 17,
#   u'W_PCT': 0.567},
#  {u'AGE': 27.0,
#   u'AST': 0.3,
#   u'BLK': 0.5,
#   u'BLKA': 0.3,
#   u'CFID': 5,
#   u'CFPARAMS': u'1626246,1610612759',
#   u'DD2': 2,
#   u'DREB': 2.3,
#   u'FG3A': 0.0,
#   u'FG3M': 0.0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 3.6,
#   u'FGM': 2.2,
#   u'FG_PCT': 0.61,
#   u'FTA': 2.3,
#   u'FTM': 1.6,
#   u'FT_PCT': 0.73,
#   u'GP': 28,
#   u'L': 2,
#   u'MIN': 8.6,
#   'MIN_PLAYED': 8.0,
#   u'OREB': 1.4,
#   u'PF': 1.2,
#   u'PFD': 1.5,
#   u'PLAYER_ID': 1626246,
#   u'PLAYER_NAME': u'Boban Marjanovic',
#   u'PLUS_MINUS': 2.1,
#   u'PTS': 6.0,
#   u'REB': 3.6,
#   'SEC_PLAYED': 0.5999999999999996,
#   u'STL': 0.3,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'SAS',
#   u'TEAM_ID': 1610612759,
#   u'TOV': 0.6,
#   u'W': 26,
#   u'W_PCT': 0.929},
#  {u'AGE': 20.0,
#   u'AST': 0.5,
#   u'BLK': 0.4,
#   u'BLKA': 0.3,
#   u'CFID': 5,
#   u'CFPARAMS': u'1626171,1610612741',
#   u'DD2': 2,
#   u'DREB': 2.8,
#   u'FG3A': 0.8,
#   u'FG3M': 0.2,
#   u'FG3_PCT': 0.316,
#   u'FGA': 6.0,
#   u'FGM': 2.7,
#   u'FG_PCT': 0.444,
#   u'FTA': 1.0,
#   u'FTM': 0.8,
#   u'FT_PCT': 0.76,
#   u'GP': 25,
#   u'L': 12,
#   u'MIN': 14.4,
#   'MIN_PLAYED': 14.0,
#   u'OREB': 1.5,
#   u'PF': 1.5,
#   u'PFD': 0.8,
#   u'PLAYER_ID': 1626171,
#   u'PLAYER_NAME': u'Bobby Portis',
#   u'PLUS_MINUS': -1.0,
#   u'PTS': 6.4,
#   u'REB': 4.3,
#   'SEC_PLAYED': 0.40000000000000036,
#   u'STL': 0.5,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'CHI',
#   u'TEAM_ID': 1610612741,
#   u'TOV': 1.1,
#   u'W': 13,
#   u'W_PCT': 0.52},
#  {u'AGE': 26.0,
#   u'AST': 1.0,
#   u'BLK': 0.1,
#   u'BLKA': 0.8,
#   u'CFID': 5,
#   u'CFPARAMS': u'202711,1610612751',
#   u'DD2': 1,
#   u'DREB': 2.8,
#   u'FG3A': 3.8,
#   u'FG3M': 1.3,
#   u'FG3_PCT': 0.339,
#   u'FGA': 8.2,
#   u'FGM': 3.4,
#   u'FG_PCT': 0.419,
#   u'FTA': 1.2,
#   u'FTM': 1.0,
#   u'FT_PCT': 0.814,
#   u'GP': 48,
#   u'L': 36,
#   u'MIN': 26.7,
#   'MIN_PLAYED': 26.0,
#   u'OREB': 0.5,
#   u'PF': 1.4,
#   u'PFD': 1.3,
#   u'PLAYER_ID': 202711,
#   u'PLAYER_NAME': u'Bojan Bogdanovic',
#   u'PLUS_MINUS': -5.6,
#   u'PTS': 9.1,
#   u'REB': 3.3,
#   'SEC_PLAYED': 0.6999999999999993,
#   u'STL': 0.5,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'BKN',
#   u'TEAM_ID': 1610612751,
#   u'TOV': 1.2,
#   u'W': 12,
#   u'W_PCT': 0.25},
#  {u'AGE': 33.0,
#   u'AST': 2.5,
#   u'BLK': 0.3,
#   u'BLKA': 0.2,
#   u'CFID': 5,
#   u'CFPARAMS': u'2564,1610612759',
#   u'DD2': 0,
#   u'DREB': 2.4,
#   u'FG3A': 1.0,
#   u'FG3M': 0.4,
#   u'FG3_PCT': 0.375,
#   u'FGA': 5.4,
#   u'FGM': 2.8,
#   u'FG_PCT': 0.528,
#   u'FTA': 1.2,
#   u'FTM': 0.9,
#   u'FT_PCT': 0.755,
#   u'GP': 46,
#   u'L': 7,
#   u'MIN': 19.1,
#   'MIN_PLAYED': 19.0,
#   u'OREB': 0.8,
#   u'PF': 1.5,
#   u'PFD': 1.3,
#   u'PLAYER_ID': 2564,
#   u'PLAYER_NAME': u'Boris Diaw',
#   u'PLUS_MINUS': 6.2,
#   u'PTS': 7.0,
#   u'REB': 3.2,
#   'SEC_PLAYED': 0.10000000000000142,
#   u'STL': 0.4,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'SAS',
#   u'TEAM_ID': 1610612759,
#   u'TOV': 1.3,
#   u'W': 39,
#   u'W_PCT': 0.848},
#  {u'AGE': 22.0,
#   u'AST': 3.0,
#   u'BLK': 0.3,
#   u'BLKA': 0.4,
#   u'CFID': 5,
#   u'CFPARAMS': u'203078,1610612764',
#   u'DD2': 0,
#   u'DREB': 3.2,
#   u'FG3A': 5.1,
#   u'FG3M': 2.0,
#   u'FG3_PCT': 0.402,
#   u'FGA': 15.3,
#   u'FGM': 6.9,
#   u'FG_PCT': 0.449,
#   u'FTA': 3.5,
#   u'FTM': 2.7,
#   u'FT_PCT': 0.763,
#   u'GP': 23,
#   u'L': 13,
#   u'MIN': 32.6,
#   'MIN_PLAYED': 32.0,
#   u'OREB': 0.9,
#   u'PF': 2.4,
#   u'PFD': 2.4,
#   u'PLAYER_ID': 203078,
#   u'PLAYER_NAME': u'Bradley Beal',
#   u'PLUS_MINUS': -2.9,
#   u'PTS': 18.4,
#   u'REB': 4.1,
#   'SEC_PLAYED': 0.6000000000000014,
#   u'STL': 1.0,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'WAS',
#   u'TEAM_ID': 1610612764,
#   u'TOV': 2.7,
#   u'W': 10,
#   u'W_PCT': 0.435},
#  {u'AGE': 28.0,
#   u'AST': 0.6,
#   u'BLK': 1.4,
#   u'BLKA': 0.0,
#   u'CFID': 5,
#   u'CFPARAMS': u'201148,1610612763',
#   u'DD2': 0,
#   u'DREB': 2.6,
#   u'FG3A': 0.0,
#   u'FG3M': 0.0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 4.3,
#   u'FGM': 2.6,
#   u'FG_PCT': 0.6,
#   u'FTA': 2.6,
#   u'FTM': 1.4,
#   u'FT_PCT': 0.556,
#   u'GP': 7,
#   u'L': 4,
#   u'MIN': 17.1,
#   'MIN_PLAYED': 17.0,
#   u'OREB': 0.9,
#   u'PF': 1.3,
#   u'PFD': 2.3,
#   u'PLAYER_ID': 201148,
#   u'PLAYER_NAME': u'Brandan Wright',
#   u'PLUS_MINUS': -7.4,
#   u'PTS': 6.6,
#   u'REB': 3.4,
#   'SEC_PLAYED': 0.10000000000000142,
#   u'STL': 0.1,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'MEM',
#   u'TEAM_ID': 1610612763,
#   u'TOV': 0.6,
#   u'W': 3,
#   u'W_PCT': 0.429},
#  {u'AGE': 22.0,
#   u'AST': 0.0,
#   u'BLK': 0.5,
#   u'BLKA': 1.0,
#   u'CFID': 5,
#   u'CFPARAMS': u'1626183,1610612746',
#   u'DD2': 0,
#   u'DREB': 0.5,
#   u'FG3A': 0.0,
#   u'FG3M': 0.0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 1.5,
#   u'FGM': 0.5,
#   u'FG_PCT': 0.333,
#   u'FTA': 0.0,
#   u'FTM': 0.0,
#   u'FT_PCT': 0.0,
#   u'GP': 2,
#   u'L': 0,
#   u'MIN': 6.3,
#   'MIN_PLAYED': 6.0,
#   u'OREB': 1.0,
#   u'PF': 1.0,
#   u'PFD': 0.0,
#   u'PLAYER_ID': 1626183,
#   u'PLAYER_NAME': u'Branden Dawson',
#   u'PLUS_MINUS': -7.0,
#   u'PTS': 1.0,
#   u'REB': 1.5,
#   'SEC_PLAYED': 0.2999999999999998,
#   u'STL': 0.0,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'LAC',
#   u'TEAM_ID': 1610612746,
#   u'TOV': 0.0,
#   u'W': 2,
#   u'W_PCT': 1.0},
#  {u'AGE': 30.0,
#   u'AST': 1.1,
#   u'BLK': 0.9,
#   u'BLKA': 0.4,
#   u'CFID': 5,
#   u'CFPARAMS': u'101138,1610612747',
#   u'DD2': 0,
#   u'DREB': 2.7,
#   u'FG3A': 0.0,
#   u'FG3M': 0.0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 4.4,
#   u'FGM': 2.5,
#   u'FG_PCT': 0.555,
#   u'FTA': 1.7,
#   u'FTM': 1.4,
#   u'FT_PCT': 0.853,
#   u'GP': 41,
#   u'L': 32,
#   u'MIN': 18.0,
#   'MIN_PLAYED': 18.0,
#   u'OREB': 1.5,
#   u'PF': 1.7,
#   u'PFD': 1.3,
#   u'PLAYER_ID': 101138,
#   u'PLAYER_NAME': u'Brandon Bass',
#   u'PLUS_MINUS': -2.0,
#   u'PTS': 6.3,
#   u'REB': 4.2,
#   'SEC_PLAYED': 0.0,
#   u'STL': 0.5,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'LAL',
#   u'TEAM_ID': 1610612747,
#   u'TOV': 0.6,
#   u'W': 9,
#   u'W_PCT': 0.22},
#  {u'AGE': 26.0,
#   u'AST': 3.2,
#   u'BLK': 0.1,
#   u'BLKA': 0.3,
#   u'CFID': 5,
#   u'CFPARAMS': u'201943,1610612765',
#   u'DD2': 0,
#   u'DREB': 1.9,
#   u'FG3A': 3.3,
#   u'FG3M': 1.1,
#   u'FG3_PCT': 0.321,
#   u'FGA': 6.2,
#   u'FGM': 2.2,
#   u'FG_PCT': 0.362,
#   u'FTA': 2.0,
#   u'FTM': 1.4,
#   u'FT_PCT': 0.706,
#   u'GP': 17,
#   u'L': 9,
#   u'MIN': 17.6,
#   'MIN_PLAYED': 17.0,
#   u'OREB': 0.3,
#   u'PF': 1.1,
#   u'PFD': 1.5,
#   u'PLAYER_ID': 201943,
#   u'PLAYER_NAME': u'Brandon Jennings',
#   u'PLUS_MINUS': 3.3,
#   u'PTS': 6.9,
#   u'REB': 2.2,
#   'SEC_PLAYED': 0.6000000000000014,
#   u'STL': 0.5,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'DET',
#   u'TEAM_ID': 1610612765,
#   u'TOV': 0.9,
#   u'W': 8,
#   u'W_PCT': 0.471},
#  {u'AGE': 24.0,
#   u'AST': 5.1,
#   u'BLK': 0.3,
#   u'BLKA': 0.6,
#   u'CFID': 5,
#   u'CFPARAMS': u'202688,1610612756',
#   u'DD2': 4,
#   u'DREB': 3.1,
#   u'FG3A': 6.2,
#   u'FG3M': 2.1,
#   u'FG3_PCT': 0.333,
#   u'FGA': 17.3,
#   u'FGM': 7.4,
#   u'FG_PCT': 0.424,
#   u'FTA': 3.4,
#   u'FTM': 2.9,
#   u'FT_PCT': 0.847,
#   u'GP': 42,
#   u'L': 29,
#   u'MIN': 36.3,
#   'MIN_PLAYED': 36.0,
#   u'OREB': 0.6,
#   u'PF': 2.4,
#   u'PFD': 3.9,
#   u'PLAYER_ID': 202688,
#   u'PLAYER_NAME': u'Brandon Knight',
#   u'PLUS_MINUS': -3.6,
#   u'PTS': 19.7,
#   u'REB': 3.7,
#   'SEC_PLAYED': 0.29999999999999716,
#   u'STL': 1.3,
#   u'TD3': 1,
#   u'TEAM_ABBREVIATION': u'PHX',
#   u'TEAM_ID': 1610612756,
#   u'TOV': 3.5,
#   u'W': 13,
#   u'W_PCT': 0.31},
#  {u'AGE': 30.0,
#   u'AST': 0.9,
#   u'BLK': 0.3,
#   u'BLKA': 0.2,
#   u'CFID': 5,
#   u'CFPARAMS': u'201575,1610612744',
#   u'DD2': 0,
#   u'DREB': 2.4,
#   u'FG3A': 2.6,
#   u'FG3M': 1.2,
#   u'FG3_PCT': 0.454,
#   u'FGA': 4.3,
#   u'FGM': 1.9,
#   u'FG_PCT': 0.457,
#   u'FTA': 0.3,
#   u'FTM': 0.2,
#   u'FT_PCT': 0.583,
#   u'GP': 38,
#   u'L': 4,
#   u'MIN': 16.2,
#   'MIN_PLAYED': 16.0,
#   u'OREB': 0.4,
#   u'PF': 0.8,
#   u'PFD': 0.2,
#   u'PLAYER_ID': 201575,
#   u'PLAYER_NAME': u'Brandon Rush',
#   u'PLUS_MINUS': 0.6,
#   u'PTS': 5.2,
#   u'REB': 2.7,
#   'SEC_PLAYED': 0.1999999999999993,
#   u'STL': 0.3,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_ID': 1610612744,
#   u'TOV': 0.5,
#   u'W': 34,
#   u'W_PCT': 0.895},
#  {u'AGE': 30.0,
#   u'AST': 1.2,
#   u'BLK': 0.0,
#   u'BLKA': 0.1,
#   u'CFID': 5,
#   u'CFPARAMS': u'203148,1610612766',
#   u'DD2': 0,
#   u'DREB': 0.8,
#   u'FG3A': 0.9,
#   u'FG3M': 0.3,
#   u'FG3_PCT': 0.375,
#   u'FGA': 3.6,
#   u'FGM': 1.6,
#   u'FG_PCT': 0.449,
#   u'FTA': 1.1,
#   u'FTM': 1.0,
#   u'FT_PCT': 0.933,
#   u'GP': 27,
#   u'L': 15,
#   u'MIN': 10.8,
#   'MIN_PLAYED': 10.0,
#   u'OREB': 0.1,
#   u'PF': 0.7,
#   u'PFD': 1.2,
#   u'PLAYER_ID': 203148,
#   u'PLAYER_NAME': u'Brian Roberts',
#   u'PLUS_MINUS': -1.1,
#   u'PTS': 4.6,
#   u'REB': 0.9,
#   'SEC_PLAYED': 0.8000000000000007,
#   u'STL': 0.3,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'CHA',
#   u'TEAM_ID': 1610612766,
#   u'TOV': 0.6,
#   u'W': 12,
#   u'W_PCT': 0.444},
#  {u'AGE': 27.0,
#   u'AST': 1.6,
#   u'BLK': 1.9,
#   u'BLKA': 0.8,
#   u'CFID': 5,
#   u'CFPARAMS': u'201572,1610612751',
#   u'DD2': 21,
#   u'DREB': 5.6,
#   u'FG3A': 0.1,
#   u'FG3M': 0.0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 16.0,
#   u'FGM': 7.9,
#   u'FG_PCT': 0.496,
#   u'FTA': 5.4,
#   u'FTM': 4.2,
#   u'FT_PCT': 0.776,
#   u'GP': 48,
#   u'L': 36,
#   u'MIN': 33.5,
#   'MIN_PLAYED': 33.0,
#   u'OREB': 2.9,
#   u'PF': 3.0,
#   u'PFD': 4.5,
#   u'PLAYER_ID': 201572,
#   u'PLAYER_NAME': u'Brook Lopez',
#   u'PLUS_MINUS': -2.7,
#   u'PTS': 20.1,
#   u'REB': 8.5,
#   'SEC_PLAYED': 0.5,
#   u'STL': 0.8,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'BKN',
#   u'TEAM_ID': 1610612751,
#   u'TOV': 2.3,
#   u'W': 12,
#   u'W_PCT': 0.25},
#  {u'AGE': 20.0,
#   u'AST': 0.0,
#   u'BLK': 0.0,
#   u'BLKA': 0.0,
#   u'CFID': 5,
#   u'CFPARAMS': u'203998,1610612761',
#   u'DD2': 0,
#   u'DREB': 0.5,
#   u'FG3A': 0.0,
#   u'FG3M': 0.0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 0.5,
#   u'FGM': 0.0,
#   u'FG_PCT': 0.0,
#   u'FTA': 0.0,
#   u'FTM': 0.0,
#   u'FT_PCT': 0.0,
#   u'GP': 2,
#   u'L': 0,
#   u'MIN': 1.2,
#   'MIN_PLAYED': 1.0,
#   u'OREB': 0.0,
#   u'PF': 0.0,
#   u'PFD': 0.0,
#   u'PLAYER_ID': 203998,
#   u'PLAYER_NAME': u'Bruno Caboclo',
#   u'PLUS_MINUS': -1.5,
#   u'PTS': 0.0,
#   u'REB': 0.5,
#   'SEC_PLAYED': 0.19999999999999996,
#   u'STL': 0.5,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'TOR',
#   u'TEAM_ID': 1610612761,
#   u'TOV': 0.5,
#   u'W': 2,
#   u'W_PCT': 1.0},
#  {u'AGE': 23.0,
#   u'AST': 1.0,
#   u'BLK': 0.0,
#   u'BLKA': 0.0,
#   u'CFID': 5,
#   u'CFPARAMS': u'203955,1610612756',
#   u'DD2': 0,
#   u'DREB': 0.0,
#   u'FG3A': 1.0,
#   u'FG3M': 0.0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 2.7,
#   u'FGM': 0.7,
#   u'FG_PCT': 0.25,
#   u'FTA': 0.0,
#   u'FTM': 0.0,
#   u'FT_PCT': 0.0,
#   u'GP': 3,
#   u'L': 3,
#   u'MIN': 10.9,
#   'MIN_PLAYED': 10.0,
#   u'OREB': 0.0,
#   u'PF': 0.7,
#   u'PFD': 0.0,
#   u'PLAYER_ID': 203955,
#   u'PLAYER_NAME': u'Bryce Cotton',
#   u'PLUS_MINUS': -4.7,
#   u'PTS': 1.3,
#   u'REB': 0.0,
#   'SEC_PLAYED': 0.9000000000000004,
#   u'STL': 1.0,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'PHX',
#   u'TEAM_ID': 1610612756,
#   u'TOV': 1.7,
#   u'W': 0,
#   u'W_PCT': 0.0},
#  {u'AGE': 23.0,
#   u'AST': 0.6,
#   u'BLK': 0.2,
#   u'BLKA': 0.6,
#   u'CFID': 5,
#   u'CFPARAMS': u'1626214,1610612740',
#   u'DD2': 0,
#   u'DREB': 2.4,
#   u'FG3A': 2.2,
#   u'FG3M': 1.0,
#   u'FG3_PCT': 0.455,
#   u'FGA': 4.2,
#   u'FGM': 1.8,
#   u'FG_PCT': 0.429,
#   u'FTA': 1.4,
#   u'FTM': 0.4,
#   u'FT_PCT': 0.286,
#   u'GP': 5,
#   u'L': 1,
#   u'MIN': 15.8,
#   'MIN_PLAYED': 15.0,
#   u'OREB': 0.6,
#   u'PF': 1.0,
#   u'PFD': 1.0,
#   u'PLAYER_ID': 1626214,
#   u'PLAYER_NAME': u'Bryce Dejean-Jones',
#   u'PLUS_MINUS': -2.2,
#   u'PTS': 5.0,
#   u'REB': 3.0,
#   'SEC_PLAYED': 0.8000000000000007,
#   u'STL': 0.6,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'NOP',
#   u'TEAM_ID': 1610612740,
#   u'TOV': 0.4,
#   u'W': 4,
#   u'W_PCT': 0.8},
#  {u'AGE': 24.0,
#   u'AST': 4.4,
#   u'BLK': 0.2,
#   u'BLKA': 1.1,
#   u'CFID': 5,
#   u'CFPARAMS': u'203468,1610612757',
#   u'DD2': 2,
#   u'DREB': 3.0,
#   u'FG3A': 6.3,
#   u'FG3M': 2.5,
#   u'FG3_PCT': 0.392,
#   u'FGA': 18.3,
#   u'FGM': 8.1,
#   u'FG_PCT': 0.441,
#   u'FTA': 2.6,
#   u'FTM': 2.1,
#   u'FT_PCT': 0.802,
#   u'GP': 46,
#   u'L': 24,
#   u'MIN': 35.1,
#   'MIN_PLAYED': 35.0,
#   u'OREB': 0.6,
#   u'PF': 2.3,
#   u'PFD': 2.3,
#   u'PLAYER_ID': 203468,
#   u'PLAYER_NAME': u'CJ McCollum',
#   u'PLUS_MINUS': 1.7,
#   u'PTS': 20.7,
#   u'REB': 3.6,
#   'SEC_PLAYED': 0.10000000000000142,
#   u'STL': 1.1,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'POR',
#   u'TEAM_ID': 1610612757,
#   u'TOV': 2.2,
#   u'W': 22,
#   u'W_PCT': 0.478},
#  {u'AGE': 28.0,
#   u'AST': 1.1,
#   u'BLK': 0.5,
#   u'BLKA': 0.6,
#   u'CFID': 5,
#   u'CFPARAMS': u'101139,1610612754',
#   u'DD2': 0,
#   u'DREB': 2.7,
#   u'FG3A': 6.4,
#   u'FG3M': 2.2,
#   u'FG3_PCT': 0.349,
#   u'FGA': 10.4,
#   u'FGM': 4.1,
#   u'FG_PCT': 0.391,
#   u'FTA': 2.3,
#   u'FTM': 1.7,
#   u'FT_PCT': 0.745,
#   u'GP': 42,
#   u'L': 20,
#   u'MIN': 25.9,
#   'MIN_PLAYED': 25.0,
#   u'OREB': 0.5,
#   u'PF': 2.4,
#   u'PFD': 1.8,
#   u'PLAYER_ID': 101139,
#   u'PLAYER_NAME': u'CJ Miles',
#   u'PLUS_MINUS': 0.1,
#   u'PTS': 12.1,
#   u'REB': 3.2,
#   'SEC_PLAYED': 0.8999999999999986,
#   u'STL': 1.0,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'IND',
#   u'TEAM_ID': 1610612754,
#   u'TOV': 1.2,
#   u'W': 22,
#   u'W_PCT': 0.524},
#  {u'AGE': 31.0,
#   u'AST': 3.1,
#   u'BLK': 0.0,
#   u'BLKA': 0.1,
#   u'CFID': 5,
#   u'CFPARAMS': u'201228,1610612753',
#   u'DD2': 0,
#   u'DREB': 1.5,
#   u'FG3A': 2.0,
#   u'FG3M': 0.6,
#   u'FG3_PCT': 0.313,
#   u'FGA': 4.8,
#   u'FGM': 1.8,
#   u'FG_PCT': 0.368,
#   u'FTA': 0.9,
#   u'FTM': 0.6,
#   u'FT_PCT': 0.714,
#   u'GP': 8,
#   u'L': 5,
#   u'MIN': 19.6,
#   'MIN_PLAYED': 19.0,
#   u'OREB': 0.5,
#   u'PF': 1.3,
#   u'PFD': 1.5,
#   u'PLAYER_ID': 201228,
#   u'PLAYER_NAME': u'CJ Watson',
#   u'PLUS_MINUS': 3.4,
#   u'PTS': 4.8,
#   u'REB': 2.0,
#   'SEC_PLAYED': 0.6000000000000014,
#   u'STL': 1.0,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'ORL',
#   u'TEAM_ID': 1610612753,
#   u'TOV': 0.8,
#   u'W': 3,
#   u'W_PCT': 0.375},
#  {u'AGE': 25.0,
#   u'AST': 0.3,
#   u'BLK': 0.0,
#   u'BLKA': 0.3,
#   u'CFID': 5,
#   u'CFPARAMS': u'203912,1610612746',
#   u'DD2': 0,
#   u'DREB': 0.3,
#   u'FG3A': 0.0,
#   u'FG3M': 0.0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 1.3,
#   u'FGM': 0.5,
#   u'FG_PCT': 0.375,
#   u'FTA': 0.0,
#   u'FTM': 0.0,
#   u'FT_PCT': 0.0,
#   u'GP': 6,
#   u'L': 3,
#   u'MIN': 3.0,
#   'MIN_PLAYED': 3.0,
#   u'OREB': 0.0,
#   u'PF': 0.2,
#   u'PFD': 0.0,
#   u'PLAYER_ID': 203912,
#   u'PLAYER_NAME': u'CJ Wilcox',
#   u'PLUS_MINUS': 0.2,
#   u'PTS': 1.0,
#   u'REB': 0.3,
#   'SEC_PLAYED': 0.0,
#   u'STL': 0.0,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'LAC',
#   u'TEAM_ID': 1610612746,
#   u'TOV': 0.0,
#   u'W': 3,
#   u'W_PCT': 0.5},
#  {u'AGE': 25.0,
#   u'AST': 0.1,
#   u'BLK': 0.1,
#   u'BLKA': 0.2,
#   u'CFID': 5,
#   u'CFPARAMS': u'203946,1610612741',
#   u'DD2': 0,
#   u'DREB': 1.0,
#   u'FG3A': 0.2,
#   u'FG3M': 0.0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 1.6,
#   u'FGM': 0.5,
#   u'FG_PCT': 0.313,
#   u'FTA': 0.0,
#   u'FTM': 0.0,
#   u'FT_PCT': 0.0,
#   u'GP': 10,
#   u'L': 6,
#   u'MIN': 3.8,
#   'MIN_PLAYED': 3.0,
#   u'OREB': 0.4,
#   u'PF': 0.8,
#   u'PFD': 0.1,
#   u'PLAYER_ID': 203946,
#   u'PLAYER_NAME': u'Cameron Bairstow',
#   u'PLUS_MINUS': 0.4,
#   u'PTS': 1.0,
#   u'REB': 1.4,
#   'SEC_PLAYED': 0.7999999999999998,
#   u'STL': 0.1,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'CHI',
#   u'TEAM_ID': 1610612741,
#   u'TOV': 0.2,
#   u'W': 4,
#   u'W_PCT': 0.4},
#  {u'AGE': 21.0,
#   u'AST': 1.8,
#   u'BLK': 0.1,
#   u'BLKA': 0.2,
#   u'CFID': 5,
#   u'CFPARAMS': u'1626166,1610612760',
#   u'DD2': 0,
#   u'DREB': 1.5,
#   u'FG3A': 2.0,
#   u'FG3M': 0.8,
#   u'FG3_PCT': 0.413,
#   u'FGA': 4.7,
#   u'FGM': 2.1,
#   u'FG_PCT': 0.444,
#   u'FTA': 0.3,
#   u'FTM': 0.2,
#   u'FT_PCT': 0.75,
#   u'GP': 32,
#   u'L': 5,
#   u'MIN': 11.4,
#   'MIN_PLAYED': 11.0,
#   u'OREB': 0.1,
#   u'PF': 1.3,
#   u'PFD': 0.4,
#   u'PLAYER_ID': 1626166,
#   u'PLAYER_NAME': u'Cameron Payne',
#   u'PLUS_MINUS': -1.0,
#   u'PTS': 5.2,
#   u'REB': 1.6,
#   'SEC_PLAYED': 0.40000000000000036,
#   u'STL': 0.7,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'OKC',
#   u'TEAM_ID': 1610612760,
#   u'TOV': 0.6,
#   u'W': 27,
#   u'W_PCT': 0.844},
#  {u'AGE': 32.0,
#   u'AST': 0.4,
#   u'BLK': 0.3,
#   u'BLKA': 0.3,
#   u'CFID': 5,
#   u'CFPARAMS': u'201171,1610612755',
#   u'DD2': 0,
#   u'DREB': 2.0,
#   u'FG3A': 0.2,
#   u'FG3M': 0.1,
#   u'FG3_PCT': 0.5,
#   u'FGA': 5.5,
#   u'FGM': 3.2,
#   u'FG_PCT': 0.574,
#   u'FTA': 2.1,
#   u'FTM': 1.4,
#   u'FT_PCT': 0.652,
#   u'GP': 11,
#   u'L': 8,
#   u'MIN': 12.8,
#   'MIN_PLAYED': 12.0,
#   u'OREB': 0.9,
#   u'PF': 1.7,
#   u'PFD': 1.6,
#   u'PLAYER_ID': 201171,
#   u'PLAYER_NAME': u'Carl Landry',
#   u'PLUS_MINUS': 1.1,
#   u'PTS': 7.8,
#   u'REB': 2.9,
#   'SEC_PLAYED': 0.8000000000000007,
#   u'STL': 0.5,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'PHI',
#   u'TEAM_ID': 1610612755,
#   u'TOV': 0.8,
#   u'W': 3,
#   u'W_PCT': 0.273},
#  {u'AGE': 31.0,
#   u'AST': 4.1,
#   u'BLK': 0.5,
#   u'BLKA': 1.2,
#   u'CFID': 5,
#   u'CFPARAMS': u'2546,1610612752',
#   u'DD2': 12,
#   u'DREB': 6.0,
#   u'FG3A': 4.1,
#   u'FG3M': 1.4,
#   u'FG3_PCT': 0.337,
#   u'FGA': 17.5,
#   u'FGM': 7.6,
#   u'FG_PCT': 0.432,
#   u'FTA': 5.8,
#   u'FTM': 4.7,
#   u'FT_PCT': 0.823,
#   u'GP': 43,
#   u'L': 20,
#   u'MIN': 34.5,
#   'MIN_PLAYED': 34.0,
#   u'OREB': 1.5,
#   u'PF': 2.4,
#   u'PFD': 4.6,
#   u'PLAYER_ID': 2546,
#   u'PLAYER_NAME': u'Carmelo Anthony',
#   u'PLUS_MINUS': 1.2,
#   u'PTS': 21.2,
#   u'REB': 7.5,
#   'SEC_PLAYED': 0.5,
#   u'STL': 0.9,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'NYK',
#   u'TEAM_ID': 1610612752,
#   u'TOV': 2.5,
#   u'W': 23,
#   u'W_PCT': 0.535},
#  {u'AGE': 35.0,
#   u'AST': 0.3,
#   u'BLK': 0.0,
#   u'BLKA': 0.0,
#   u'CFID': 5,
#   u'CFPARAMS': u'2406,1610612758',
#   u'DD2': 0,
#   u'DREB': 0.9,
#   u'FG3A': 0.9,
#   u'FG3M': 0.1,
#   u'FG3_PCT': 0.125,
#   u'FGA': 2.9,
#   u'FGM': 1.2,
#   u'FG_PCT': 0.423,
#   u'FTA': 0.2,
#   u'FTM': 0.1,
#   u'FT_PCT': 0.5,
#   u'GP': 9,
#   u'L': 8,
#   u'MIN': 9.6,
#   'MIN_PLAYED': 9.0,
#   u'OREB': 0.3,
#   u'PF': 0.8,
#   u'PFD': 0.2,
#   u'PLAYER_ID': 2406,
#   u'PLAYER_NAME': u'Caron Butler',
#   u'PLUS_MINUS': -4.8,
#   u'PTS': 2.7,
#   u'REB': 1.2,
#   'SEC_PLAYED': 0.5999999999999996,
#   u'STL': 0.6,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'SAC',
#   u'TEAM_ID': 1610612758,
#   u'TOV': 0.2,
#   u'W': 1,
#   u'W_PCT': 0.111},
#  {u'AGE': 27.0,
#   u'AST': 2.5,
#   u'BLK': 0.3,
#   u'BLKA': 0.6,
#   u'CFID': 5,
#   u'CFPARAMS': u'202718,1610612742',
#   u'DD2': 1,
#   u'DREB': 3.9,
#   u'FG3A': 3.5,
#   u'FG3M': 1.4,
#   u'FG3_PCT': 0.4,
#   u'FGA': 9.5,
#   u'FGM': 4.6,
#   u'FG_PCT': 0.487,
#   u'FTA': 2.0,
#   u'FTM': 1.2,
#   u'FT_PCT': 0.61,
#   u'GP': 41,
#   u'L': 19,
#   u'MIN': 27.4,
#   'MIN_PLAYED': 27.0,
#   u'OREB': 0.4,
#   u'PF': 1.8,
#   u'PFD': 2.0,
#   u'PLAYER_ID': 202718,
#   u'PLAYER_NAME': u'Chandler Parsons',
#   u'PLUS_MINUS': -0.4,
#   u'PTS': 11.9,
#   u'REB': 4.3,
#   'SEC_PLAYED': 0.3999999999999986,
#   u'STL': 0.5,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'DAL',
#   u'TEAM_ID': 1610612742,
#   u'TOV': 1.4,
#   u'W': 22,
#   u'W_PCT': 0.537},
#  {u'AGE': 32.0,
#   u'AST': 1.1,
#   u'BLK': 0.5,
#   u'BLKA': 0.1,
#   u'CFID': 5,
#   u'CFPARAMS': u'101112,1610612753',
#   u'DD2': 0,
#   u'DREB': 2.7,
#   u'FG3A': 2.8,
#   u'FG3M': 1.2,
#   u'FG3_PCT': 0.414,
#   u'FGA': 4.2,
#   u'FGM': 1.9,
#   u'FG_PCT': 0.444,
#   u'FTA': 0.5,
#   u'FTM': 0.5,
#   u'FT_PCT': 0.905,
#   u'GP': 40,
#   u'L': 22,
#   u'MIN': 17.5,
#   'MIN_PLAYED': 17.0,
#   u'OREB': 0.5,
#   u'PF': 1.6,
#   u'PFD': 0.9,
#   u'PLAYER_ID': 101112,
#   u'PLAYER_NAME': u'Channing Frye',
#   u'PLUS_MINUS': 2.0,
#   u'PTS': 5.4,
#   u'REB': 3.2,
#   'SEC_PLAYED': 0.5,
#   u'STL': 0.5,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'ORL',
#   u'TEAM_ID': 1610612753,
#   u'TOV': 0.7,
#   u'W': 18,
#   u'W_PCT': 0.45},
#  {u'AGE': 32.0,
#   u'AST': 1.0,
#   u'BLK': 0.0,
#   u'BLKA': 0.0,
#   u'CFID': 5,
#   u'CFPARAMS': u'101236,1610612745',
#   u'DD2': 0,
#   u'DREB': 4.0,
#   u'FG3A': 0.0,
#   u'FG3M': 0.0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 1.0,
#   u'FGM': 0.5,
#   u'FG_PCT': 0.5,
#   u'FTA': 1.0,
#   u'FTM': 1.0,
#   u'FT_PCT': 1.0,
#   u'GP': 2,
#   u'L': 1,
#   u'MIN': 11.9,
#   'MIN_PLAYED': 11.0,
#   u'OREB': 0.0,
#   u'PF': 3.0,
#   u'PFD': 0.5,
#   u'PLAYER_ID': 101236,
#   u'PLAYER_NAME': u'Charles Hayes',
#   u'PLUS_MINUS': -1.5,
#   u'PTS': 2.0,
#   u'REB': 4.0,
#   'SEC_PLAYED': 0.9000000000000004,
#   u'STL': 0.0,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'HOU',
#   u'TEAM_ID': 1610612745,
#   u'TOV': 1.5,
#   u'W': 1,
#   u'W_PCT': 0.5},
#  {u'AGE': 31.0,
#   u'AST': 0.4,
#   u'BLK': 0.3,
#   u'BLKA': 0.2,
#   u'CFID': 5,
#   u'CFPARAMS': u'101111,1610612742',
#   u'DD2': 0,
#   u'DREB': 2.4,
#   u'FG3A': 3.2,
#   u'FG3M': 0.8,
#   u'FG3_PCT': 0.246,
#   u'FGA': 6.1,
#   u'FGM': 2.3,
#   u'FG_PCT': 0.379,
#   u'FTA': 0.4,
#   u'FTM': 0.4,
#   u'FT_PCT': 0.875,
#   u'GP': 40,
#   u'L': 20,
#   u'MIN': 12.1,
#   'MIN_PLAYED': 12.0,
#   u'OREB': 0.4,
#   u'PF': 1.4,
#   u'PFD': 0.2,
#   u'PLAYER_ID': 101111,
#   u'PLAYER_NAME': u'Charlie Villanueva',
#   u'PLUS_MINUS': -2.3,
#   u'PTS': 5.7,
#   u'REB': 2.7,
#   'SEC_PLAYED': 0.09999999999999964,
#   u'STL': 0.3,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'DAL',
#   u'TEAM_ID': 1610612742,
#   u'TOV': 0.5,
#   u'W': 20,
#   u'W_PCT': 0.5},
#  {u'AGE': 27.0,
#   u'AST': 1.1,
#   u'BLK': 0.2,
#   u'BLKA': 0.2,
#   u'CFID': 5,
#   u'CFPARAMS': u'201978,1610612754',
#   u'DD2': 0,
#   u'DREB': 1.9,
#   u'FG3A': 1.5,
#   u'FG3M': 0.5,
#   u'FG3_PCT': 0.295,
#   u'FGA': 4.1,
#   u'FGM': 1.7,
#   u'FG_PCT': 0.402,
#   u'FTA': 1.1,
#   u'FTM': 0.8,
#   u'FT_PCT': 0.705,
#   u'GP': 40,
#   u'L': 19,
#   u'MIN': 15.7,
#   'MIN_PLAYED': 15.0,
#   u'OREB': 0.6,
#   u'PF': 0.9,
#   u'PFD': 0.9,
#   u'PLAYER_ID': 201978,
#   u'PLAYER_NAME': u'Chase Budinger',
#   u'PLUS_MINUS': 0.8,
#   u'PTS': 4.5,
#   u'REB': 2.5,
#   'SEC_PLAYED': 0.6999999999999993,
#   u'STL': 0.6,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'IND',
#   u'TEAM_ID': 1610612754,
#   u'TOV': 0.6,
#   u'W': 21,
#   u'W_PCT': 0.525},
#  {u'AGE': 37.0,
#   u'AST': 0.4,
#   u'BLK': 0.4,
#   u'BLKA': 0.1,
#   u'CFID': 5,
#   u'CFPARAMS': u'2365,1610612748',
#   u'DD2': 0,
#   u'DREB': 0.9,
#   u'FG3A': 0.7,
#   u'FG3M': 0.3,
#   u'FG3_PCT': 0.4,
#   u'FGA': 1.4,
#   u'FGM': 0.6,
#   u'FG_PCT': 0.4,
#   u'FTA': 0.6,
#   u'FTM': 0.4,
#   u'FT_PCT': 0.75,
#   u'GP': 7,
#   u'L': 3,
#   u'MIN': 5.2,
#   'MIN_PLAYED': 5.0,
#   u'OREB': 0.4,
#   u'PF': 0.6,
#   u'PFD': 0.6,
#   u'PLAYER_ID': 2365,
#   u'PLAYER_NAME': u'Chris Andersen',
#   u'PLUS_MINUS': -2.4,
#   u'PTS': 1.9,
#   u'REB': 1.3,
#   'SEC_PLAYED': 0.20000000000000018,
#   u'STL': 0.1,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'MIA',
#   u'TEAM_ID': 1610612748,
#   u'TOV': 0.3,
#   u'W': 4,
#   u'W_PCT': 0.571},
#  {u'AGE': 31.0,
#   u'AST': 2.5,
#   u'BLK': 0.7,
#   u'BLKA': 0.6,
#   u'CFID': 5,
#   u'CFPARAMS': u'2547,1610612748',
#   u'DD2': 15,
#   u'DREB': 6.6,
#   u'FG3A': 4.3,
#   u'FG3M': 1.6,
#   u'FG3_PCT': 0.373,
#   u'FGA': 14.3,
#   u'FGM': 6.8,
#   u'FG_PCT': 0.476,
#   u'FTA': 5.1,
#   u'FTM': 4.1,
#   u'FT_PCT': 0.799,
#   u'GP': 47,
#   u'L': 21,
#   u'MIN': 33.6,
#   'MIN_PLAYED': 33.0,
#   u'OREB': 0.9,
#   u'PF': 1.8,
#   u'PFD': 3.9,
#   u'PLAYER_ID': 2547,
#   u'PLAYER_NAME': u'Chris Bosh',
#   u'PLUS_MINUS': 1.0,
#   u'PTS': 19.2,
#   u'REB': 7.6,
#   'SEC_PLAYED': 0.6000000000000014,
#   u'STL': 0.7,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'MIA',
#   u'TEAM_ID': 1610612748,
#   u'TOV': 1.4,
#   u'W': 26,
#   u'W_PCT': 0.553},
#  {u'AGE': 31.0,
#   u'AST': 0.5,
#   u'BLK': 0.0,
#   u'BLKA': 0.1,
#   u'CFID': 5,
#   u'CFPARAMS': u'203142,1610612749',
#   u'DD2': 0,
#   u'DREB': 0.4,
#   u'FG3A': 1.6,
#   u'FG3M': 0.4,
#   u'FG3_PCT': 0.278,
#   u'FGA': 2.2,
#   u'FGM': 0.7,
#   u'FG_PCT': 0.333,
#   u'FTA': 0.3,
#   u'FTM': 0.3,
#   u'FT_PCT': 0.857,
#   u'GP': 23,
#   u'L': 13,
#   u'MIN': 6.7,
#   'MIN_PLAYED': 6.0,
#   u'OREB': 0.0,
#   u'PF': 0.7,
#   u'PFD': 0.3,
#   u'PLAYER_ID': 203142,
#   u'PLAYER_NAME': u'Chris Copeland',
#   u'PLUS_MINUS': -3.6,
#   u'PTS': 2.2,
#   u'REB': 0.4,
#   'SEC_PLAYED': 0.7000000000000002,
#   u'STL': 0.1,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'MIL',
#   u'TEAM_ID': 1610612749,
#   u'TOV': 0.3,
#   u'W': 10,
#   u'W_PCT': 0.435},
#  {u'AGE': 25.0,
#   u'AST': 0.8,
#   u'BLK': 0.2,
#   u'BLKA': 0.2,
#   u'CFID': 5,
#   u'CFPARAMS': u'203187,1610612762',
#   u'DD2': 0,
#   u'DREB': 1.4,
#   u'FG3A': 1.3,
#   u'FG3M': 0.4,
#   u'FG3_PCT': 0.286,
#   u'FGA': 2.7,
#   u'FGM': 1.1,
#   u'FG_PCT': 0.386,
#   u'FTA': 0.6,
#   u'FTM': 0.5,
#   u'FT_PCT': 0.75,
#   u'GP': 37,
#   u'L': 18,
#   u'MIN': 11.3,
#   'MIN_PLAYED': 11.0,
#   u'OREB': 0.3,
#   u'PF': 1.3,
# ...
#   u'FT_PCT': 0.61,
#   u'GP': 44,
#   u'L': 25,
#   u'MIN': 18.2,
#   'MIN_PLAYED': 18.0,
#   u'OREB': 1.0,
#   u'PF': 1.5,
#   u'PFD': 0.9,
#   u'PLAYER_ID': 1626168,
#   u'PLAYER_NAME': u'Trey Lyles',
#   u'PLUS_MINUS': -0.5,
#   u'PTS': 4.7,
#   u'REB': 4.1,
#   'SEC_PLAYED': 0.1999999999999993,
#   u'STL': 0.3,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'UTA',
#   u'TEAM_ID': 1610612762,
#   u'TOV': 0.8,
#   u'W': 19,
#   u'W_PCT': 0.432},
#  {u'AGE': 24.0,
#   u'AST': 0.7,
#   u'BLK': 0.4,
#   u'BLKA': 0.5,
#   u'CFID': 5,
#   u'CFPARAMS': u'202684,1610612739',
#   u'DD2': 12,
#   u'DREB': 6.1,
#   u'FG3A': 0.0,
#   u'FG3M': 0.0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 5.4,
#   u'FGM': 3.0,
#   u'FG_PCT': 0.564,
#   u'FTA': 3.0,
#   u'FTM': 1.8,
#   u'FT_PCT': 0.6,
#   u'GP': 45,
#   u'L': 12,
#   u'MIN': 27.5,
#   'MIN_PLAYED': 27.0,
#   u'OREB': 3.3,
#   u'PF': 2.5,
#   u'PFD': 2.6,
#   u'PLAYER_ID': 202684,
#   u'PLAYER_NAME': u'Tristan Thompson',
#   u'PLUS_MINUS': 4.7,
#   u'PTS': 7.8,
#   u'REB': 9.4,
#   'SEC_PLAYED': 0.5,
#   u'STL': 0.3,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'CLE',
#   u'TEAM_ID': 1610612739,
#   u'TOV': 0.7,
#   u'W': 33,
#   u'W_PCT': 0.733},
#  {u'AGE': 24.0,
#   u'AST': 0.3,
#   u'BLK': 0.0,
#   u'BLKA': 0.1,
#   u'CFID': 5,
#   u'CFPARAMS': u'203584,1610612766',
#   u'DD2': 0,
#   u'DREB': 1.0,
#   u'FG3A': 2.6,
#   u'FG3M': 1.4,
#   u'FG3_PCT': 0.515,
#   u'FGA': 4.2,
#   u'FGM': 2.0,
#   u'FG_PCT': 0.471,
#   u'FTA': 0.3,
#   u'FTM': 0.2,
#   u'FT_PCT': 0.5,
#   u'GP': 25,
#   u'L': 13,
#   u'MIN': 10.8,
#   'MIN_PLAYED': 10.0,
#   u'OREB': 0.2,
#   u'PF': 1.1,
#   u'PFD': 0.2,
#   u'PLAYER_ID': 203584,
#   u'PLAYER_NAME': u'Troy Daniels',
#   u'PLUS_MINUS': -0.9,
#   u'PTS': 5.4,
#   u'REB': 1.2,
#   'SEC_PLAYED': 0.8000000000000007,
#   u'STL': 0.2,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'CHA',
#   u'TEAM_ID': 1610612766,
#   u'TOV': 0.6,
#   u'W': 12,
#   u'W_PCT': 0.48},
#  {u'AGE': 28.0,
#   u'AST': 3.9,
#   u'BLK': 0.1,
#   u'BLKA': 0.5,
#   u'CFID': 5,
#   u'CFPARAMS': u'201951,1610612745',
#   u'DD2': 1,
#   u'DREB': 1.4,
#   u'FG3A': 1.9,
#   u'FG3M': 0.6,
#   u'FG3_PCT': 0.329,
#   u'FGA': 5.9,
#   u'FGM': 2.3,
#   u'FG_PCT': 0.394,
#   u'FTA': 1.8,
#   u'FTM': 1.2,
#   u'FT_PCT': 0.703,
#   u'GP': 42,
#   u'L': 24,
#   u'MIN': 24.3,
#   'MIN_PLAYED': 24.0,
#   u'OREB': 0.5,
#   u'PF': 1.5,
#   u'PFD': 1.5,
#   u'PLAYER_ID': 201951,
#   u'PLAYER_NAME': u'Ty Lawson',
#   u'PLUS_MINUS': -2.8,
#   u'PTS': 6.5,
#   u'REB': 1.9,
#   'SEC_PLAYED': 0.3000000000000007,
#   u'STL': 0.9,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'HOU',
#   u'TEAM_ID': 1610612745,
#   u'TOV': 1.7,
#   u'W': 18,
#   u'W_PCT': 0.429},
#  {u'AGE': 21.0,
#   u'AST': 1.0,
#   u'BLK': 0.0,
#   u'BLKA': 0.0,
#   u'CFID': 5,
#   u'CFPARAMS': u'203898,1610612749',
#   u'DD2': 0,
#   u'DREB': 0.8,
#   u'FG3A': 0.6,
#   u'FG3M': 0.2,
#   u'FG3_PCT': 0.286,
#   u'FGA': 2.7,
#   u'FGM': 1.1,
#   u'FG_PCT': 0.4,
#   u'FTA': 0.5,
#   u'FTM': 0.4,
#   u'FT_PCT': 0.75,
#   u'GP': 22,
#   u'L': 13,
#   u'MIN': 9.0,
#   'MIN_PLAYED': 9.0,
#   u'OREB': 0.1,
#   u'PF': 1.0,
#   u'PFD': 0.5,
#   u'PLAYER_ID': 203898,
#   u'PLAYER_NAME': u'Tyler Ennis',
#   u'PLUS_MINUS': -2.3,
#   u'PTS': 2.8,
#   u'REB': 1.0,
#   'SEC_PLAYED': 0.0,
#   u'STL': 0.2,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'MIL',
#   u'TEAM_ID': 1610612749,
#   u'TOV': 0.6,
#   u'W': 9,
#   u'W_PCT': 0.409},
#  {u'AGE': 30.0,
#   u'AST': 0.3,
#   u'BLK': 0.2,
#   u'BLKA': 0.4,
#   u'CFID': 5,
#   u'CFPARAMS': u'201946,1610612766',
#   u'DD2': 1,
#   u'DREB': 1.4,
#   u'FG3A': 0.1,
#   u'FG3M': 0.1,
#   u'FG3_PCT': 0.667,
#   u'FGA': 1.9,
#   u'FGM': 0.8,
#   u'FG_PCT': 0.423,
#   u'FTA': 1.6,
#   u'FTM': 0.9,
#   u'FT_PCT': 0.571,
#   u'GP': 27,
#   u'L': 13,
#   u'MIN': 9.2,
#   'MIN_PLAYED': 9.0,
#   u'OREB': 1.3,
#   u'PF': 1.5,
#   u'PFD': 1.3,
#   u'PLAYER_ID': 201946,
#   u'PLAYER_NAME': u'Tyler Hansbrough',
#   u'PLUS_MINUS': -1.2,
#   u'PTS': 2.6,
#   u'REB': 2.6,
#   'SEC_PLAYED': 0.1999999999999993,
#   u'STL': 0.3,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'CHA',
#   u'TEAM_ID': 1610612766,
#   u'TOV': 0.4,
#   u'W': 14,
#   u'W_PCT': 0.519},
#  {u'AGE': 23.0,
#   u'AST': 2.2,
#   u'BLK': 0.4,
#   u'BLKA': 0.6,
#   u'CFID': 5,
#   u'CFPARAMS': u'204020,1610612748',
#   u'DD2': 0,
#   u'DREB': 2.3,
#   u'FG3A': 1.9,
#   u'FG3M': 0.8,
#   u'FG3_PCT': 0.386,
#   u'FGA': 6.7,
#   u'FGM': 3.3,
#   u'FG_PCT': 0.488,
#   u'FTA': 1.8,
#   u'FTM': 1.4,
#   u'FT_PCT': 0.797,
#   u'GP': 36,
#   u'L': 17,
#   u'MIN': 24.0,
#   'MIN_PLAYED': 24.0,
#   u'OREB': 0.8,
#   u'PF': 1.8,
#   u'PFD': 1.8,
#   u'PLAYER_ID': 204020,
#   u'PLAYER_NAME': u'Tyler Johnson',
#   u'PLUS_MINUS': 0.3,
#   u'PTS': 8.7,
#   u'REB': 3.0,
#   'SEC_PLAYED': 0.0,
#   u'STL': 0.7,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'MIA',
#   u'TEAM_ID': 1610612748,
#   u'TOV': 1.3,
#   u'W': 19,
#   u'W_PCT': 0.528},
#  {u'AGE': 26.0,
#   u'AST': 0.3,
#   u'BLK': 0.1,
#   u'BLKA': 0.2,
#   u'CFID': 5,
#   u'CFPARAMS': u'203092,1610612738',
#   u'DD2': 0,
#   u'DREB': 1.5,
#   u'FG3A': 0.0,
#   u'FG3M': 0.0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 3.9,
#   u'FGM': 1.8,
#   u'FG_PCT': 0.458,
#   u'FTA': 1.2,
#   u'FTM': 0.8,
#   u'FT_PCT': 0.684,
#   u'GP': 31,
#   u'L': 11,
#   u'MIN': 8.8,
#   'MIN_PLAYED': 8.0,
#   u'OREB': 0.8,
#   u'PF': 1.4,
#   u'PFD': 1.0,
#   u'PLAYER_ID': 203092,
#   u'PLAYER_NAME': u'Tyler Zeller',
#   u'PLUS_MINUS': -0.7,
#   u'PTS': 4.4,
#   u'REB': 2.3,
#   'SEC_PLAYED': 0.8000000000000007,
#   u'STL': 0.2,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'BOS',
#   u'TEAM_ID': 1610612738,
#   u'TOV': 0.7,
#   u'W': 20,
#   u'W_PCT': 0.645},
#  {u'AGE': 26.0,
#   u'AST': 6.6,
#   u'BLK': 0.3,
#   u'BLKA': 0.9,
#   u'CFID': 5,
#   u'CFPARAMS': u'201936,1610612740',
#   u'DD2': 6,
#   u'DREB': 4.4,
#   u'FG3A': 3.4,
#   u'FG3M': 1.3,
#   u'FG3_PCT': 0.388,
#   u'FGA': 12.6,
#   u'FGM': 5.4,
#   u'FG_PCT': 0.433,
#   u'FTA': 3.7,
#   u'FTM': 3.0,
#   u'FT_PCT': 0.796,
#   u'GP': 25,
#   u'L': 14,
#   u'MIN': 30.6,
#   'MIN_PLAYED': 30.0,
#   u'OREB': 0.8,
#   u'PF': 2.6,
#   u'PFD': 3.0,
#   u'PLAYER_ID': 201936,
#   u'PLAYER_NAME': u'Tyreke Evans',
#   u'PLUS_MINUS': -0.6,
#   u'PTS': 15.2,
#   u'REB': 5.2,
#   'SEC_PLAYED': 0.6000000000000014,
#   u'STL': 1.3,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'NOP',
#   u'TEAM_ID': 1610612740,
#   u'TOV': 2.9,
#   u'W': 11,
#   u'W_PCT': 0.44},
#  {u'AGE': 33.0,
#   u'AST': 1.0,
#   u'BLK': 0.6,
#   u'BLKA': 0.4,
#   u'CFID': 5,
#   u'CFPARAMS': u'2199,1610612756',
#   u'DD2': 6,
#   u'DREB': 5.7,
#   u'FG3A': 0.0,
#   u'FG3M': 0.0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 4.0,
#   u'FGM': 1.9,
#   u'FG_PCT': 0.484,
#   u'FTA': 2.5,
#   u'FTM': 1.6,
#   u'FT_PCT': 0.646,
#   u'GP': 39,
#   u'L': 28,
#   u'MIN': 23.2,
#   'MIN_PLAYED': 23.0,
#   u'OREB': 2.6,
#   u'PF': 1.9,
#   u'PFD': 2.3,
#   u'PLAYER_ID': 2199,
#   u'PLAYER_NAME': u'Tyson Chandler',
#   u'PLUS_MINUS': -7.1,
#   u'PTS': 5.5,
#   u'REB': 8.3,
#   'SEC_PLAYED': 0.1999999999999993,
#   u'STL': 0.5,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'PHX',
#   u'TEAM_ID': 1610612756,
#   u'TOV': 1.2,
#   u'W': 11,
#   u'W_PCT': 0.282},
#  {u'AGE': 19.0,
#   u'AST': 1.6,
#   u'BLK': 0.1,
#   u'BLKA': 0.4,
#   u'CFID': 5,
#   u'CFPARAMS': u'1626145,1610612750',
#   u'DD2': 0,
#   u'DREB': 1.3,
#   u'FG3A': 0.4,
#   u'FG3M': 0.2,
#   u'FG3_PCT': 0.5,
#   u'FGA': 3.4,
#   u'FGM': 1.2,
#   u'FG_PCT': 0.355,
#   u'FTA': 0.6,
#   u'FTM': 0.3,
#   u'FT_PCT': 0.6,
#   u'GP': 9,
#   u'L': 8,
#   u'MIN': 10.9,
#   'MIN_PLAYED': 10.0,
#   u'OREB': 0.3,
#   u'PF': 0.7,
#   u'PFD': 0.7,
#   u'PLAYER_ID': 1626145,
#   u'PLAYER_NAME': u'Tyus Jones',
#   u'PLUS_MINUS': -9.2,
#   u'PTS': 3.0,
#   u'REB': 1.7,
#   'SEC_PLAYED': 0.9000000000000004,
#   u'STL': 0.4,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'MIN',
#   u'TEAM_ID': 1610612750,
#   u'TOV': 0.9,
#   u'W': 1,
#   u'W_PCT': 0.111},
#  {u'AGE': 35.0,
#   u'AST': 0.6,
#   u'BLK': 0.1,
#   u'BLKA': 0.0,
#   u'CFID': 5,
#   u'CFPARAMS': u'2617,1610612748',
#   u'DD2': 0,
#   u'DREB': 2.0,
#   u'FG3A': 0.3,
#   u'FG3M': 0.0,
#   u'FG3_PCT': 0.167,
#   u'FGA': 1.8,
#   u'FGM': 0.7,
#   u'FG_PCT': 0.357,
#   u'FTA': 0.3,
#   u'FTM': 0.3,
#   u'FT_PCT': 1.0,
#   u'GP': 23,
#   u'L': 9,
#   u'MIN': 8.5,
#   'MIN_PLAYED': 8.0,
#   u'OREB': 0.3,
#   u'PF': 0.7,
#   u'PFD': 0.7,
#   u'PLAYER_ID': 2617,
#   u'PLAYER_NAME': u'Udonis Haslem',
#   u'PLUS_MINUS': -1.1,
#   u'PTS': 1.7,
#   u'REB': 2.3,
#   'SEC_PLAYED': 0.5,
#   u'STL': 0.2,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'MIA',
#   u'TEAM_ID': 1610612748,
#   u'TOV': 0.2,
#   u'W': 14,
#   u'W_PCT': 0.609},
#  {u'AGE': 23.0,
#   u'AST': 4.0,
#   u'BLK': 0.6,
#   u'BLKA': 1.0,
#   u'CFID': 5,
#   u'CFPARAMS': u'203506,1610612753',
#   u'DD2': 2,
#   u'DREB': 4.2,
#   u'FG3A': 3.8,
#   u'FG3M': 1.3,
#   u'FG3_PCT': 0.353,
#   u'FGA': 12.2,
#   u'FGM': 5.0,
#   u'FG_PCT': 0.405,
#   u'FTA': 3.0,
#   u'FTM': 2.4,
#   u'FT_PCT': 0.826,
#   u'GP': 41,
#   u'L': 22,
#   u'MIN': 30.4,
#   'MIN_PLAYED': 30.0,
#   u'OREB': 0.5,
#   u'PF': 2.3,
#   u'PFD': 2.7,
#   u'PLAYER_ID': 203506,
#   u'PLAYER_NAME': u'Victor Oladipo',
#   u'PLUS_MINUS': -0.4,
#   u'PTS': 13.7,
#   u'REB': 4.7,
#   'SEC_PLAYED': 0.3999999999999986,
#   u'STL': 1.2,
#   u'TD3': 1,
#   u'TEAM_ABBREVIATION': u'ORL',
#   u'TEAM_ID': 1610612753,
#   u'TOV': 2.1,
#   u'W': 19,
#   u'W_PCT': 0.463},
#  {u'AGE': 39.0,
#   u'AST': 0.7,
#   u'BLK': 0.3,
#   u'BLKA': 0.2,
#   u'CFID': 5,
#   u'CFPARAMS': u'1713,1610612763',
#   u'DD2': 0,
#   u'DREB': 1.3,
#   u'FG3A': 2.0,
#   u'FG3M': 0.5,
#   u'FG3_PCT': 0.237,
#   u'FGA': 3.7,
#   u'FGM': 1.1,
#   u'FG_PCT': 0.306,
#   u'FTA': 0.8,
#   u'FTM': 0.7,
#   u'FT_PCT': 0.864,
#   u'GP': 29,
#   u'L': 11,
#   u'MIN': 12.7,
#   'MIN_PLAYED': 12.0,
#   u'OREB': 0.3,
#   u'PF': 1.6,
#   u'PFD': 0.9,
#   u'PLAYER_ID': 1713,
#   u'PLAYER_NAME': u'Vince Carter',
#   u'PLUS_MINUS': -1.0,
#   u'PTS': 3.4,
#   u'REB': 1.7,
#   'SEC_PLAYED': 0.6999999999999993,
#   u'STL': 0.4,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'MEM',
#   u'TEAM_ID': 1610612763,
#   u'TOV': 0.4,
#   u'W': 18,
#   u'W_PCT': 0.621},
#  {u'AGE': 23.0,
#   u'AST': 0.3,
#   u'BLK': 0.6,
#   u'BLKA': 0.3,
#   u'CFID': 5,
#   u'CFPARAMS': u'204002,1610612737',
#   u'DD2': 0,
#   u'DREB': 1.1,
#   u'FG3A': 0.0,
#   u'FG3M': 0.0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 1.9,
#   u'FGM': 1.0,
#   u'FG_PCT': 0.533,
#   u'FTA': 1.0,
#   u'FTM': 0.4,
#   u'FT_PCT': 0.375,
#   u'GP': 8,
#   u'L': 4,
#   u'MIN': 7.2,
#   'MIN_PLAYED': 7.0,
#   u'OREB': 0.8,
#   u'PF': 0.6,
#   u'PFD': 0.5,
#   u'PLAYER_ID': 204002,
#   u'PLAYER_NAME': u'Walter Tavares',
#   u'PLUS_MINUS': -2.9,
#   u'PTS': 2.4,
#   u'REB': 1.9,
#   'SEC_PLAYED': 0.20000000000000018,
#   u'STL': 0.1,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'ATL',
#   u'TEAM_ID': 1610612737,
#   u'TOV': 0.5,
#   u'W': 4,
#   u'W_PCT': 0.5},
#  {u'AGE': 28.0,
#   u'AST': 0.9,
#   u'BLK': 0.1,
#   u'BLKA': 0.3,
#   u'CFID': 5,
#   u'CFPARAMS': u'201961,1610612751',
#   u'DD2': 0,
#   u'DREB': 1.9,
#   u'FG3A': 3.1,
#   u'FG3M': 1.0,
#   u'FG3_PCT': 0.331,
#   u'FGA': 6.7,
#   u'FGM': 2.6,
#   u'FG_PCT': 0.382,
#   u'FTA': 0.7,
#   u'FTM': 0.6,
#   u'FT_PCT': 0.794,
#   u'GP': 47,
#   u'L': 36,
#   u'MIN': 19.5,
#   'MIN_PLAYED': 19.0,
#   u'OREB': 0.2,
#   u'PF': 1.0,
#   u'PFD': 0.6,
#   u'PLAYER_ID': 201961,
#   u'PLAYER_NAME': u'Wayne Ellington',
#   u'PLUS_MINUS': -3.8,
#   u'PTS': 6.7,
#   u'REB': 2.2,
#   'SEC_PLAYED': 0.5,
#   u'STL': 0.7,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'BKN',
#   u'TEAM_ID': 1610612751,
#   u'TOV': 0.6,
#   u'W': 11,
#   u'W_PCT': 0.234},
#  {u'AGE': 28.0,
#   u'AST': 0.6,
#   u'BLK': 0.6,
#   u'BLKA': 0.1,
#   u'CFID': 5,
#   u'CFPARAMS': u'202325,1610612746',
#   u'DD2': 0,
#   u'DREB': 2.1,
#   u'FG3A': 3.7,
#   u'FG3M': 1.3,
#   u'FG3_PCT': 0.337,
#   u'FGA': 5.8,
#   u'FGM': 2.5,
#   u'FG_PCT': 0.425,
#   u'FTA': 0.6,
#   u'FTM': 0.4,
#   u'FT_PCT': 0.6,
#   u'GP': 47,
#   u'L': 16,
#   u'MIN': 18.6,
#   'MIN_PLAYED': 18.0,
#   u'OREB': 0.4,
#   u'PF': 1.9,
#   u'PFD': 0.5,
#   u'PLAYER_ID': 202325,
#   u'PLAYER_NAME': u'Wesley Johnson',
#   u'PLUS_MINUS': 1.3,
#   u'PTS': 6.6,
#   u'REB': 2.5,
#   'SEC_PLAYED': 0.6000000000000014,
#   u'STL': 1.0,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'LAC',
#   u'TEAM_ID': 1610612746,
#   u'TOV': 0.6,
#   u'W': 31,
#   u'W_PCT': 0.66},
#  {u'AGE': 29.0,
#   u'AST': 1.8,
#   u'BLK': 0.3,
#   u'BLKA': 0.4,
#   u'CFID': 5,
#   u'CFPARAMS': u'202083,1610612742',
#   u'DD2': 0,
#   u'DREB': 2.6,
#   u'FG3A': 6.7,
#   u'FG3M': 2.4,
#   u'FG3_PCT': 0.353,
#   u'FGA': 11.0,
#   u'FGM': 4.3,
#   u'FG_PCT': 0.388,
#   u'FTA': 1.8,
#   u'FTM': 1.6,
#   u'FT_PCT': 0.854,
#   u'GP': 45,
#   u'L': 20,
#   u'MIN': 33.0,
#   'MIN_PLAYED': 33.0,
#   u'OREB': 0.4,
#   u'PF': 2.2,
#   u'PFD': 1.8,
#   u'PLAYER_ID': 202083,
#   u'PLAYER_NAME': u'Wesley Matthews',
#   u'PLUS_MINUS': 2.1,
#   u'PTS': 12.5,
#   u'REB': 3.1,
#   'SEC_PLAYED': 0.0,
#   u'STL': 1.0,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'DAL',
#   u'TEAM_ID': 1610612742,
#   u'TOV': 1.0,
#   u'W': 25,
#   u'W_PCT': 0.556},
#  {u'AGE': 25.0,
#   u'AST': 2.4,
#   u'BLK': 0.4,
#   u'BLKA': 0.7,
#   u'CFID': 5,
#   u'CFPARAMS': u'203115,1610612743',
#   u'DD2': 3,
#   u'DREB': 5.1,
#   u'FG3A': 4.1,
#   u'FG3M': 1.6,
#   u'FG3_PCT': 0.382,
#   u'FGA': 12.6,
#   u'FGM': 5.6,
#   u'FG_PCT': 0.445,
#   u'FTA': 3.1,
#   u'FTM': 2.7,
#   u'FT_PCT': 0.854,
#   u'GP': 48,
#   u'L': 30,
#   u'MIN': 28.8,
#   'MIN_PLAYED': 28.0,
#   u'OREB': 0.9,
#   u'PF': 1.8,
#   u'PFD': 2.6,
#   u'PLAYER_ID': 203115,
#   u'PLAYER_NAME': u'Will Barton',
#   u'PLUS_MINUS': -1.7,
#   u'PTS': 15.5,
#   u'REB': 5.9,
#   'SEC_PLAYED': 0.8000000000000007,
#   u'STL': 0.9,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'DEN',
#   u'TEAM_ID': 1610612743,
#   u'TOV': 1.6,
#   u'W': 18,
#   u'W_PCT': 0.375},
#  {u'AGE': 22.0,
#   u'AST': 0.4,
#   u'BLK': 1.2,
#   u'BLKA': 0.2,
#   u'CFID': 5,
#   u'CFPARAMS': u'1626161,1610612758',
#   u'DD2': 2,
#   u'DREB': 3.5,
#   u'FG3A': 0.0,
#   u'FG3M': 0.0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 4.0,
#   u'FGM': 2.4,
#   u'FG_PCT': 0.598,
#   u'FTA': 2.0,
#   u'FTM': 1.1,
#   u'FT_PCT': 0.571,
#   u'GP': 32,
#   u'L': 18,
#   u'MIN': 19.9,
#   'MIN_PLAYED': 19.0,
#   u'OREB': 2.1,
#   u'PF': 2.4,
#   u'PFD': 1.3,
#   u'PLAYER_ID': 1626161,
#   u'PLAYER_NAME': u'Willie Cauley-Stein',
#   u'PLUS_MINUS': 1.2,
#   u'PTS': 5.9,
#   u'REB': 5.6,
#   'SEC_PLAYED': 0.8999999999999986,
#   u'STL': 0.7,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'SAC',
#   u'TEAM_ID': 1610612758,
#   u'TOV': 0.6,
#   u'W': 14,
#   u'W_PCT': 0.438},
#  {u'AGE': 25.0,
#   u'AST': 0.2,
#   u'BLK': 0.5,
#   u'BLKA': 0.2,
#   u'CFID': 5,
#   u'CFPARAMS': u'203186,1610612751',
#   u'DD2': 0,
#   u'DREB': 1.7,
#   u'FG3A': 0.0,
#   u'FG3M': 0.0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 3.1,
#   u'FGM': 1.8,
#   u'FG_PCT': 0.588,
#   u'FTA': 1.2,
#   u'FTM': 0.6,
#   u'FT_PCT': 0.5,
#   u'GP': 26,
#   u'L': 20,
#   u'MIN': 10.3,
#   'MIN_PLAYED': 10.0,
#   u'OREB': 1.0,
#   u'PF': 1.3,
#   u'PFD': 1.7,
#   u'PLAYER_ID': 203186,
#   u'PLAYER_NAME': u'Willie Reed',
#   u'PLUS_MINUS': -1.8,
#   u'PTS': 4.2,
#   u'REB': 2.7,
#   'SEC_PLAYED': 0.3000000000000007,
#   u'STL': 0.1,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'BKN',
#   u'TEAM_ID': 1610612751,
#   u'TOV': 0.5,
#   u'W': 6,
#   u'W_PCT': 0.231},
#  {u'AGE': 20.0,
#   u'AST': 3.1,
#   u'BLK': 0.1,
#   u'BLKA': 0.8,
#   u'CFID': 5,
#   u'CFPARAMS': u'203897,1610612750',
#   u'DD2': 0,
#   u'DREB': 2.6,
#   u'FG3A': 3.0,
#   u'FG3M': 1.0,
#   u'FG3_PCT': 0.345,
#   u'FGA': 10.9,
#   u'FGM': 4.8,
#   u'FG_PCT': 0.439,
#   u'FTA': 2.6,
#   u'FTM': 2.1,
#   u'FT_PCT': 0.815,
#   u'GP': 48,
#   u'L': 34,
#   u'MIN': 23.5,
#   'MIN_PLAYED': 23.0,
#   u'OREB': 0.4,
#   u'PF': 2.4,
#   u'PFD': 1.9,
#   u'PLAYER_ID': 203897,
#   u'PLAYER_NAME': u'Zach LaVine',
#   u'PLUS_MINUS': -3.7,
#   u'PTS': 12.7,
#   u'REB': 3.0,
#   'SEC_PLAYED': 0.5,
#   u'STL': 0.6,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'MIN',
#   u'TEAM_ID': 1610612750,
#   u'TOV': 1.9,
#   u'W': 14,
#   u'W_PCT': 0.292},
#  {u'AGE': 34.0,
#   u'AST': 1.4,
#   u'BLK': 0.2,
#   u'BLKA': 1.0,
#   u'CFID': 5,
#   u'CFPARAMS': u'2216,1610612763',
#   u'DD2': 11,
#   u'DREB': 5.1,
#   u'FG3A': 0.1,
#   u'FG3M': 0.0,
#   u'FG3_PCT': 0.167,
#   u'FGA': 11.9,
#   u'FGM': 5.7,
#   u'FG_PCT': 0.48,
#   u'FTA': 3.0,
#   u'FTM': 2.3,
#   u'FT_PCT': 0.756,
#   u'GP': 42,
#   u'L': 18,
#   u'MIN': 28.6,
#   'MIN_PLAYED': 28.0,
#   u'OREB': 3.0,
#   u'PF': 2.0,
#   u'PFD': 2.8,
#   u'PLAYER_ID': 2216,
#   u'PLAYER_NAME': u'Zach Randolph',
#   u'PLUS_MINUS': -0.5,
#   u'PTS': 13.7,
#   u'REB': 8.0,
#   'SEC_PLAYED': 0.6000000000000014,
#   u'STL': 0.6,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'MEM',
#   u'TEAM_ID': 1610612763,
#   u'TOV': 1.4,
#   u'W': 24,
#   u'W_PCT': 0.571},
#  {u'AGE': 31.0,
#   u'AST': 1.9,
#   u'BLK': 0.4,
#   u'BLKA': 0.6,
#   u'CFID': 5,
#   u'CFPARAMS': u'2585,1610612742',
#   u'DD2': 21,
#   u'DREB': 7.1,
#   u'FG3A': 0.0,
#   u'FG3M': 0.0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 7.3,
#   u'FGM': 3.5,
#   u'FG_PCT': 0.483,
#   u'FTA': 4.3,
#   u'FTM': 3.4,
#   u'FT_PCT': 0.789,
#   u'GP': 44,
#   u'L': 19,
#   u'MIN': 29.3,
#   'MIN_PLAYED': 29.0,
#   u'OREB': 3.7,
#   u'PF': 2.7,
#   u'PFD': 4.0,
#   u'PLAYER_ID': 2585,
#   u'PLAYER_NAME': u'Zaza Pachulia',
#   u'PLUS_MINUS': 1.0,
#   u'PTS': 10.5,
#   u'REB': 10.8,
#   'SEC_PLAYED': 0.3000000000000007,
#   u'STL': 1.0,
#   u'TD3': 0,
#   u'TEAM_ABBREVIATION': u'DAL',
#   u'TEAM_ID': 1610612742,
#   u'TOV': 1.9,
#   u'W': 25,
#   u'W_PCT': 0.568}]

# %% [markdown]
# ## Scoreboard
#
# http://stats.nba.com/stats/scoreboardV2?DayOffset=0&GameDate=2016-01-29&LeagueID=00

# %%
sb = parser.scoreboard(scraper.scoreboard(game_date='2016-01-29'))

# %%
sb
# Out:
# {'date': None,
#  'game_headers': [{u'GAMECODE': u'20160129/PHXNYK',
#    u'GAME_DATE_EST': u'2016-01-29T00:00:00',
#    u'GAME_ID': u'0021500700',
#    u'GAME_SEQUENCE': 3,
#    u'GAME_STATUS_ID': 3,
#    u'GAME_STATUS_TEXT': u'Final',
#    u'HOME_TEAM_ID': 1610612752,
#    u'LIVE_PC_TIME': u'     ',
#    u'LIVE_PERIOD': 4,
#    u'LIVE_PERIOD_TIME_BCAST': u'Q4       - ',
#    u'NATL_TV_BROADCASTER_ABBREVIATION': None,
#    u'SEASON': u'2015',
#    u'VISITOR_TEAM_ID': 1610612756,
#    u'WH_STATUS': 1},
#   {u'GAMECODE': u'20160129/BKNDAL',
#    u'GAME_DATE_EST': u'2016-01-29T00:00:00',
#    u'GAME_ID': u'0021500702',
#    u'GAME_SEQUENCE': 6,
#    u'GAME_STATUS_ID': 3,
#    u'GAME_STATUS_TEXT': u'Final',
#    u'HOME_TEAM_ID': 1610612742,
#    u'LIVE_PC_TIME': u'     ',
#    u'LIVE_PERIOD': 4,
#    u'LIVE_PERIOD_TIME_BCAST': u'Q4       - ',
#    u'NATL_TV_BROADCASTER_ABBREVIATION': None,
#    u'SEASON': u'2015',
#    u'VISITOR_TEAM_ID': 1610612751,
#    u'WH_STATUS': 1},
#   {u'GAMECODE': u'20160129/CHAPOR',
#    u'GAME_DATE_EST': u'2016-01-29T00:00:00',
#    u'GAME_ID': u'0021500705',
#    u'GAME_SEQUENCE': 8,
#    u'GAME_STATUS_ID': 3,
#    u'GAME_STATUS_TEXT': u'Final',
#    u'HOME_TEAM_ID': 1610612757,
#    u'LIVE_PC_TIME': u'     ',
#    u'LIVE_PERIOD': 4,
#    u'LIVE_PERIOD_TIME_BCAST': u'Q4       - ',
#    u'NATL_TV_BROADCASTER_ABBREVIATION': None,
#    u'SEASON': u'2015',
#    u'VISITOR_TEAM_ID': 1610612766,
#    u'WH_STATUS': 1},
#   {u'GAMECODE': u'20160129/MINUTA',
#    u'GAME_DATE_EST': u'2016-01-29T00:00:00',
#    u'GAME_ID': u'0021500704',
#    u'GAME_SEQUENCE': 7,
#    u'GAME_STATUS_ID': 3,
#    u'GAME_STATUS_TEXT': u'Final',
#    u'HOME_TEAM_ID': 1610612762,
#    u'LIVE_PC_TIME': u'     ',
#    u'LIVE_PERIOD': 4,
#    u'LIVE_PERIOD_TIME_BCAST': u'Q4       - ',
#    u'NATL_TV_BROADCASTER_ABBREVIATION': None,
#    u'SEASON': u'2015',
#    u'VISITOR_TEAM_ID': 1610612750,
#    u'WH_STATUS': 1},
#   {u'GAMECODE': u'20160129/HOUOKC',
#    u'GAME_DATE_EST': u'2016-01-29T00:00:00',
#    u'GAME_ID': u'0021500701',
#    u'GAME_SEQUENCE': 4,
#    u'GAME_STATUS_ID': 3,
#    u'GAME_STATUS_TEXT': u'Final',
#    u'HOME_TEAM_ID': 1610612760,
#    u'LIVE_PC_TIME': u'     ',
#    u'LIVE_PERIOD': 4,
#    u'LIVE_PERIOD_TIME_BCAST': u'Q4       - NBA TV',
#    u'NATL_TV_BROADCASTER_ABBREVIATION': u'NBA TV',
#    u'SEASON': u'2015',
#    u'VISITOR_TEAM_ID': 1610612745,
#    u'WH_STATUS': 1},
#   {u'GAMECODE': u'20160129/MIAMIL',
#    u'GAME_DATE_EST': u'2016-01-29T00:00:00',
#    u'GAME_ID': u'0021500703',
#    u'GAME_SEQUENCE': 5,
#    u'GAME_STATUS_ID': 3,
#    u'GAME_STATUS_TEXT': u'Final',
#    u'HOME_TEAM_ID': 1610612749,
#    u'LIVE_PC_TIME': u'     ',
#    u'LIVE_PERIOD': 4,
#    u'LIVE_PERIOD_TIME_BCAST': u'Q4       - ',
#    u'NATL_TV_BROADCASTER_ABBREVIATION': None,
#    u'SEASON': u'2015',
#    u'VISITOR_TEAM_ID': 1610612748,
#    u'WH_STATUS': 1},
#   {u'GAMECODE': u'20160129/LALLAC',
#    u'GAME_DATE_EST': u'2016-01-29T00:00:00',
#    u'GAME_ID': u'0021500706',
#    u'GAME_SEQUENCE': 9,
#    u'GAME_STATUS_ID': 3,
#    u'GAME_STATUS_TEXT': u'Final',
#    u'HOME_TEAM_ID': 1610612746,
#    u'LIVE_PC_TIME': u'     ',
#    u'LIVE_PERIOD': 4,
#    u'LIVE_PERIOD_TIME_BCAST': u'Q4       - NBA TV',
#    u'NATL_TV_BROADCASTER_ABBREVIATION': u'NBA TV',
#    u'SEASON': u'2015',
#    u'VISITOR_TEAM_ID': 1610612747,
#    u'WH_STATUS': 1},
#   {u'GAMECODE': u'20160129/ORLBOS',
#    u'GAME_DATE_EST': u'2016-01-29T00:00:00',
#    u'GAME_ID': u'0021500698',
#    u'GAME_SEQUENCE': 1,
#    u'GAME_STATUS_ID': 3,
#    u'GAME_STATUS_TEXT': u'Final',
#    u'HOME_TEAM_ID': 1610612738,
#    u'LIVE_PC_TIME': u'     ',
#    u'LIVE_PERIOD': 4,
#    u'LIVE_PERIOD_TIME_BCAST': u'Q4       - ',
#    u'NATL_TV_BROADCASTER_ABBREVIATION': None,
#    u'SEASON': u'2015',
#    u'VISITOR_TEAM_ID': 1610612753,
#    u'WH_STATUS': 1},
#   {u'GAMECODE': u'20160129/CLEDET',
#    u'GAME_DATE_EST': u'2016-01-29T00:00:00',
#    u'GAME_ID': u'0021500699',
#    u'GAME_SEQUENCE': 2,
#    u'GAME_STATUS_ID': 3,
#    u'GAME_STATUS_TEXT': u'Final',
#    u'HOME_TEAM_ID': 1610612765,
#    u'LIVE_PC_TIME': u'     ',
#    u'LIVE_PERIOD': 4,
#    u'LIVE_PERIOD_TIME_BCAST': u'Q4       - ',
#    u'NATL_TV_BROADCASTER_ABBREVIATION': None,
#    u'SEASON': u'2015',
#    u'VISITOR_TEAM_ID': 1610612739,
#    u'WH_STATUS': 1}],
#  'game_linescores': [{u'ast': 17,
#    u'fg3_pct': 0.35,
#    u'fg_pct': 0.405,
#    u'ft_pct': 0.793,
#    u'game_date_est': u'2016-01-29T00:00:00',
#    u'game_id': u'0021500698',
#    u'pts': 94,
#    u'pts_ot1': 0,
#    u'pts_ot10': 0,
#    u'pts_ot2': 0,
#    u'pts_ot3': 0,
#    u'pts_ot4': 0,
#    u'pts_ot5': 0,
#    u'pts_ot6': 0,
#    u'pts_ot7': 0,
#    u'pts_ot8': 0,
#    u'pts_ot9': 0,
#    u'pts_qtr1': 22,
#    u'pts_qtr2': 28,
#    u'pts_qtr3': 27,
#    u'pts_qtr4': 17,
#    u'reb': 41,
#    u'team_abbreviation': u'ORL',
#    u'team_city_name': u'Orlando',
#    'team_game_id': '1610612753:0021500698',
#    u'team_id': 1610612753,
#    'team_losses': u'25',
#    'team_wins': u'20',
#    u'team_wins_losses': u'20-25',
#    u'tov': 16},
#   {u'ast': 28,
#    u'fg3_pct': 0.417,
#    u'fg_pct': 0.5,
#    u'ft_pct': 0.81,
#    u'game_date_est': u'2016-01-29T00:00:00',
#    u'game_id': u'0021500698',
#    u'pts': 113,
#    u'pts_ot1': 0,
#    u'pts_ot10': 0,
#    u'pts_ot2': 0,
#    u'pts_ot3': 0,
#    u'pts_ot4': 0,
#    u'pts_ot5': 0,
#    u'pts_ot6': 0,
#    u'pts_ot7': 0,
#    u'pts_ot8': 0,
#    u'pts_ot9': 0,
#    u'pts_qtr1': 26,
#    u'pts_qtr2': 32,
#    u'pts_qtr3': 28,
#    u'pts_qtr4': 27,
#    u'reb': 46,
#    u'team_abbreviation': u'BOS',
#    u'team_city_name': u'Boston',
#    'team_game_id': '1610612738:0021500698',
#    u'team_id': 1610612738,
#    'team_losses': u'21',
#    'team_wins': u'27',
#    u'team_wins_losses': u'27-21',
#    u'tov': 12},
#   {u'ast': 20,
#    u'fg3_pct': 0.391,
#    u'fg_pct': 0.47,
#    u'ft_pct': 0.931,
#    u'game_date_est': u'2016-01-29T00:00:00',
#    u'game_id': u'0021500699',
#    u'pts': 114,
#    u'pts_ot1': 0,
#    u'pts_ot10': 0,
#    u'pts_ot2': 0,
#    u'pts_ot3': 0,
#    u'pts_ot4': 0,
#    u'pts_ot5': 0,
#    u'pts_ot6': 0,
#    u'pts_ot7': 0,
#    u'pts_ot8': 0,
#    u'pts_ot9': 0,
#    u'pts_qtr1': 33,
#    u'pts_qtr2': 33,
#    u'pts_qtr3': 30,
#    u'pts_qtr4': 18,
#    u'reb': 47,
#    u'team_abbreviation': u'CLE',
#    u'team_city_name': u'Cleveland',
#    'team_game_id': '1610612739:0021500699',
#    u'team_id': 1610612739,
#    'team_losses': u'12',
#    'team_wins': u'33',
#    u'team_wins_losses': u'33-12',
#    u'tov': 7},
#   {u'ast': 20,
#    u'fg3_pct': 0.304,
#    u'fg_pct': 0.476,
#    u'ft_pct': 0.731,
#    u'game_date_est': u'2016-01-29T00:00:00',
#    u'game_id': u'0021500699',
#    u'pts': 106,
#    u'pts_ot1': 0,
#    u'pts_ot10': 0,
#    u'pts_ot2': 0,
#    u'pts_ot3': 0,
#    u'pts_ot4': 0,
#    u'pts_ot5': 0,
#    u'pts_ot6': 0,
#    u'pts_ot7': 0,
#    u'pts_ot8': 0,
#    u'pts_ot9': 0,
#    u'pts_qtr1': 27,
#    u'pts_qtr2': 31,
#    u'pts_qtr3': 20,
#    u'pts_qtr4': 28,
#    u'reb': 39,
#    u'team_abbreviation': u'DET',
#    u'team_city_name': u'Detroit',
#    'team_game_id': '1610612765:0021500699',
#    u'team_id': 1610612765,
#    'team_losses': u'22',
#    'team_wins': u'25',
#    u'team_wins_losses': u'25-22',
#    u'tov': 9},
#   {u'ast': 20,
#    u'fg3_pct': 0.269,
#    u'fg_pct': 0.412,
#    u'ft_pct': 0.583,
#    u'game_date_est': u'2016-01-29T00:00:00',
#    u'game_id': u'0021500700',
#    u'pts': 84,
#    u'pts_ot1': 0,
#    u'pts_ot10': 0,
#    u'pts_ot2': 0,
#    u'pts_ot3': 0,
#    u'pts_ot4': 0,
#    u'pts_ot5': 0,
#    u'pts_ot6': 0,
#    u'pts_ot7': 0,
#    u'pts_ot8': 0,
#    u'pts_ot9': 0,
#    u'pts_qtr1': 16,
#    u'pts_qtr2': 24,
#    u'pts_qtr3': 21,
#    u'pts_qtr4': 23,
#    u'reb': 47,
#    u'team_abbreviation': u'PHX',
#    u'team_city_name': u'Phoenix',
#    'team_game_id': '1610612756:0021500700',
#    u'team_id': 1610612756,
#    'team_losses': u'34',
#    'team_wins': u'14',
#    u'team_wins_losses': u'14-34',
#    u'tov': 16},
#   {u'ast': 24,
#    u'fg3_pct': 0.35,
#    u'fg_pct': 0.429,
#    u'ft_pct': 0.885,
#    u'game_date_est': u'2016-01-29T00:00:00',
#    u'game_id': u'0021500700',
#    u'pts': 102,
#    u'pts_ot1': 0,
#    u'pts_ot10': 0,
#    u'pts_ot2': 0,
#    u'pts_ot3': 0,
#    u'pts_ot4': 0,
#    u'pts_ot5': 0,
#    u'pts_ot6': 0,
#    u'pts_ot7': 0,
#    u'pts_ot8': 0,
#    u'pts_ot9': 0,
#    u'pts_qtr1': 26,
#    u'pts_qtr2': 32,
#    u'pts_qtr3': 27,
#    u'pts_qtr4': 17,
#    u'reb': 49,
#    u'team_abbreviation': u'NYK',
#    u'team_city_name': u'New York',
#    'team_game_id': '1610612752:0021500700',
#    u'team_id': 1610612752,
#    'team_losses': u'26',
#    'team_wins': u'23',
#    u'team_wins_losses': u'23-26',
#    u'tov': 8},
#   {u'ast': 23,
#    u'fg3_pct': 0.231,
#    u'fg_pct': 0.379,
#    u'ft_pct': 0.628,
#    u'game_date_est': u'2016-01-29T00:00:00',
#    u'game_id': u'0021500701',
#    u'pts': 108,
#    u'pts_ot1': 0,
#    u'pts_ot10': 0,
#    u'pts_ot2': 0,
#    u'pts_ot3': 0,
#    u'pts_ot4': 0,
#    u'pts_ot5': 0,
#    u'pts_ot6': 0,
#    u'pts_ot7': 0,
#    u'pts_ot8': 0,
#    u'pts_ot9': 0,
#    u'pts_qtr1': 29,
#    u'pts_qtr2': 29,
#    u'pts_qtr3': 25,
#    u'pts_qtr4': 25,
#    u'reb': 40,
#    u'team_abbreviation': u'HOU',
#    u'team_city_name': u'Houston',
#    'team_game_id': '1610612745:0021500701',
#    u'team_id': 1610612745,
#    'team_losses': u'24',
#    'team_wins': u'25',
#    u'team_wins_losses': u'25-24',
#    u'tov': 10},
#   {u'ast': 23,
#    u'fg3_pct': 0.421,
#    u'fg_pct': 0.477,
#    u'ft_pct': 0.867,
#    u'game_date_est': u'2016-01-29T00:00:00',
#    u'game_id': u'0021500701',
#    u'pts': 116,
#    u'pts_ot1': 0,
#    u'pts_ot10': 0,
#    u'pts_ot2': 0,
#    u'pts_ot3': 0,
#    u'pts_ot4': 0,
#    u'pts_ot5': 0,
#    u'pts_ot6': 0,
#    u'pts_ot7': 0,
#    u'pts_ot8': 0,
#    u'pts_ot9': 0,
#    u'pts_qtr1': 22,
#    u'pts_qtr2': 33,
#    u'pts_qtr3': 34,
#    u'pts_qtr4': 27,
#    u'reb': 57,
#    u'team_abbreviation': u'OKC',
#    u'team_city_name': u'Oklahoma City',
#    'team_game_id': '1610612760:0021500701',
#    u'team_id': 1610612760,
#    'team_losses': u'13',
#    'team_wins': u'36',
#    u'team_wins_losses': u'36-13',
#    u'tov': 18},
#   {u'ast': 27,
#    u'fg3_pct': 0.389,
#    u'fg_pct': 0.5,
#    u'ft_pct': 0.813,
#    u'game_date_est': u'2016-01-29T00:00:00',
#    u'game_id': u'0021500703',
#    u'pts': 107,
#    u'pts_ot1': 0,
#    u'pts_ot10': 0,
#    u'pts_ot2': 0,
#    u'pts_ot3': 0,
#    u'pts_ot4': 0,
#    u'pts_ot5': 0,
#    u'pts_ot6': 0,
#    u'pts_ot7': 0,
#    u'pts_ot8': 0,
#    u'pts_ot9': 0,
#    u'pts_qtr1': 33,
#    u'pts_qtr2': 22,
#    u'pts_qtr3': 26,
#    u'pts_qtr4': 26,
#    u'reb': 34,
#    u'team_abbreviation': u'MIA',
#    u'team_city_name': u'Miami',
#    'team_game_id': '1610612748:0021500703',
#    u'team_id': 1610612748,
#    'team_losses': u'21',
#    'team_wins': u'26',
#    u'team_wins_losses': u'26-21',
#    u'tov': 17},
#   {u'ast': 18,
#    u'fg3_pct': 0.167,
#    u'fg_pct': 0.475,
#    u'ft_pct': 0.893,
#    u'game_date_est': u'2016-01-29T00:00:00',
#    u'game_id': u'0021500703',
#    u'pts': 103,
#    u'pts_ot1': 0,
#    u'pts_ot10': 0,
#    u'pts_ot2': 0,
#    u'pts_ot3': 0,
#    u'pts_ot4': 0,
#    u'pts_ot5': 0,
#    u'pts_ot6': 0,
#    u'pts_ot7': 0,
#    u'pts_ot8': 0,
#    u'pts_ot9': 0,
#    u'pts_qtr1': 28,
#    u'pts_qtr2': 20,
#    u'pts_qtr3': 35,
#    u'pts_qtr4': 20,
#    u'reb': 40,
#    u'team_abbreviation': u'MIL',
#    u'team_city_name': u'Milwaukee',
#    'team_game_id': '1610612749:0021500703',
#    u'team_id': 1610612749,
#    'team_losses': u'29',
#    'team_wins': u'20',
#    u'team_wins_losses': u'20-29',
#    u'tov': 19},
#   {u'ast': 13,
#    u'fg3_pct': 0.2,
#    u'fg_pct': 0.359,
#    u'ft_pct': 0.826,
#    u'game_date_est': u'2016-01-29T00:00:00',
#    u'game_id': u'0021500702',
#    u'pts': 79,
#    u'pts_ot1': 0,
#    u'pts_ot10': 0,
#    u'pts_ot2': 0,
#    u'pts_ot3': 0,
#    u'pts_ot4': 0,
#    u'pts_ot5': 0,
#    u'pts_ot6': 0,
#    u'pts_ot7': 0,
#    u'pts_ot8': 0,
#    u'pts_ot9': 0,
#    u'pts_qtr1': 18,
#    u'pts_qtr2': 21,
#    u'pts_qtr3': 16,
#    u'pts_qtr4': 24,
#    u'reb': 44,
#    u'team_abbreviation': u'BKN',
#    u'team_city_name': u'Brooklyn',
#    'team_game_id': '1610612751:0021500702',
#    u'team_id': 1610612751,
#    'team_losses': u'35',
#    'team_wins': u'12',
#    u'team_wins_losses': u'12-35',
#    u'tov': 10},
#   {u'ast': 22,
#    u'fg3_pct': 0.381,
#    u'fg_pct': 0.463,
#    u'ft_pct': 0.6,
#    u'game_date_est': u'2016-01-29T00:00:00',
#    u'game_id': u'0021500702',
#    u'pts': 91,
#    u'pts_ot1': 0,
#    u'pts_ot10': 0,
#    u'pts_ot2': 0,
#    u'pts_ot3': 0,
#    u'pts_ot4': 0,
#    u'pts_ot5': 0,
#    u'pts_ot6': 0,
#    u'pts_ot7': 0,
#    u'pts_ot8': 0,
#    u'pts_ot9': 0,
#    u'pts_qtr1': 25,
#    u'pts_qtr2': 26,
#    u'pts_qtr3': 20,
#    u'pts_qtr4': 20,
#    u'reb': 49,
#    u'team_abbreviation': u'DAL',
#    u'team_city_name': u'Dallas',
#    'team_game_id': '1610612742:0021500702',
#    u'team_id': 1610612742,
#    'team_losses': u'22',
#    'team_wins': u'27',
#    u'team_wins_losses': u'27-22',
#    u'tov': 12},
#   {u'ast': 17,
#    u'fg3_pct': 0.2,
#    u'fg_pct': 0.467,
#    u'ft_pct': 0.692,
#    u'game_date_est': u'2016-01-29T00:00:00',
#    u'game_id': u'0021500704',
#    u'pts': 90,
#    u'pts_ot1': 0,
#    u'pts_ot10': 0,
#    u'pts_ot2': 0,
#    u'pts_ot3': 0,
#    u'pts_ot4': 0,
#    u'pts_ot5': 0,
#    u'pts_ot6': 0,
#    u'pts_ot7': 0,
#    u'pts_ot8': 0,
#    u'pts_ot9': 0,
#    u'pts_qtr1': 29,
#    u'pts_qtr2': 26,
#    u'pts_qtr3': 14,
#    u'pts_qtr4': 21,
#    u'reb': 38,
#    u'team_abbreviation': u'MIN',
#    u'team_city_name': u'Minnesota',
#    'team_game_id': '1610612750:0021500704',
#    u'team_id': 1610612750,
#    'team_losses': u'34',
#    'team_wins': u'14',
#    u'team_wins_losses': u'14-34',
#    u'tov': 14},
#   {u'ast': 24,
#    u'fg3_pct': 0.4,
#    u'fg_pct': 0.526,
#    u'ft_pct': 0.813,
#    u'game_date_est': u'2016-01-29T00:00:00',
#    u'game_id': u'0021500704',
#    u'pts': 103,
#    u'pts_ot1': 0,
#    u'pts_ot10': 0,
#    u'pts_ot2': 0,
#    u'pts_ot3': 0,
#    u'pts_ot4': 0,
#    u'pts_ot5': 0,
#    u'pts_ot6': 0,
#    u'pts_ot7': 0,
#    u'pts_ot8': 0,
#    u'pts_ot9': 0,
#    u'pts_qtr1': 27,
#    u'pts_qtr2': 29,
#    u'pts_qtr3': 26,
#    u'pts_qtr4': 21,
#    u'reb': 40,
#    u'team_abbreviation': u'UTA',
#    u'team_city_name': u'Utah',
#    'team_game_id': '1610612762:0021500704',
#    u'team_id': 1610612762,
#    'team_losses': u'25',
#    'team_wins': u'21',
#    u'team_wins_losses': u'21-25',
#    u'tov': 13},
#   {u'ast': 17,
#    u'fg3_pct': 0.345,
#    u'fg_pct': 0.388,
#    u'ft_pct': 0.679,
#    u'game_date_est': u'2016-01-29T00:00:00',
#    u'game_id': u'0021500705',
#    u'pts': 91,
#    u'pts_ot1': 0,
#    u'pts_ot10': 0,
#    u'pts_ot2': 0,
#    u'pts_ot3': 0,
#    u'pts_ot4': 0,
#    u'pts_ot5': 0,
#    u'pts_ot6': 0,
#    u'pts_ot7': 0,
#    u'pts_ot8': 0,
#    u'pts_ot9': 0,
#    u'pts_qtr1': 25,
#    u'pts_qtr2': 20,
#    u'pts_qtr3': 24,
#    u'pts_qtr4': 22,
#    u'reb': 47,
#    u'team_abbreviation': u'CHA',
#    u'team_city_name': u'Charlotte',
#    'team_game_id': '1610612766:0021500705',
#    u'team_id': 1610612766,
#    'team_losses': u'25',
#    'team_wins': u'22',
#    u'team_wins_losses': u'22-25',
#    u'tov': 16},
#   {u'ast': 24,
#    u'fg3_pct': 0.35,
#    u'fg_pct': 0.489,
#    u'ft_pct': 0.75,
#    u'game_date_est': u'2016-01-29T00:00:00',
#    u'game_id': u'0021500705',
#    u'pts': 109,
#    u'pts_ot1': 0,
#    u'pts_ot10': 0,
#    u'pts_ot2': 0,
#    u'pts_ot3': 0,
#    u'pts_ot4': 0,
#    u'pts_ot5': 0,
#    u'pts_ot6': 0,
#    u'pts_ot7': 0,
#    u'pts_ot8': 0,
#    u'pts_ot9': 0,
#    u'pts_qtr1': 21,
#    u'pts_qtr2': 29,
#    u'pts_qtr3': 33,
#    u'pts_qtr4': 26,
#    u'reb': 51,
#    u'team_abbreviation': u'POR',
#    u'team_city_name': u'Portland',
#    'team_game_id': '1610612757:0021500705',
#    u'team_id': 1610612757,
#    'team_losses': u'26',
#    'team_wins': u'22',
#    u'team_wins_losses': u'22-26',
#    u'tov': 11},
#   {u'ast': 19,
#    u'fg3_pct': 0.385,
#    u'fg_pct': 0.436,
#    u'ft_pct': 0.8,
#    u'game_date_est': u'2016-01-29T00:00:00',
#    u'game_id': u'0021500706',
#    u'pts': 93,
#    u'pts_ot1': 0,
#    u'pts_ot10': 0,
#    u'pts_ot2': 0,
#    u'pts_ot3': 0,
#    u'pts_ot4': 0,
#    u'pts_ot5': 0,
#    u'pts_ot6': 0,
#    u'pts_ot7': 0,
#    u'pts_ot8': 0,
#    u'pts_ot9': 0,
#    u'pts_qtr1': 29,
#    u'pts_qtr2': 20,
#    u'pts_qtr3': 22,
#    u'pts_qtr4': 22,
#    u'reb': 48,
#    u'team_abbreviation': u'LAL',
#    u'team_city_name': u'Los Angeles',
#    'team_game_id': '1610612747:0021500706',
#    u'team_id': 1610612747,
#    'team_losses': u'40',
#    'team_wins': u'9',
#    u'team_wins_losses': u'9-40',
#    u'tov': 17},
#   {u'ast': 20,
#    u'fg3_pct': 0.308,
#    u'fg_pct': 0.494,
#    u'ft_pct': 0.708,
#    u'game_date_est': u'2016-01-29T00:00:00',
#    u'game_id': u'0021500706',
#    u'pts': 105,
#    u'pts_ot1': 0,
#    u'pts_ot10': 0,
#    u'pts_ot2': 0,
#    u'pts_ot3': 0,
#    u'pts_ot4': 0,
#    u'pts_ot5': 0,
#    u'pts_ot6': 0,
#    u'pts_ot7': 0,
#    u'pts_ot8': 0,
#    u'pts_ot9': 0,
#    u'pts_qtr1': 28,
#    u'pts_qtr2': 26,
#    u'pts_qtr3': 24,
#    u'pts_qtr4': 27,
#    u'reb': 38,
#    u'team_abbreviation': u'LAC',
#    u'team_city_name': u'Los Angeles',
#    'team_game_id': '1610612746:0021500706',
#    u'team_id': 1610612746,
#    'team_losses': u'16',
#    'team_wins': u'31',
#    u'team_wins_losses': u'31-16',
#    u'tov': 8}],
#  'standings': [{u'CONFERENCE': u'East',
#    u'G': 45,
#    u'HOME_RECORD': u'18-3',
#    u'L': 12,
#    u'LEAGUE_ID': u'00',
#    u'ROAD_RECORD': u'15-9',
#    u'SEASON_ID': u'22015',
#    u'STANDINGSDATE': u'01/29/2016',
#    u'TEAM': u'Cleveland',
#    u'TEAM_ID': 1610612739,
#    u'W': 33,
#    u'W_PCT': 0.733},
#   {u'CONFERENCE': u'East',
#    u'G': 46,
#    u'HOME_RECORD': u'17-6',
#    u'L': 15,
#    u'LEAGUE_ID': u'00',
#    u'ROAD_RECORD': u'14-9',
#    u'SEASON_ID': u'22015',
#    u'STANDINGSDATE': u'01/29/2016',
#    u'TEAM': u'Toronto',
#    u'TEAM_ID': 1610612761,
#    u'W': 31,
#    u'W_PCT': 0.674},
#   {u'CONFERENCE': u'East',
#    u'G': 45,
#    u'HOME_RECORD': u'16-9',
#    u'L': 19,
#    u'LEAGUE_ID': u'00',
#    u'ROAD_RECORD': u'10-10',
#    u'SEASON_ID': u'22015',
#    u'STANDINGSDATE': u'01/29/2016',
#    u'TEAM': u'Chicago',
#    u'TEAM_ID': 1610612741,
#    u'W': 26,
#    u'W_PCT': 0.578},
#   {u'CONFERENCE': u'East',
#    u'G': 48,
#    u'HOME_RECORD': u'15-8',
#    u'L': 21,
#    u'LEAGUE_ID': u'00',
#    u'ROAD_RECORD': u'12-13',
#    u'SEASON_ID': u'22015',
#    u'STANDINGSDATE': u'01/29/2016',
#    u'TEAM': u'Atlanta',
#    u'TEAM_ID': 1610612737,
#    u'W': 27,
#    u'W_PCT': 0.563},
#   {u'CONFERENCE': u'East',
#    u'G': 48,
#    u'HOME_RECORD': u'14-10',
#    u'L': 21,
#    u'LEAGUE_ID': u'00',
#    u'ROAD_RECORD': u'13-11',
#    u'SEASON_ID': u'22015',
#    u'STANDINGSDATE': u'01/29/2016',
#    u'TEAM': u'Boston',
#    u'TEAM_ID': 1610612738,
#    u'W': 27,
#    u'W_PCT': 0.563},
#   {u'CONFERENCE': u'East',
#    u'G': 47,
#    u'HOME_RECORD': u'15-9',
#    u'L': 21,
#    u'LEAGUE_ID': u'00',
#    u'ROAD_RECORD': u'11-12',
#    u'SEASON_ID': u'22015',
#    u'STANDINGSDATE': u'01/29/2016',
#    u'TEAM': u'Miami',
#    u'TEAM_ID': 1610612748,
#    u'W': 26,
#    u'W_PCT': 0.553},
#   {u'CONFERENCE': u'East',
#    u'G': 47,
#    u'HOME_RECORD': u'15-8',
#    u'L': 22,
#    u'LEAGUE_ID': u'00',
#    u'ROAD_RECORD': u'10-14',
#    u'SEASON_ID': u'22015',
#    u'STANDINGSDATE': u'01/29/2016',
#    u'TEAM': u'Detroit',
#    u'TEAM_ID': 1610612765,
#    u'W': 25,
#    u'W_PCT': 0.532},
#   {u'CONFERENCE': u'East',
#    u'G': 46,
#    u'HOME_RECORD': u'14-7',
#    u'L': 22,
#    u'LEAGUE_ID': u'00',
#    u'ROAD_RECORD': u'10-15',
#    u'SEASON_ID': u'22015',
#    u'STANDINGSDATE': u'01/29/2016',
#    u'TEAM': u'Indiana',
#    u'TEAM_ID': 1610612754,
#    u'W': 24,
#    u'W_PCT': 0.522},
#   {u'CONFERENCE': u'East',
#    u'G': 49,
#    u'HOME_RECORD': u'14-10',
#    u'L': 26,
#    u'LEAGUE_ID': u'00',
#    u'ROAD_RECORD': u'9-16',
#    u'SEASON_ID': u'22015',
#    u'STANDINGSDATE': u'01/29/2016',
#    u'TEAM': u'New York',
#    u'TEAM_ID': 1610612752,
#    u'W': 23,
#    u'W_PCT': 0.469},
#   {u'CONFERENCE': u'East',
#    u'G': 47,
#    u'HOME_RECORD': u'16-8',
#    u'L': 25,
#    u'LEAGUE_ID': u'00',
#    u'ROAD_RECORD': u'6-17',
#    u'SEASON_ID': u'22015',
#    u'STANDINGSDATE': u'01/29/2016',
#    u'TEAM': u'Charlotte',
#    u'TEAM_ID': 1610612766,
#    u'W': 22,
#    u'W_PCT': 0.468},
#   {u'CONFERENCE': u'East',
#    u'G': 44,
#    u'HOME_RECORD': u'10-15',
#    u'L': 24,
#    u'LEAGUE_ID': u'00',
#    u'ROAD_RECORD': u'10-9',
#    u'SEASON_ID': u'22015',
#    u'STANDINGSDATE': u'01/29/2016',
#    u'TEAM': u'Washington',
#    u'TEAM_ID': 1610612764,
#    u'W': 20,
#    u'W_PCT': 0.455},
#   {u'CONFERENCE': u'East',
#    u'G': 45,
#    u'HOME_RECORD': u'12-11',
#    u'L': 25,
#    u'LEAGUE_ID': u'00',
#    u'ROAD_RECORD': u'8-14',
#    u'SEASON_ID': u'22015',
#    u'STANDINGSDATE': u'01/29/2016',
#    u'TEAM': u'Orlando',
#    u'TEAM_ID': 1610612753,
#    u'W': 20,
#    u'W_PCT': 0.444},
#   {u'CONFERENCE': u'East',
#    u'G': 49,
#    u'HOME_RECORD': u'13-8',
#    u'L': 29,
#    u'LEAGUE_ID': u'00',
#    u'ROAD_RECORD': u'7-21',
#    u'SEASON_ID': u'22015',
#    u'STANDINGSDATE': u'01/29/2016',
#    u'TEAM': u'Milwaukee',
#    u'TEAM_ID': 1610612749,
#    u'W': 20,
#    u'W_PCT': 0.408},
#   {u'CONFERENCE': u'East',
#    u'G': 47,
#    u'HOME_RECORD': u'8-18',
#    u'L': 35,
#    u'LEAGUE_ID': u'00',
#    u'ROAD_RECORD': u'4-17',
#    u'SEASON_ID': u'22015',
#    u'STANDINGSDATE': u'01/29/2016',
#    u'TEAM': u'Brooklyn',
#    u'TEAM_ID': 1610612751,
#    u'W': 12,
#    u'W_PCT': 0.255},
#   {u'CONFERENCE': u'East',
#    u'G': 47,
#    u'HOME_RECORD': u'4-17',
#    u'L': 40,
#    u'LEAGUE_ID': u'00',
#    u'ROAD_RECORD': u'3-23',
#    u'SEASON_ID': u'22015',
#    u'STANDINGSDATE': u'01/29/2016',
#    u'TEAM': u'Philadelphia',
#    u'TEAM_ID': 1610612755,
#    u'W': 7,
#    u'W_PCT': 0.149},
#   {u'CONFERENCE': u'West',
#    u'G': 46,
#    u'HOME_RECORD': u'22-0',
#    u'L': 4,
#    u'LEAGUE_ID': u'00',
#    u'ROAD_RECORD': u'20-4',
#    u'SEASON_ID': u'22015',
#    u'STANDINGSDATE': u'01/29/2016',
#    u'TEAM': u'Golden State',
#    u'TEAM_ID': 1610612744,
#    u'W': 42,
#    u'W_PCT': 0.913},
#   {u'CONFERENCE': u'West',
#    u'G': 46,
#    u'HOME_RECORD': u'25-0',
#    u'L': 7,
#    u'LEAGUE_ID': u'00',
#    u'ROAD_RECORD': u'14-7',
#    u'SEASON_ID': u'22015',
#    u'STANDINGSDATE': u'01/29/2016',
#    u'TEAM': u'San Antonio',
#    u'TEAM_ID': 1610612759,
#    u'W': 39,
#    u'W_PCT': 0.848},
#   {u'CONFERENCE': u'West',
#    u'G': 49,
#    u'HOME_RECORD': u'22-5',
#    u'L': 13,
#    u'LEAGUE_ID': u'00',
#    u'ROAD_RECORD': u'14-8',
#    u'SEASON_ID': u'22015',
#    u'STANDINGSDATE': u'01/29/2016',
#    u'TEAM': u'Oklahoma City',
#    u'TEAM_ID': 1610612760,
#    u'W': 36,
#    u'W_PCT': 0.735},
#   {u'CONFERENCE': u'West',
#    u'G': 47,
#    u'HOME_RECORD': u'16-7',
#    u'L': 16,
#    u'LEAGUE_ID': u'00',
#    u'ROAD_RECORD': u'15-9',
#    u'SEASON_ID': u'22015',
#    u'STANDINGSDATE': u'01/29/2016',
#    u'TEAM': u'L.A. Clippers',
#    u'TEAM_ID': 1610612746,
#    u'W': 31,
#    u'W_PCT': 0.66},
#   {u'CONFERENCE': u'West',
#    u'G': 47,
#    u'HOME_RECORD': u'18-7',
#    u'L': 20,
#    u'LEAGUE_ID': u'00',
#    u'ROAD_RECORD': u'9-13',
#    u'SEASON_ID': u'22015',
#    u'STANDINGSDATE': u'01/29/2016',
#    u'TEAM': u'Memphis',
#    u'TEAM_ID': 1610612763,
#    u'W': 27,
#    u'W_PCT': 0.574},
#   {u'CONFERENCE': u'West',
#    u'G': 49,
#    u'HOME_RECORD': u'14-8',
#    u'L': 22,
#    u'LEAGUE_ID': u'00',
#    u'ROAD_RECORD': u'13-14',
#    u'SEASON_ID': u'22015',
#    u'STANDINGSDATE': u'01/29/2016',
#    u'TEAM': u'Dallas',
#    u'TEAM_ID': 1610612742,
#    u'W': 27,
#    u'W_PCT': 0.551},
#   {u'CONFERENCE': u'West',
#    u'G': 49,
#    u'HOME_RECORD': u'15-11',
#    u'L': 24,
#    u'LEAGUE_ID': u'00',
#    u'ROAD_RECORD': u'10-13',
#    u'SEASON_ID': u'22015',
#    u'STANDINGSDATE': u'01/29/2016',
#    u'TEAM': u'Houston',
#    u'TEAM_ID': 1610612745,
#    u'W': 25,
#    u'W_PCT': 0.51},
#   {u'CONFERENCE': u'West',
#    u'G': 48,
#    u'HOME_RECORD': u'13-10',
#    u'L': 26,
#    u'LEAGUE_ID': u'00',
#    u'ROAD_RECORD': u'9-16',
#    u'SEASON_ID': u'22015',
#    u'STANDINGSDATE': u'01/29/2016',
#    u'TEAM': u'Portland',
#    u'TEAM_ID': 1610612757,
#    u'W': 22,
#    u'W_PCT': 0.458},
#   {u'CONFERENCE': u'West',
#    u'G': 46,
#    u'HOME_RECORD': u'14-10',
#    u'L': 25,
#    u'LEAGUE_ID': u'00',
#    u'ROAD_RECORD': u'7-15',
#    u'SEASON_ID': u'22015',
#    u'STANDINGSDATE': u'01/29/2016',
#    u'TEAM': u'Utah',
#    u'TEAM_ID': 1610612762,
#    u'W': 21,
#    u'W_PCT': 0.457},
#   {u'CONFERENCE': u'West',
#    u'G': 46,
#    u'HOME_RECORD': u'12-12',
#    u'L': 26,
#    u'LEAGUE_ID': u'00',
#    u'ROAD_RECORD': u'8-14',
#    u'SEASON_ID': u'22015',
#    u'STANDINGSDATE': u'01/29/2016',
#    u'TEAM': u'Sacramento',
#    u'TEAM_ID': 1610612758,
#    u'W': 20,
#    u'W_PCT': 0.435},
#   {u'CONFERENCE': u'West',
#    u'G': 47,
#    u'HOME_RECORD': u'9-15',
#    u'L': 29,
#    u'LEAGUE_ID': u'00',
#    u'ROAD_RECORD': u'9-14',
#    u'SEASON_ID': u'22015',
#    u'STANDINGSDATE': u'01/29/2016',
#    u'TEAM': u'Denver',
#    u'TEAM_ID': 1610612743,
#    u'W': 18,
#    u'W_PCT': 0.383},
#   {u'CONFERENCE': u'West',
#    u'G': 45,
#    u'HOME_RECORD': u'12-10',
#    u'L': 28,
#    u'LEAGUE_ID': u'00',
#    u'ROAD_RECORD': u'5-18',
#    u'SEASON_ID': u'22015',
#    u'STANDINGSDATE': u'01/29/2016',
#    u'TEAM': u'New Orleans',
#    u'TEAM_ID': 1610612740,
#    u'W': 17,
#    u'W_PCT': 0.378},
#   {u'CONFERENCE': u'West',
#    u'G': 48,
#    u'HOME_RECORD': u'7-18',
#    u'L': 34,
#    u'LEAGUE_ID': u'00',
#    u'ROAD_RECORD': u'7-16',
#    u'SEASON_ID': u'22015',
#    u'STANDINGSDATE': u'01/29/2016',
#    u'TEAM': u'Minnesota',
#    u'TEAM_ID': 1610612750,
#    u'W': 14,
#    u'W_PCT': 0.292},
#   {u'CONFERENCE': u'West',
#    u'G': 48,
#    u'HOME_RECORD': u'10-13',
#    u'L': 34,
#    u'LEAGUE_ID': u'00',
#    u'ROAD_RECORD': u'4-21',
#    u'SEASON_ID': u'22015',
#    u'STANDINGSDATE': u'01/29/2016',
#    u'TEAM': u'Phoenix',
#    u'TEAM_ID': 1610612756,
#    u'W': 14,
#    u'W_PCT': 0.292},
#   {u'CONFERENCE': u'West',
#    u'G': 49,
#    u'HOME_RECORD': u'5-17',
#    u'L': 40,
#    u'LEAGUE_ID': u'00',
#    u'ROAD_RECORD': u'4-23',
#    u'SEASON_ID': u'22015',
#    u'STANDINGSDATE': u'01/29/2016',
#    u'TEAM': u'L.A. Lakers',
#    u'TEAM_ID': 1610612747,
#    u'W': 9,
#    u'W_PCT': 0.184}]}

# %% [markdown]
# ## Season_gamelogs (players)
#
# http://stats.nba.com/stats/leaguegamelog?Counter=0&Direction=DESC&LeagueID=00&PlayerOrTeam=P&Season=2015-16&SeasonType=Regular+Season&Sorter=PTS

# %%
player_gamelogs = parser.season_gamelogs(content=scraper.season_gamelogs(season='2015-16', player_or_team='P'), player_or_team='P')

# %%
player_gamelogs
# Out:
# [{u'AST': 4,
#   u'BLK': 2,
#   u'DREB': 11,
#   u'FG3A': 3,
#   u'FG3M': 1,
#   u'FG3_PCT': 0.333,
#   u'FGA': 30,
#   u'FGM': 21,
#   u'FG_PCT': 0.7,
#   u'FTA': 16,
#   u'FTM': 13,
#   u'FT_PCT': 0.813,
#   u'GAME_DATE': u'2016-01-25',
#   u'GAME_ID': u'0021500674',
#   u'MATCHUP': u'SAC vs. CHA',
#   u'MIN': 46,
#   u'OREB': 1,
#   u'PF': 6,
#   u'PLAYER_ID': 202326,
#   u'PLAYER_NAME': u'DeMarcus Cousins',
#   u'PLUS_MINUS': 15,
#   u'PTS': 56,
#   u'REB': 12,
#   u'SEASON_ID': u'22015',
#   u'STL': 1,
#   u'TEAM_ABBREVIATION': u'SAC',
#   u'TEAM_NAME': u'Sacramento Kings',
#   u'TOV': 7,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 6,
#   u'BLK': 0,
#   u'DREB': 6,
#   u'FG3A': 4,
#   u'FG3M': 2,
#   u'FG3_PCT': 0.5,
#   u'FGA': 30,
#   u'FGM': 15,
#   u'FG_PCT': 0.5,
#   u'FTA': 25,
#   u'FTM': 21,
#   u'FT_PCT': 0.84,
#   u'GAME_DATE': u'2016-01-14',
#   u'GAME_ID': u'0021500587',
#   u'MATCHUP': u'CHI @ PHI',
#   u'MIN': 49,
#   u'OREB': 4,
#   u'PF': 4,
#   u'PLAYER_ID': 202710,
#   u'PLAYER_NAME': u'Jimmy Butler',
#   u'PLUS_MINUS': 11,
#   u'PTS': 53,
#   u'REB': 10,
#   u'SEASON_ID': u'22015',
#   u'STL': 3,
#   u'TEAM_ABBREVIATION': u'CHI',
#   u'TEAM_NAME': u'Chicago Bulls',
#   u'TOV': 4,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 9,
#   u'BLK': 0,
#   u'DREB': 4,
#   u'FG3A': 14,
#   u'FG3M': 8,
#   u'FG3_PCT': 0.571,
#   u'FGA': 27,
#   u'FGM': 17,
#   u'FG_PCT': 0.63,
#   u'FTA': 11,
#   u'FTM': 11,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2015-10-31',
#   u'GAME_ID': u'0021500035',
#   u'MATCHUP': u'GSW @ NOP',
#   u'MIN': 36,
#   u'OREB': 0,
#   u'PF': 3,
#   u'PLAYER_ID': 201939,
#   u'PLAYER_NAME': u'Stephen Curry',
#   u'PLUS_MINUS': 16,
#   u'PTS': 53,
#   u'REB': 4,
#   u'SEASON_ID': u'22015',
#   u'STL': 4,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 2,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 8,
#   u'BLK': 0,
#   u'DREB': 8,
#   u'FG3A': 11,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.545,
#   u'FGA': 33,
#   u'FGM': 16,
#   u'FG_PCT': 0.485,
#   u'FTA': 15,
#   u'FTM': 14,
#   u'FT_PCT': 0.933,
#   u'GAME_DATE': u'2016-01-18',
#   u'GAME_ID': u'0021500616',
#   u'MATCHUP': u'CHA vs. UTA',
#   u'MIN': 47,
#   u'OREB': 1,
#   u'PF': 3,
#   u'PLAYER_ID': 202689,
#   u'PLAYER_NAME': u'Kemba Walker',
#   u'PLUS_MINUS': 4,
#   u'PTS': 52,
#   u'REB': 9,
#   u'SEASON_ID': u'22015',
#   u'STL': 2,
#   u'TEAM_ABBREVIATION': u'CHA',
#   u'TEAM_NAME': u'Charlotte Hornets',
#   u'TOV': 3,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 8,
#   u'BLK': 0,
#   u'DREB': 7,
#   u'FG3A': 12,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.5,
#   u'FGA': 28,
#   u'FGM': 14,
#   u'FG_PCT': 0.5,
#   u'FTA': 20,
#   u'FTM': 16,
#   u'FT_PCT': 0.8,
#   u'GAME_DATE': u'2015-11-27',
#   u'GAME_ID': u'0021500232',
#   u'MATCHUP': u'HOU vs. PHI',
#   u'MIN': 40,
#   u'OREB': 2,
#   u'PF': 2,
#   u'PLAYER_ID': 201935,
#   u'PLAYER_NAME': u'James Harden',
#   u'PLUS_MINUS': 13,
#   u'PTS': 50,
#   u'REB': 9,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'HOU',
#   u'TEAM_NAME': u'Houston Rockets',
#   u'TOV': 9,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 2,
#   u'BLK': 0,
#   u'DREB': 11,
#   u'FG3A': 2,
#   u'FG3M': 1,
#   u'FG3_PCT': 0.5,
#   u'FGA': 29,
#   u'FGM': 17,
#   u'FG_PCT': 0.586,
#   u'FTA': 20,
#   u'FTM': 13,
#   u'FT_PCT': 0.65,
#   u'GAME_DATE': u'2016-01-23',
#   u'GAME_ID': u'0021500663',
#   u'MATCHUP': u'SAC vs. IND',
#   u'MIN': 39,
#   u'OREB': 2,
#   u'PF': 4,
#   u'PLAYER_ID': 202326,
#   u'PLAYER_NAME': u'DeMarcus Cousins',
#   u'PLUS_MINUS': 16,
#   u'PTS': 48,
#   u'REB': 13,
#   u'SEASON_ID': u'22015',
#   u'STL': 1,
#   u'TEAM_ABBREVIATION': u'SAC',
#   u'TEAM_NAME': u'Sacramento Kings',
#   u'TOV': 5,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 3,
#   u'BLK': 0,
#   u'DREB': 8,
#   u'FG3A': 11,
#   u'FG3M': 8,
#   u'FG3_PCT': 0.727,
#   u'FGA': 27,
#   u'FGM': 15,
#   u'FG_PCT': 0.556,
#   u'FTA': 13,
#   u'FTM': 10,
#   u'FT_PCT': 0.769,
#   u'GAME_DATE': u'2015-12-05',
#   u'GAME_ID': u'0021500297',
#   u'MATCHUP': u'IND @ UTA',
#   u'MIN': 42,
#   u'OREB': 0,
#   u'PF': 4,
#   u'PLAYER_ID': 202331,
#   u'PLAYER_NAME': u'Paul George',
#   u'PLUS_MINUS': -12,
#   u'PTS': 48,
#   u'REB': 8,
#   u'SEASON_ID': u'22015',
#   u'STL': 3,
#   u'TEAM_ABBREVIATION': u'IND',
#   u'TEAM_NAME': u'Indiana Pacers',
#   u'TOV': 2,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 8,
#   u'BLK': 1,
#   u'DREB': 6,
#   u'FG3A': 5,
#   u'FG3M': 1,
#   u'FG3_PCT': 0.2,
#   u'FGA': 36,
#   u'FGM': 17,
#   u'FG_PCT': 0.472,
#   u'FTA': 16,
#   u'FTM': 13,
#   u'FT_PCT': 0.813,
#   u'GAME_DATE': u'2015-10-30',
#   u'GAME_ID': u'0021500022',
#   u'MATCHUP': u'OKC @ ORL',
#   u'MIN': 48,
#   u'OREB': 5,
#   u'PF': 3,
#   u'PLAYER_ID': 201566,
#   u'PLAYER_NAME': u'Russell Westbrook',
#   u'PLUS_MINUS': 2,
#   u'PTS': 48,
#   u'REB': 11,
#   u'SEASON_ID': u'22015',
#   u'STL': 1,
#   u'TEAM_ABBREVIATION': u'OKC',
#   u'TEAM_NAME': u'Oklahoma City Thunder',
#   u'TOV': 6,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 4,
#   u'BLK': 0,
#   u'DREB': 5,
#   u'FG3A': 13,
#   u'FG3M': 8,
#   u'FG3_PCT': 0.615,
#   u'FGA': 25,
#   u'FGM': 15,
#   u'FG_PCT': 0.6,
#   u'FTA': 8,
#   u'FTM': 8,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2015-11-12',
#   u'GAME_ID': u'0021500125',
#   u'MATCHUP': u'GSW @ MIN',
#   u'MIN': 38,
#   u'OREB': 0,
#   u'PF': 3,
#   u'PLAYER_ID': 201939,
#   u'PLAYER_NAME': u'Stephen Curry',
#   u'PLUS_MINUS': 21,
#   u'PTS': 46,
#   u'REB': 5,
#   u'SEASON_ID': u'22015',
#   u'STL': 2,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 3,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 2,
#   u'BLK': 0,
#   u'DREB': 4,
#   u'FG3A': 10,
#   u'FG3M': 5,
#   u'FG3_PCT': 0.5,
#   u'FGA': 26,
#   u'FGM': 14,
#   u'FG_PCT': 0.538,
#   u'FTA': 14,
#   u'FTM': 13,
#   u'FT_PCT': 0.929,
#   u'GAME_DATE': u'2015-11-07',
#   u'GAME_ID': u'0021500093',
#   u'MATCHUP': u'HOU @ LAC',
#   u'MIN': 40,
#   u'OREB': 0,
#   u'PF': 4,
#   u'PLAYER_ID': 201935,
#   u'PLAYER_NAME': u'James Harden',
#   u'PLUS_MINUS': 6,
#   u'PTS': 46,
#   u'REB': 4,
#   u'SEASON_ID': u'22015',
#   u'STL': 1,
#   u'TEAM_ABBREVIATION': u'HOU',
#   u'TEAM_NAME': u'Houston Rockets',
#   u'TOV': 7,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 1,
#   u'BLK': 2,
#   u'DREB': 5,
#   u'FG3A': 12,
#   u'FG3M': 7,
#   u'FG3_PCT': 0.583,
#   u'FGA': 20,
#   u'FGM': 14,
#   u'FG_PCT': 0.7,
#   u'FTA': 10,
#   u'FTM': 10,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2016-01-27',
#   u'GAME_ID': u'0021500691',
#   u'MATCHUP': u'GSW vs. DAL',
#   u'MIN': 32,
#   u'OREB': 0,
#   u'PF': 1,
#   u'PLAYER_ID': 202691,
#   u'PLAYER_NAME': u'Klay Thompson',
#   u'PLUS_MINUS': 14,
#   u'PTS': 45,
#   u'REB': 5,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 1,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 11,
#   u'BLK': 1,
#   u'DREB': 7,
#   u'FG3A': 15,
#   u'FG3M': 4,
#   u'FG3_PCT': 0.267,
#   u'FGA': 29,
#   u'FGM': 11,
#   u'FG_PCT': 0.379,
#   u'FTA': 20,
#   u'FTM': 19,
#   u'FT_PCT': 0.95,
#   u'GAME_DATE': u'2015-11-18',
#   u'GAME_ID': u'0021500170',
#   u'MATCHUP': u'HOU vs. POR',
#   u'MIN': 47,
#   u'OREB': 1,
#   u'PF': 2,
#   u'PLAYER_ID': 201935,
#   u'PLAYER_NAME': u'James Harden',
#   u'PLUS_MINUS': 10,
#   u'PTS': 45,
#   u'REB': 8,
#   u'SEASON_ID': u'22015',
#   u'STL': 5,
#   u'TEAM_ABBREVIATION': u'HOU',
#   u'TEAM_NAME': u'Houston Rockets',
#   u'TOV': 5,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 5,
#   u'BLK': 0,
#   u'DREB': 12,
#   u'FG3A': 7,
#   u'FG3M': 4,
#   u'FG3_PCT': 0.571,
#   u'FGA': 26,
#   u'FGM': 12,
#   u'FG_PCT': 0.462,
#   u'FTA': 18,
#   u'FTM': 16,
#   u'FT_PCT': 0.889,
#   u'GAME_DATE': u'2016-01-26',
#   u'GAME_ID': u'0021500679',
#   u'MATCHUP': u'OKC @ NYK',
#   u'MIN': 43,
#   u'OREB': 2,
#   u'PF': 3,
#   u'PLAYER_ID': 201142,
#   u'PLAYER_NAME': u'Kevin Durant',
#   u'PLUS_MINUS': 12,
#   u'PTS': 44,
#   u'REB': 14,
#   u'SEASON_ID': u'22015',
#   u'STL': 1,
#   u'TEAM_ABBREVIATION': u'OKC',
#   u'TEAM_NAME': u'Oklahoma City Thunder',
#   u'TOV': 4,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 1,
#   u'BLK': 0,
#   u'DREB': 2,
#   u'FG3A': 14,
#   u'FG3M': 5,
#   u'FG3_PCT': 0.357,
#   u'FGA': 25,
#   u'FGM': 12,
#   u'FG_PCT': 0.48,
#   u'FTA': 15,
#   u'FTM': 15,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2016-01-08',
#   u'GAME_ID': u'0021500549',
#   u'MATCHUP': u'LAL vs. OKC',
#   u'MIN': 35,
#   u'OREB': 0,
#   u'PF': 1,
#   u'PLAYER_ID': 101150,
#   u'PLAYER_NAME': u'Lou Williams',
#   u'PLUS_MINUS': 4,
#   u'PTS': 44,
#   u'REB': 2,
#   u'SEASON_ID': u'22015',
#   u'STL': 2,
#   u'TEAM_ABBREVIATION': u'LAL',
#   u'TEAM_NAME': u'Los Angeles Lakers',
#   u'TOV': 1,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 7,
#   u'BLK': 0,
#   u'DREB': 1,
#   u'FG3A': 15,
#   u'FG3M': 9,
#   u'FG3_PCT': 0.6,
#   u'FGA': 24,
#   u'FGM': 14,
#   u'FG_PCT': 0.583,
#   u'FTA': 9,
#   u'FTM': 7,
#   u'FT_PCT': 0.778,
#   u'GAME_DATE': u'2015-12-05',
#   u'GAME_ID': u'0021500290',
#   u'MATCHUP': u'GSW @ TOR',
#   u'MIN': 38,
#   u'OREB': 1,
#   u'PF': 4,
#   u'PLAYER_ID': 201939,
#   u'PLAYER_NAME': u'Stephen Curry',
#   u'PLUS_MINUS': 15,
#   u'PTS': 44,
#   u'REB': 2,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 3,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 2,
#   u'BLK': 2,
#   u'DREB': 7,
#   u'FG3A': 4,
#   u'FG3M': 1,
#   u'FG3_PCT': 0.25,
#   u'FGA': 29,
#   u'FGM': 14,
#   u'FG_PCT': 0.483,
#   u'FTA': 16,
#   u'FTM': 14,
#   u'FT_PCT': 0.875,
#   u'GAME_DATE': u'2015-12-18',
#   u'GAME_ID': u'0021500391',
#   u'MATCHUP': u'CHI vs. DET',
#   u'MIN': 56,
#   u'OREB': 1,
#   u'PF': 5,
#   u'PLAYER_ID': 202710,
#   u'PLAYER_NAME': u'Jimmy Butler',
#   u'PLUS_MINUS': -5,
#   u'PTS': 43,
#   u'REB': 8,
#   u'SEASON_ID': u'22015',
#   u'STL': 2,
#   u'TEAM_ABBREVIATION': u'CHI',
#   u'TEAM_NAME': u'Chicago Bulls',
#   u'TOV': 3,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 2,
#   u'BLK': 0,
#   u'DREB': 3,
#   u'FG3A': 13,
#   u'FG3M': 8,
#   u'FG3_PCT': 0.615,
#   u'FGA': 22,
#   u'FGM': 15,
#   u'FG_PCT': 0.682,
#   u'FTA': 5,
#   u'FTM': 5,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2015-12-16',
#   u'GAME_ID': u'0021500381',
#   u'MATCHUP': u'GSW vs. PHX',
#   u'MIN': 31,
#   u'OREB': 0,
#   u'PF': 0,
#   u'PLAYER_ID': 202691,
#   u'PLAYER_NAME': u'Klay Thompson',
#   u'PLUS_MINUS': 37,
#   u'PTS': 43,
#   u'REB': 3,
#   u'SEASON_ID': u'22015',
#   u'STL': 1,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 1,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 8,
#   u'BLK': 1,
#   u'DREB': 6,
#   u'FG3A': 3,
#   u'FG3M': 0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 25,
#   u'FGM': 14,
#   u'FG_PCT': 0.56,
#   u'FTA': 20,
#   u'FTM': 15,
#   u'FT_PCT': 0.75,
#   u'GAME_DATE': u'2015-11-18',
#   u'GAME_ID': u'0021500171',
#   u'MATCHUP': u'OKC vs. NOP',
#   u'MIN': 36,
#   u'OREB': 3,
#   u'PF': 1,
#   u'PLAYER_ID': 201566,
#   u'PLAYER_NAME': u'Russell Westbrook',
#   u'PLUS_MINUS': -5,
#   u'PTS': 43,
#   u'REB': 9,
#   u'SEASON_ID': u'22015',
#   u'STL': 1,
#   u'TEAM_ABBREVIATION': u'OKC',
#   u'TEAM_NAME': u'Oklahoma City Thunder',
#   u'TOV': 4,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 13,
#   u'BLK': 0,
#   u'DREB': 4,
#   u'FG3A': 10,
#   u'FG3M': 4,
#   u'FG3_PCT': 0.4,
#   u'FGA': 23,
#   u'FGM': 13,
#   u'FG_PCT': 0.565,
#   u'FTA': 16,
#   u'FTM': 13,
#   u'FT_PCT': 0.813,
#   u'GAME_DATE': u'2015-11-06',
#   u'GAME_ID': u'0021500084',
#   u'MATCHUP': u'HOU @ SAC',
#   u'MIN': 42,
#   u'OREB': 2,
#   u'PF': 0,
#   u'PLAYER_ID': 201935,
#   u'PLAYER_NAME': u'James Harden',
#   u'PLUS_MINUS': 24,
#   u'PTS': 43,
#   u'REB': 6,
#   u'SEASON_ID': u'22015',
#   u'STL': 2,
#   u'TEAM_ABBREVIATION': u'HOU',
#   u'TEAM_NAME': u'Houston Rockets',
#   u'TOV': 7,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 3,
#   u'BLK': 3,
#   u'DREB': 8,
#   u'FG3A': 1,
#   u'FG3M': 1,
#   u'FG3_PCT': 1.0,
#   u'FGA': 23,
#   u'FGM': 14,
#   u'FG_PCT': 0.609,
#   u'FTA': 16,
#   u'FTM': 14,
#   u'FT_PCT': 0.875,
#   u'GAME_DATE': u'2015-11-06',
#   u'GAME_ID': u'0021500081',
#   u'MATCHUP': u'NOP vs. ATL',
#   u'MIN': 41,
#   u'OREB': 2,
#   u'PF': 5,
#   u'PLAYER_ID': 203076,
#   u'PLAYER_NAME': u'Anthony Davis',
#   u'PLUS_MINUS': -1,
#   u'PTS': 43,
#   u'REB': 10,
#   u'SEASON_ID': u'22015',
#   u'STL': 4,
#   u'TEAM_ABBREVIATION': u'NOP',
#   u'TEAM_NAME': u'New Orleans Pelicans',
#   u'TOV': 1,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 2,
#   u'BLK': 2,
#   u'DREB': 11,
#   u'FG3A': 9,
#   u'FG3M': 3,
#   u'FG3_PCT': 0.333,
#   u'FGA': 30,
#   u'FGM': 15,
#   u'FG_PCT': 0.5,
#   u'FTA': 11,
#   u'FTM': 10,
#   u'FT_PCT': 0.909,
#   u'GAME_DATE': u'2015-10-30',
#   u'GAME_ID': u'0021500022',
#   u'MATCHUP': u'OKC @ ORL',
#   u'MIN': 54,
#   u'OREB': 1,
#   u'PF': 4,
#   u'PLAYER_ID': 201142,
#   u'PLAYER_NAME': u'Kevin Durant',
#   u'PLUS_MINUS': 3,
#   u'PTS': 43,
#   u'REB': 12,
#   u'SEASON_ID': u'22015',
#   u'STL': 1,
#   u'TEAM_ABBREVIATION': u'OKC',
#   u'TEAM_NAME': u'Oklahoma City Thunder',
#   u'TOV': 2,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 5,
#   u'BLK': 1,
#   u'DREB': 3,
#   u'FG3A': 3,
#   u'FG3M': 2,
#   u'FG3_PCT': 0.667,
#   u'FGA': 23,
#   u'FGM': 15,
#   u'FG_PCT': 0.652,
#   u'FTA': 11,
#   u'FTM': 10,
#   u'FT_PCT': 0.909,
#   u'GAME_DATE': u'2016-01-03',
#   u'GAME_ID': u'0021500507',
#   u'MATCHUP': u'CHI @ TOR',
#   u'MIN': 39,
#   u'OREB': 1,
#   u'PF': 3,
#   u'PLAYER_ID': 202710,
#   u'PLAYER_NAME': u'Jimmy Butler',
#   u'PLUS_MINUS': 11,
#   u'PTS': 42,
#   u'REB': 4,
#   u'SEASON_ID': u'22015',
#   u'STL': 1,
#   u'TEAM_ABBREVIATION': u'CHI',
#   u'TEAM_NAME': u'Chicago Bulls',
#   u'TOV': 3,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 7,
#   u'BLK': 2,
#   u'DREB': 7,
#   u'FG3A': 9,
#   u'FG3M': 5,
#   u'FG3_PCT': 0.556,
#   u'FGA': 23,
#   u'FGM': 13,
#   u'FG_PCT': 0.565,
#   u'FTA': 12,
#   u'FTM': 11,
#   u'FT_PCT': 0.917,
#   u'GAME_DATE': u'2015-12-09',
#   u'GAME_ID': u'0021500321',
#   u'MATCHUP': u'HOU @ WAS',
#   u'MIN': 40,
#   u'OREB': 2,
#   u'PF': 4,
#   u'PLAYER_ID': 201935,
#   u'PLAYER_NAME': u'James Harden',
#   u'PLUS_MINUS': 7,
#   u'PTS': 42,
#   u'REB': 9,
#   u'SEASON_ID': u'22015',
#   u'STL': 2,
#   u'TEAM_ABBREVIATION': u'HOU',
#   u'TEAM_NAME': u'Houston Rockets',
#   u'TOV': 7,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 7,
#   u'BLK': 1,
#   u'DREB': 2,
#   u'FG3A': 10,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.6,
#   u'FGA': 26,
#   u'FGM': 14,
#   u'FG_PCT': 0.538,
#   u'FTA': 8,
#   u'FTM': 7,
#   u'FT_PCT': 0.875,
#   u'GAME_DATE': u'2015-12-05',
#   u'GAME_ID': u'0021500290',
#   u'MATCHUP': u'TOR vs. GSW',
#   u'MIN': 38,
#   u'OREB': 1,
#   u'PF': 2,
#   u'PLAYER_ID': 200768,
#   u'PLAYER_NAME': u'Kyle Lowry',
#   u'PLUS_MINUS': 8,
#   u'PTS': 41,
#   u'REB': 3,
#   u'SEASON_ID': u'22015',
#   u'STL': 4,
#   u'TEAM_ABBREVIATION': u'TOR',
#   u'TEAM_NAME': u'Toronto Raptors',
#   u'TOV': 1,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 8,
#   u'BLK': 0,
#   u'DREB': 5,
#   u'FG3A': 16,
#   u'FG3M': 9,
#   u'FG3_PCT': 0.563,
#   u'FGA': 20,
#   u'FGM': 11,
#   u'FG_PCT': 0.55,
#   u'FTA': 11,
#   u'FTM': 10,
#   u'FT_PCT': 0.909,
#   u'GAME_DATE': u'2015-11-27',
#   u'GAME_ID': u'0021500236',
#   u'MATCHUP': u'GSW @ PHX',
#   u'MIN': 31,
#   u'OREB': 1,
#   u'PF': 2,
#   u'PLAYER_ID': 201939,
#   u'PLAYER_NAME': u'Stephen Curry',
#   u'PLUS_MINUS': 27,
#   u'PTS': 41,
#   u'REB': 6,
#   u'SEASON_ID': u'22015',
#   u'STL': 2,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 6,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 9,
#   u'BLK': 1,
#   u'DREB': 7,
#   u'FG3A': 7,
#   u'FG3M': 2,
#   u'FG3_PCT': 0.286,
#   u'FGA': 28,
#   u'FGM': 14,
#   u'FG_PCT': 0.5,
#   u'FTA': 12,
#   u'FTM': 10,
#   u'FT_PCT': 0.833,
#   u'GAME_DATE': u'2016-01-22',
#   u'GAME_ID': u'0021500645',
#   u'MATCHUP': u'CHA @ ORL',
#   u'MIN': 46,
#   u'OREB': 0,
#   u'PF': 0,
#   u'PLAYER_ID': 202689,
#   u'PLAYER_NAME': u'Kemba Walker',
#   u'PLUS_MINUS': 7,
#   u'PTS': 40,
#   u'REB': 7,
#   u'SEASON_ID': u'22015',
#   u'STL': 4,
#   u'TEAM_ABBREVIATION': u'CHA',
#   u'TEAM_NAME': u'Charlotte Hornets',
#   u'TOV': 2,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 2,
#   u'BLK': 0,
#   u'DREB': 0,
#   u'FG3A': 12,
#   u'FG3M': 9,
#   u'FG3_PCT': 0.75,
#   u'FGA': 19,
#   u'FGM': 11,
#   u'FG_PCT': 0.579,
#   u'FTA': 9,
#   u'FTM': 9,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2016-01-18',
#   u'GAME_ID': u'0021500624',
#   u'MATCHUP': u'LAC vs. HOU',
#   u'MIN': 39,
#   u'OREB': 1,
#   u'PF': 4,
#   u'PLAYER_ID': 200755,
#   u'PLAYER_NAME': u'JJ Redick',
#   u'PLUS_MINUS': 18,
#   u'PTS': 40,
#   u'REB': 1,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'LAC',
#   u'TEAM_NAME': u'Los Angeles Clippers',
#   u'TOV': 1,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 10,
#   u'BLK': 2,
#   u'DREB': 2,
#   u'FG3A': 15,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.4,
#   u'FGA': 27,
#   u'FGM': 12,
#   u'FG_PCT': 0.444,
#   u'FTA': 12,
#   u'FTM': 10,
#   u'FT_PCT': 0.833,
#   u'GAME_DATE': u'2016-01-08',
#   u'GAME_ID': u'0021500548',
#   u'MATCHUP': u'POR vs. GSW',
#   u'MIN': 38,
#   u'OREB': 1,
#   u'PF': 2,
#   u'PLAYER_ID': 203081,
#   u'PLAYER_NAME': u'Damian Lillard',
#   u'PLUS_MINUS': -18,
#   u'PTS': 40,
#   u'REB': 3,
#   u'SEASON_ID': u'22015',
#   u'STL': 2,
#   u'TEAM_ABBREVIATION': u'POR',
#   u'TEAM_NAME': u'Portland Trail Blazers',
#   u'TOV': 3,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 5,
#   u'BLK': 0,
#   u'DREB': 3,
#   u'FG3A': 11,
#   u'FG3M': 8,
#   u'FG3_PCT': 0.727,
#   u'FGA': 18,
#   u'FGM': 14,
#   u'FG_PCT': 0.778,
#   u'FTA': 4,
#   u'FTM': 4,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2015-12-02',
#   u'GAME_ID': u'0021500268',
#   u'MATCHUP': u'GSW @ CHA',
#   u'MIN': 31,
#   u'OREB': 0,
#   u'PF': 2,
#   u'PLAYER_ID': 201939,
#   u'PLAYER_NAME': u'Stephen Curry',
#   u'PLUS_MINUS': 19,
#   u'PTS': 40,
#   u'REB': 3,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 5,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 3,
#   u'BLK': 2,
#   u'DREB': 11,
#   u'FG3A': 0,
#   u'FG3M': 0,
#   u'FG3_PCT': None,
#   u'FGA': 23,
#   u'FGM': 18,
#   u'FG_PCT': 0.783,
#   u'FTA': 5,
#   u'FTM': 4,
#   u'FT_PCT': 0.8,
#   u'GAME_DATE': u'2015-11-25',
#   u'GAME_ID': u'0021500226',
#   u'MATCHUP': u'LAC vs. UTA',
#   u'MIN': 39,
#   u'OREB': 1,
#   u'PF': 2,
#   u'PLAYER_ID': 201933,
#   u'PLAYER_NAME': u'Blake Griffin',
#   u'PLUS_MINUS': -3,
#   u'PTS': 40,
#   u'REB': 12,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'LAC',
#   u'TEAM_NAME': u'Los Angeles Clippers',
#   u'TOV': 3,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 5,
#   u'BLK': 1,
#   u'DREB': 4,
#   u'FG3A': 9,
#   u'FG3M': 5,
#   u'FG3_PCT': 0.556,
#   u'FGA': 19,
#   u'FGM': 12,
#   u'FG_PCT': 0.632,
#   u'FTA': 11,
#   u'FTM': 11,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2015-11-25',
#   u'GAME_ID': u'0021500220',
#   u'MATCHUP': u'HOU vs. MEM',
#   u'MIN': 41,
#   u'OREB': 1,
#   u'PF': 2,
#   u'PLAYER_ID': 201935,
#   u'PLAYER_NAME': u'James Harden',
#   u'PLUS_MINUS': 1,
#   u'PTS': 40,
#   u'REB': 5,
#   u'SEASON_ID': u'22015',
#   u'STL': 3,
#   u'TEAM_ABBREVIATION': u'HOU',
#   u'TEAM_NAME': u'Houston Rockets',
#   u'TOV': 4,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 4,
#   u'BLK': 0,
#   u'DREB': 7,
#   u'FG3A': 8,
#   u'FG3M': 7,
#   u'FG3_PCT': 0.875,
#   u'FGA': 19,
#   u'FGM': 14,
#   u'FG_PCT': 0.737,
#   u'FTA': 6,
#   u'FTM': 5,
#   u'FT_PCT': 0.833,
#   u'GAME_DATE': u'2015-11-24',
#   u'GAME_ID': u'0021500209',
#   u'MATCHUP': u'IND @ WAS',
#   u'MIN': 37,
#   u'OREB': 1,
#   u'PF': 1,
#   u'PLAYER_ID': 202331,
#   u'PLAYER_NAME': u'Paul George',
#   u'PLUS_MINUS': 24,
#   u'PTS': 40,
#   u'REB': 8,
#   u'SEASON_ID': u'22015',
#   u'STL': 2,
#   u'TEAM_ABBREVIATION': u'IND',
#   u'TEAM_NAME': u'Indiana Pacers',
#   u'TOV': 4,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 4,
#   u'BLK': 0,
#   u'DREB': 11,
#   u'FG3A': 14,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.429,
#   u'FGA': 22,
#   u'FGM': 11,
#   u'FG_PCT': 0.5,
#   u'FTA': 12,
#   u'FTM': 12,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2015-11-19',
#   u'GAME_ID': u'0021500177',
#   u'MATCHUP': u'GSW @ LAC',
#   u'MIN': 37,
#   u'OREB': 0,
#   u'PF': 2,
#   u'PLAYER_ID': 201939,
#   u'PLAYER_NAME': u'Stephen Curry',
#   u'PLUS_MINUS': 12,
#   u'PTS': 40,
#   u'REB': 11,
#   u'SEASON_ID': u'22015',
#   u'STL': 3,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 7,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 14,
#   u'BLK': 0,
#   u'DREB': 3,
#   u'FG3A': 8,
#   u'FG3M': 5,
#   u'FG3_PCT': 0.625,
#   u'FGA': 19,
#   u'FGM': 13,
#   u'FG_PCT': 0.684,
#   u'FTA': 13,
#   u'FTM': 9,
#   u'FT_PCT': 0.692,
#   u'GAME_DATE': u'2015-11-16',
#   u'GAME_ID': u'0021500155',
#   u'MATCHUP': u'OKC @ MEM',
#   u'MIN': 39,
#   u'OREB': 1,
#   u'PF': 1,
#   u'PLAYER_ID': 201566,
#   u'PLAYER_NAME': u'Russell Westbrook',
#   u'PLUS_MINUS': 2,
#   u'PTS': 40,
#   u'REB': 4,
#   u'SEASON_ID': u'22015',
#   u'STL': 3,
#   u'TEAM_ABBREVIATION': u'OKC',
#   u'TEAM_NAME': u'Oklahoma City Thunder',
#   u'TOV': 8,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 1,
#   u'BLK': 1,
#   u'DREB': 7,
#   u'FG3A': 4,
#   u'FG3M': 2,
#   u'FG3_PCT': 0.5,
#   u'FGA': 27,
#   u'FGM': 13,
#   u'FG_PCT': 0.481,
#   u'FTA': 13,
#   u'FTM': 12,
#   u'FT_PCT': 0.923,
#   u'GAME_DATE': u'2015-11-13',
#   u'GAME_ID': u'0021500137',
#   u'MATCHUP': u'SAC vs. BKN',
#   u'MIN': 34,
#   u'OREB': 6,
#   u'PF': 6,
#   u'PLAYER_ID': 202326,
#   u'PLAYER_NAME': u'DeMarcus Cousins',
#   u'PLUS_MINUS': -1,
#   u'PTS': 40,
#   u'REB': 13,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'SAC',
#   u'TEAM_NAME': u'Sacramento Kings',
#   u'TOV': 1,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 5,
#   u'BLK': 0,
#   u'DREB': 3,
#   u'FG3A': 3,
#   u'FG3M': 3,
#   u'FG3_PCT': 1.0,
#   u'FGA': 26,
#   u'FGM': 15,
#   u'FG_PCT': 0.577,
#   u'FTA': 8,
#   u'FTM': 7,
#   u'FT_PCT': 0.875,
#   u'GAME_DATE': u'2015-11-08',
#   u'GAME_ID': u'0021500098',
#   u'MATCHUP': u'DET @ POR',
#   u'MIN': 34,
#   u'OREB': 2,
#   u'PF': 1,
#   u'PLAYER_ID': 202704,
#   u'PLAYER_NAME': u'Reggie Jackson',
#   u'PLUS_MINUS': 22,
#   u'PTS': 40,
#   u'REB': 5,
#   u'SEASON_ID': u'22015',
#   u'STL': 2,
#   u'TEAM_ABBREVIATION': u'DET',
#   u'TEAM_NAME': u'Detroit Pistons',
#   u'TOV': 2,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 7,
#   u'BLK': 0,
#   u'DREB': 3,
#   u'FG3A': 12,
#   u'FG3M': 5,
#   u'FG3_PCT': 0.417,
#   u'FGA': 26,
#   u'FGM': 14,
#   u'FG_PCT': 0.538,
#   u'FTA': 7,
#   u'FTM': 7,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2015-10-27',
#   u'GAME_ID': u'0021500003',
#   u'MATCHUP': u'GSW vs. NOP',
#   u'MIN': 36,
#   u'OREB': 3,
#   u'PF': 1,
#   u'PLAYER_ID': 201939,
#   u'PLAYER_NAME': u'Stephen Curry',
#   u'PLUS_MINUS': 12,
#   u'PTS': 40,
#   u'REB': 6,
#   u'SEASON_ID': u'22015',
#   u'STL': 2,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 2,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 11,
#   u'BLK': 0,
#   u'DREB': 6,
#   u'FG3A': 9,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.667,
#   u'FGA': 19,
#   u'FGM': 12,
#   u'FG_PCT': 0.632,
#   u'FTA': 9,
#   u'FTM': 9,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2016-01-30',
#   u'GAME_ID': u'0021500711',
#   u'MATCHUP': u'HOU vs. WAS',
#   u'MIN': 37,
#   u'OREB': 1,
#   u'PF': 5,
#   u'PLAYER_ID': 201935,
#   u'PLAYER_NAME': u'James Harden',
#   u'PLUS_MINUS': -3,
#   u'PTS': 39,
#   u'REB': 7,
#   u'SEASON_ID': u'22015',
#   u'STL': 4,
#   u'TEAM_ABBREVIATION': u'HOU',
#   u'TEAM_NAME': u'Houston Rockets',
#   u'TOV': 2,
#   u'VIDEO_AVAILABLE': 0,
#   u'WL': None},
#  {u'AST': 12,
#   u'BLK': 0,
#   u'DREB': 8,
#   u'FG3A': 15,
#   u'FG3M': 8,
#   u'FG3_PCT': 0.533,
#   u'FGA': 19,
#   u'FGM': 11,
#   u'FG_PCT': 0.579,
#   u'FTA': 9,
#   u'FTM': 9,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2016-01-22',
#   u'GAME_ID': u'0021500652',
#   u'MATCHUP': u'GSW vs. IND',
#   u'MIN': 37,
#   u'OREB': 2,
#   u'PF': 1,
#   u'PLAYER_ID': 201939,
#   u'PLAYER_NAME': u'Stephen Curry',
#   u'PLUS_MINUS': 22,
#   u'PTS': 39,
#   u'REB': 10,
#   u'SEASON_ID': u'22015',
#   u'STL': 1,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 2,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 6,
#   u'BLK': 1,
#   u'DREB': 6,
#   u'FG3A': 16,
#   u'FG3M': 10,
#   u'FG3_PCT': 0.625,
#   u'FGA': 21,
#   u'FGM': 13,
#   u'FG_PCT': 0.619,
#   u'FTA': 3,
#   u'FTM': 3,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2015-12-08',
#   u'GAME_ID': u'0021500314',
#   u'MATCHUP': u'GSW @ IND',
#   u'MIN': 34,
#   u'OREB': 1,
#   u'PF': 2,
#   u'PLAYER_ID': 202691,
#   u'PLAYER_NAME': u'Klay Thompson',
#   u'PLUS_MINUS': 19,
#   u'PTS': 39,
#   u'REB': 7,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 4,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 1,
#   u'BLK': 1,
#   u'DREB': 3,
#   u'FG3A': 11,
#   u'FG3M': 5,
#   u'FG3_PCT': 0.455,
#   u'FGA': 22,
#   u'FGM': 10,
#   u'FG_PCT': 0.455,
#   u'FTA': 17,
#   u'FTM': 14,
#   u'FT_PCT': 0.824,
#   u'GAME_DATE': u'2015-11-29',
#   u'GAME_ID': u'0021500253',
#   u'MATCHUP': u'IND @ LAL',
#   u'MIN': 37,
#   u'OREB': 1,
#   u'PF': 1,
#   u'PLAYER_ID': 202331,
#   u'PLAYER_NAME': u'Paul George',
#   u'PLUS_MINUS': 10,
#   u'PTS': 39,
#   u'REB': 4,
#   u'SEASON_ID': u'22015',
#   u'STL': 2,
#   u'TEAM_ABBREVIATION': u'IND',
#   u'TEAM_NAME': u'Indiana Pacers',
#   u'TOV': 4,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 5,
#   u'BLK': 3,
#   u'DREB': 4,
#   u'FG3A': 6,
#   u'FG3M': 4,
#   u'FG3_PCT': 0.667,
#   u'FGA': 23,
#   u'FGM': 16,
#   u'FG_PCT': 0.696,
#   u'FTA': 4,
#   u'FTM': 3,
#   u'FT_PCT': 0.75,
#   u'GAME_DATE': u'2015-11-23',
#   u'GAME_ID': u'0021500202',
#   u'MATCHUP': u'CHA vs. SAC',
#   u'MIN': 47,
#   u'OREB': 2,
#   u'PF': 0,
#   u'PLAYER_ID': 202689,
#   u'PLAYER_NAME': u'Kemba Walker',
#   u'PLUS_MINUS': 11,
#   u'PTS': 39,
#   u'REB': 6,
#   u'SEASON_ID': u'22015',
#   u'STL': 2,
#   u'TEAM_ABBREVIATION': u'CHA',
#   u'TEAM_NAME': u'Charlotte Hornets',
#   u'TOV': 2,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 5,
#   u'BLK': 0,
#   u'DREB': 6,
#   u'FG3A': 15,
#   u'FG3M': 7,
#   u'FG3_PCT': 0.467,
#   u'FGA': 26,
#   u'FGM': 13,
#   u'FG_PCT': 0.5,
#   u'FTA': 6,
#   u'FTM': 5,
#   u'FT_PCT': 0.833,
#   u'GAME_DATE': u'2016-01-16',
#   u'GAME_ID': u'0021500605',
#   u'MATCHUP': u'GSW @ DET',
#   u'MIN': 37,
#   u'OREB': 1,
#   u'PF': 1,
#   u'PLAYER_ID': 201939,
#   u'PLAYER_NAME': u'Stephen Curry',
#   u'PLUS_MINUS': 2,
#   u'PTS': 38,
#   u'REB': 7,
#   u'SEASON_ID': u'22015',
#   u'STL': 2,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 2,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 9,
#   u'BLK': 1,
#   u'DREB': 3,
#   u'FG3A': 12,
#   u'FG3M': 5,
#   u'FG3_PCT': 0.417,
#   u'FGA': 25,
#   u'FGM': 13,
#   u'FG_PCT': 0.52,
#   u'FTA': 7,
#   u'FTM': 7,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2016-01-13',
#   u'GAME_ID': u'0021500583',
#   u'MATCHUP': u'GSW @ DEN',
#   u'MIN': 40,
#   u'OREB': 2,
#   u'PF': 1,
#   u'PLAYER_ID': 201939,
#   u'PLAYER_NAME': u'Stephen Curry',
#   u'PLUS_MINUS': -4,
#   u'PTS': 38,
#   u'REB': 5,
#   u'SEASON_ID': u'22015',
#   u'STL': 3,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 8,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 11,
#   u'BLK': 1,
#   u'DREB': 5,
#   u'FG3A': 14,
#   u'FG3M': 8,
#   u'FG3_PCT': 0.571,
#   u'FGA': 21,
#   u'FGM': 12,
#   u'FG_PCT': 0.571,
#   u'FTA': 7,
#   u'FTM': 6,
#   u'FT_PCT': 0.857,
#   u'GAME_DATE': u'2016-01-09',
#   u'GAME_ID': u'0021500556',
#   u'MATCHUP': u'GSW @ SAC',
#   u'MIN': 38,
#   u'OREB': 1,
#   u'PF': 3,
#   u'PLAYER_ID': 201939,
#   u'PLAYER_NAME': u'Stephen Curry',
#   u'PLUS_MINUS': 16,
#   u'PTS': 38,
#   u'REB': 6,
#   u'SEASON_ID': u'22015',
#   u'STL': 1,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 4,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 2,
#   u'BLK': 1,
#   u'DREB': 2,
#   u'FG3A': 8,
#   u'FG3M': 7,
#   u'FG3_PCT': 0.875,
#   u'FGA': 17,
#   u'FGM': 14,
#   u'FG_PCT': 0.824,
#   u'FTA': 4,
#   u'FTM': 3,
#   u'FT_PCT': 0.75,
#   u'GAME_DATE': u'2016-01-03',
#   u'GAME_ID': u'0021500506',
#   u'MATCHUP': u'NYK vs. ATL',
#   u'MIN': 37,
#   u'OREB': 0,
#   u'PF': 2,
#   u'PLAYER_ID': 201167,
#   u'PLAYER_NAME': u'Arron Afflalo',
#   u'PLUS_MINUS': 14,
#   u'PTS': 38,
#   u'REB': 2,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'NYK',
#   u'TEAM_NAME': u'New York Knicks',
#   u'TOV': 1,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 0,
#   u'BLK': 1,
#   u'DREB': 5,
#   u'FG3A': 11,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.545,
#   u'FGA': 27,
#   u'FGM': 16,
#   u'FG_PCT': 0.593,
#   u'FTA': 3,
#   u'FTM': 0,
#   u'FT_PCT': 0.0,
#   u'GAME_DATE': u'2015-12-31',
#   u'GAME_ID': u'0021500485',
#   u'MATCHUP': u'GSW @ HOU',
#   u'MIN': 40,
#   u'OREB': 2,
#   u'PF': 5,
#   u'PLAYER_ID': 202691,
#   u'PLAYER_NAME': u'Klay Thompson',
#   u'PLUS_MINUS': 10,
#   u'PTS': 38,
#   u'REB': 7,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 4,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 5,
#   u'BLK': 2,
#   u'DREB': 5,
#   u'FG3A': 6,
#   u'FG3M': 3,
#   u'FG3_PCT': 0.5,
#   u'FGA': 25,
#   u'FGM': 14,
#   u'FG_PCT': 0.56,
#   u'FTA': 7,
#   u'FTM': 7,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2015-12-28',
#   u'GAME_ID': u'0021500458',
#   u'MATCHUP': u'CHA vs. LAL',
#   u'MIN': 42,
#   u'OREB': 1,
#   u'PF': 1,
#   u'PLAYER_ID': 202689,
#   u'PLAYER_NAME': u'Kemba Walker',
#   u'PLUS_MINUS': 14,
#   u'PTS': 38,
#   u'REB': 6,
#   u'SEASON_ID': u'22015',
#   u'STL': 3,
#   u'TEAM_ABBREVIATION': u'CHA',
#   u'TEAM_NAME': u'Charlotte Hornets',
#   u'TOV': 2,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 7,
#   u'BLK': 0,
#   u'DREB': 1,
#   u'FG3A': 5,
#   u'FG3M': 3,
#   u'FG3_PCT': 0.6,
#   u'FGA': 20,
#   u'FGM': 12,
#   u'FG_PCT': 0.6,
#   u'FTA': 11,
#   u'FTM': 11,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2015-12-16',
#   u'GAME_ID': u'0021500374',
#   u'MATCHUP': u'BOS @ DET',
#   u'MIN': 38,
#   u'OREB': 2,
#   u'PF': 5,
#   u'PLAYER_ID': 202738,
#   u'PLAYER_NAME': u'Isaiah Thomas',
#   u'PLUS_MINUS': 13,
#   u'PTS': 38,
#   u'REB': 3,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'BOS',
#   u'TEAM_NAME': u'Boston Celtics',
#   u'TOV': 4,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 8,
#   u'BLK': 0,
#   u'DREB': 8,
#   u'FG3A': 13,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.462,
#   u'FGA': 27,
#   u'FGM': 9,
#   u'FG_PCT': 0.333,
#   u'FTA': 14,
#   u'FTM': 14,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2015-12-11',
#   u'GAME_ID': u'0021500336',
#   u'MATCHUP': u'GSW @ BOS',
#   u'MIN': 47,
#   u'OREB': 3,
#   u'PF': 4,
#   u'PLAYER_ID': 201939,
#   u'PLAYER_NAME': u'Stephen Curry',
#   u'PLUS_MINUS': 15,
#   u'PTS': 38,
#   u'REB': 11,
#   u'SEASON_ID': u'22015',
#   u'STL': 2,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 8,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 6,
#   u'BLK': 4,
#   u'DREB': 13,
#   u'FG3A': 0,
#   u'FG3M': 0,
#   u'FG3_PCT': None,
#   u'FGA': 22,
#   u'FGM': 11,
#   u'FG_PCT': 0.5,
#   u'FTA': 16,
#   u'FTM': 16,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2015-12-01',
#   u'GAME_ID': u'0021500266',
#   u'MATCHUP': u'MEM @ NOP',
#   u'MIN': 42,
#   u'OREB': 0,
#   u'PF': 1,
#   u'PLAYER_ID': 201188,
#   u'PLAYER_NAME': u'Marc Gasol',
#   u'PLUS_MINUS': 8,
#   u'PTS': 38,
#   u'REB': 13,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'MEM',
#   u'TEAM_NAME': u'Memphis Grizzlies',
#   u'TOV': 3,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 6,
#   u'BLK': 1,
#   u'DREB': 7,
#   u'FG3A': 10,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.6,
#   u'FGA': 20,
#   u'FGM': 11,
#   u'FG_PCT': 0.55,
#   u'FTA': 12,
#   u'FTM': 10,
#   u'FT_PCT': 0.833,
#   u'GAME_DATE': u'2015-11-20',
#   u'GAME_ID': u'0021500185',
#   u'MATCHUP': u'PHX @ DEN',
#   u'MIN': 36,
#   u'OREB': 4,
#   u'PF': 1,
#   u'PLAYER_ID': 202688,
#   u'PLAYER_NAME': u'Brandon Knight',
#   u'PLUS_MINUS': 10,
#   u'PTS': 38,
#   u'REB': 11,
#   u'SEASON_ID': u'22015',
#   u'STL': 2,
#   u'TEAM_ABBREVIATION': u'PHX',
#   u'TEAM_NAME': u'Phoenix Suns',
#   u'TOV': 5,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 3,
#   u'BLK': 0,
#   u'DREB': 1,
#   u'FG3A': 9,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.667,
#   u'FGA': 20,
#   u'FGM': 12,
#   u'FG_PCT': 0.6,
#   u'FTA': 7,
#   u'FTM': 7,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2016-01-25',
#   u'GAME_ID': u'0021500675',
#   u'MATCHUP': u'GSW vs. SAS',
#   u'MIN': 28,
#   u'OREB': 1,
#   u'PF': 0,
#   u'PLAYER_ID': 201939,
#   u'PLAYER_NAME': u'Stephen Curry',
#   u'PLUS_MINUS': 23,
#   u'PTS': 37,
#   u'REB': 2,
#   u'SEASON_ID': u'22015',
#   u'STL': 5,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 1,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 3,
#   u'BLK': 3,
#   u'DREB': 7,
#   u'FG3A': 0,
#   u'FG3M': 0,
#   u'FG3_PCT': None,
#   u'FGA': 29,
#   u'FGM': 15,
#   u'FG_PCT': 0.517,
#   u'FTA': 8,
#   u'FTM': 7,
#   u'FT_PCT': 0.875,
#   u'GAME_DATE': u'2016-01-16',
#   u'GAME_ID': u'0021500607',
#   u'MATCHUP': u'MEM vs. NYK',
#   u'MIN': 41,
#   u'OREB': 1,
#   u'PF': 4,
#   u'PLAYER_ID': 201188,
#   u'PLAYER_NAME': u'Marc Gasol',
#   u'PLUS_MINUS': 11,
#   u'PTS': 37,
#   u'REB': 8,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'MEM',
#   u'TEAM_NAME': u'Memphis Grizzlies',
#   u'TOV': 1,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 9,
#   u'BLK': 0,
#   u'DREB': 7,
#   u'FG3A': 5,
#   u'FG3M': 3,
#   u'FG3_PCT': 0.6,
#   u'FGA': 22,
#   u'FGM': 15,
#   u'FG_PCT': 0.682,
#   u'FTA': 6,
#   u'FTM': 4,
#   u'FT_PCT': 0.667,
#   u'GAME_DATE': u'2016-01-10',
#   u'GAME_ID': u'0021500559',
#   u'MATCHUP': u'CLE @ PHI',
#   u'MIN': 37,
#   u'OREB': 0,
#   u'PF': 1,
#   u'PLAYER_ID': 2544,
#   u'PLAYER_NAME': u'LeBron James',
#   u'PLUS_MINUS': 11,
#   u'PTS': 37,
#   u'REB': 7,
#   u'SEASON_ID': u'22015',
#   u'STL': 2,
#   u'TEAM_ABBREVIATION': u'CLE',
#   u'TEAM_NAME': u'Cleveland Cavaliers',
#   u'TOV': 2,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 2,
#   u'BLK': 2,
#   u'DREB': 4,
#   u'FG3A': 5,
#   u'FG3M': 2,
#   u'FG3_PCT': 0.4,
#   u'FGA': 21,
#   u'FGM': 13,
#   u'FG_PCT': 0.619,
#   u'FTA': 9,
#   u'FTM': 9,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2015-12-12',
#   u'GAME_ID': u'0021500352',
#   u'MATCHUP': u'NYK @ POR',
#   u'MIN': 38,
#   u'OREB': 2,
#   u'PF': 0,
#   u'PLAYER_ID': 2546,
#   u'PLAYER_NAME': u'Carmelo Anthony',
#   u'PLUS_MINUS': -8,
#   u'PTS': 37,
#   u'REB': 6,
#   u'SEASON_ID': u'22015',
#   u'STL': 1,
#   u'TEAM_ABBREVIATION': u'NYK',
#   u'TEAM_NAME': u'New York Knicks',
#   u'TOV': 4,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 3,
#   u'BLK': 0,
#   u'DREB': 1,
#   u'FG3A': 9,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.667,
#   u'FGA': 27,
#   u'FGM': 14,
#   u'FG_PCT': 0.519,
#   u'FTA': 3,
#   u'FTM': 3,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2015-12-09',
#   u'GAME_ID': u'0021500325',
#   u'MATCHUP': u'MIN vs. LAL',
#   u'MIN': 40,
#   u'OREB': 0,
#   u'PF': 3,
#   u'PLAYER_ID': 2755,
#   u'PLAYER_NAME': u'Kevin Martin',
#   u'PLUS_MINUS': 8,
#   u'PTS': 37,
#   u'REB': 1,
#   u'SEASON_ID': u'22015',
#   u'STL': 1,
#   u'TEAM_ABBREVIATION': u'MIN',
#   u'TEAM_NAME': u'Minnesota Timberwolves',
#   u'TOV': 1,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 8,
#   u'BLK': 1,
#   u'DREB': 5,
#   u'FG3A': 5,
#   u'FG3M': 1,
#   u'FG3_PCT': 0.2,
#   u'FGA': 29,
#   u'FGM': 13,
#   u'FG_PCT': 0.448,
#   u'FTA': 11,
#   u'FTM': 10,
#   u'FT_PCT': 0.909,
#   u'GAME_DATE': u'2015-12-04',
#   u'GAME_ID': u'0021500288',
#   u'MATCHUP': u'CLE @ NOP',
#   u'MIN': 45,
#   u'OREB': 2,
#   u'PF': 4,
#   u'PLAYER_ID': 2544,
#   u'PLAYER_NAME': u'LeBron James',
#   u'PLUS_MINUS': -4,
#   u'PTS': 37,
#   u'REB': 7,
#   u'SEASON_ID': u'22015',
#   u'STL': 1,
#   u'TEAM_ABBREVIATION': u'CLE',
#   u'TEAM_NAME': u'Cleveland Cavaliers',
#   u'TOV': 5,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 9,
#   u'BLK': 0,
#   u'DREB': 2,
#   u'FG3A': 10,
#   u'FG3M': 5,
#   u'FG3_PCT': 0.5,
#   u'FGA': 23,
#   u'FGM': 13,
#   u'FG_PCT': 0.565,
#   u'FTA': 7,
#   u'FTM': 6,
#   u'FT_PCT': 0.857,
#   u'GAME_DATE': u'2015-11-17',
#   u'GAME_ID': u'0021500164',
#   u'MATCHUP': u'GSW vs. TOR',
#   u'MIN': 40,
#   u'OREB': 0,
#   u'PF': 1,
#   u'PLAYER_ID': 201939,
#   u'PLAYER_NAME': u'Stephen Curry',
#   u'PLUS_MINUS': 11,
#   u'PTS': 37,
#   u'REB': 2,
#   u'SEASON_ID': u'22015',
#   u'STL': 2,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 7,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 5,
#   u'BLK': 3,
#   u'DREB': 8,
#   u'FG3A': 11,
#   u'FG3M': 5,
#   u'FG3_PCT': 0.455,
#   u'FGA': 27,
#   u'FGM': 13,
#   u'FG_PCT': 0.481,
#   u'FTA': 12,
#   u'FTM': 6,
#   u'FT_PCT': 0.5,
#   u'GAME_DATE': u'2015-11-14',
#   u'GAME_ID': u'0021500141',
#   u'MATCHUP': u'CLE @ MIL',
#   u'MIN': 45,
#   u'OREB': 4,
#   u'PF': 3,
#   u'PLAYER_ID': 2544,
#   u'PLAYER_NAME': u'LeBron James',
#   u'PLUS_MINUS': -2,
#   u'PTS': 37,
#   u'REB': 12,
#   u'SEASON_ID': u'22015',
#   u'STL': 1,
#   u'TEAM_ABBREVIATION': u'CLE',
#   u'TEAM_NAME': u'Cleveland Cavaliers',
#   u'TOV': 7,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 8,
#   u'BLK': 1,
#   u'DREB': 5,
#   u'FG3A': 7,
#   u'FG3M': 3,
#   u'FG3_PCT': 0.429,
#   u'FGA': 27,
#   u'FGM': 12,
#   u'FG_PCT': 0.444,
#   u'FTA': 10,
#   u'FTM': 10,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2015-11-14',
#   u'GAME_ID': u'0021500138',
#   u'MATCHUP': u'LAC vs. DET',
#   u'MIN': 41,
#   u'OREB': 1,
#   u'PF': 4,
#   u'PLAYER_ID': 2037,
#   u'PLAYER_NAME': u'Jamal Crawford',
#   u'PLUS_MINUS': 21,
#   u'PTS': 37,
#   u'REB': 6,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'LAC',
#   u'TEAM_NAME': u'Los Angeles Clippers',
#   u'TOV': 3,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 4,
#   u'BLK': 0,
#   u'DREB': 2,
#   u'FG3A': 10,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.6,
#   u'FGA': 22,
#   u'FGM': 14,
#   u'FG_PCT': 0.636,
#   u'FTA': 4,
#   u'FTM': 3,
#   u'FT_PCT': 0.75,
#   u'GAME_DATE': u'2015-11-12',
#   u'GAME_ID': u'0021500126',
#   u'MATCHUP': u'PHX vs. LAC',
#   u'MIN': 34,
#   u'OREB': 0,
#   u'PF': 3,
#   u'PLAYER_ID': 202688,
#   u'PLAYER_NAME': u'Brandon Knight',
#   u'PLUS_MINUS': 21,
#   u'PTS': 37,
#   u'REB': 2,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'PHX',
#   u'TEAM_NAME': u'Phoenix Suns',
#   u'TOV': 1,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 3,
#   u'BLK': 2,
#   u'DREB': 5,
#   u'FG3A': 12,
#   u'FG3M': 4,
#   u'FG3_PCT': 0.333,
#   u'FGA': 26,
#   u'FGM': 12,
#   u'FG_PCT': 0.462,
#   u'FTA': 11,
#   u'FTM': 9,
#   u'FT_PCT': 0.818,
#   u'GAME_DATE': u'2015-11-02',
#   u'GAME_ID': u'0021500049',
#   u'MATCHUP': u'HOU vs. OKC',
#   u'MIN': 38,
#   u'OREB': 0,
#   u'PF': 1,
#   u'PLAYER_ID': 201935,
#   u'PLAYER_NAME': u'James Harden',
#   u'PLUS_MINUS': 6,
#   u'PTS': 37,
#   u'REB': 5,
#   u'SEASON_ID': u'22015',
#   u'STL': 3,
#   u'TEAM_ABBREVIATION': u'HOU',
#   u'TEAM_NAME': u'Houston Rockets',
#   u'TOV': 2,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 4,
#   u'BLK': 1,
#   u'DREB': 6,
#   u'FG3A': 5,
#   u'FG3M': 4,
#   u'FG3_PCT': 0.8,
#   u'FGA': 18,
#   u'FGM': 11,
#   u'FG_PCT': 0.611,
#   u'FTA': 12,
#   u'FTM': 11,
#   u'FT_PCT': 0.917,
#   u'GAME_DATE': u'2015-10-31',
#   u'GAME_ID': u'0021500034',
#   u'MATCHUP': u'NYK @ WAS',
#   u'MIN': 36,
#   u'OREB': 1,
#   u'PF': 3,
#   u'PLAYER_ID': 2546,
#   u'PLAYER_NAME': u'Carmelo Anthony',
#   u'PLUS_MINUS': 6,
#   u'PTS': 37,
#   u'REB': 7,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'NYK',
#   u'TEAM_NAME': u'New York Knicks',
#   u'TOV': 2,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 6,
#   u'BLK': 0,
#   u'DREB': 8,
#   u'FG3A': 0,
#   u'FG3M': 0,
#   u'FG3_PCT': None,
#   u'FGA': 22,
#   u'FGM': 13,
#   u'FG_PCT': 0.591,
#   u'FTA': 15,
#   u'FTM': 11,
#   u'FT_PCT': 0.733,
#   u'GAME_DATE': u'2015-10-31',
#   u'GAME_ID': u'0021500038',
#   u'MATCHUP': u'LAC vs. SAC',
#   u'MIN': 36,
#   u'OREB': 1,
#   u'PF': 4,
#   u'PLAYER_ID': 201933,
#   u'PLAYER_NAME': u'Blake Griffin',
#   u'PLUS_MINUS': 23,
#   u'PTS': 37,
#   u'REB': 9,
#   u'SEASON_ID': u'22015',
#   u'STL': 2,
#   u'TEAM_ABBREVIATION': u'LAC',
#   u'TEAM_NAME': u'Los Angeles Clippers',
#   u'TOV': 3,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 1,
#   u'BLK': 0,
#   u'DREB': 5,
#   u'FG3A': 9,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.667,
#   u'FGA': 22,
#   u'FGM': 14,
#   u'FG_PCT': 0.636,
#   u'FTA': 3,
#   u'FTM': 3,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2015-10-28',
#   u'GAME_ID': u'0021500015',
#   u'MATCHUP': u'POR vs. NOP',
#   u'MIN': 37,
#   u'OREB': 1,
#   u'PF': 3,
#   u'PLAYER_ID': 203468,
#   u'PLAYER_NAME': u'CJ McCollum',
#   u'PLUS_MINUS': 22,
#   u'PTS': 37,
#   u'REB': 6,
#   u'SEASON_ID': u'22015',
#   u'STL': 1,
#   u'TEAM_ABBREVIATION': u'POR',
#   u'TEAM_NAME': u'Portland Trail Blazers',
#   u'TOV': 0,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 4,
#   u'BLK': 0,
#   u'DREB': 6,
#   u'FG3A': 11,
#   u'FG3M': 5,
#   u'FG3_PCT': 0.455,
#   u'FGA': 25,
#   u'FGM': 13,
#   u'FG_PCT': 0.52,
#   u'FTA': 6,
#   u'FTM': 5,
#   u'FT_PCT': 0.833,
#   u'GAME_DATE': u'2016-01-28',
#   u'GAME_ID': u'0021500696',
#   u'MATCHUP': u'NOP vs. SAC',
#   u'MIN': 40,
#   u'OREB': 3,
#   u'PF': 2,
#   u'PLAYER_ID': 201583,
#   u'PLAYER_NAME': u'Ryan Anderson',
#   u'PLUS_MINUS': 11,
#   u'PTS': 36,
#   u'REB': 9,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'NOP',
#   u'TEAM_NAME': u'New Orleans Pelicans',
#   u'TOV': 1,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 5,
#   u'BLK': 0,
#   u'DREB': 1,
#   u'FG3A': 8,
#   u'FG3M': 5,
#   u'FG3_PCT': 0.625,
#   u'FGA': 19,
#   u'FGM': 14,
#   u'FG_PCT': 0.737,
#   u'FTA': 4,
#   u'FTM': 3,
#   u'FT_PCT': 0.75,
#   u'GAME_DATE': u'2016-01-23',
#   u'GAME_ID': u'0021500662',
#   u'MATCHUP': u'POR vs. LAL',
#   u'MIN': 29,
#   u'OREB': 0,
#   u'PF': 0,
#   u'PLAYER_ID': 203081,
#   u'PLAYER_NAME': u'Damian Lillard',
#   u'PLUS_MINUS': 27,
#   u'PTS': 36,
#   u'REB': 1,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'POR',
#   u'TEAM_NAME': u'Portland Trail Blazers',
#   u'TOV': 0,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 3,
#   u'BLK': 1,
#   u'DREB': 10,
#   u'FG3A': 0,
#   u'FG3M': 0,
#   u'FG3_PCT': None,
#   u'FGA': 22,
#   u'FGM': 13,
#   u'FG_PCT': 0.591,
#   u'FTA': 12,
#   u'FTM': 10,
#   u'FT_PCT': 0.833,
#   u'GAME_DATE': u'2016-01-20',
#   u'GAME_ID': u'0021500638',
#   u'MATCHUP': u'SAC @ LAL',
#   u'MIN': 35,
#   u'OREB': 6,
#   u'PF': 5,
#   u'PLAYER_ID': 202326,
#   u'PLAYER_NAME': u'DeMarcus Cousins',
#   u'PLUS_MINUS': 26,
#   u'PTS': 36,
#   u'REB': 16,
#   u'SEASON_ID': u'22015',
#   u'STL': 1,
#   u'TEAM_ABBREVIATION': u'SAC',
#   u'TEAM_NAME': u'Sacramento Kings',
#   u'TOV': 2,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 9,
#   u'BLK': 1,
#   u'DREB': 4,
#   u'FG3A': 12,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.5,
#   u'FGA': 24,
#   u'FGM': 12,
#   u'FG_PCT': 0.5,
#   u'FTA': 6,
#   u'FTM': 6,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2016-01-18',
#   u'GAME_ID': u'0021500616',
#   u'MATCHUP': u'UTA @ CHA',
#   u'MIN': 48,
#   u'OREB': 1,
#   u'PF': 3,
#   u'PLAYER_ID': 202330,
#   u'PLAYER_NAME': u'Gordon Hayward',
#   u'PLUS_MINUS': -5,
#   u'PTS': 36,
#   u'REB': 5,
#   u'SEASON_ID': u'22015',
#   u'STL': 2,
#   u'TEAM_ABBREVIATION': u'UTA',
#   u'TEAM_NAME': u'Utah Jazz',
#   u'TOV': 4,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 4,
#   u'BLK': 1,
#   u'DREB': 16,
#   u'FG3A': 0,
#   u'FG3M': 0,
#   u'FG3_PCT': None,
#   u'FGA': 16,
#   u'FGM': 11,
#   u'FG_PCT': 0.688,
#   u'FTA': 18,
#   u'FTM': 14,
#   u'FT_PCT': 0.778,
#   u'GAME_DATE': u'2016-01-18',
#   u'GAME_ID': u'0021500624',
#   u'MATCHUP': u'HOU @ LAC',
#   u'MIN': 45,
#   u'OREB': 10,
#   u'PF': 2,
#   u'PLAYER_ID': 2730,
#   u'PLAYER_NAME': u'Dwight Howard',
#   u'PLUS_MINUS': -5,
#   u'PTS': 36,
#   u'REB': 26,
#   u'SEASON_ID': u'22015',
#   u'STL': 1,
#   u'TEAM_ABBREVIATION': u'HOU',
#   u'TEAM_NAME': u'Houston Rockets',
#   u'TOV': 4,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 13,
#   u'BLK': 1,
#   u'DREB': 6,
#   u'FG3A': 2,
#   u'FG3M': 1,
#   u'FG3_PCT': 0.5,
#   u'FGA': 25,
#   u'FGM': 12,
#   u'FG_PCT': 0.48,
#   u'FTA': 13,
#   u'FTM': 11,
#   u'FT_PCT': 0.846,
#   u'GAME_DATE': u'2016-01-16',
#   u'GAME_ID': u'0021500604',
#   u'MATCHUP': u'WAS vs. BOS',
#   u'MIN': 44,
#   u'OREB': 1,
#   u'PF': 3,
#   u'PLAYER_ID': 202322,
#   u'PLAYER_NAME': u'John Wall',
#   u'PLUS_MINUS': -5,
#   u'PTS': 36,
#   u'REB': 7,
#   u'SEASON_ID': u'22015',
#   u'STL': 7,
#   u'TEAM_ABBREVIATION': u'WAS',
#   u'TEAM_NAME': u'Washington Wizards',
#   u'TOV': 6,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 1,
#   u'BLK': 1,
#   u'DREB': 12,
#   u'FG3A': 2,
#   u'FG3M': 2,
#   u'FG3_PCT': 1.0,
#   u'FGA': 21,
#   u'FGM': 10,
#   u'FG_PCT': 0.476,
#   u'FTA': 21,
#   u'FTM': 14,
#   u'FT_PCT': 0.667,
#   u'GAME_DATE': u'2016-01-14',
#   u'GAME_ID': u'0021500591',
#   u'MATCHUP': u'SAC @ UTA',
#   u'MIN': 39,
#   u'OREB': 5,
#   u'PF': 2,
#   u'PLAYER_ID': 202326,
#   u'PLAYER_NAME': u'DeMarcus Cousins',
#   u'PLUS_MINUS': 3,
#   u'PTS': 36,
#   u'REB': 17,
#   u'SEASON_ID': u'22015',
#   u'STL': 1,
#   u'TEAM_ABBREVIATION': u'SAC',
#   u'TEAM_NAME': u'Sacramento Kings',
#   u'TOV': 4,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 5,
#   u'BLK': 0,
#   u'DREB': 6,
#   u'FG3A': 10,
#   u'FG3M': 7,
#   u'FG3_PCT': 0.7,
#   u'FGA': 22,
#   u'FGM': 13,
#   u'FG_PCT': 0.591,
#   u'FTA': 4,
#   u'FTM': 3,
#   u'FT_PCT': 0.75,
#   u'GAME_DATE': u'2016-01-08',
#   u'GAME_ID': u'0021500548',
#   u'MATCHUP': u'GSW @ POR',
#   u'MIN': 32,
#   u'OREB': 0,
#   u'PF': 1,
#   u'PLAYER_ID': 202691,
#   u'PLAYER_NAME': u'Klay Thompson',
#   u'PLUS_MINUS': 27,
#   u'PTS': 36,
#   u'REB': 6,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 0,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 7,
#   u'BLK': 0,
#   u'DREB': 9,
#   u'FG3A': 4,
#   u'FG3M': 1,
#   u'FG3_PCT': 0.25,
#   u'FGA': 24,
#   u'FGM': 11,
#   u'FG_PCT': 0.458,
#   u'FTA': 16,
#   u'FTM': 13,
#   u'FT_PCT': 0.813,
#   u'GAME_DATE': u'2016-01-08',
#   u'GAME_ID': u'0021500549',
#   u'MATCHUP': u'OKC @ LAL',
#   u'MIN': 35,
#   u'OREB': 3,
#   u'PF': 1,
#   u'PLAYER_ID': 201566,
#   u'PLAYER_NAME': u'Russell Westbrook',
#   u'PLUS_MINUS': 1,
#   u'PTS': 36,
#   u'REB': 12,
#   u'SEASON_ID': u'22015',
#   u'STL': 1,
#   u'TEAM_ABBREVIATION': u'OKC',
#   u'TEAM_NAME': u'Oklahoma City Thunder',
#   u'TOV': 6,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 1,
#   u'BLK': 1,
#   u'DREB': 2,
#   u'FG3A': 13,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.462,
#   u'FGA': 22,
#   u'FGM': 12,
#   u'FG_PCT': 0.545,
#   u'FTA': 6,
#   u'FTM': 6,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2016-01-05',
#   u'GAME_ID': u'0021500524',
#   u'MATCHUP': u'GSW @ LAL',
#   u'MIN': 34,
#   u'OREB': 0,
#   u'PF': 1,
#   u'PLAYER_ID': 202691,
#   u'PLAYER_NAME': u'Klay Thompson',
#   u'PLUS_MINUS': 29,
#   u'PTS': 36,
#   u'REB': 2,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 1,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 12,
#   u'BLK': 1,
#   u'DREB': 1,
#   u'FG3A': 3,
#   u'FG3M': 1,
#   u'FG3_PCT': 0.333,
#   u'FGA': 19,
#   u'FGM': 12,
#   u'FG_PCT': 0.632,
#   u'FTA': 11,
#   u'FTM': 11,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2015-12-31',
#   u'GAME_ID': u'0021500488',
#   u'MATCHUP': u'OKC vs. PHX',
#   u'MIN': 34,
#   u'OREB': 0,
#   u'PF': 1,
#   u'PLAYER_ID': 201566,
#   u'PLAYER_NAME': u'Russell Westbrook',
#   u'PLUS_MINUS': 11,
#   u'PTS': 36,
#   u'REB': 1,
#   u'SEASON_ID': u'22015',
#   u'STL': 5,
#   u'TEAM_ABBREVIATION': u'OKC',
#   u'TEAM_NAME': u'Oklahoma City Thunder',
#   u'TOV': 2,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 7,
#   u'BLK': 0,
#   u'DREB': 0,
#   u'FG3A': 9,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.667,
#   u'FGA': 22,
#   u'FGM': 13,
#   u'FG_PCT': 0.591,
#   u'FTA': 4,
#   u'FTM': 4,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2015-12-29',
#   u'GAME_ID': u'0021500472',
#   u'MATCHUP': u'MIL @ OKC',
#   u'MIN': 37,
#   u'OREB': 0,
#   u'PF': 2,
#   u'PLAYER_ID': 203114,
#   u'PLAYER_NAME': u'Khris Middleton',
#   u'PLUS_MINUS': 4,
#   u'PTS': 36,
#   u'REB': 0,
#   u'SEASON_ID': u'22015',
#   u'STL': 1,
#   u'TEAM_ABBREVIATION': u'MIL',
#   u'TEAM_NAME': u'Milwaukee Bucks',
#   u'TOV': 2,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 1,
#   u'BLK': 0,
#   u'DREB': 5,
#   u'FG3A': 12,
#   u'FG3M': 9,
#   u'FG3_PCT': 0.75,
#   u'FGA': 18,
#   u'FGM': 13,
#   u'FG_PCT': 0.722,
#   u'FTA': 4,
#   u'FTM': 1,
#   u'FT_PCT': 0.25,
#   u'GAME_DATE': u'2015-12-28',
#   u'GAME_ID': u'0021500468',
#   u'MATCHUP': u'SAC @ GSW',
#   u'MIN': 35,
#   u'OREB': 1,
#   u'PF': 4,
#   u'PLAYER_ID': 201956,
#   u'PLAYER_NAME': u'Omri Casspi',
#   u'PLUS_MINUS': -16,
#   u'PTS': 36,
#   u'REB': 6,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'SAC',
#   u'TEAM_NAME': u'Sacramento Kings',
#   u'TOV': 4,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 2,
#   u'BLK': 2,
#   u'DREB': 4,
#   u'FG3A': 7,
#   u'FG3M': 2,
#   u'FG3_PCT': 0.286,
#   u'FGA': 26,
#   u'FGM': 12,
#   u'FG_PCT': 0.462,
#   u'FTA': 12,
#   u'FTM': 10,
#   u'FT_PCT': 0.833,
#   u'GAME_DATE': u'2015-12-27',
#   u'GAME_ID': u'0021500457',
#   u'MATCHUP': u'SAC vs. POR',
#   u'MIN': 37,
#   u'OREB': 2,
#   u'PF': 3,
#   u'PLAYER_ID': 202326,
#   u'PLAYER_NAME': u'DeMarcus Cousins',
#   u'PLUS_MINUS': 0,
#   u'PTS': 36,
#   u'REB': 6,
#   u'SEASON_ID': u'22015',
#   u'STL': 1,
#   u'TEAM_ABBREVIATION': u'SAC',
#   u'TEAM_NAME': u'Sacramento Kings',
#   u'TOV': 5,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 7,
#   u'BLK': 1,
#   u'DREB': 4,
#   u'FG3A': 7,
#   u'FG3M': 2,
#   u'FG3_PCT': 0.286,
#   u'FGA': 16,
#   u'FGM': 9,
#   u'FG_PCT': 0.563,
#   u'FTA': 19,
#   u'FTM': 16,
#   u'FT_PCT': 0.842,
#   u'GAME_DATE': u'2015-12-21',
#   u'GAME_ID': u'0021500415',
#   u'MATCHUP': u'HOU vs. CHA',
#   u'MIN': 35,
#   u'OREB': 1,
#   u'PF': 4,
#   u'PLAYER_ID': 201935,
#   u'PLAYER_NAME': u'James Harden',
#   u'PLUS_MINUS': -1,
#   u'PTS': 36,
#   u'REB': 5,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'HOU',
#   u'TEAM_NAME': u'Houston Rockets',
#   u'TOV': 4,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 0,
#   u'BLK': 0,
#   u'DREB': 7,
#   u'FG3A': 5,
#   u'FG3M': 0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 24,
#   u'FGM': 12,
#   u'FG_PCT': 0.5,
#   u'FTA': 14,
#   u'FTM': 12,
#   u'FT_PCT': 0.857,
#   u'GAME_DATE': u'2015-12-09',
#   u'GAME_ID': u'0021500319',
#   u'MATCHUP': u'CHI @ BOS',
#   u'MIN': 39,
#   u'OREB': 0,
#   u'PF': 3,
#   u'PLAYER_ID': 202710,
#   u'PLAYER_NAME': u'Jimmy Butler',
#   u'PLUS_MINUS': 3,
#   u'PTS': 36,
#   u'REB': 7,
#   u'SEASON_ID': u'22015',
#   u'STL': 1,
#   u'TEAM_ABBREVIATION': u'CHI',
#   u'TEAM_NAME': u'Chicago Bulls',
#   u'TOV': 1,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 5,
#   u'BLK': 1,
#   u'DREB': 6,
#   u'FG3A': 17,
#   u'FG3M': 10,
#   u'FG3_PCT': 0.588,
#   u'FGA': 23,
#   u'FGM': 12,
#   u'FG_PCT': 0.522,
#   u'FTA': 2,
#   u'FTM': 2,
# ...
#   u'GAME_DATE': u'2015-11-16',
#   u'GAME_ID': u'0021500154',
#   u'MATCHUP': u'BOS @ HOU',
#   u'MIN': 24,
#   u'OREB': 1,
#   u'PF': 0,
#   u'PLAYER_ID': 202738,
#   u'PLAYER_NAME': u'Isaiah Thomas',
#   u'PLUS_MINUS': 0,
#   u'PTS': 23,
#   u'REB': 3,
#   u'SEASON_ID': u'22015',
#   u'STL': 2,
#   u'TEAM_ABBREVIATION': u'BOS',
#   u'TEAM_NAME': u'Boston Celtics',
#   u'TOV': 1,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 3,
#   u'BLK': 2,
#   u'DREB': 5,
#   u'FG3A': 1,
#   u'FG3M': 0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 20,
#   u'FGM': 11,
#   u'FG_PCT': 0.55,
#   u'FTA': 1,
#   u'FTM': 1,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2015-11-15',
#   u'GAME_ID': u'0021500148',
#   u'MATCHUP': u'UTA @ ATL',
#   u'MIN': 32,
#   u'OREB': 4,
#   u'PF': 2,
#   u'PLAYER_ID': 202324,
#   u'PLAYER_NAME': u'Derrick Favors',
#   u'PLUS_MINUS': 1,
#   u'PTS': 23,
#   u'REB': 9,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'UTA',
#   u'TEAM_NAME': u'Utah Jazz',
#   u'TOV': 4,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 5,
#   u'BLK': 0,
#   u'DREB': 6,
#   u'FG3A': 9,
#   u'FG3M': 1,
#   u'FG3_PCT': 0.111,
#   u'FGA': 25,
#   u'FGM': 9,
#   u'FG_PCT': 0.36,
#   u'FTA': 5,
#   u'FTM': 4,
#   u'FT_PCT': 0.8,
#   u'GAME_DATE': u'2015-11-15',
#   u'GAME_ID': u'0021500147',
#   u'MATCHUP': u'POR @ CHA',
#   u'MIN': 37,
#   u'OREB': 2,
#   u'PF': 0,
#   u'PLAYER_ID': 203081,
#   u'PLAYER_NAME': u'Damian Lillard',
#   u'PLUS_MINUS': -12,
#   u'PTS': 23,
#   u'REB': 8,
#   u'SEASON_ID': u'22015',
#   u'STL': 1,
#   u'TEAM_ABBREVIATION': u'POR',
#   u'TEAM_NAME': u'Portland Trail Blazers',
#   u'TOV': 5,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 1,
#   u'BLK': 3,
#   u'DREB': 6,
#   u'FG3A': 3,
#   u'FG3M': 1,
#   u'FG3_PCT': 0.333,
#   u'FGA': 15,
#   u'FGM': 10,
#   u'FG_PCT': 0.667,
#   u'FTA': 4,
#   u'FTM': 2,
#   u'FT_PCT': 0.5,
#   u'GAME_DATE': u'2015-11-14',
#   u'GAME_ID': u'0021500140',
#   u'MATCHUP': u'HOU vs. DAL',
#   u'MIN': 42,
#   u'OREB': 0,
#   u'PF': 4,
#   u'PLAYER_ID': 203093,
#   u'PLAYER_NAME': u'Terrence Jones',
#   u'PLUS_MINUS': -10,
#   u'PTS': 23,
#   u'REB': 6,
#   u'SEASON_ID': u'22015',
#   u'STL': 1,
#   u'TEAM_ABBREVIATION': u'HOU',
#   u'TEAM_NAME': u'Houston Rockets',
#   u'TOV': 2,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 1,
#   u'BLK': 0,
#   u'DREB': 5,
#   u'FG3A': 4,
#   u'FG3M': 1,
#   u'FG3_PCT': 0.25,
#   u'FGA': 16,
#   u'FGM': 8,
#   u'FG_PCT': 0.5,
#   u'FTA': 6,
#   u'FTM': 6,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2015-11-14',
#   u'GAME_ID': u'0021500140',
#   u'MATCHUP': u'DAL @ HOU',
#   u'MIN': 34,
#   u'OREB': 1,
#   u'PF': 3,
#   u'PLAYER_ID': 101109,
#   u'PLAYER_NAME': u'Raymond Felton',
#   u'PLUS_MINUS': -3,
#   u'PTS': 23,
#   u'REB': 6,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'DAL',
#   u'TEAM_NAME': u'Dallas Mavericks',
#   u'TOV': 2,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 0,
#   u'BLK': 2,
#   u'DREB': 4,
#   u'FG3A': 8,
#   u'FG3M': 5,
#   u'FG3_PCT': 0.625,
#   u'FGA': 14,
#   u'FGM': 9,
#   u'FG_PCT': 0.643,
#   u'FTA': 0,
#   u'FTM': 0,
#   u'FT_PCT': None,
#   u'GAME_DATE': u'2015-11-14',
#   u'GAME_ID': u'0021500139',
#   u'MATCHUP': u'WAS vs. ORL',
#   u'MIN': 30,
#   u'OREB': 1,
#   u'PF': 2,
#   u'PLAYER_ID': 2743,
#   u'PLAYER_NAME': u'Kris Humphries',
#   u'PLUS_MINUS': 7,
#   u'PTS': 23,
#   u'REB': 5,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'WAS',
#   u'TEAM_NAME': u'Washington Wizards',
#   u'TOV': 1,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 10,
#   u'BLK': 0,
#   u'DREB': 5,
#   u'FG3A': 9,
#   u'FG3M': 4,
#   u'FG3_PCT': 0.444,
#   u'FGA': 18,
#   u'FGM': 8,
#   u'FG_PCT': 0.444,
#   u'FTA': 4,
#   u'FTM': 3,
#   u'FT_PCT': 0.75,
#   u'GAME_DATE': u'2015-11-13',
#   u'GAME_ID': u'0021500129',
#   u'MATCHUP': u'BOS vs. ATL',
#   u'MIN': 34,
#   u'OREB': 0,
#   u'PF': 3,
#   u'PLAYER_ID': 202738,
#   u'PLAYER_NAME': u'Isaiah Thomas',
#   u'PLUS_MINUS': 22,
#   u'PTS': 23,
#   u'REB': 5,
#   u'SEASON_ID': u'22015',
#   u'STL': 2,
#   u'TEAM_ABBREVIATION': u'BOS',
#   u'TEAM_NAME': u'Boston Celtics',
#   u'TOV': 2,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 14,
#   u'BLK': 0,
#   u'DREB': 8,
#   u'FG3A': 4,
#   u'FG3M': 2,
#   u'FG3_PCT': 0.5,
#   u'FGA': 19,
#   u'FGM': 10,
#   u'FG_PCT': 0.526,
#   u'FTA': 4,
#   u'FTM': 1,
#   u'FT_PCT': 0.25,
#   u'GAME_DATE': u'2015-11-13',
#   u'GAME_ID': u'0021500137',
#   u'MATCHUP': u'SAC vs. BKN',
#   u'MIN': 44,
#   u'OREB': 2,
#   u'PF': 2,
#   u'PLAYER_ID': 200765,
#   u'PLAYER_NAME': u'Rajon Rondo',
#   u'PLUS_MINUS': 8,
#   u'PTS': 23,
#   u'REB': 10,
#   u'SEASON_ID': u'22015',
#   u'STL': 2,
#   u'TEAM_ABBREVIATION': u'SAC',
#   u'TEAM_NAME': u'Sacramento Kings',
#   u'TOV': 4,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 0,
#   u'BLK': 4,
#   u'DREB': 3,
#   u'FG3A': 4,
#   u'FG3M': 3,
#   u'FG3_PCT': 0.75,
#   u'FGA': 12,
#   u'FGM': 9,
#   u'FG_PCT': 0.75,
#   u'FTA': 2,
#   u'FTM': 2,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2015-11-13',
#   u'GAME_ID': u'0021500136',
#   u'MATCHUP': u'HOU @ DEN',
#   u'MIN': 21,
#   u'OREB': 4,
#   u'PF': 1,
#   u'PLAYER_ID': 203093,
#   u'PLAYER_NAME': u'Terrence Jones',
#   u'PLUS_MINUS': 3,
#   u'PTS': 23,
#   u'REB': 7,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'HOU',
#   u'TEAM_NAME': u'Houston Rockets',
#   u'TOV': 2,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 12,
#   u'BLK': 2,
#   u'DREB': 8,
#   u'FG3A': 3,
#   u'FG3M': 2,
#   u'FG3_PCT': 0.667,
#   u'FGA': 10,
#   u'FGM': 8,
#   u'FG_PCT': 0.8,
#   u'FTA': 5,
#   u'FTM': 5,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2015-11-12',
#   u'GAME_ID': u'0021500125',
#   u'MATCHUP': u'GSW @ MIN',
#   u'MIN': 35,
#   u'OREB': 0,
#   u'PF': 3,
#   u'PLAYER_ID': 203110,
#   u'PLAYER_NAME': u'Draymond Green',
#   u'PLUS_MINUS': 34,
#   u'PTS': 23,
#   u'REB': 8,
#   u'SEASON_ID': u'22015',
#   u'STL': 2,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 2,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 8,
#   u'BLK': 0,
#   u'DREB': 3,
#   u'FG3A': 6,
#   u'FG3M': 2,
#   u'FG3_PCT': 0.333,
#   u'FGA': 12,
#   u'FGM': 6,
#   u'FG_PCT': 0.5,
#   u'FTA': 10,
#   u'FTM': 9,
#   u'FT_PCT': 0.9,
#   u'GAME_DATE': u'2015-11-11',
#   u'GAME_ID': u'0021500115',
#   u'MATCHUP': u'TOR @ PHI',
#   u'MIN': 29,
#   u'OREB': 0,
#   u'PF': 2,
#   u'PLAYER_ID': 200768,
#   u'PLAYER_NAME': u'Kyle Lowry',
#   u'PLUS_MINUS': 14,
#   u'PTS': 23,
#   u'REB': 3,
#   u'SEASON_ID': u'22015',
#   u'STL': 2,
#   u'TEAM_ABBREVIATION': u'TOR',
#   u'TEAM_NAME': u'Toronto Raptors',
#   u'TOV': 2,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 2,
#   u'BLK': 1,
#   u'DREB': 4,
#   u'FG3A': 1,
#   u'FG3M': 0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 18,
#   u'FGM': 9,
#   u'FG_PCT': 0.5,
#   u'FTA': 6,
#   u'FTM': 5,
#   u'FT_PCT': 0.833,
#   u'GAME_DATE': u'2015-11-11',
#   u'GAME_ID': u'0021500123',
#   u'MATCHUP': u'SAS @ POR',
#   u'MIN': 35,
#   u'OREB': 2,
#   u'PF': 3,
#   u'PLAYER_ID': 200746,
#   u'PLAYER_NAME': u'LaMarcus Aldridge',
#   u'PLUS_MINUS': 3,
#   u'PTS': 23,
#   u'REB': 6,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'SAS',
#   u'TEAM_NAME': u'San Antonio Spurs',
#   u'TOV': 4,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 6,
#   u'BLK': 0,
#   u'DREB': 9,
#   u'FG3A': 10,
#   u'FG3M': 3,
#   u'FG3_PCT': 0.3,
#   u'FGA': 22,
#   u'FGM': 8,
#   u'FG_PCT': 0.364,
#   u'FTA': 5,
#   u'FTM': 4,
#   u'FT_PCT': 0.8,
#   u'GAME_DATE': u'2015-11-11',
#   u'GAME_ID': u'0021500119',
#   u'MATCHUP': u'HOU vs. BKN',
#   u'MIN': 38,
#   u'OREB': 0,
#   u'PF': 2,
#   u'PLAYER_ID': 201935,
#   u'PLAYER_NAME': u'James Harden',
#   u'PLUS_MINUS': 1,
#   u'PTS': 23,
#   u'REB': 9,
#   u'SEASON_ID': u'22015',
#   u'STL': 1,
#   u'TEAM_ABBREVIATION': u'HOU',
#   u'TEAM_NAME': u'Houston Rockets',
#   u'TOV': 4,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 9,
#   u'BLK': 1,
#   u'DREB': 5,
#   u'FG3A': 5,
#   u'FG3M': 2,
#   u'FG3_PCT': 0.4,
#   u'FGA': 18,
#   u'FGM': 8,
#   u'FG_PCT': 0.444,
#   u'FTA': 7,
#   u'FTM': 5,
#   u'FT_PCT': 0.714,
#   u'GAME_DATE': u'2015-11-10',
#   u'GAME_ID': u'0021500109',
#   u'MATCHUP': u'TOR vs. NYK',
#   u'MIN': 37,
#   u'OREB': 1,
#   u'PF': 5,
#   u'PLAYER_ID': 200768,
#   u'PLAYER_NAME': u'Kyle Lowry',
#   u'PLUS_MINUS': 9,
#   u'PTS': 23,
#   u'REB': 6,
#   u'SEASON_ID': u'22015',
#   u'STL': 3,
#   u'TEAM_ABBREVIATION': u'TOR',
#   u'TEAM_NAME': u'Toronto Raptors',
#   u'TOV': 4,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 3,
#   u'BLK': 0,
#   u'DREB': 3,
#   u'FG3A': 3,
#   u'FG3M': 3,
#   u'FG3_PCT': 1.0,
#   u'FGA': 15,
#   u'FGM': 9,
#   u'FG_PCT': 0.6,
#   u'FTA': 3,
#   u'FTM': 2,
#   u'FT_PCT': 0.667,
#   u'GAME_DATE': u'2015-11-10',
#   u'GAME_ID': u'0021500107',
#   u'MATCHUP': u'OKC @ WAS',
#   u'MIN': 30,
#   u'OREB': 3,
#   u'PF': 3,
#   u'PLAYER_ID': 201586,
#   u'PLAYER_NAME': u'Serge Ibaka',
#   u'PLUS_MINUS': 20,
#   u'PTS': 23,
#   u'REB': 6,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'OKC',
#   u'TEAM_NAME': u'Oklahoma City Thunder',
#   u'TOV': 2,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 2,
#   u'BLK': 1,
#   u'DREB': 7,
#   u'FG3A': 6,
#   u'FG3M': 4,
#   u'FG3_PCT': 0.667,
#   u'FGA': 13,
#   u'FGM': 8,
#   u'FG_PCT': 0.615,
#   u'FTA': 4,
#   u'FTM': 3,
#   u'FT_PCT': 0.75,
#   u'GAME_DATE': u'2015-11-09',
#   u'GAME_ID': u'0021500099',
#   u'MATCHUP': u'IND vs. ORL',
#   u'MIN': 35,
#   u'OREB': 0,
#   u'PF': 3,
#   u'PLAYER_ID': 201588,
#   u'PLAYER_NAME': u'George Hill',
#   u'PLUS_MINUS': 20,
#   u'PTS': 23,
#   u'REB': 7,
#   u'SEASON_ID': u'22015',
#   u'STL': 2,
#   u'TEAM_ABBREVIATION': u'IND',
#   u'TEAM_NAME': u'Indiana Pacers',
#   u'TOV': 0,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 1,
#   u'BLK': 0,
#   u'DREB': 7,
#   u'FG3A': 7,
#   u'FG3M': 4,
#   u'FG3_PCT': 0.571,
#   u'FGA': 14,
#   u'FGM': 8,
#   u'FG_PCT': 0.571,
#   u'FTA': 5,
#   u'FTM': 3,
#   u'FT_PCT': 0.6,
#   u'GAME_DATE': u'2015-11-08',
#   u'GAME_ID': u'0021500096',
#   u'MATCHUP': u'MIA vs. TOR',
#   u'MIN': 30,
#   u'OREB': 1,
#   u'PF': 3,
#   u'PLAYER_ID': 2547,
#   u'PLAYER_NAME': u'Chris Bosh',
#   u'PLUS_MINUS': 15,
#   u'PTS': 23,
#   u'REB': 8,
#   u'SEASON_ID': u'22015',
#   u'STL': 1,
#   u'TEAM_ABBREVIATION': u'MIA',
#   u'TEAM_NAME': u'Miami Heat',
#   u'TOV': 0,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 1,
#   u'BLK': 0,
#   u'DREB': 2,
#   u'FG3A': 5,
#   u'FG3M': 3,
#   u'FG3_PCT': 0.6,
#   u'FGA': 12,
#   u'FGM': 8,
#   u'FG_PCT': 0.667,
#   u'FTA': 4,
#   u'FTM': 4,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2015-11-07',
#   u'GAME_ID': u'0021500086',
#   u'MATCHUP': u'WAS @ ATL',
#   u'MIN': 39,
#   u'OREB': 1,
#   u'PF': 2,
#   u'PLAYER_ID': 203490,
#   u'PLAYER_NAME': u'Otto Porter',
#   u'PLUS_MINUS': -12,
#   u'PTS': 23,
#   u'REB': 3,
#   u'SEASON_ID': u'22015',
#   u'STL': 1,
#   u'TEAM_ABBREVIATION': u'WAS',
#   u'TEAM_NAME': u'Washington Wizards',
#   u'TOV': 1,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 2,
#   u'BLK': 0,
#   u'DREB': 4,
#   u'FG3A': 4,
#   u'FG3M': 2,
#   u'FG3_PCT': 0.5,
#   u'FGA': 16,
#   u'FGM': 10,
#   u'FG_PCT': 0.625,
#   u'FTA': 2,
#   u'FTM': 1,
#   u'FT_PCT': 0.5,
#   u'GAME_DATE': u'2015-11-07',
#   u'GAME_ID': u'0021500090',
#   u'MATCHUP': u'SAS vs. CHA',
#   u'MIN': 34,
#   u'OREB': 0,
#   u'PF': 3,
#   u'PLAYER_ID': 202695,
#   u'PLAYER_NAME': u'Kawhi Leonard',
#   u'PLUS_MINUS': 11,
#   u'PTS': 23,
#   u'REB': 4,
#   u'SEASON_ID': u'22015',
#   u'STL': 2,
#   u'TEAM_ABBREVIATION': u'SAS',
#   u'TEAM_NAME': u'San Antonio Spurs',
#   u'TOV': 0,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 1,
#   u'BLK': 1,
#   u'DREB': 3,
#   u'FG3A': 12,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.5,
#   u'FGA': 16,
#   u'FGM': 8,
#   u'FG_PCT': 0.5,
#   u'FTA': 1,
#   u'FTM': 1,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2015-11-07',
#   u'GAME_ID': u'0021500087',
#   u'MATCHUP': u'PHI vs. ORL',
#   u'MIN': 27,
#   u'OREB': 0,
#   u'PF': 2,
#   u'PLAYER_ID': 203477,
#   u'PLAYER_NAME': u'Isaiah Canaan',
#   u'PLUS_MINUS': 1,
#   u'PTS': 23,
#   u'REB': 3,
#   u'SEASON_ID': u'22015',
#   u'STL': 3,
#   u'TEAM_ABBREVIATION': u'PHI',
#   u'TEAM_NAME': u'Philadelphia 76ers',
#   u'TOV': 1,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 7,
#   u'BLK': 1,
#   u'DREB': 6,
#   u'FG3A': 4,
#   u'FG3M': 1,
#   u'FG3_PCT': 0.25,
#   u'FGA': 18,
#   u'FGM': 8,
#   u'FG_PCT': 0.444,
#   u'FTA': 8,
#   u'FTM': 6,
#   u'FT_PCT': 0.75,
#   u'GAME_DATE': u'2015-11-06',
#   u'GAME_ID': u'0021500082',
#   u'MATCHUP': u'DET @ PHX',
#   u'MIN': 30,
#   u'OREB': 0,
#   u'PF': 3,
#   u'PLAYER_ID': 202704,
#   u'PLAYER_NAME': u'Reggie Jackson',
#   u'PLUS_MINUS': 7,
#   u'PTS': 23,
#   u'REB': 6,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'DET',
#   u'TEAM_NAME': u'Detroit Pistons',
#   u'TOV': 4,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 1,
#   u'BLK': 4,
#   u'DREB': 6,
#   u'FG3A': 1,
#   u'FG3M': 0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 19,
#   u'FGM': 8,
#   u'FG_PCT': 0.421,
#   u'FTA': 7,
#   u'FTM': 7,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2015-11-06',
#   u'GAME_ID': u'0021500077',
#   u'MATCHUP': u'BKN vs. LAL',
#   u'MIN': 39,
#   u'OREB': 4,
#   u'PF': 3,
#   u'PLAYER_ID': 201572,
#   u'PLAYER_NAME': u'Brook Lopez',
#   u'PLUS_MINUS': -4,
#   u'PTS': 23,
#   u'REB': 10,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'BKN',
#   u'TEAM_NAME': u'Brooklyn Nets',
#   u'TOV': 2,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 2,
#   u'BLK': 2,
#   u'DREB': 4,
#   u'FG3A': 1,
#   u'FG3M': 0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 15,
#   u'FGM': 7,
#   u'FG_PCT': 0.467,
#   u'FTA': 12,
#   u'FTM': 9,
#   u'FT_PCT': 0.75,
#   u'GAME_DATE': u'2015-11-06',
#   u'GAME_ID': u'0021500075',
#   u'MATCHUP': u'TOR @ ORL',
#   u'MIN': 41,
#   u'OREB': 3,
#   u'PF': 1,
#   u'PLAYER_ID': 201942,
#   u'PLAYER_NAME': u'DeMar DeRozan',
#   u'PLUS_MINUS': 3,
#   u'PTS': 23,
#   u'REB': 7,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'TOR',
#   u'TEAM_NAME': u'Toronto Raptors',
#   u'TOV': 2,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 6,
#   u'BLK': 1,
#   u'DREB': 8,
#   u'FG3A': 2,
#   u'FG3M': 0,
#   u'FG3_PCT': 0.0,
#   u'FGA': 21,
#   u'FGM': 10,
#   u'FG_PCT': 0.476,
#   u'FTA': 3,
#   u'FTM': 3,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2015-11-04',
#   u'GAME_ID': u'0021500069',
#   u'MATCHUP': u'LAC @ GSW',
#   u'MIN': 38,
#   u'OREB': 2,
#   u'PF': 4,
#   u'PLAYER_ID': 201933,
#   u'PLAYER_NAME': u'Blake Griffin',
#   u'PLUS_MINUS': 8,
#   u'PTS': 23,
#   u'REB': 10,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'LAC',
#   u'TEAM_NAME': u'Los Angeles Clippers',
#   u'TOV': 2,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 0,
#   u'BLK': 0,
#   u'DREB': 6,
#   u'FG3A': 4,
#   u'FG3M': 1,
#   u'FG3_PCT': 0.25,
#   u'FGA': 22,
#   u'FGM': 10,
#   u'FG_PCT': 0.455,
#   u'FTA': 2,
#   u'FTM': 2,
#   u'FT_PCT': 1.0,
#   u'GAME_DATE': u'2015-11-04',
#   u'GAME_ID': u'0021500061',
#   u'MATCHUP': u'SAS @ WAS',
#   u'MIN': 35,
#   u'OREB': 3,
#   u'PF': 4,
#   u'PLAYER_ID': 202695,
#   u'PLAYER_NAME': u'Kawhi Leonard',
#   u'PLUS_MINUS': -12,
#   u'PTS': 23,
#   u'REB': 9,
#   u'SEASON_ID': u'22015',
#   u'STL': 1,
#   u'TEAM_ABBREVIATION': u'SAS',
#   u'TEAM_NAME': u'San Antonio Spurs',
#   u'TOV': 1,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 2,
#   u'BLK': 0,
#   u'DREB': 8,
#   u'FG3A': 0,
#   u'FG3M': 0,
#   u'FG3_PCT': None,
#   u'FGA': 10,
#   u'FGM': 10,
#   u'FG_PCT': 1.0,
#   u'FTA': 7,
#   u'FTM': 3,
#   u'FT_PCT': 0.429,
#   u'GAME_DATE': u'2015-11-04',
#   u'GAME_ID': u'0021500064',
#   u'MATCHUP': u'HOU vs. ORL',
#   u'MIN': 31,
#   u'OREB': 6,
#   u'PF': 4,
#   u'PLAYER_ID': 2730,
#   u'PLAYER_NAME': u'Dwight Howard',
#   u'PLUS_MINUS': 3,
#   u'PTS': 23,
#   u'REB': 14,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'HOU',
#   u'TEAM_NAME': u'Houston Rockets',
#   u'TOV': 3,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 3,
#   u'BLK': 1,
#   u'DREB': 3,
#   u'FG3A': 5,
#   u'FG3M': 1,
#   u'FG3_PCT': 0.2,
#   u'FGA': 23,
#   u'FGM': 9,
#   u'FG_PCT': 0.391,
#   u'FTA': 7,
#   u'FTM': 4,
#   u'FT_PCT': 0.571,
#   u'GAME_DATE': u'2015-11-04',
#   u'GAME_ID': u'0021500063',
#   u'MATCHUP': u'CLE vs. NYK',
#   u'MIN': 35,
#   u'OREB': 2,
#   u'PF': 1,
#   u'PLAYER_ID': 2544,
#   u'PLAYER_NAME': u'LeBron James',
#   u'PLUS_MINUS': 14,
#   u'PTS': 23,
#   u'REB': 5,
#   u'SEASON_ID': u'22015',
#   u'STL': 4,
#   u'TEAM_ABBREVIATION': u'CLE',
#   u'TEAM_NAME': u'Cleveland Cavaliers',
#   u'TOV': 3,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 0,
#   u'BLK': 4,
#   u'DREB': 9,
#   u'FG3A': 0,
#   u'FG3M': 0,
#   u'FG3_PCT': None,
#   u'FGA': 12,
#   u'FGM': 11,
#   u'FG_PCT': 0.917,
#   u'FTA': 2,
#   u'FTM': 1,
#   u'FT_PCT': 0.5,
#   u'GAME_DATE': u'2015-11-03',
#   u'GAME_ID': u'0021500055',
#   u'MATCHUP': u'MIA vs. ATL',
#   u'MIN': 31,
#   u'OREB': 5,
#   u'PF': 0,
#   u'PLAYER_ID': 202355,
#   u'PLAYER_NAME': u'Hassan Whiteside',
#   u'PLUS_MINUS': -4,
#   u'PTS': 23,
#   u'REB': 14,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'MIA',
#   u'TEAM_NAME': u'Miami Heat',
#   u'TOV': 3,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  ...]

# %% [markdown]
# ## Season_gamelogs (teams)
#
# http://stats.nba.com/stats/leaguegamelog?Counter=0&Direction=DESC&LeagueID=00&PlayerOrTeam=T&Season=2015-16&SeasonType=Regular+Season&Sorter=PTS

# %%
team_gamelogs = parser.season_gamelogs(content=scraper.season_gamelogs(season='2015-16', player_or_team='T'), player_or_team='T')

# %%
team_gamelogs
# Out:
# [{u'AST': 28,
#   u'BLK': 4,
#   u'DREB': 45,
#   u'FG3A': 29,
#   u'FG3M': 8,
#   u'FG3_PCT': 0.276,
#   u'FGA': 124,
#   u'FGM': 56,
#   u'FG_PCT': 0.452,
#   u'FTA': 46,
#   u'FTM': 27,
#   u'FT_PCT': 0.587,
#   u'GAME_DATE': u'2015-12-18',
#   u'GAME_ID': u'0021500391',
#   u'MATCHUP': u'DET @ CHI',
#   u'MIN': 340,
#   'OPPONENT_PTS': 144,
#   u'OREB': 19,
#   u'PF': 35,
#   u'PLUS_MINUS': 3,
#   u'PTS': 147,
#   u'REB': 64,
#   u'SEASON_ID': u'22015',
#   u'STL': 7,
#   u'TEAM_ABBREVIATION': u'DET',
#   u'TEAM_ID': 1610612765,
#   u'TEAM_NAME': u'Detroit Pistons',
#   u'TOV': 11,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 21,
#   u'BLK': 9,
#   u'DREB': 42,
#   u'FG3A': 22,
#   u'FG3M': 5,
#   u'FG3_PCT': 0.227,
#   u'FGA': 120,
#   u'FGM': 50,
#   u'FG_PCT': 0.417,
#   u'FTA': 44,
#   u'FTM': 39,
#   u'FT_PCT': 0.886,
#   u'GAME_DATE': u'2015-12-18',
#   u'GAME_ID': u'0021500391',
#   u'MATCHUP': u'CHI vs. DET',
#   u'MIN': 340,
#   'OPPONENT_PTS': 147,
#   u'OREB': 20,
#   u'PF': 35,
#   u'PLUS_MINUS': -3,
#   u'PTS': 144,
#   u'REB': 62,
#   u'SEASON_ID': u'22015',
#   u'STL': 5,
#   u'TEAM_ABBREVIATION': u'CHI',
#   u'TEAM_ID': 1610612741,
#   u'TEAM_NAME': u'Chicago Bulls',
#   u'TOV': 17,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 30,
#   u'BLK': 2,
#   u'DREB': 36,
#   u'FG3A': 23,
#   u'FG3M': 9,
#   u'FG3_PCT': 0.391,
#   u'FGA': 87,
#   u'FGM': 53,
#   u'FG_PCT': 0.609,
#   u'FTA': 34,
#   u'FTM': 27,
#   u'FT_PCT': 0.794,
#   u'GAME_DATE': u'2016-01-02',
#   u'GAME_ID': u'0021500496',
#   u'MATCHUP': u'SAC vs. PHX',
#   u'MIN': 240,
#   'OPPONENT_PTS': 119,
#   u'OREB': 10,
#   u'PF': 23,
#   u'PLUS_MINUS': 23,
#   u'PTS': 142,
#   u'REB': 46,
#   u'SEASON_ID': u'22015',
#   u'STL': 9,
#   u'TEAM_ABBREVIATION': u'SAC',
#   u'TEAM_ID': 1610612758,
#   u'TEAM_NAME': u'Sacramento Kings',
#   u'TOV': 15,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 28,
#   u'BLK': 6,
#   u'DREB': 32,
#   u'FG3A': 37,
#   u'FG3M': 22,
#   u'FG3_PCT': 0.595,
#   u'FGA': 91,
#   u'FGM': 47,
#   u'FG_PCT': 0.516,
#   u'FTA': 33,
#   u'FTM': 24,
#   u'FT_PCT': 0.727,
#   u'GAME_DATE': u'2016-01-18',
#   u'GAME_ID': u'0021500624',
#   u'MATCHUP': u'LAC vs. HOU',
#   u'MIN': 265,
#   'OPPONENT_PTS': 132,
#   u'OREB': 9,
#   u'PF': 30,
#   u'PLUS_MINUS': 8,
#   u'PTS': 140,
#   u'REB': 41,
#   u'SEASON_ID': u'22015',
#   u'STL': 10,
#   u'TEAM_ABBREVIATION': u'LAC',
#   u'TEAM_ID': 1610612746,
#   u'TEAM_NAME': u'Los Angeles Clippers',
#   u'TOV': 13,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 19,
#   u'BLK': 9,
#   u'DREB': 40,
#   u'FG3A': 27,
#   u'FG3M': 8,
#   u'FG3_PCT': 0.296,
#   u'FGA': 110,
#   u'FGM': 50,
#   u'FG_PCT': 0.455,
#   u'FTA': 38,
#   u'FTM': 31,
#   u'FT_PCT': 0.816,
#   u'GAME_DATE': u'2015-10-30',
#   u'GAME_ID': u'0021500022',
#   u'MATCHUP': u'OKC @ ORL',
#   u'MIN': 290,
#   'OPPONENT_PTS': 136,
#   u'OREB': 22,
#   u'PF': 28,
#   u'PLUS_MINUS': 3,
#   u'PTS': 139,
#   u'REB': 62,
#   u'SEASON_ID': u'22015',
#   u'STL': 8,
#   u'TEAM_ABBREVIATION': u'OKC',
#   u'TEAM_ID': 1610612760,
#   u'TEAM_NAME': u'Oklahoma City Thunder',
#   u'TOV': 21,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 25,
#   u'BLK': 10,
#   u'DREB': 35,
#   u'FG3A': 33,
#   u'FG3M': 12,
#   u'FG3_PCT': 0.364,
#   u'FGA': 106,
#   u'FGM': 47,
#   u'FG_PCT': 0.443,
#   u'FTA': 38,
#   u'FTM': 30,
#   u'FT_PCT': 0.789,
#   u'GAME_DATE': u'2015-10-30',
#   u'GAME_ID': u'0021500022',
#   u'MATCHUP': u'ORL vs. OKC',
#   u'MIN': 290,
#   'OPPONENT_PTS': 139,
#   u'OREB': 14,
#   u'PF': 31,
#   u'PLUS_MINUS': -3,
#   u'PTS': 136,
#   u'REB': 49,
#   u'SEASON_ID': u'22015',
#   u'STL': 10,
#   u'TEAM_ABBREVIATION': u'ORL',
#   u'TEAM_ID': 1610612753,
#   u'TEAM_NAME': u'Orlando Magic',
#   u'TOV': 18,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 32,
#   u'BLK': 9,
#   u'DREB': 42,
#   u'FG3A': 38,
#   u'FG3M': 22,
#   u'FG3_PCT': 0.579,
#   u'FGA': 81,
#   u'FGM': 46,
#   u'FG_PCT': 0.568,
#   u'FTA': 31,
#   u'FTM': 21,
#   u'FT_PCT': 0.677,
#   u'GAME_DATE': u'2015-11-27',
#   u'GAME_ID': u'0021500236',
#   u'MATCHUP': u'GSW @ PHX',
#   u'MIN': 240,
#   'OPPONENT_PTS': 116,
#   u'OREB': 11,
#   u'PF': 26,
#   u'PLUS_MINUS': 19,
#   u'PTS': 135,
#   u'REB': 53,
#   u'SEASON_ID': u'22015',
#   u'STL': 7,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_ID': 1610612744,
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 24,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 26,
#   u'BLK': 4,
#   u'DREB': 35,
#   u'FG3A': 30,
#   u'FG3M': 17,
#   u'FG3_PCT': 0.567,
#   u'FGA': 84,
#   u'FGM': 46,
#   u'FG_PCT': 0.548,
#   u'FTA': 35,
#   u'FTM': 25,
#   u'FT_PCT': 0.714,
#   u'GAME_DATE': u'2015-10-31',
#   u'GAME_ID': u'0021500035',
#   u'MATCHUP': u'GSW @ NOP',
#   u'MIN': 240,
#   'OPPONENT_PTS': 120,
#   u'OREB': 3,
#   u'PF': 24,
#   u'PLUS_MINUS': 14,
#   u'PTS': 134,
#   u'REB': 38,
#   u'SEASON_ID': u'22015',
#   u'STL': 10,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_ID': 1610612744,
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 10,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 33,
#   u'BLK': 2,
#   u'DREB': 31,
#   u'FG3A': 40,
#   u'FG3M': 19,
#   u'FG3_PCT': 0.475,
#   u'FGA': 85,
#   u'FGM': 46,
#   u'FG_PCT': 0.541,
#   u'FTA': 27,
#   u'FTM': 21,
#   u'FT_PCT': 0.778,
#   u'GAME_DATE': u'2016-01-18',
#   u'GAME_ID': u'0021500622',
#   u'MATCHUP': u'GSW @ CLE',
#   u'MIN': 240,
#   'OPPONENT_PTS': 98,
#   u'OREB': 6,
#   u'PF': 25,
#   u'PLUS_MINUS': 34,
#   u'PTS': 132,
#   u'REB': 37,
#   u'SEASON_ID': u'22015',
#   u'STL': 7,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_ID': 1610612744,
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 8,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 31,
#   u'BLK': 5,
#   u'DREB': 36,
#   u'FG3A': 32,
#   u'FG3M': 11,
#   u'FG3_PCT': 0.344,
#   u'FGA': 88,
#   u'FGM': 44,
#   u'FG_PCT': 0.5,
#   u'FTA': 52,
#   u'FTM': 33,
#   u'FT_PCT': 0.635,
#   u'GAME_DATE': u'2016-01-18',
#   u'GAME_ID': u'0021500624',
#   u'MATCHUP': u'HOU @ LAC',
#   u'MIN': 265,
#   'OPPONENT_PTS': 140,
#   u'OREB': 16,
#   u'PF': 28,
#   u'PLUS_MINUS': -8,
#   u'PTS': 132,
#   u'REB': 52,
#   u'SEASON_ID': u'22015',
#   u'STL': 8,
#   u'TEAM_ABBREVIATION': u'HOU',
#   u'TEAM_ID': 1610612745,
#   u'TEAM_NAME': u'Houston Rockets',
#   u'TOV': 14,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 26,
#   u'BLK': 7,
#   u'DREB': 40,
#   u'FG3A': 22,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.273,
#   u'FGA': 101,
#   u'FGM': 52,
#   u'FG_PCT': 0.515,
#   u'FTA': 30,
#   u'FTM': 22,
#   u'FT_PCT': 0.733,
#   u'GAME_DATE': u'2015-10-30',
#   u'GAME_ID': u'0021500031',
#   u'MATCHUP': u'SAC vs. LAL',
#   u'MIN': 240,
#   'OPPONENT_PTS': 114,
#   u'OREB': 16,
#   u'PF': 23,
#   u'PLUS_MINUS': 18,
#   u'PTS': 132,
#   u'REB': 56,
#   u'SEASON_ID': u'22015',
#   u'STL': 6,
#   u'TEAM_ABBREVIATION': u'SAC',
#   u'TEAM_ID': 1610612758,
#   u'TEAM_NAME': u'Sacramento Kings',
#   u'TOV': 14,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 21,
#   u'BLK': 7,
#   u'DREB': 30,
#   u'FG3A': 22,
#   u'FG3M': 8,
#   u'FG3_PCT': 0.364,
#   u'FGA': 86,
#   u'FGM': 43,
#   u'FG_PCT': 0.5,
#   u'FTA': 40,
#   u'FTM': 37,
#   u'FT_PCT': 0.925,
#   u'GAME_DATE': u'2015-12-29',
#   u'GAME_ID': u'0021500472',
#   u'MATCHUP': u'OKC vs. MIL',
#   u'MIN': 240,
#   'OPPONENT_PTS': 123,
#   u'OREB': 11,
#   u'PF': 19,
#   u'PLUS_MINUS': 8,
#   u'PTS': 131,
#   u'REB': 41,
#   u'SEASON_ID': u'22015',
#   u'STL': 12,
#   u'TEAM_ABBREVIATION': u'OKC',
#   u'TEAM_ID': 1610612760,
#   u'TEAM_NAME': u'Oklahoma City Thunder',
#   u'TOV': 12,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 29,
#   u'BLK': 6,
#   u'DREB': 36,
#   u'FG3A': 35,
#   u'FG3M': 16,
#   u'FG3_PCT': 0.457,
#   u'FGA': 95,
#   u'FGM': 52,
#   u'FG_PCT': 0.547,
#   u'FTA': 15,
#   u'FTM': 11,
#   u'FT_PCT': 0.733,
#   u'GAME_DATE': u'2015-12-08',
#   u'GAME_ID': u'0021500314',
#   u'MATCHUP': u'GSW @ IND',
#   u'MIN': 240,
#   'OPPONENT_PTS': 123,
#   u'OREB': 10,
#   u'PF': 19,
#   u'PLUS_MINUS': 8,
#   u'PTS': 131,
#   u'REB': 46,
#   u'SEASON_ID': u'22015',
#   u'STL': 10,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_ID': 1610612744,
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 15,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 34,
#   u'BLK': 3,
#   u'DREB': 37,
#   u'FG3A': 23,
#   u'FG3M': 12,
#   u'FG3_PCT': 0.522,
#   u'FGA': 90,
#   u'FGM': 50,
#   u'FG_PCT': 0.556,
#   u'FTA': 21,
#   u'FTM': 18,
#   u'FT_PCT': 0.857,
#   u'GAME_DATE': u'2016-01-27',
#   u'GAME_ID': u'0021500689',
#   u'MATCHUP': u'SAS vs. HOU',
#   u'MIN': 240,
#   'OPPONENT_PTS': 99,
#   u'OREB': 12,
#   u'PF': 28,
#   u'PLUS_MINUS': 31,
#   u'PTS': 130,
#   u'REB': 49,
#   u'SEASON_ID': u'22015',
#   u'STL': 7,
#   u'TEAM_ABBREVIATION': u'SAS',
#   u'TEAM_ID': 1610612759,
#   u'TEAM_NAME': u'San Antonio Spurs',
#   u'TOV': 14,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 28,
#   u'BLK': 6,
#   u'DREB': 41,
#   u'FG3A': 23,
#   u'FG3M': 12,
#   u'FG3_PCT': 0.522,
#   u'FGA': 81,
#   u'FGM': 49,
#   u'FG_PCT': 0.605,
#   u'FTA': 25,
#   u'FTM': 20,
#   u'FT_PCT': 0.8,
#   u'GAME_DATE': u'2016-01-02',
#   u'GAME_ID': u'0021500505',
#   u'MATCHUP': u'LAC vs. PHI',
#   u'MIN': 240,
#   'OPPONENT_PTS': 99,
#   u'OREB': 6,
#   u'PF': 17,
#   u'PLUS_MINUS': 31,
#   u'PTS': 130,
#   u'REB': 47,
#   u'SEASON_ID': u'22015',
#   u'STL': 7,
#   u'TEAM_ABBREVIATION': u'LAC',
#   u'TEAM_ID': 1610612746,
#   u'TEAM_NAME': u'Los Angeles Clippers',
#   u'TOV': 15,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 24,
#   u'BLK': 11,
#   u'DREB': 29,
#   u'FG3A': 24,
#   u'FG3M': 11,
#   u'FG3_PCT': 0.458,
#   u'FGA': 78,
#   u'FGM': 44,
#   u'FG_PCT': 0.564,
#   u'FTA': 39,
#   u'FTM': 31,
#   u'FT_PCT': 0.795,
#   u'GAME_DATE': u'2015-12-20',
#   u'GAME_ID': u'0021500409',
#   u'MATCHUP': u'NOP @ DEN',
#   u'MIN': 240,
#   'OPPONENT_PTS': 125,
#   u'OREB': 7,
#   u'PF': 22,
#   u'PLUS_MINUS': 5,
#   u'PTS': 130,
#   u'REB': 36,
#   u'SEASON_ID': u'22015',
#   u'STL': 4,
#   u'TEAM_ABBREVIATION': u'NOP',
#   u'TEAM_ID': 1610612740,
#   u'TEAM_NAME': u'New Orleans Pelicans',
#   u'TOV': 10,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 26,
#   u'BLK': 4,
#   u'DREB': 40,
#   u'FG3A': 23,
#   u'FG3M': 14,
#   u'FG3_PCT': 0.609,
#   u'FGA': 91,
#   u'FGM': 47,
#   u'FG_PCT': 0.516,
#   u'FTA': 23,
#   u'FTM': 22,
#   u'FT_PCT': 0.957,
#   u'GAME_DATE': u'2015-11-03',
#   u'GAME_ID': u'0021500053',
#   u'MATCHUP': u'CHA vs. CHI',
#   u'MIN': 240,
#   'OPPONENT_PTS': 105,
#   u'OREB': 12,
#   u'PF': 11,
#   u'PLUS_MINUS': 25,
#   u'PTS': 130,
#   u'REB': 52,
#   u'SEASON_ID': u'22015',
#   u'STL': 6,
#   u'TEAM_ABBREVIATION': u'CHA',
#   u'TEAM_ID': 1610612766,
#   u'TEAM_NAME': u'Charlotte Hornets',
#   u'TOV': 10,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 27,
#   u'BLK': 2,
#   u'DREB': 30,
#   u'FG3A': 44,
#   u'FG3M': 20,
#   u'FG3_PCT': 0.455,
#   u'FGA': 110,
#   u'FGM': 44,
#   u'FG_PCT': 0.4,
#   u'FTA': 26,
#   u'FTM': 21,
#   u'FT_PCT': 0.808,
#   u'GAME_DATE': u'2016-01-25',
#   u'GAME_ID': u'0021500674',
#   u'MATCHUP': u'CHA @ SAC',
#   u'MIN': 290,
#   'OPPONENT_PTS': 128,
#   u'OREB': 16,
#   u'PF': 31,
#   u'PLUS_MINUS': 1,
#   u'PTS': 129,
#   u'REB': 46,
#   u'SEASON_ID': u'22015',
#   u'STL': 11,
#   u'TEAM_ABBREVIATION': u'CHA',
#   u'TEAM_ID': 1610612766,
#   u'TEAM_NAME': u'Charlotte Hornets',
#   u'TOV': 10,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 25,
#   u'BLK': 4,
#   u'DREB': 25,
#   u'FG3A': 26,
#   u'FG3M': 10,
#   u'FG3_PCT': 0.385,
#   u'FGA': 91,
#   u'FGM': 46,
#   u'FG_PCT': 0.505,
#   u'FTA': 38,
#   u'FTM': 27,
#   u'FT_PCT': 0.711,
#   u'GAME_DATE': u'2016-01-17',
#   u'GAME_ID': u'0021500613',
#   u'MATCHUP': u'DEN vs. IND',
#   u'MIN': 240,
#   'OPPONENT_PTS': 126,
#   u'OREB': 17,
#   u'PF': 26,
#   u'PLUS_MINUS': 3,
#   u'PTS': 129,
#   u'REB': 42,
#   u'SEASON_ID': u'22015',
#   u'STL': 12,
#   u'TEAM_ABBREVIATION': u'DEN',
#   u'TEAM_ID': 1610612743,
#   u'TEAM_NAME': u'Denver Nuggets',
#   u'TOV': 17,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 23,
#   u'BLK': 7,
#   u'DREB': 35,
#   u'FG3A': 23,
#   u'FG3M': 10,
#   u'FG3_PCT': 0.435,
#   u'FGA': 77,
#   u'FGM': 44,
#   u'FG_PCT': 0.571,
#   u'FTA': 37,
#   u'FTM': 31,
#   u'FT_PCT': 0.838,
#   u'GAME_DATE': u'2015-11-25',
#   u'GAME_ID': u'0021500221',
#   u'MATCHUP': u'SAC @ MIL',
#   u'MIN': 240,
#   'OPPONENT_PTS': 118,
#   u'OREB': 7,
#   u'PF': 19,
#   u'PLUS_MINUS': 11,
#   u'PTS': 129,
#   u'REB': 42,
#   u'SEASON_ID': u'22015',
#   u'STL': 9,
#   u'TEAM_ABBREVIATION': u'SAC',
#   u'TEAM_ID': 1610612758,
#   u'TEAM_NAME': u'Sacramento Kings',
#   u'TOV': 9,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 34,
#   u'BLK': 7,
#   u'DREB': 27,
#   u'FG3A': 38,
#   u'FG3M': 18,
#   u'FG3_PCT': 0.474,
#   u'FGA': 89,
#   u'FGM': 48,
#   u'FG_PCT': 0.539,
#   u'FTA': 16,
#   u'FTM': 15,
#   u'FT_PCT': 0.938,
#   u'GAME_DATE': u'2015-11-12',
#   u'GAME_ID': u'0021500125',
#   u'MATCHUP': u'GSW @ MIN',
#   u'MIN': 240,
#   'OPPONENT_PTS': 116,
#   u'OREB': 6,
#   u'PF': 25,
#   u'PLUS_MINUS': 13,
#   u'PTS': 129,
#   u'REB': 33,
#   u'SEASON_ID': u'22015',
#   u'STL': 8,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_ID': 1610612744,
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 11,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 23,
#   u'BLK': 2,
#   u'DREB': 43,
#   u'FG3A': 20,
#   u'FG3M': 11,
#   u'FG3_PCT': 0.55,
#   u'FGA': 99,
#   u'FGM': 46,
#   u'FG_PCT': 0.465,
#   u'FTA': 29,
#   u'FTM': 25,
#   u'FT_PCT': 0.862,
#   u'GAME_DATE': u'2016-01-26',
#   u'GAME_ID': u'0021500679',
#   u'MATCHUP': u'OKC @ NYK',
#   u'MIN': 265,
#   'OPPONENT_PTS': 122,
#   u'OREB': 16,
#   u'PF': 22,
#   u'PLUS_MINUS': 6,
#   u'PTS': 128,
#   u'REB': 59,
#   u'SEASON_ID': u'22015',
#   u'STL': 7,
#   u'TEAM_ABBREVIATION': u'OKC',
#   u'TEAM_ID': 1610612760,
#   u'TEAM_NAME': u'Oklahoma City Thunder',
#   u'TOV': 14,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 36,
#   u'BLK': 8,
#   u'DREB': 47,
#   u'FG3A': 23,
#   u'FG3M': 7,
#   u'FG3_PCT': 0.304,
#   u'FGA': 91,
#   u'FGM': 48,
#   u'FG_PCT': 0.527,
#   u'FTA': 32,
#   u'FTM': 25,
#   u'FT_PCT': 0.781,
#   u'GAME_DATE': u'2016-01-25',
#   u'GAME_ID': u'0021500674',
#   u'MATCHUP': u'SAC vs. CHA',
#   u'MIN': 290,
#   'OPPONENT_PTS': 129,
#   u'OREB': 9,
#   u'PF': 31,
#   u'PLUS_MINUS': -1,
#   u'PTS': 128,
#   u'REB': 56,
#   u'SEASON_ID': u'22015',
#   u'STL': 4,
#   u'TEAM_ABBREVIATION': u'SAC',
#   u'TEAM_ID': 1610612758,
#   u'TEAM_NAME': u'Sacramento Kings',
#   u'TOV': 23,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 35,
#   u'BLK': 8,
#   u'DREB': 39,
#   u'FG3A': 37,
#   u'FG3M': 19,
#   u'FG3_PCT': 0.514,
#   u'FGA': 87,
#   u'FGM': 49,
#   u'FG_PCT': 0.563,
#   u'FTA': 15,
#   u'FTM': 11,
#   u'FT_PCT': 0.733,
#   u'GAME_DATE': u'2016-01-09',
#   u'GAME_ID': u'0021500556',
#   u'MATCHUP': u'GSW @ SAC',
#   u'MIN': 240,
#   'OPPONENT_PTS': 116,
#   u'OREB': 9,
#   u'PF': 25,
#   u'PLUS_MINUS': 12,
#   u'PTS': 128,
#   u'REB': 48,
#   u'SEASON_ID': u'22015',
#   u'STL': 5,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_ID': 1610612744,
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 19,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 36,
#   u'BLK': 5,
#   u'DREB': 43,
#   u'FG3A': 32,
#   u'FG3M': 18,
#   u'FG3_PCT': 0.563,
#   u'FGA': 87,
#   u'FGM': 46,
#   u'FG_PCT': 0.529,
#   u'FTA': 21,
#   u'FTM': 18,
#   u'FT_PCT': 0.857,
#   u'GAME_DATE': u'2016-01-08',
#   u'GAME_ID': u'0021500548',
#   u'MATCHUP': u'GSW @ POR',
#   u'MIN': 240,
#   'OPPONENT_PTS': 108,
#   u'OREB': 5,
#   u'PF': 20,
#   u'PLUS_MINUS': 20,
#   u'PTS': 128,
#   u'REB': 48,
#   u'SEASON_ID': u'22015',
#   u'STL': 6,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_ID': 1610612744,
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 15,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 32,
#   u'BLK': 4,
#   u'DREB': 40,
#   u'FG3A': 32,
#   u'FG3M': 15,
#   u'FG3_PCT': 0.469,
#   u'FGA': 88,
#   u'FGM': 46,
#   u'FG_PCT': 0.523,
#   u'FTA': 27,
#   u'FTM': 21,
#   u'FT_PCT': 0.778,
#   u'GAME_DATE': u'2015-12-16',
#   u'GAME_ID': u'0021500381',
#   u'MATCHUP': u'GSW vs. PHX',
#   u'MIN': 240,
#   'OPPONENT_PTS': 103,
#   u'OREB': 9,
#   u'PF': 17,
#   u'PLUS_MINUS': 25,
#   u'PTS': 128,
#   u'REB': 49,
#   u'SEASON_ID': u'22015',
#   u'STL': 12,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_ID': 1610612744,
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 17,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 33,
#   u'BLK': 4,
#   u'DREB': 33,
#   u'FG3A': 29,
#   u'FG3M': 14,
#   u'FG3_PCT': 0.483,
#   u'FGA': 81,
#   u'FGM': 47,
#   u'FG_PCT': 0.58,
#   u'FTA': 21,
#   u'FTM': 19,
#   u'FT_PCT': 0.905,
#   u'GAME_DATE': u'2016-01-27',
#   u'GAME_ID': u'0021500691',
#   u'MATCHUP': u'GSW vs. DAL',
#   u'MIN': 240,
#   'OPPONENT_PTS': 107,
#   u'OREB': 7,
#   u'PF': 18,
#   u'PLUS_MINUS': 20,
#   u'PTS': 127,
#   u'REB': 40,
#   u'SEASON_ID': u'22015',
#   u'STL': 5,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_ID': 1610612744,
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 9,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 32,
#   u'BLK': 7,
#   u'DREB': 23,
#   u'FG3A': 21,
#   u'FG3M': 10,
#   u'FG3_PCT': 0.476,
#   u'FGA': 78,
#   u'FGM': 48,
#   u'FG_PCT': 0.615,
#   u'FTA': 24,
#   u'FTM': 21,
#   u'FT_PCT': 0.875,
#   u'GAME_DATE': u'2015-12-16',
#   u'GAME_ID': u'0021500376',
#   u'MATCHUP': u'ATL vs. PHI',
#   u'MIN': 240,
#   'OPPONENT_PTS': 106,
#   u'OREB': 2,
#   u'PF': 21,
#   u'PLUS_MINUS': 21,
#   u'PTS': 127,
#   u'REB': 25,
#   u'SEASON_ID': u'22015',
#   u'STL': 11,
#   u'TEAM_ABBREVIATION': u'ATL',
#   u'TEAM_ID': 1610612737,
#   u'TEAM_NAME': u'Atlanta Hawks',
#   u'TOV': 12,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 24,
#   u'BLK': 1,
#   u'DREB': 37,
#   u'FG3A': 27,
#   u'FG3M': 12,
#   u'FG3_PCT': 0.444,
#   u'FGA': 87,
#   u'FGM': 44,
#   u'FG_PCT': 0.506,
#   u'FTA': 44,
#   u'FTM': 27,
#   u'FT_PCT': 0.614,
#   u'GAME_DATE': u'2015-12-02',
#   u'GAME_ID': u'0021500270',
#   u'MATCHUP': u'DET vs. PHX',
#   u'MIN': 265,
#   'OPPONENT_PTS': 122,
#   u'OREB': 13,
#   u'PF': 20,
#   u'PLUS_MINUS': 5,
#   u'PTS': 127,
#   u'REB': 50,
#   u'SEASON_ID': u'22015',
#   u'STL': 10,
#   u'TEAM_ABBREVIATION': u'DET',
#   u'TEAM_ID': 1610612765,
#   u'TEAM_NAME': u'Detroit Pistons',
#   u'TOV': 20,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 24,
#   u'BLK': 7,
#   u'DREB': 40,
#   u'FG3A': 29,
#   u'FG3M': 9,
#   u'FG3_PCT': 0.31,
#   u'FGA': 98,
#   u'FGM': 49,
#   u'FG_PCT': 0.5,
#   u'FTA': 26,
#   u'FTM': 20,
#   u'FT_PCT': 0.769,
#   u'GAME_DATE': u'2015-11-23',
#   u'GAME_ID': u'0021500202',
#   u'MATCHUP': u'CHA vs. SAC',
#   u'MIN': 265,
#   'OPPONENT_PTS': 122,
#   u'OREB': 8,
#   u'PF': 19,
#   u'PLUS_MINUS': 5,
#   u'PTS': 127,
#   u'REB': 48,
#   u'SEASON_ID': u'22015',
#   u'STL': 10,
#   u'TEAM_ABBREVIATION': u'CHA',
#   u'TEAM_ID': 1610612766,
#   u'TEAM_NAME': u'Charlotte Hornets',
#   u'TOV': 19,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 23,
#   u'BLK': 6,
#   u'DREB': 32,
#   u'FG3A': 20,
#   u'FG3M': 10,
#   u'FG3_PCT': 0.5,
#   u'FGA': 91,
#   u'FGM': 48,
#   u'FG_PCT': 0.527,
#   u'FTA': 21,
#   u'FTM': 20,
#   u'FT_PCT': 0.952,
#   u'GAME_DATE': u'2016-01-27',
#   u'GAME_ID': u'0021500688',
#   u'MATCHUP': u'OKC @ MIN',
#   u'MIN': 240,
#   'OPPONENT_PTS': 123,
#   u'OREB': 15,
#   u'PF': 25,
#   u'PLUS_MINUS': 3,
#   u'PTS': 126,
#   u'REB': 47,
#   u'SEASON_ID': u'22015',
#   u'STL': 0,
#   u'TEAM_ABBREVIATION': u'OKC',
#   u'TEAM_ID': 1610612760,
#   u'TEAM_NAME': u'Oklahoma City Thunder',
#   u'TOV': 13,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 27,
#   u'BLK': 6,
#   u'DREB': 24,
#   u'FG3A': 20,
#   u'FG3M': 9,
#   u'FG3_PCT': 0.45,
#   u'FGA': 82,
#   u'FGM': 48,
#   u'FG_PCT': 0.585,
#   u'FTA': 30,
#   u'FTM': 21,
#   u'FT_PCT': 0.7,
#   u'GAME_DATE': u'2016-01-17',
#   u'GAME_ID': u'0021500613',
#   u'MATCHUP': u'IND @ DEN',
#   u'MIN': 240,
#   'OPPONENT_PTS': 129,
#   u'OREB': 9,
#   u'PF': 29,
#   u'PLUS_MINUS': -3,
#   u'PTS': 126,
#   u'REB': 33,
#   u'SEASON_ID': u'22015',
#   u'STL': 10,
#   u'TEAM_ABBREVIATION': u'IND',
#   u'TEAM_ID': 1610612754,
#   u'TEAM_NAME': u'Indiana Pacers',
#   u'TOV': 15,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 36,
#   u'BLK': 6,
#   u'DREB': 34,
#   u'FG3A': 32,
#   u'FG3M': 13,
#   u'FG3_PCT': 0.406,
#   u'FGA': 92,
#   u'FGM': 49,
#   u'FG_PCT': 0.533,
#   u'FTA': 19,
#   u'FTM': 15,
#   u'FT_PCT': 0.789,
#   u'GAME_DATE': u'2016-01-07',
#   u'GAME_ID': u'0021500536',
#   u'MATCHUP': u'ATL @ PHI',
#   u'MIN': 240,
#   'OPPONENT_PTS': 98,
#   u'OREB': 14,
#   u'PF': 23,
#   u'PLUS_MINUS': 28,
#   u'PTS': 126,
#   u'REB': 48,
#   u'SEASON_ID': u'22015',
#   u'STL': 18,
#   u'TEAM_ABBREVIATION': u'ATL',
#   u'TEAM_ID': 1610612737,
#   u'TEAM_NAME': u'Atlanta Hawks',
#   u'TOV': 17,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 32,
#   u'BLK': 7,
#   u'DREB': 37,
#   u'FG3A': 33,
#   u'FG3M': 15,
#   u'FG3_PCT': 0.455,
#   u'FGA': 90,
#   u'FGM': 47,
#   u'FG_PCT': 0.522,
#   u'FTA': 28,
#   u'FTM': 17,
#   u'FT_PCT': 0.607,
#   u'GAME_DATE': u'2015-12-12',
#   u'GAME_ID': u'0021500349',
#   u'MATCHUP': u'HOU vs. LAL',
#   u'MIN': 240,
#   'OPPONENT_PTS': 97,
#   u'OREB': 15,
#   u'PF': 15,
#   u'PLUS_MINUS': 29,
#   u'PTS': 126,
#   u'REB': 52,
#   u'SEASON_ID': u'22015',
#   u'STL': 16,
#   u'TEAM_ABBREVIATION': u'HOU',
#   u'TEAM_ID': 1610612745,
#   u'TEAM_NAME': u'Houston Rockets',
#   u'TOV': 16,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 38,
#   u'BLK': 9,
#   u'DREB': 43,
#   u'FG3A': 32,
#   u'FG3M': 12,
#   u'FG3_PCT': 0.375,
#   u'FGA': 95,
#   u'FGM': 50,
#   u'FG_PCT': 0.526,
#   u'FTA': 20,
#   u'FTM': 13,
#   u'FT_PCT': 0.65,
#   u'GAME_DATE': u'2016-01-20',
#   u'GAME_ID': u'0021500634',
#   u'MATCHUP': u'GSW @ CHI',
#   u'MIN': 240,
#   'OPPONENT_PTS': 94,
#   u'OREB': 12,
#   u'PF': 17,
#   u'PLUS_MINUS': 31,
#   u'PTS': 125,
#   u'REB': 55,
#   u'SEASON_ID': u'22015',
#   u'STL': 8,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_ID': 1610612744,
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 10,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 23,
#   u'BLK': 5,
#   u'DREB': 33,
#   u'FG3A': 27,
#   u'FG3M': 13,
#   u'FG3_PCT': 0.481,
#   u'FGA': 81,
#   u'FGM': 43,
#   u'FG_PCT': 0.531,
#   u'FTA': 29,
#   u'FTM': 26,
#   u'FT_PCT': 0.897,
#   u'GAME_DATE': u'2016-01-08',
#   u'GAME_ID': u'0021500543',
#   u'MATCHUP': u'CLE @ MIN',
#   u'MIN': 240,
#   'OPPONENT_PTS': 99,
#   u'OREB': 10,
#   u'PF': 19,
#   u'PLUS_MINUS': 26,
#   u'PTS': 125,
#   u'REB': 43,
#   u'SEASON_ID': u'22015',
#   u'STL': 8,
#   u'TEAM_ABBREVIATION': u'CLE',
#   u'TEAM_ID': 1610612739,
#   u'TEAM_NAME': u'Cleveland Cavaliers',
#   u'TOV': 12,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 26,
#   u'BLK': 4,
#   u'DREB': 26,
#   u'FG3A': 35,
#   u'FG3M': 17,
#   u'FG3_PCT': 0.486,
#   u'FGA': 96,
#   u'FGM': 45,
#   u'FG_PCT': 0.469,
#   u'FTA': 22,
#   u'FTM': 18,
#   u'FT_PCT': 0.818,
#   u'GAME_DATE': u'2015-12-20',
#   u'GAME_ID': u'0021500409',
#   u'MATCHUP': u'DEN vs. NOP',
#   u'MIN': 240,
#   'OPPONENT_PTS': 130,
#   u'OREB': 13,
#   u'PF': 25,
#   u'PLUS_MINUS': -5,
#   u'PTS': 125,
#   u'REB': 39,
#   u'SEASON_ID': u'22015',
#   u'STL': 5,
#   u'TEAM_ABBREVIATION': u'DEN',
#   u'TEAM_ID': 1610612743,
#   u'TEAM_NAME': u'Denver Nuggets',
#   u'TOV': 6,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 31,
#   u'BLK': 3,
#   u'DREB': 36,
#   u'FG3A': 26,
#   u'FG3M': 13,
#   u'FG3_PCT': 0.5,
#   u'FGA': 84,
#   u'FGM': 47,
#   u'FG_PCT': 0.56,
#   u'FTA': 23,
#   u'FTM': 18,
#   u'FT_PCT': 0.783,
#   u'GAME_DATE': u'2015-12-08',
#   u'GAME_ID': u'0021500316',
#   u'MATCHUP': u'OKC @ MEM',
#   u'MIN': 240,
#   'OPPONENT_PTS': 88,
#   u'OREB': 10,
#   u'PF': 17,
#   u'PLUS_MINUS': 37,
#   u'PTS': 125,
#   u'REB': 46,
#   u'SEASON_ID': u'22015',
#   u'STL': 11,
#   u'TEAM_ABBREVIATION': u'OKC',
#   u'TEAM_ID': 1610612760,
#   u'TEAM_NAME': u'Oklahoma City Thunder',
#   u'TOV': 12,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 27,
#   u'BLK': 2,
#   u'DREB': 43,
#   u'FG3A': 23,
#   u'FG3M': 15,
#   u'FG3_PCT': 0.652,
#   u'FGA': 86,
#   u'FGM': 44,
#   u'FG_PCT': 0.512,
#   u'FTA': 29,
#   u'FTM': 22,
#   u'FT_PCT': 0.759,
#   u'GAME_DATE': u'2015-11-10',
#   u'GAME_ID': u'0021500107',
#   u'MATCHUP': u'OKC @ WAS',
#   u'MIN': 240,
#   'OPPONENT_PTS': 101,
#   u'OREB': 10,
#   u'PF': 22,
#   u'PLUS_MINUS': 24,
#   u'PTS': 125,
#   u'REB': 53,
#   u'SEASON_ID': u'22015',
#   u'STL': 4,
#   u'TEAM_ABBREVIATION': u'OKC',
#   u'TEAM_ID': 1610612760,
#   u'TEAM_NAME': u'Oklahoma City Thunder',
#   u'TOV': 13,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 20,
#   u'BLK': 4,
#   u'DREB': 43,
#   u'FG3A': 27,
#   u'FG3M': 14,
#   u'FG3_PCT': 0.519,
#   u'FGA': 88,
#   u'FGM': 41,
#   u'FG_PCT': 0.466,
#   u'FTA': 32,
#   u'FTM': 28,
#   u'FT_PCT': 0.875,
#   u'GAME_DATE': u'2016-01-18',
#   u'GAME_ID': u'0021500616',
#   u'MATCHUP': u'CHA vs. UTA',
#   u'MIN': 290,
#   'OPPONENT_PTS': 119,
#   u'OREB': 7,
#   u'PF': 18,
#   u'PLUS_MINUS': 5,
#   u'PTS': 124,
#   u'REB': 50,
#   u'SEASON_ID': u'22015',
#   u'STL': 6,
#   u'TEAM_ABBREVIATION': u'CHA',
#   u'TEAM_ID': 1610612766,
#   u'TEAM_NAME': u'Charlotte Hornets',
#   u'TOV': 16,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 28,
#   u'BLK': 11,
#   u'DREB': 50,
#   u'FG3A': 31,
#   u'FG3M': 9,
#   u'FG3_PCT': 0.29,
#   u'FGA': 107,
#   u'FGM': 42,
#   u'FG_PCT': 0.393,
#   u'FTA': 39,
#   u'FTM': 31,
#   u'FT_PCT': 0.795,
#   u'GAME_DATE': u'2015-12-11',
#   u'GAME_ID': u'0021500336',
#   u'MATCHUP': u'GSW @ BOS',
#   u'MIN': 290,
#   'OPPONENT_PTS': 119,
#   u'OREB': 17,
#   u'PF': 22,
#   u'PLUS_MINUS': 5,
#   u'PTS': 124,
#   u'REB': 67,
#   u'SEASON_ID': u'22015',
#   u'STL': 10,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_ID': 1610612744,
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 18,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 31,
#   u'BLK': 4,
#   u'DREB': 36,
#   u'FG3A': 30,
#   u'FG3M': 17,
#   u'FG3_PCT': 0.567,
#   u'FGA': 73,
#   u'FGM': 38,
#   u'FG_PCT': 0.521,
#   u'FTA': 36,
#   u'FTM': 31,
#   u'FT_PCT': 0.861,
#   u'GAME_DATE': u'2015-11-19',
#   u'GAME_ID': u'0021500177',
#   u'MATCHUP': u'GSW @ LAC',
#   u'MIN': 240,
#   'OPPONENT_PTS': 117,
#   u'OREB': 8,
#   u'PF': 20,
#   u'PLUS_MINUS': 7,
#   u'PTS': 124,
#   u'REB': 44,
#   u'SEASON_ID': u'22015',
#   u'STL': 4,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_ID': 1610612744,
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 19,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 26,
#   u'BLK': 8,
#   u'DREB': 35,
#   u'FG3A': 20,
#   u'FG3M': 4,
#   u'FG3_PCT': 0.2,
#   u'FGA': 94,
#   u'FGM': 49,
#   u'FG_PCT': 0.521,
#   u'FTA': 30,
#   u'FTM': 22,
#   u'FT_PCT': 0.733,
#   u'GAME_DATE': u'2015-11-08',
#   u'GAME_ID': u'0021500097',
#   u'MATCHUP': u'OKC vs. PHX',
#   u'MIN': 240,
#   'OPPONENT_PTS': 103,
#   u'OREB': 17,
#   u'PF': 25,
#   u'PLUS_MINUS': 21,
#   u'PTS': 124,
#   u'REB': 52,
#   u'SEASON_ID': u'22015',
#   u'STL': 14,
#   u'TEAM_ABBREVIATION': u'OKC',
#   u'TEAM_ID': 1610612760,
#   u'TEAM_NAME': u'Oklahoma City Thunder',
#   u'TOV': 15,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 30,
#   u'BLK': 5,
#   u'DREB': 37,
#   u'FG3A': 31,
#   u'FG3M': 11,
#   u'FG3_PCT': 0.355,
#   u'FGA': 85,
#   u'FGM': 45,
#   u'FG_PCT': 0.529,
#   u'FTA': 30,
#   u'FTM': 22,
#   u'FT_PCT': 0.733,
#   u'GAME_DATE': u'2016-01-30',
#   u'GAME_ID': u'0021500711',
#   u'MATCHUP': u'WAS @ HOU',
#   u'MIN': 180,
#   'OPPONENT_PTS': 122,
#   u'OREB': 7,
#   u'PF': 25,
#   u'PLUS_MINUS': 1,
#   u'PTS': 123,
#   u'REB': 44,
#   u'SEASON_ID': u'22015',
#   u'STL': 6,
#   u'TEAM_ABBREVIATION': u'WAS',
#   u'TEAM_ID': 1610612764,
#   u'TEAM_NAME': u'Washington Wizards',
#   u'TOV': 13,
#   u'VIDEO_AVAILABLE': 0,
#   u'WL': None},
#  {u'AST': 31,
#   u'BLK': 4,
#   u'DREB': 23,
#   u'FG3A': 14,
#   u'FG3M': 5,
#   u'FG3_PCT': 0.357,
#   u'FGA': 90,
#   u'FGM': 50,
#   u'FG_PCT': 0.556,
#   u'FTA': 28,
#   u'FTM': 18,
#   u'FT_PCT': 0.643,
#   u'GAME_DATE': u'2016-01-27',
#   u'GAME_ID': u'0021500688',
#   u'MATCHUP': u'MIN vs. OKC',
#   u'MIN': 240,
#   'OPPONENT_PTS': 126,
#   u'OREB': 12,
#   u'PF': 16,
#   u'PLUS_MINUS': -3,
#   u'PTS': 123,
#   u'REB': 35,
#   u'SEASON_ID': u'22015',
#   u'STL': 6,
#   u'TEAM_ABBREVIATION': u'MIN',
#   u'TEAM_ID': 1610612750,
#   u'TEAM_NAME': u'Minnesota Timberwolves',
#   u'TOV': 9,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 23,
#   u'BLK': 7,
#   u'DREB': 38,
#   u'FG3A': 30,
#   u'FG3M': 12,
#   u'FG3_PCT': 0.4,
#   u'FGA': 80,
#   u'FGM': 38,
#   u'FG_PCT': 0.475,
#   u'FTA': 59,
#   u'FTM': 35,
#   u'FT_PCT': 0.593,
#   u'GAME_DATE': u'2016-01-20',
#   u'GAME_ID': u'0021500635',
#   u'MATCHUP': u'DET @ HOU',
#   u'MIN': 240,
#   'OPPONENT_PTS': 114,
#   u'OREB': 14,
#   u'PF': 17,
#   u'PLUS_MINUS': 9,
#   u'PTS': 123,
#   u'REB': 52,
#   u'SEASON_ID': u'22015',
#   u'STL': 8,
#   u'TEAM_ABBREVIATION': u'DET',
#   u'TEAM_ID': 1610612765,
#   u'TEAM_NAME': u'Detroit Pistons',
#   u'TOV': 10,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 34,
#   u'BLK': 2,
#   u'DREB': 30,
#   u'FG3A': 21,
#   u'FG3M': 9,
#   u'FG3_PCT': 0.429,
#   u'FGA': 86,
#   u'FGM': 52,
#   u'FG_PCT': 0.605,
#   u'FTA': 13,
#   u'FTM': 10,
#   u'FT_PCT': 0.769,
#   u'GAME_DATE': u'2016-01-06',
#   u'GAME_ID': u'0021500532',
#   u'MATCHUP': u'SAS vs. UTA',
#   u'MIN': 240,
#   'OPPONENT_PTS': 98,
#   u'OREB': 8,
#   u'PF': 21,
#   u'PLUS_MINUS': 25,
#   u'PTS': 123,
#   u'REB': 38,
#   u'SEASON_ID': u'22015',
#   u'STL': 10,
#   u'TEAM_ABBREVIATION': u'SAS',
#   u'TEAM_ID': 1610612759,
#   u'TEAM_NAME': u'San Antonio Spurs',
#   u'TOV': 13,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 32,
#   u'BLK': 5,
#   u'DREB': 31,
#   u'FG3A': 20,
#   u'FG3M': 9,
#   u'FG3_PCT': 0.45,
#   u'FGA': 90,
#   u'FGM': 49,
#   u'FG_PCT': 0.544,
#   u'FTA': 20,
#   u'FTM': 16,
#   u'FT_PCT': 0.8,
#   u'GAME_DATE': u'2016-01-04',
#   u'GAME_ID': u'0021500516',
#   u'MATCHUP': u'SAS @ MIL',
#   u'MIN': 240,
#   'OPPONENT_PTS': 98,
#   u'OREB': 13,
#   u'PF': 20,
#   u'PLUS_MINUS': 25,
#   u'PTS': 123,
#   u'REB': 44,
#   u'SEASON_ID': u'22015',
#   u'STL': 11,
#   u'TEAM_ABBREVIATION': u'SAS',
#   u'TEAM_ID': 1610612759,
#   u'TEAM_NAME': u'San Antonio Spurs',
#   u'TOV': 13,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 29,
#   u'BLK': 5,
#   u'DREB': 29,
#   u'FG3A': 16,
#   u'FG3M': 10,
#   u'FG3_PCT': 0.625,
#   u'FGA': 100,
#   u'FGM': 49,
#   u'FG_PCT': 0.49,
#   u'FTA': 22,
#   u'FTM': 15,
#   u'FT_PCT': 0.682,
#   u'GAME_DATE': u'2015-12-29',
#   u'GAME_ID': u'0021500472',
#   u'MATCHUP': u'MIL @ OKC',
#   u'MIN': 240,
#   'OPPONENT_PTS': 131,
#   u'OREB': 18,
#   u'PF': 26,
#   u'PLUS_MINUS': -8,
#   u'PTS': 123,
#   u'REB': 47,
#   u'SEASON_ID': u'22015',
#   u'STL': 6,
#   u'TEAM_ABBREVIATION': u'MIL',
#   u'TEAM_ID': 1610612749,
#   u'TEAM_NAME': u'Milwaukee Bucks',
#   u'TOV': 14,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 23,
#   u'BLK': 5,
#   u'DREB': 34,
#   u'FG3A': 37,
#   u'FG3M': 18,
#   u'FG3_PCT': 0.486,
#   u'FGA': 78,
#   u'FGM': 39,
#   u'FG_PCT': 0.5,
#   u'FTA': 30,
#   u'FTM': 27,
#   u'FT_PCT': 0.9,
#   u'GAME_DATE': u'2015-12-11',
#   u'GAME_ID': u'0021500338',
#   u'MATCHUP': u'CHA @ MEM',
#   u'MIN': 240,
#   'OPPONENT_PTS': 99,
#   u'OREB': 7,
#   u'PF': 24,
#   u'PLUS_MINUS': 24,
#   u'PTS': 123,
#   u'REB': 41,
#   u'SEASON_ID': u'22015',
#   u'STL': 5,
#   u'TEAM_ABBREVIATION': u'CHA',
#   u'TEAM_ID': 1610612766,
#   u'TEAM_NAME': u'Charlotte Hornets',
#   u'TOV': 16,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 30,
#   u'BLK': 4,
#   u'DREB': 33,
#   u'FG3A': 19,
#   u'FG3M': 7,
#   u'FG3_PCT': 0.368,
#   u'FGA': 93,
#   u'FGM': 46,
#   u'FG_PCT': 0.495,
#   u'FTA': 31,
#   u'FTM': 24,
#   u'FT_PCT': 0.774,
#   u'GAME_DATE': u'2015-12-09',
#   u'GAME_ID': u'0021500325',
#   u'MATCHUP': u'MIN vs. LAL',
#   u'MIN': 265,
#   'OPPONENT_PTS': 122,
#   u'OREB': 14,
#   u'PF': 20,
#   u'PLUS_MINUS': 1,
#   u'PTS': 123,
#   u'REB': 47,
#   u'SEASON_ID': u'22015',
#   u'STL': 4,
#   u'TEAM_ABBREVIATION': u'MIN',
#   u'TEAM_ID': 1610612750,
#   u'TEAM_NAME': u'Minnesota Timberwolves',
#   u'TOV': 15,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 23,
#   u'BLK': 3,
#   u'DREB': 28,
#   u'FG3A': 33,
#   u'FG3M': 14,
#   u'FG3_PCT': 0.424,
#   u'FGA': 100,
#   u'FGM': 44,
#   u'FG_PCT': 0.44,
#   u'FTA': 26,
#   u'FTM': 21,
#   u'FT_PCT': 0.808,
#   u'GAME_DATE': u'2015-12-08',
#   u'GAME_ID': u'0021500314',
#   u'MATCHUP': u'IND vs. GSW',
#   u'MIN': 240,
#   'OPPONENT_PTS': 131,
#   u'OREB': 16,
#   u'PF': 18,
#   u'PLUS_MINUS': -8,
#   u'PTS': 123,
#   u'REB': 44,
#   u'SEASON_ID': u'22015',
#   u'STL': 8,
#   u'TEAM_ABBREVIATION': u'IND',
#   u'TEAM_ID': 1610612754,
#   u'TEAM_NAME': u'Indiana Pacers',
#   u'TOV': 16,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 26,
#   u'BLK': 3,
#   u'DREB': 33,
#   u'FG3A': 36,
#   u'FG3M': 18,
#   u'FG3_PCT': 0.5,
#   u'FGA': 85,
#   u'FGM': 44,
#   u'FG_PCT': 0.518,
#   u'FTA': 20,
#   u'FTM': 17,
#   u'FT_PCT': 0.85,
#   u'GAME_DATE': u'2015-12-03',
#   u'GAME_ID': u'0021500281',
#   u'MATCHUP': u'POR vs. IND',
#   u'MIN': 240,
#   'OPPONENT_PTS': 111,
#   u'OREB': 15,
#   u'PF': 20,
#   u'PLUS_MINUS': 12,
#   u'PTS': 123,
#   u'REB': 48,
#   u'SEASON_ID': u'22015',
#   u'STL': 11,
#   u'TEAM_ABBREVIATION': u'POR',
#   u'TEAM_ID': 1610612757,
#   u'TEAM_NAME': u'Portland Trail Blazers',
#   u'TOV': 16,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 25,
#   u'BLK': 0,
#   u'DREB': 34,
#   u'FG3A': 26,
#   u'FG3M': 19,
#   u'FG3_PCT': 0.731,
#   u'FGA': 80,
#   u'FGM': 44,
#   u'FG_PCT': 0.55,
#   u'FTA': 23,
#   u'FTM': 16,
#   u'FT_PCT': 0.696,
#   u'GAME_DATE': u'2015-11-24',
#   u'GAME_ID': u'0021500209',
#   u'MATCHUP': u'IND @ WAS',
#   u'MIN': 240,
#   'OPPONENT_PTS': 106,
#   u'OREB': 7,
#   u'PF': 18,
#   u'PLUS_MINUS': 17,
#   u'PTS': 123,
#   u'REB': 41,
#   u'SEASON_ID': u'22015',
#   u'STL': 11,
#   u'TEAM_ABBREVIATION': u'IND',
#   u'TEAM_ID': 1610612754,
#   u'TEAM_NAME': u'Indiana Pacers',
#   u'TOV': 20,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 28,
#   u'BLK': 5,
#   u'DREB': 31,
#   u'FG3A': 30,
#   u'FG3M': 15,
#   u'FG3_PCT': 0.5,
#   u'FGA': 91,
#   u'FGM': 47,
#   u'FG_PCT': 0.516,
#   u'FTA': 23,
#   u'FTM': 14,
#   u'FT_PCT': 0.609,
#   u'GAME_DATE': u'2015-11-21',
#   u'GAME_ID': u'0021500190',
#   u'MATCHUP': u'IND vs. MIL',
#   u'MIN': 240,
#   'OPPONENT_PTS': 86,
#   u'OREB': 11,
#   u'PF': 13,
#   u'PLUS_MINUS': 37,
#   u'PTS': 123,
#   u'REB': 42,
#   u'SEASON_ID': u'22015',
#   u'STL': 15,
#   u'TEAM_ABBREVIATION': u'IND',
#   u'TEAM_ID': 1610612754,
#   u'TEAM_NAME': u'Indiana Pacers',
#   u'TOV': 14,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 24,
#   u'BLK': 3,
#   u'DREB': 27,
#   u'FG3A': 35,
#   u'FG3M': 17,
#   u'FG3_PCT': 0.486,
#   u'FGA': 84,
#   u'FGM': 41,
#   u'FG_PCT': 0.488,
#   u'FTA': 33,
#   u'FTM': 23,
#   u'FT_PCT': 0.697,
#   u'GAME_DATE': u'2016-01-30',
#   u'GAME_ID': u'0021500711',
#   u'MATCHUP': u'HOU vs. WAS',
#   u'MIN': 180,
#   'OPPONENT_PTS': 123,
#   u'OREB': 9,
#   u'PF': 23,
#   u'PLUS_MINUS': -1,
#   u'PTS': 122,
#   u'REB': 36,
#   u'SEASON_ID': u'22015',
#   u'STL': 8,
#   u'TEAM_ABBREVIATION': u'HOU',
#   u'TEAM_ID': 1610612745,
#   u'TEAM_NAME': u'Houston Rockets',
#   u'TOV': 10,
#   u'VIDEO_AVAILABLE': 0,
#   u'WL': None},
#  {u'AST': 24,
#   u'BLK': 7,
#   u'DREB': 33,
#   u'FG3A': 23,
#   u'FG3M': 11,
#   u'FG3_PCT': 0.478,
#   u'FGA': 95,
#   u'FGM': 44,
#   u'FG_PCT': 0.463,
#   u'FTA': 30,
#   u'FTM': 23,
#   u'FT_PCT': 0.767,
#   u'GAME_DATE': u'2016-01-26',
#   u'GAME_ID': u'0021500679',
#   u'MATCHUP': u'NYK vs. OKC',
#   u'MIN': 265,
#   'OPPONENT_PTS': 128,
#   u'OREB': 9,
#   u'PF': 21,
#   u'PLUS_MINUS': -6,
#   u'PTS': 122,
#   u'REB': 42,
#   u'SEASON_ID': u'22015',
#   u'STL': 9,
#   u'TEAM_ABBREVIATION': u'NYK',
#   u'TEAM_ID': 1610612752,
#   u'TEAM_NAME': u'New York Knicks',
#   u'TOV': 9,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 31,
#   u'BLK': 4,
#   u'DREB': 36,
#   u'FG3A': 33,
#   u'FG3M': 14,
#   u'FG3_PCT': 0.424,
#   u'FGA': 90,
#   u'FGM': 43,
#   u'FG_PCT': 0.478,
#   u'FTA': 25,
#   u'FTM': 22,
#   u'FT_PCT': 0.88,
#   u'GAME_DATE': u'2016-01-22',
#   u'GAME_ID': u'0021500652',
#   u'MATCHUP': u'GSW vs. IND',
#   u'MIN': 240,
#   'OPPONENT_PTS': 110,
#   u'OREB': 14,
#   u'PF': 24,
#   u'PLUS_MINUS': 12,
#   u'PTS': 122,
#   u'REB': 50,
#   u'SEASON_ID': u'22015',
#   u'STL': 9,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_ID': 1610612744,
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 17,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 25,
#   u'BLK': 4,
#   u'DREB': 29,
#   u'FG3A': 33,
#   u'FG3M': 17,
#   u'FG3_PCT': 0.515,
#   u'FGA': 74,
#   u'FGM': 41,
#   u'FG_PCT': 0.554,
#   u'FTA': 26,
#   u'FTM': 23,
#   u'FT_PCT': 0.885,
#   u'GAME_DATE': u'2016-01-04',
#   u'GAME_ID': u'0021500511',
#   u'MATCHUP': u'CLE vs. TOR',
#   u'MIN': 240,
#   'OPPONENT_PTS': 100,
#   u'OREB': 11,
#   u'PF': 22,
#   u'PLUS_MINUS': 22,
#   u'PTS': 122,
#   u'REB': 40,
#   u'SEASON_ID': u'22015',
#   u'STL': 6,
#   u'TEAM_ABBREVIATION': u'CLE',
#   u'TEAM_ID': 1610612739,
#   u'TEAM_NAME': u'Cleveland Cavaliers',
#   u'TOV': 14,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 27,
#   u'BLK': 7,
#   u'DREB': 31,
#   u'FG3A': 30,
#   u'FG3M': 15,
#   u'FG3_PCT': 0.5,
#   u'FGA': 71,
#   u'FGM': 37,
#   u'FG_PCT': 0.521,
#   u'FTA': 41,
#   u'FTM': 33,
#   u'FT_PCT': 0.805,
#   u'GAME_DATE': u'2015-12-30',
#   u'GAME_ID': u'0021500474',
#   u'MATCHUP': u'LAC @ CHA',
#   u'MIN': 240,
#   'OPPONENT_PTS': 117,
#   u'OREB': 8,
#   u'PF': 26,
#   u'PLUS_MINUS': 5,
#   u'PTS': 122,
#   u'REB': 39,
#   u'SEASON_ID': u'22015',
#   u'STL': 7,
#   u'TEAM_ABBREVIATION': u'LAC',
#   u'TEAM_ID': 1610612746,
#   u'TEAM_NAME': u'Los Angeles Clippers',
#   u'TOV': 13,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 33,
#   u'BLK': 8,
#   u'DREB': 46,
#   u'FG3A': 42,
#   u'FG3M': 20,
#   u'FG3_PCT': 0.476,
#   u'FGA': 89,
#   u'FGM': 43,
#   u'FG_PCT': 0.483,
#   u'FTA': 24,
#   u'FTM': 16,
#   u'FT_PCT': 0.667,
#   u'GAME_DATE': u'2015-12-28',
#   u'GAME_ID': u'0021500468',
#   u'MATCHUP': u'GSW vs. SAC',
#   u'MIN': 240,
#   'OPPONENT_PTS': 103,
#   u'OREB': 13,
#   u'PF': 25,
#   u'PLUS_MINUS': 19,
#   u'PTS': 122,
#   u'REB': 59,
#   u'SEASON_ID': u'22015',
#   u'STL': 12,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_ID': 1610612744,
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 18,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 27,
#   u'BLK': 5,
#   u'DREB': 30,
#   u'FG3A': 15,
#   u'FG3M': 8,
#   u'FG3_PCT': 0.533,
#   u'FGA': 83,
#   u'FGM': 48,
#   u'FG_PCT': 0.578,
#   u'FTA': 21,
#   u'FTM': 18,
#   u'FT_PCT': 0.857,
#   u'GAME_DATE': u'2015-12-27',
#   u'GAME_ID': u'0021500456',
#   u'MATCHUP': u'OKC vs. DEN',
#   u'MIN': 240,
#   'OPPONENT_PTS': 112,
#   u'OREB': 13,
#   u'PF': 17,
#   u'PLUS_MINUS': 10,
#   u'PTS': 122,
#   u'REB': 43,
#   u'SEASON_ID': u'22015',
#   u'STL': 5,
#   u'TEAM_ABBREVIATION': u'OKC',
#   u'TEAM_ID': 1610612760,
#   u'TEAM_NAME': u'Oklahoma City Thunder',
#   u'TOV': 14,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 19,
#   u'BLK': 1,
#   u'DREB': 31,
#   u'FG3A': 23,
#   u'FG3M': 9,
#   u'FG3_PCT': 0.391,
#   u'FGA': 93,
#   u'FGM': 48,
#   u'FG_PCT': 0.516,
#   u'FTA': 27,
#   u'FTM': 17,
#   u'FT_PCT': 0.63,
#   u'GAME_DATE': u'2015-12-09',
#   u'GAME_ID': u'0021500325',
#   u'MATCHUP': u'LAL @ MIN',
#   u'MIN': 265,
#   'OPPONENT_PTS': 123,
#   u'OREB': 9,
#   u'PF': 23,
#   u'PLUS_MINUS': -1,
#   u'PTS': 122,
#   u'REB': 40,
#   u'SEASON_ID': u'22015',
#   u'STL': 9,
#   u'TEAM_ABBREVIATION': u'LAL',
#   u'TEAM_ID': 1610612747,
#   u'TEAM_NAME': u'Los Angeles Lakers',
#   u'TOV': 9,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 21,
#   u'BLK': 3,
#   u'DREB': 35,
#   u'FG3A': 23,
#   u'FG3M': 8,
#   u'FG3_PCT': 0.348,
#   u'FGA': 92,
#   u'FGM': 43,
#   u'FG_PCT': 0.467,
#   u'FTA': 37,
#   u'FTM': 28,
#   u'FT_PCT': 0.757,
#   u'GAME_DATE': u'2015-12-05',
#   u'GAME_ID': u'0021500297',
#   u'MATCHUP': u'UTA vs. IND',
#   u'MIN': 265,
#   'OPPONENT_PTS': 119,
#   u'OREB': 19,
#   u'PF': 30,
#   u'PLUS_MINUS': 3,
#   u'PTS': 122,
#   u'REB': 54,
#   u'SEASON_ID': u'22015',
#   u'STL': 7,
#   u'TEAM_ABBREVIATION': u'UTA',
#   u'TEAM_ID': 1610612762,
#   u'TEAM_NAME': u'Utah Jazz',
#   u'TOV': 15,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 28,
#   u'BLK': 3,
#   u'DREB': 26,
#   u'FG3A': 33,
#   u'FG3M': 14,
#   u'FG3_PCT': 0.424,
#   u'FGA': 97,
#   u'FGM': 47,
#   u'FG_PCT': 0.485,
#   u'FTA': 15,
#   u'FTM': 14,
#   u'FT_PCT': 0.933,
#   u'GAME_DATE': u'2015-12-02',
#   u'GAME_ID': u'0021500270',
#   u'MATCHUP': u'PHX @ DET',
#   u'MIN': 265,
#   'OPPONENT_PTS': 127,
#   u'OREB': 10,
#   u'PF': 33,
#   u'PLUS_MINUS': -5,
#   u'PTS': 122,
#   u'REB': 36,
#   u'SEASON_ID': u'22015',
#   u'STL': 7,
#   u'TEAM_ABBREVIATION': u'PHX',
#   u'TEAM_ID': 1610612756,
#   u'TEAM_NAME': u'Phoenix Suns',
#   u'TOV': 16,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 34,
#   u'BLK': 8,
#   u'DREB': 38,
#   u'FG3A': 31,
#   u'FG3M': 8,
#   u'FG3_PCT': 0.258,
#   u'FGA': 104,
#   u'FGM': 52,
#   u'FG_PCT': 0.5,
#   u'FTA': 16,
#   u'FTM': 10,
#   u'FT_PCT': 0.625,
#   u'GAME_DATE': u'2015-11-23',
#   u'GAME_ID': u'0021500202',
#   u'MATCHUP': u'SAC @ CHA',
#   u'MIN': 265,
#   'OPPONENT_PTS': 127,
#   u'OREB': 8,
#   u'PF': 30,
#   u'PLUS_MINUS': -5,
#   u'PTS': 122,
#   u'REB': 46,
#   u'SEASON_ID': u'22015',
#   u'STL': 10,
#   u'TEAM_ABBREVIATION': u'SAC',
#   u'TEAM_ID': 1610612758,
#   u'TEAM_NAME': u'Sacramento Kings',
#   u'TOV': 20,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 23,
#   u'BLK': 6,
#   u'DREB': 39,
#   u'FG3A': 30,
#   u'FG3M': 11,
#   u'FG3_PCT': 0.367,
#   u'FGA': 85,
#   u'FGM': 39,
#   u'FG_PCT': 0.459,
#   u'FTA': 40,
#   u'FTM': 33,
#   u'FT_PCT': 0.825,
#   u'GAME_DATE': u'2015-11-22',
#   u'GAME_ID': u'0021500198',
#   u'MATCHUP': u'NOP vs. PHX',
#   u'MIN': 240,
#   'OPPONENT_PTS': 116,
#   u'OREB': 10,
#   u'PF': 26,
#   u'PLUS_MINUS': 6,
#   u'PTS': 122,
#   u'REB': 49,
#   u'SEASON_ID': u'22015',
#   u'STL': 11,
#   u'TEAM_ABBREVIATION': u'NOP',
#   u'TEAM_ID': 1610612740,
#   u'TEAM_NAME': u'New Orleans Pelicans',
#   u'TOV': 14,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 23,
#   u'BLK': 4,
#   u'DREB': 22,
#   u'FG3A': 17,
#   u'FG3M': 12,
#   u'FG3_PCT': 0.706,
#   u'FGA': 84,
#   u'FGM': 37,
#   u'FG_PCT': 0.44,
#   u'FTA': 39,
#   u'FTM': 36,
#   u'FT_PCT': 0.923,
#   u'GAME_DATE': u'2015-11-16',
#   u'GAME_ID': u'0021500155',
#   u'MATCHUP': u'MEM vs. OKC',
#   u'MIN': 240,
#   'OPPONENT_PTS': 114,
#   u'OREB': 12,
#   u'PF': 22,
#   u'PLUS_MINUS': 8,
#   u'PTS': 122,
#   u'REB': 34,
#   u'SEASON_ID': u'22015',
#   u'STL': 11,
#   u'TEAM_ABBREVIATION': u'MEM',
#   u'TEAM_ID': 1610612763,
#   u'TEAM_NAME': u'Memphis Grizzlies',
#   u'TOV': 10,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 24,
#   u'BLK': 7,
#   u'DREB': 30,
#   u'FG3A': 23,
#   u'FG3M': 9,
#   u'FG3_PCT': 0.391,
#   u'FGA': 93,
#   u'FGM': 42,
#   u'FG_PCT': 0.452,
#   u'FTA': 35,
#   u'FTM': 29,
#   u'FT_PCT': 0.829,
#   u'GAME_DATE': u'2015-10-28',
#   u'GAME_ID': u'0021500012',
#   u'MATCHUP': u'NYK @ MIL',
#   u'MIN': 240,
#   'OPPONENT_PTS': 97,
#   u'OREB': 19,
#   u'PF': 28,
#   u'PLUS_MINUS': 25,
#   u'PTS': 122,
#   u'REB': 49,
#   u'SEASON_ID': u'22015',
#   u'STL': 11,
#   u'TEAM_ABBREVIATION': u'NYK',
#   u'TEAM_ID': 1610612752,
#   u'TEAM_NAME': u'New York Knicks',
#   u'TOV': 11,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 23,
#   u'BLK': 9,
#   u'DREB': 30,
#   u'FG3A': 18,
#   u'FG3M': 8,
#   u'FG3_PCT': 0.444,
#   u'FGA': 79,
#   u'FGM': 41,
#   u'FG_PCT': 0.519,
#   u'FTA': 37,
#   u'FTM': 31,
#   u'FT_PCT': 0.838,
#   u'GAME_DATE': u'2016-01-30',
#   u'GAME_ID': u'0021500712',
#   u'MATCHUP': u'MEM vs. SAC',
#   u'MIN': 240,
#   'OPPONENT_PTS': 117,
#   u'OREB': 2,
#   u'PF': 26,
#   u'PLUS_MINUS': 4,
#   u'PTS': 121,
#   u'REB': 32,
#   u'SEASON_ID': u'22015',
#   u'STL': 15,
#   u'TEAM_ABBREVIATION': u'MEM',
#   u'TEAM_ID': 1610612763,
#   u'TEAM_NAME': u'Memphis Grizzlies',
#   u'TOV': 13,
#   u'VIDEO_AVAILABLE': 0,
#   u'WL': u'W'},
#  {u'AST': 26,
#   u'BLK': 1,
#   u'DREB': 28,
#   u'FG3A': 31,
#   u'FG3M': 10,
#   u'FG3_PCT': 0.323,
#   u'FGA': 93,
#   u'FGM': 47,
#   u'FG_PCT': 0.505,
#   u'FTA': 22,
#   u'FTM': 17,
#   u'FT_PCT': 0.773,
#   u'GAME_DATE': u'2016-01-23',
#   u'GAME_ID': u'0021500662',
#   u'MATCHUP': u'POR vs. LAL',
#   u'MIN': 240,
#   'OPPONENT_PTS': 103,
#   u'OREB': 14,
#   u'PF': 22,
#   u'PLUS_MINUS': 18,
#   u'PTS': 121,
#   u'REB': 42,
#   u'SEASON_ID': u'22015',
#   u'STL': 12,
#   u'TEAM_ABBREVIATION': u'POR',
#   u'TEAM_ID': 1610612757,
#   u'TEAM_NAME': u'Portland Trail Blazers',
#   u'TOV': 9,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 16,
#   u'BLK': 3,
#   u'DREB': 31,
#   u'FG3A': 29,
#   u'FG3M': 12,
#   u'FG3_PCT': 0.414,
#   u'FGA': 89,
#   u'FGM': 48,
#   u'FG_PCT': 0.539,
#   u'FTA': 19,
#   u'FTM': 13,
#   u'FT_PCT': 0.684,
#   u'GAME_DATE': u'2016-01-06',
#   u'GAME_ID': u'0021500527',
#   u'MATCHUP': u'CLE @ WAS',
#   u'MIN': 240,
#   'OPPONENT_PTS': 115,
#   u'OREB': 13,
#   u'PF': 20,
#   u'PLUS_MINUS': 6,
#   u'PTS': 121,
#   u'REB': 44,
#   u'SEASON_ID': u'22015',
#   u'STL': 9,
#   u'TEAM_ABBREVIATION': u'CLE',
#   u'TEAM_ID': 1610612739,
#   u'TEAM_NAME': u'Cleveland Cavaliers',
#   u'TOV': 12,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 31,
#   u'BLK': 2,
#   u'DREB': 31,
#   u'FG3A': 24,
#   u'FG3M': 13,
#   u'FG3_PCT': 0.542,
#   u'FGA': 86,
#   u'FGM': 45,
#   u'FG_PCT': 0.523,
#   u'FTA': 19,
#   u'FTM': 18,
#   u'FT_PCT': 0.947,
#   u'GAME_DATE': u'2016-01-02',
#   u'GAME_ID': u'0021500502',
#   u'MATCHUP': u'SAS vs. HOU',
#   u'MIN': 240,
#   'OPPONENT_PTS': 103,
#   u'OREB': 8,
#   u'PF': 22,
#   u'PLUS_MINUS': 18,
#   u'PTS': 121,
#   u'REB': 39,
#   u'SEASON_ID': u'22015',
#   u'STL': 9,
#   u'TEAM_ABBREVIATION': u'SAS',
#   u'TEAM_ID': 1610612759,
#   u'TEAM_NAME': u'San Antonio Spurs',
#   u'TOV': 11,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 27,
#   u'BLK': 7,
#   u'DREB': 28,
#   u'FG3A': 41,
#   u'FG3M': 14,
#   u'FG3_PCT': 0.341,
#   u'FGA': 99,
#   u'FGM': 43,
#   u'FG_PCT': 0.434,
#   u'FTA': 25,
#   u'FTM': 21,
#   u'FT_PCT': 0.84,
#   u'GAME_DATE': u'2015-12-29',
#   u'GAME_ID': u'0021500470',
#   u'MATCHUP': u'ATL @ HOU',
#   u'MIN': 240,
#   'OPPONENT_PTS': 115,
#   u'OREB': 17,
#   u'PF': 24,
#   u'PLUS_MINUS': 6,
#   u'PTS': 121,
#   u'REB': 45,
#   u'SEASON_ID': u'22015',
#   u'STL': 10,
#   u'TEAM_ABBREVIATION': u'ATL',
#   u'TEAM_ID': 1610612737,
#   u'TEAM_NAME': u'Atlanta Hawks',
#   u'TOV': 12,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 31,
#   u'BLK': 4,
#   u'DREB': 31,
#   u'FG3A': 26,
#   u'FG3M': 9,
#   u'FG3_PCT': 0.346,
#   u'FGA': 87,
#   u'FGM': 42,
#   u'FG_PCT': 0.483,
#   u'FTA': 37,
#   u'FTM': 28,
#   u'FT_PCT': 0.757,
#   u'GAME_DATE': u'2015-12-18',
#   u'GAME_ID': u'0021500397',
#   u'MATCHUP': u'GSW vs. MIL',
#   u'MIN': 240,
#   'OPPONENT_PTS': 112,
#   u'OREB': 15,
#   u'PF': 22,
#   u'PLUS_MINUS': 9,
#   u'PTS': 121,
#   u'REB': 46,
#   u'SEASON_ID': u'22015',
#   u'STL': 7,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_ID': 1610612744,
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 15,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 33,
#   u'BLK': 7,
#   u'DREB': 37,
#   u'FG3A': 24,
#   u'FG3M': 12,
#   u'FG3_PCT': 0.5,
#   u'FGA': 80,
#   u'FGM': 45,
#   u'FG_PCT': 0.563,
#   u'FTA': 22,
#   u'FTM': 19,
#   u'FT_PCT': 0.864,
#   u'GAME_DATE': u'2015-11-24',
#   u'GAME_ID': u'0021500210',
#   u'MATCHUP': u'ATL vs. BOS',
#   u'MIN': 240,
#   'OPPONENT_PTS': 97,
#   u'OREB': 6,
#   u'PF': 25,
#   u'PLUS_MINUS': 24,
#   u'PTS': 121,
#   u'REB': 43,
#   u'SEASON_ID': u'22015',
#   u'STL': 8,
#   u'TEAM_ABBREVIATION': u'ATL',
#   u'TEAM_ID': 1610612737,
#   u'TEAM_NAME': u'Atlanta Hawks',
#   u'TOV': 21,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 30,
#   u'BLK': 6,
#   u'DREB': 35,
#   u'FG3A': 21,
#   u'FG3M': 9,
#   u'FG3_PCT': 0.429,
#   u'FGA': 77,
#   u'FGM': 41,
#   u'FG_PCT': 0.532,
#   u'FTA': 35,
#   u'FTM': 30,
#   u'FT_PCT': 0.857,
#   u'GAME_DATE': u'2015-11-06',
#   u'GAME_ID': u'0021500081',
#   u'MATCHUP': u'ATL @ NOP',
#   u'MIN': 240,
#   'OPPONENT_PTS': 115,
#   u'OREB': 6,
#   u'PF': 21,
#   u'PLUS_MINUS': 6,
#   u'PTS': 121,
#   u'REB': 41,
#   u'SEASON_ID': u'22015',
#   u'STL': 10,
#   u'TEAM_ABBREVIATION': u'ATL',
#   u'TEAM_ID': 1610612737,
#   u'TEAM_NAME': u'Atlanta Hawks',
#   u'TOV': 15,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 31,
#   u'BLK': 3,
#   u'DREB': 35,
#   u'FG3A': 26,
#   u'FG3M': 11,
#   u'FG3_PCT': 0.423,
#   u'FGA': 85,
#   u'FGM': 44,
#   u'FG_PCT': 0.518,
#   u'FTA': 25,
#   u'FTM': 21,
#   u'FT_PCT': 0.84,
#   u'GAME_DATE': u'2016-01-25',
#   u'GAME_ID': u'0021500675',
#   u'MATCHUP': u'GSW vs. SAS',
#   u'MIN': 240,
#   'OPPONENT_PTS': 90,
#   u'OREB': 10,
#   u'PF': 25,
#   u'PLUS_MINUS': 30,
#   u'PTS': 120,
#   u'REB': 45,
#   u'SEASON_ID': u'22015',
#   u'STL': 15,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_ID': 1610612744,
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 21,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 23,
#   u'BLK': 4,
#   u'DREB': 34,
#   u'FG3A': 27,
#   u'FG3M': 10,
#   u'FG3_PCT': 0.37,
#   u'FGA': 101,
#   u'FGM': 45,
#   u'FG_PCT': 0.446,
#   u'FTA': 22,
#   u'FTM': 20,
#   u'FT_PCT': 0.909,
#   u'GAME_DATE': u'2016-01-22',
#   u'GAME_ID': u'0021500645',
#   u'MATCHUP': u'CHA @ ORL',
#   u'MIN': 265,
#   'OPPONENT_PTS': 116,
#   u'OREB': 14,
#   u'PF': 19,
#   u'PLUS_MINUS': 4,
#   u'PTS': 120,
#   u'REB': 48,
#   u'SEASON_ID': u'22015',
#   u'STL': 10,
#   u'TEAM_ABBREVIATION': u'CHA',
#   u'TEAM_ID': 1610612766,
#   u'TEAM_NAME': u'Charlotte Hornets',
#   u'TOV': 9,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 24,
#   u'BLK': 5,
#   u'DREB': 33,
#   u'FG3A': 20,
#   u'FG3M': 7,
#   u'FG3_PCT': 0.35,
#   u'FGA': 81,
#   u'FGM': 43,
#   u'FG_PCT': 0.531,
#   u'FTA': 30,
#   u'FTM': 27,
#   u'FT_PCT': 0.9,
#   u'GAME_DATE': u'2016-01-12',
#   u'GAME_ID': u'0021500571',
#   u'MATCHUP': u'NYK vs. BOS',
#   u'MIN': 240,
#   'OPPONENT_PTS': 114,
#   u'OREB': 6,
#   u'PF': 17,
#   u'PLUS_MINUS': 6,
#   u'PTS': 120,
#   u'REB': 39,
#   u'SEASON_ID': u'22015',
#   u'STL': 5,
#   u'TEAM_ABBREVIATION': u'NYK',
#   u'TEAM_ID': 1610612752,
#   u'TEAM_NAME': u'New York Knicks',
#   u'TOV': 11,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 33,
#   u'BLK': 13,
#   u'DREB': 32,
#   u'FG3A': 24,
#   u'FG3M': 10,
#   u'FG3_PCT': 0.417,
#   u'FGA': 94,
#   u'FGM': 49,
#   u'FG_PCT': 0.521,
#   u'FTA': 15,
#   u'FTM': 12,
#   u'FT_PCT': 0.8,
#   u'GAME_DATE': u'2016-01-09',
#   u'GAME_ID': u'0021500551',
#   u'MATCHUP': u'ATL vs. CHI',
#   u'MIN': 240,
#   'OPPONENT_PTS': 105,
#   u'OREB': 8,
#   u'PF': 22,
#   u'PLUS_MINUS': 15,
#   u'PTS': 120,
#   u'REB': 40,
#   u'SEASON_ID': u'22015',
#   u'STL': 15,
#   u'TEAM_ABBREVIATION': u'ATL',
#   u'TEAM_ID': 1610612737,
#   u'TEAM_NAME': u'Atlanta Hawks',
#   u'TOV': 16,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 18,
#   u'BLK': 10,
#   u'DREB': 28,
#   u'FG3A': 14,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.429,
#   u'FGA': 77,
#   u'FGM': 45,
#   u'FG_PCT': 0.584,
#   u'FTA': 35,
#   u'FTM': 24,
#   u'FT_PCT': 0.686,
#   u'GAME_DATE': u'2015-12-31',
#   u'GAME_ID': u'0021500484',
#   u'MATCHUP': u'MIL @ IND',
#   u'MIN': 240,
#   'OPPONENT_PTS': 116,
#   u'OREB': 6,
#   u'PF': 25,
#   u'PLUS_MINUS': 4,
#   u'PTS': 120,
#   u'REB': 34,
#   u'SEASON_ID': u'22015',
#   u'STL': 12,
#   u'TEAM_ABBREVIATION': u'MIL',
#   u'TEAM_ID': 1610612749,
#   u'TEAM_NAME': u'Milwaukee Bucks',
#   u'TOV': 17,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 23,
#   u'BLK': 13,
#   u'DREB': 42,
#   u'FG3A': 19,
#   u'FG3M': 5,
#   u'FG3_PCT': 0.263,
#   u'FGA': 95,
#   u'FGM': 51,
#   u'FG_PCT': 0.537,
#   u'FTA': 17,
#   u'FTM': 13,
# ...
#   u'MATCHUP': u'LAL vs. HOU',
#   u'MIN': 240,
#   'OPPONENT_PTS': 112,
#   u'OREB': 3,
#   u'PF': 16,
#   u'PLUS_MINUS': -17,
#   u'PTS': 95,
#   u'REB': 36,
#   u'SEASON_ID': u'22015',
#   u'STL': 8,
#   u'TEAM_ABBREVIATION': u'LAL',
#   u'TEAM_ID': 1610612747,
#   u'TEAM_NAME': u'Los Angeles Lakers',
#   u'TOV': 14,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 20,
#   u'BLK': 6,
#   u'DREB': 30,
#   u'FG3A': 20,
#   u'FG3M': 5,
#   u'FG3_PCT': 0.25,
#   u'FGA': 77,
#   u'FGM': 35,
#   u'FG_PCT': 0.455,
#   u'FTA': 24,
#   u'FTM': 20,
#   u'FT_PCT': 0.833,
#   u'GAME_DATE': u'2016-01-16',
#   u'GAME_ID': u'0021500607',
#   u'MATCHUP': u'NYK @ MEM',
#   u'MIN': 240,
#   'OPPONENT_PTS': 103,
#   u'OREB': 6,
#   u'PF': 20,
#   u'PLUS_MINUS': -8,
#   u'PTS': 95,
#   u'REB': 36,
#   u'SEASON_ID': u'22015',
#   u'STL': 4,
#   u'TEAM_ABBREVIATION': u'NYK',
#   u'TEAM_ID': 1610612752,
#   u'TEAM_NAME': u'New York Knicks',
#   u'TOV': 11,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 18,
#   u'BLK': 9,
#   u'DREB': 33,
#   u'FG3A': 25,
#   u'FG3M': 10,
#   u'FG3_PCT': 0.4,
#   u'FGA': 94,
#   u'FGM': 34,
#   u'FG_PCT': 0.362,
#   u'FTA': 23,
#   u'FTM': 17,
#   u'FT_PCT': 0.739,
#   u'GAME_DATE': u'2016-01-16',
#   u'GAME_ID': u'0021500605',
#   u'MATCHUP': u'GSW @ DET',
#   u'MIN': 240,
#   'OPPONENT_PTS': 113,
#   u'OREB': 14,
#   u'PF': 16,
#   u'PLUS_MINUS': -18,
#   u'PTS': 95,
#   u'REB': 47,
#   u'SEASON_ID': u'22015',
#   u'STL': 6,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_ID': 1610612744,
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 13,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 23,
#   u'BLK': 6,
#   u'DREB': 31,
#   u'FG3A': 18,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.333,
#   u'FGA': 78,
#   u'FGM': 32,
#   u'FG_PCT': 0.41,
#   u'FTA': 26,
#   u'FTM': 25,
#   u'FT_PCT': 0.962,
#   u'GAME_DATE': u'2016-01-15',
#   u'GAME_ID': u'0021500600',
#   u'MATCHUP': u'DEN vs. MIA',
#   u'MIN': 240,
#   'OPPONENT_PTS': 98,
#   u'OREB': 6,
#   u'PF': 18,
#   u'PLUS_MINUS': -3,
#   u'PTS': 95,
#   u'REB': 37,
#   u'SEASON_ID': u'22015',
#   u'STL': 4,
#   u'TEAM_ABBREVIATION': u'DEN',
#   u'TEAM_ID': 1610612743,
#   u'TEAM_NAME': u'Denver Nuggets',
#   u'TOV': 14,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 15,
#   u'BLK': 2,
#   u'DREB': 34,
#   u'FG3A': 26,
#   u'FG3M': 10,
#   u'FG3_PCT': 0.385,
#   u'FGA': 82,
#   u'FGM': 38,
#   u'FG_PCT': 0.463,
#   u'FTA': 11,
#   u'FTM': 9,
#   u'FT_PCT': 0.818,
#   u'GAME_DATE': u'2016-01-14',
#   u'GAME_ID': u'0021500590',
#   u'MATCHUP': u'CLE @ SAS',
#   u'MIN': 240,
#   'OPPONENT_PTS': 99,
#   u'OREB': 9,
#   u'PF': 23,
#   u'PLUS_MINUS': -4,
#   u'PTS': 95,
#   u'REB': 43,
#   u'SEASON_ID': u'22015',
#   u'STL': 4,
#   u'TEAM_ABBREVIATION': u'CLE',
#   u'TEAM_ID': 1610612739,
#   u'TEAM_NAME': u'Cleveland Cavaliers',
#   u'TOV': 18,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 16,
#   u'BLK': 4,
#   u'DREB': 36,
#   u'FG3A': 29,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.207,
#   u'FGA': 87,
#   u'FGM': 32,
#   u'FG_PCT': 0.368,
#   u'FTA': 32,
#   u'FTM': 25,
#   u'FT_PCT': 0.781,
#   u'GAME_DATE': u'2016-01-12',
#   u'GAME_ID': u'0021500576',
#   u'MATCHUP': u'LAL vs. NOP',
#   u'MIN': 240,
#   'OPPONENT_PTS': 91,
#   u'OREB': 11,
#   u'PF': 17,
#   u'PLUS_MINUS': 4,
#   u'PTS': 95,
#   u'REB': 47,
#   u'SEASON_ID': u'22015',
#   u'STL': 7,
#   u'TEAM_ABBREVIATION': u'LAL',
#   u'TEAM_ID': 1610612747,
#   u'TEAM_NAME': u'Los Angeles Lakers',
#   u'TOV': 8,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 20,
#   u'BLK': 2,
#   u'DREB': 38,
#   u'FG3A': 32,
#   u'FG3M': 9,
#   u'FG3_PCT': 0.281,
#   u'FGA': 90,
#   u'FGM': 35,
#   u'FG_PCT': 0.389,
#   u'FTA': 23,
#   u'FTM': 16,
#   u'FT_PCT': 0.696,
#   u'GAME_DATE': u'2016-01-10',
#   u'GAME_ID': u'0021500559',
#   u'MATCHUP': u'CLE @ PHI',
#   u'MIN': 240,
#   'OPPONENT_PTS': 85,
#   u'OREB': 13,
#   u'PF': 16,
#   u'PLUS_MINUS': 10,
#   u'PTS': 95,
#   u'REB': 51,
#   u'SEASON_ID': u'22015',
#   u'STL': 9,
#   u'TEAM_ABBREVIATION': u'CLE',
#   u'TEAM_ID': 1610612739,
#   u'TEAM_NAME': u'Cleveland Cavaliers',
#   u'TOV': 11,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 25,
#   u'BLK': 7,
#   u'DREB': 36,
#   u'FG3A': 27,
#   u'FG3M': 12,
#   u'FG3_PCT': 0.444,
#   u'FGA': 77,
#   u'FGM': 32,
#   u'FG_PCT': 0.416,
#   u'FTA': 23,
#   u'FTM': 19,
#   u'FT_PCT': 0.826,
#   u'GAME_DATE': u'2016-01-10',
#   u'GAME_ID': u'0021500563',
#   u'MATCHUP': u'DEN vs. CHA',
#   u'MIN': 240,
#   'OPPONENT_PTS': 92,
#   u'OREB': 8,
#   u'PF': 20,
#   u'PLUS_MINUS': 3,
#   u'PTS': 95,
#   u'REB': 44,
#   u'SEASON_ID': u'22015',
#   u'STL': 7,
#   u'TEAM_ABBREVIATION': u'DEN',
#   u'TEAM_ID': 1610612743,
#   u'TEAM_NAME': u'Denver Nuggets',
#   u'TOV': 15,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 26,
#   u'BLK': 5,
#   u'DREB': 26,
#   u'FG3A': 17,
#   u'FG3M': 11,
#   u'FG3_PCT': 0.647,
#   u'FGA': 80,
#   u'FGM': 39,
#   u'FG_PCT': 0.488,
#   u'FTA': 14,
#   u'FTM': 6,
#   u'FT_PCT': 0.429,
#   u'GAME_DATE': u'2016-01-09',
#   u'GAME_ID': u'0021500554',
#   u'MATCHUP': u'PHI vs. TOR',
#   u'MIN': 240,
#   'OPPONENT_PTS': 108,
#   u'OREB': 9,
#   u'PF': 23,
#   u'PLUS_MINUS': -13,
#   u'PTS': 95,
#   u'REB': 35,
#   u'SEASON_ID': u'22015',
#   u'STL': 9,
#   u'TEAM_ABBREVIATION': u'PHI',
#   u'TEAM_ID': 1610612755,
#   u'TEAM_NAME': u'Philadelphia 76ers',
#   u'TOV': 13,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 15,
#   u'BLK': 4,
#   u'DREB': 31,
#   u'FG3A': 24,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.25,
#   u'FGA': 92,
#   u'FGM': 40,
#   u'FG_PCT': 0.435,
#   u'FTA': 13,
#   u'FTM': 9,
#   u'FT_PCT': 0.692,
#   u'GAME_DATE': u'2016-01-08',
#   u'GAME_ID': u'0021500547',
#   u'MATCHUP': u'PHX vs. MIA',
#   u'MIN': 240,
#   'OPPONENT_PTS': 103,
#   u'OREB': 15,
#   u'PF': 22,
#   u'PLUS_MINUS': -8,
#   u'PTS': 95,
#   u'REB': 46,
#   u'SEASON_ID': u'22015',
#   u'STL': 5,
#   u'TEAM_ABBREVIATION': u'PHX',
#   u'TEAM_ID': 1610612756,
#   u'TEAM_NAME': u'Phoenix Suns',
#   u'TOV': 14,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 27,
#   u'BLK': 5,
#   u'DREB': 26,
#   u'FG3A': 44,
#   u'FG3M': 14,
#   u'FG3_PCT': 0.318,
#   u'FGA': 84,
#   u'FGM': 35,
#   u'FG_PCT': 0.417,
#   u'FTA': 16,
#   u'FTM': 11,
#   u'FT_PCT': 0.688,
#   u'GAME_DATE': u'2016-01-08',
#   u'GAME_ID': u'0021500545',
#   u'MATCHUP': u'DAL @ MIL',
#   u'MIN': 240,
#   'OPPONENT_PTS': 96,
#   u'OREB': 16,
#   u'PF': 21,
#   u'PLUS_MINUS': -1,
#   u'PTS': 95,
#   u'REB': 42,
#   u'SEASON_ID': u'22015',
#   u'STL': 6,
#   u'TEAM_ABBREVIATION': u'DAL',
#   u'TEAM_ID': 1610612742,
#   u'TEAM_NAME': u'Dallas Mavericks',
#   u'TOV': 16,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 19,
#   u'BLK': 6,
#   u'DREB': 33,
#   u'FG3A': 22,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.273,
#   u'FGA': 76,
#   u'FGM': 32,
#   u'FG_PCT': 0.421,
#   u'FTA': 29,
#   u'FTM': 25,
#   u'FT_PCT': 0.862,
#   u'GAME_DATE': u'2016-01-06',
#   u'GAME_ID': u'0021500526',
#   u'MATCHUP': u'IND @ ORL',
#   u'MIN': 240,
#   'OPPONENT_PTS': 86,
#   u'OREB': 9,
#   u'PF': 18,
#   u'PLUS_MINUS': 9,
#   u'PTS': 95,
#   u'REB': 42,
#   u'SEASON_ID': u'22015',
#   u'STL': 11,
#   u'TEAM_ABBREVIATION': u'IND',
#   u'TEAM_ID': 1610612754,
#   u'TEAM_NAME': u'Indiana Pacers',
#   u'TOV': 16,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 20,
#   u'BLK': 5,
#   u'DREB': 37,
#   u'FG3A': 16,
#   u'FG3M': 8,
#   u'FG3_PCT': 0.5,
#   u'FGA': 75,
#   u'FGM': 32,
#   u'FG_PCT': 0.427,
#   u'FTA': 28,
#   u'FTM': 23,
#   u'FT_PCT': 0.821,
#   u'GAME_DATE': u'2016-01-02',
#   u'GAME_ID': u'0021500500',
#   u'MATCHUP': u'MIL @ MIN',
#   u'MIN': 240,
#   'OPPONENT_PTS': 85,
#   u'OREB': 11,
#   u'PF': 18,
#   u'PLUS_MINUS': 10,
#   u'PTS': 95,
#   u'REB': 48,
#   u'SEASON_ID': u'22015',
#   u'STL': 7,
#   u'TEAM_ABBREVIATION': u'MIL',
#   u'TEAM_ID': 1610612749,
#   u'TEAM_NAME': u'Milwaukee Bucks',
#   u'TOV': 13,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 24,
#   u'BLK': 6,
#   u'DREB': 34,
#   u'FG3A': 34,
#   u'FG3M': 10,
#   u'FG3_PCT': 0.294,
#   u'FGA': 90,
#   u'FGM': 35,
#   u'FG_PCT': 0.389,
#   u'FTA': 19,
#   u'FTM': 15,
#   u'FT_PCT': 0.789,
#   u'GAME_DATE': u'2015-12-31',
#   u'GAME_ID': u'0021500487',
#   u'MATCHUP': u'LAC @ NOP',
#   u'MIN': 240,
#   'OPPONENT_PTS': 89,
#   u'OREB': 13,
#   u'PF': 14,
#   u'PLUS_MINUS': 6,
#   u'PTS': 95,
#   u'REB': 47,
#   u'SEASON_ID': u'22015',
#   u'STL': 8,
#   u'TEAM_ABBREVIATION': u'LAC',
#   u'TEAM_ID': 1610612746,
#   u'TEAM_NAME': u'Los Angeles Clippers',
#   u'TOV': 12,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 25,
#   u'BLK': 4,
#   u'DREB': 26,
#   u'FG3A': 11,
#   u'FG3M': 3,
#   u'FG3_PCT': 0.273,
#   u'FGA': 82,
#   u'FGM': 39,
#   u'FG_PCT': 0.476,
#   u'FTA': 24,
#   u'FTM': 14,
#   u'FT_PCT': 0.583,
#   u'GAME_DATE': u'2015-12-28',
#   u'GAME_ID': u'0021500465',
#   u'MATCHUP': u'MIN @ SAS',
#   u'MIN': 240,
#   'OPPONENT_PTS': 101,
#   u'OREB': 6,
#   u'PF': 29,
#   u'PLUS_MINUS': -6,
#   u'PTS': 95,
#   u'REB': 32,
#   u'SEASON_ID': u'22015',
#   u'STL': 12,
#   u'TEAM_ABBREVIATION': u'MIN',
#   u'TEAM_ID': 1610612750,
#   u'TEAM_NAME': u'Minnesota Timberwolves',
#   u'TOV': 15,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 13,
#   u'BLK': 9,
#   u'DREB': 38,
#   u'FG3A': 26,
#   u'FG3M': 7,
#   u'FG3_PCT': 0.269,
#   u'FGA': 84,
#   u'FGM': 28,
#   u'FG_PCT': 0.333,
#   u'FTA': 36,
#   u'FTM': 32,
#   u'FT_PCT': 0.889,
#   u'GAME_DATE': u'2015-12-28',
#   u'GAME_ID': u'0021500467',
#   u'MATCHUP': u'UTA vs. PHI',
#   u'MIN': 240,
#   'OPPONENT_PTS': 91,
#   u'OREB': 15,
#   u'PF': 18,
#   u'PLUS_MINUS': 4,
#   u'PTS': 95,
#   u'REB': 53,
#   u'SEASON_ID': u'22015',
#   u'STL': 11,
#   u'TEAM_ABBREVIATION': u'UTA',
#   u'TEAM_ID': 1610612762,
#   u'TEAM_NAME': u'Utah Jazz',
#   u'TOV': 19,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  {u'AST': 20,
#   u'BLK': 3,
#   u'DREB': 26,
#   u'FG3A': 41,
#   u'FG3M': 12,
#   u'FG3_PCT': 0.293,
#   u'FGA': 83,
#   u'FGM': 29,
#   u'FG_PCT': 0.349,
#   u'FTA': 31,
#   u'FTM': 25,
#   u'FT_PCT': 0.806,
#   u'GAME_DATE': u'2015-12-21',
#   u'GAME_ID': u'0021500415',
#   u'MATCHUP': u'CHA @ HOU',
#   u'MIN': 240,
#   'OPPONENT_PTS': 102,
#   u'OREB': 9,
#   u'PF': 27,
#   u'PLUS_MINUS': -7,
#   u'PTS': 95,
#   u'REB': 35,
#   u'SEASON_ID': u'22015',
#   u'STL': 8,
#   u'TEAM_ABBREVIATION': u'CHA',
#   u'TEAM_ID': 1610612766,
#   u'TEAM_NAME': u'Charlotte Hornets',
#   u'TOV': 12,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 18,
#   u'BLK': 2,
#   u'DREB': 33,
#   u'FG3A': 18,
#   u'FG3M': 8,
#   u'FG3_PCT': 0.444,
#   u'FGA': 74,
#   u'FGM': 33,
#   u'FG_PCT': 0.446,
#   u'FTA': 24,
#   u'FTM': 21,
#   u'FT_PCT': 0.875,
#   u'GAME_DATE': u'2015-12-20',
#   u'GAME_ID': u'0021500406',
#   u'MATCHUP': u'PHX vs. MIL',
#   u'MIN': 240,
#   'OPPONENT_PTS': 101,
#   u'OREB': 6,
#   u'PF': 22,
#   u'PLUS_MINUS': -6,
#   u'PTS': 95,
#   u'REB': 39,
#   u'SEASON_ID': u'22015',
#   u'STL': 8,
#   u'TEAM_ABBREVIATION': u'PHX',
#   u'TEAM_ID': 1610612756,
#   u'TEAM_NAME': u'Phoenix Suns',
#   u'TOV': 21,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 22,
#   u'BLK': 2,
#   u'DREB': 23,
#   u'FG3A': 23,
#   u'FG3M': 7,
#   u'FG3_PCT': 0.304,
#   u'FGA': 81,
#   u'FGM': 38,
#   u'FG_PCT': 0.469,
#   u'FTA': 17,
#   u'FTM': 12,
#   u'FT_PCT': 0.706,
#   u'GAME_DATE': u'2015-12-18',
#   u'GAME_ID': u'0021500392',
#   u'MATCHUP': u'SAC @ MIN',
#   u'MIN': 240,
#   'OPPONENT_PTS': 99,
#   u'OREB': 8,
#   u'PF': 19,
#   u'PLUS_MINUS': -4,
#   u'PTS': 95,
#   u'REB': 31,
#   u'SEASON_ID': u'22015',
#   u'STL': 10,
#   u'TEAM_ABBREVIATION': u'SAC',
#   u'TEAM_ID': 1610612758,
#   u'TEAM_NAME': u'Sacramento Kings',
#   u'TOV': 13,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 22,
#   u'BLK': 4,
#   u'DREB': 28,
#   u'FG3A': 15,
#   u'FG3M': 3,
#   u'FG3_PCT': 0.2,
#   u'FGA': 84,
#   u'FGM': 35,
#   u'FG_PCT': 0.417,
#   u'FTA': 25,
#   u'FTM': 22,
#   u'FT_PCT': 0.88,
#   u'GAME_DATE': u'2015-12-16',
#   u'GAME_ID': u'0021500379',
#   u'MATCHUP': u'WAS @ SAS',
#   u'MIN': 240,
#   'OPPONENT_PTS': 114,
#   u'OREB': 10,
#   u'PF': 18,
#   u'PLUS_MINUS': -19,
#   u'PTS': 95,
#   u'REB': 38,
#   u'SEASON_ID': u'22015',
#   u'STL': 6,
#   u'TEAM_ABBREVIATION': u'WAS',
#   u'TEAM_ID': 1610612764,
#   u'TEAM_NAME': u'Washington Wizards',
#   u'TOV': 12,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 23,
#   u'BLK': 7,
#   u'DREB': 26,
#   u'FG3A': 13,
#   u'FG3M': 4,
#   u'FG3_PCT': 0.308,
#   u'FGA': 85,
#   u'FGM': 40,
#   u'FG_PCT': 0.471,
#   u'FTA': 20,
#   u'FTM': 11,
#   u'FT_PCT': 0.55,
#   u'GAME_DATE': u'2015-12-15',
#   u'GAME_ID': u'0021500370',
#   u'MATCHUP': u'MIL @ LAL',
#   u'MIN': 240,
#   'OPPONENT_PTS': 113,
#   u'OREB': 12,
#   u'PF': 20,
#   u'PLUS_MINUS': -18,
#   u'PTS': 95,
#   u'REB': 38,
#   u'SEASON_ID': u'22015',
#   u'STL': 7,
#   u'TEAM_ABBREVIATION': u'MIL',
#   u'TEAM_ID': 1610612749,
#   u'TEAM_NAME': u'Milwaukee Bucks',
#   u'TOV': 11,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 22,
#   u'BLK': 3,
#   u'DREB': 26,
#   u'FG3A': 24,
#   u'FG3M': 9,
#   u'FG3_PCT': 0.375,
#   u'FGA': 86,
#   u'FGM': 37,
#   u'FG_PCT': 0.43,
#   u'FTA': 20,
#   u'FTM': 12,
#   u'FT_PCT': 0.6,
#   u'GAME_DATE': u'2015-12-14',
#   u'GAME_ID': u'0021500362',
#   u'MATCHUP': u'WAS @ MEM',
#   u'MIN': 240,
#   'OPPONENT_PTS': 112,
#   u'OREB': 10,
#   u'PF': 13,
#   u'PLUS_MINUS': -17,
#   u'PTS': 95,
#   u'REB': 36,
#   u'SEASON_ID': u'22015',
#   u'STL': 9,
#   u'TEAM_ABBREVIATION': u'WAS',
#   u'TEAM_ID': 1610612764,
#   u'TEAM_NAME': u'Washington Wizards',
#   u'TOV': 14,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 23,
#   u'BLK': 8,
#   u'DREB': 34,
#   u'FG3A': 27,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.222,
#   u'FGA': 89,
#   u'FGM': 36,
#   u'FG_PCT': 0.404,
#   u'FTA': 25,
#   u'FTM': 17,
#   u'FT_PCT': 0.68,
#   u'GAME_DATE': u'2015-12-12',
#   u'GAME_ID': u'0021500351',
#   u'MATCHUP': u'GSW @ MIL',
#   u'MIN': 240,
#   'OPPONENT_PTS': 108,
#   u'OREB': 15,
#   u'PF': 20,
#   u'PLUS_MINUS': -13,
#   u'PTS': 95,
#   u'REB': 49,
#   u'SEASON_ID': u'22015',
#   u'STL': 9,
#   u'TEAM_ABBREVIATION': u'GSW',
#   u'TEAM_ID': 1610612744,
#   u'TEAM_NAME': u'Golden State Warriors',
#   u'TOV': 17,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 22,
#   u'BLK': 5,
#   u'DREB': 31,
#   u'FG3A': 18,
#   u'FG3M': 6,
#   u'FG3_PCT': 0.333,
#   u'FGA': 80,
#   u'FGM': 36,
#   u'FG_PCT': 0.45,
#   u'FTA': 24,
#   u'FTM': 17,
#   u'FT_PCT': 0.708,
#   u'GAME_DATE': u'2015-12-11',
#   u'GAME_ID': u'0021500335',
#   u'MATCHUP': u'PHI vs. DET',
#   u'MIN': 240,
#   'OPPONENT_PTS': 107,
#   u'OREB': 13,
#   u'PF': 16,
#   u'PLUS_MINUS': -12,
#   u'PTS': 95,
#   u'REB': 44,
#   u'SEASON_ID': u'22015',
#   u'STL': 5,
#   u'TEAM_ABBREVIATION': u'PHI',
#   u'TEAM_ID': 1610612755,
#   u'TEAM_NAME': u'Philadelphia 76ers',
#   u'TOV': 21,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 18,
#   u'BLK': 3,
#   u'DREB': 31,
#   u'FG3A': 31,
#   u'FG3M': 7,
#   u'FG3_PCT': 0.226,
#   u'FGA': 100,
#   u'FGM': 36,
#   u'FG_PCT': 0.36,
#   u'FTA': 19,
#   u'FTM': 16,
#   u'FT_PCT': 0.842,
#   u'GAME_DATE': u'2015-12-09',
#   u'GAME_ID': u'0021500328',
#   u'MATCHUP': u'DAL vs. ATL',
#   u'MIN': 240,
#   'OPPONENT_PTS': 98,
#   u'OREB': 20,
#   u'PF': 15,
#   u'PLUS_MINUS': -3,
#   u'PTS': 95,
#   u'REB': 51,
#   u'SEASON_ID': u'22015',
#   u'STL': 7,
#   u'TEAM_ABBREVIATION': u'DAL',
#   u'TEAM_ID': 1610612742,
#   u'TEAM_NAME': u'Dallas Mavericks',
#   u'TOV': 9,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 26,
#   u'BLK': 1,
#   u'DREB': 33,
#   u'FG3A': 10,
#   u'FG3M': 2,
#   u'FG3_PCT': 0.2,
#   u'FGA': 90,
#   u'FGM': 42,
#   u'FG_PCT': 0.467,
#   u'FTA': 12,
#   u'FTM': 9,
#   u'FT_PCT': 0.75,
#   u'GAME_DATE': u'2015-12-09',
#   u'GAME_ID': u'0021500324',
#   u'MATCHUP': u'MIL vs. LAC',
#   u'MIN': 240,
#   'OPPONENT_PTS': 109,
#   u'OREB': 7,
#   u'PF': 29,
#   u'PLUS_MINUS': -14,
#   u'PTS': 95,
#   u'REB': 40,
#   u'SEASON_ID': u'22015',
#   u'STL': 7,
#   u'TEAM_ABBREVIATION': u'MIL',
#   u'TEAM_ID': 1610612749,
#   u'TEAM_NAME': u'Milwaukee Bucks',
#   u'TOV': 12,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 20,
#   u'BLK': 5,
#   u'DREB': 28,
#   u'FG3A': 24,
#   u'FG3M': 7,
#   u'FG3_PCT': 0.292,
#   u'FGA': 88,
#   u'FGM': 35,
#   u'FG_PCT': 0.398,
#   u'FTA': 30,
#   u'FTM': 18,
#   u'FT_PCT': 0.6,
#   u'GAME_DATE': u'2015-12-06',
#   u'GAME_ID': u'0021500303',
#   u'MATCHUP': u'SAC @ OKC',
#   u'MIN': 240,
#   'OPPONENT_PTS': 98,
#   u'OREB': 13,
#   u'PF': 20,
#   u'PLUS_MINUS': -3,
#   u'PTS': 95,
#   u'REB': 41,
#   u'SEASON_ID': u'22015',
#   u'STL': 11,
#   u'TEAM_ABBREVIATION': u'SAC',
#   u'TEAM_ID': 1610612758,
#   u'TEAM_NAME': u'Sacramento Kings',
#   u'TOV': 14,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'L'},
#  {u'AST': 23,
#   u'BLK': 5,
#   u'DREB': 31,
#   u'FG3A': 15,
#   u'FG3M': 5,
#   u'FG3_PCT': 0.333,
#   u'FGA': 90,
#   u'FGM': 36,
#   u'FG_PCT': 0.4,
#   u'FTA': 24,
#   u'FTM': 18,
#   u'FT_PCT': 0.75,
#   u'GAME_DATE': u'2015-12-06',
#   u'GAME_ID': u'0021500299',
#   u'MATCHUP': u'MEM vs. PHX',
#   u'MIN': 240,
#   'OPPONENT_PTS': 93,
#   u'OREB': 15,
#   u'PF': 16,
#   u'PLUS_MINUS': 2,
#   u'PTS': 95,
#   u'REB': 46,
#   u'SEASON_ID': u'22015',
#   u'STL': 8,
#   u'TEAM_ABBREVIATION': u'MEM',
#   u'TEAM_ID': 1610612763,
#   u'TEAM_NAME': u'Memphis Grizzlies',
#   u'TOV': 13,
#   u'VIDEO_AVAILABLE': 1,
#   u'WL': u'W'},
#  ...]
